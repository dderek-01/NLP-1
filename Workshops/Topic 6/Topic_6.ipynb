# %% [markdown]
# # Topic 6: Opinion Extraction

# %% [markdown]
# ## Preliminaries
# Run this cell.

# %%
import sys
# sys.path.append(r'\\ad.susx.ac.uk\ITS\TeachingResources\Departments\Informatics\LanguageEngineering\resources')
sys.path.append(r'/Users/warrenboult/Documents/MSC/nlp/resources/')
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import collections
from collections import defaultdict,Counter
from itertools import zip_longest
from IPython.display import display
from random import seed
get_ipython().magic('matplotlib inline')
import random
import math
import matplotlib.pylab as pylab
# %matplotlib inline
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)
from pylab import rcParams
from operator import itemgetter, attrgetter, methodcaller
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
import seaborn as sns
import csv

# %% [markdown]
# ## Overview
# In this topic you will be looking at ways to extract opinion bearing words from DVD Amazon reviews. The goal is to find words that describe particular aspects of the film being reviewed. The specific aspects of films that we will be considering are: the **plot**, the **characters**, the **cinematography** and the **dialogue**.
#
# We are, in other words, interested in finding all of those words in a review that express the reviewers opinion about one of these aspects of the film. The idea is that this will provide a fine-grained characterisation of the opinion being expressed by the author of the review. We will refer to the words we are looking for as **opinion words**, and refer to the words used for particular aspects of the review as **aspect words**.
#
# Following on from previous topic's material on dependency parsing, you will use the spaCy's output as the basis for identifying opinion words. This is based on the assumption that the opinion words we are looking for are words that occur in a sentence in the review in a particular (dependency) relationship to one of our aspect words (plot, characters, cinematography and dialogue).
#
# For example, the opinion word "*amazing*" might be found because it is used in a sentence where it is an adjective modifying the aspect word "*plot*", as in the sentence "*I thought it had an amazing plot.*".
#
# ### Exercise
# Run the cell below to set up spaCy and load in a corpus of Amazon DVD reviews.

# %%
import spacy
from sussex_nltk.corpus_readers import AmazonReviewCorpusReader

nlp = spacy.load('en')
dvd_reviews = [review for review in AmazonReviewCorpusReader().category("dvd").raw()]
print("The dvd review dataset contains {} reviews".format(len(dvd_reviews)))
parsed_reviews = [nlp(review) for review in dvd_reviews]
print('done')
# Out:
# The dvd review dataset contains 5491 reviews
# done

# %% [markdown]
# ### Exercise
# We are now going to create code that finds all dependents and all heads of a list of aspect words. This code will be similar to the final exercise of the previous topic.
#
# In the blank cell below, write code that takes a set of aspect words ("*plot*","*characters*","*cinematography*", and "*dialogue*") as an argument, and produces a dictionary that maps each aspect word to a dictionary with two keys: `deps` and `heads`, where the `deps` key maps to the list of dependents of the aspect word and `heads` maps to the list of heads of the aspect word.
#
# - Note that our aspect words are nouns.
# - Note that our aspect words are not all lemmas.
#
# Display your results for dependents and heads in separate tables. For example, suppose we have the following:
# - `aspect_words` is a list of the aspect words we we interested in,
# - `all_heads` is a list of lists of the aspect word's heads, and
# - `all_dependents` is a list of lists of the aspect word's dependents
#
#
# Given this, this code will display the results:
#
# ```df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
#                 columns = aspect_words).applymap(lambda x: '' if x == None else x)
# print("Heads")
# df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
#                 columns = aspect_words).applymap(lambda x: '' if x == None else x)
# display(df_heads)
# print("Dependents")
# display(df_deps)
# ```
#
# Run your code and look at the output.

# %%
aspect_words = ["plot","characters","cinematography","dialogue"]
word_dict = defaultdict(lambda: defaultdict(list))
for review in parsed_reviews:
    for token in review:
        if token.head.pos_ == 'NOUN' and token.text in aspect_words:
            word_dict[token.text]["heads"].append(token.head.text)
            for child in token.children:
                word_dict[token.text]["deps"].append(child.text)
all_heads = [word_dict[asp_wd]["heads"] for asp_wd in aspect_words]
all_dependents = [word_dict[asp_wd]["deps"] for asp_wd in aspect_words]
print('Done building lists')
df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Heads")
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
display(df_heads)
print("Dependents")
display(df_deps)

# %%
# %load solutions/all_heads_and_deps
aspect_words = ["plot","characters","cinematography","dialogue"]
linked_words = defaultdict(lambda: defaultdict(list)) 
for parsed_review in parsed_reviews:
    for token in parsed_review:
        if token.pos_ == 'NOUN' and token.orth_ in aspect_words:
            linked_words[token.orth_]["heads"].append(token.head.orth_)
            for child in token.children:
                linked_words[token.orth_]["deps"].append(child.orth_)
all_heads = [linked_words[word]["heads"] for word in aspect_words]
all_dependents = [linked_words[word]["deps"] for word in aspect_words]
df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Heads")
display(df_heads)
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Dependents")
display(df_deps)

# %% [markdown]
# Our goal here is to find out what the reviewer is saying about the different aspects we are interested in.
# As you can see, not all of the words being returned are informative. In the next two exercises we look at how to (partially) address this.
#
# ### Exercise
# Make a copy of your solution to the last exercise and position it below this cell.
#
# Then adapt the code so that instead of creating lists containing just the tokens, we record the following other features:
# - For the heads:
#  - the lemma of the head,
#  - the part of speech of the head,
#  - the dependency between the head and the aspect word
# - For the dependencies:
#  - the lemma of the dependent,
#  - the port of speech of the dependent,
#  - the dependency between the dependent and the aspect word
#
# What is the point of this?
#
# The idea is that with this additional information, we will be in a better position to work out what makes heads and dependents uninteresting. For example, we might want to remove punctuation.
#
# Once you have made the necessary changes to the code, run the code on the dataset and look at the outputs to see if you can figure out ways of spotting the uninteresting entries in the table.

# %%
aspect_words = ["plot","characters","cinematography","dialogue"]
word_dict = defaultdict(lambda: defaultdict(list))
for review in parsed_reviews:
    for token in review:
        if token.pos_ == 'NOUN' and token.text in aspect_words:
            word_dict[token.text]["heads"].append((token.head.text,token.head.lemma_,token.head.pos_,token.head.dep_))
            for child in token.children:
                word_dict[token.text]["deps"].append((child.text,child.lemma_,child.pos_,child.dep_))
all_heads = [word_dict[asp_wd]["heads"] for asp_wd in aspect_words]
all_dependents = [word_dict[asp_wd]["deps"] for asp_wd in aspect_words]
print('Done building lists')
df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Tuple format: (word, lemma, POS, dep. relation)")
print("Heads")
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
display(df_heads)
print("Dependents")
display(df_deps)
# Out:
# Done building lists
# Tuple format: (word, lemma, POS, dep. relation)
# Heads
#                                        plot  \
# 0                     (was, be, VERB, ROOT)
# 1                       (to, to, ADP, prep)
# 2                 (holes, hole, NOUN, dobj)
# 3                      (is, be, VERB, ROOT)
# 4                    ('s, have, VERB, ROOT)
# 5       (characters, character, NOUN, pobj)
# 6             (centers, center, NOUN, ROOT)
# 7                     (for, for, ADP, prep)
# 8      (irrelevant, irrelevant, ADJ, ccomp)
# 9                     (was, be, VERB, ROOT)
# 10                     (is, be, VERB, conj)
# 11   (uninvolving, uninvolving, ADJ, ccomp)
# 12                   (are, be, VERB, ccomp)
# 13                      (of, of, ADP, prep)
# 14                (line, line, NOUN, nsubj)
# 15                     (is, be, VERB, conj)
# 16                 (line, line, NOUN, pobj)
# 17                      (to, to, ADP, prep)
# 18        (dialogue, dialogue, NOUN, nsubj)
# 19               (point, point, NOUN, pobj)
# 20                     (is, be, VERB, ROOT)
# 21                     (is, be, VERB, ROOT)
# 22                      (to, to, ADP, prep)
# 23                    (is, be, VERB, ccomp)
# 24                     (is, be, VERB, ROOT)
# 25                     (is, be, VERB, ROOT)
# 26                 (lost, lose, VERB, ROOT)
# 27                     (is, be, VERB, ROOT)
# 28           (summary, summary, NOUN, attr)
# 29                  (got, get, VERB, ccomp)
# ..                                      ...
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909
# 910
# 911
# 912
# 913
#
#                               characters  \
# 0               (talk, talk, VERB, ROOT)
# 1                    (of, of, ADP, prep)
# 2              (know, know, VERB, ccomp)
# 3                 (are, be, VERB, ccomp)
# 4             (lumped, lump, VERB, ROOT)
# 5             (saying, say, VERB, ccomp)
# 6                  (for, for, ADP, prep)
# 7                    (of, of, ADP, prep)
# 8          (between, between, ADP, prep)
# 9               (sees, see, VERB, relcl)
# 10                   (of, of, ADP, prep)
# 11            (hides, hide, VERB, advcl)
# 12                   (of, of, ADP, prep)
# 13         (between, between, ADP, prep)
# 14             (plot, plot, NOUN, nsubj)
# 15                   (of, of, ADP, prep)
# 16                (were, be, VERB, ROOT)
# 17                (are, be, VERB, advcl)
# 18      (presented, present, VERB, ROOT)
# 19                   (of, of, ADP, prep)
# 20                (were, be, VERB, conj)
# 21                 (are, be, VERB, ROOT)
# 22     (locations, location, NOUN, conj)
# 23               (with, with, ADP, prep)
# 24                   (of, of, ADP, prep)
# 25                 (are, be, VERB, ROOT)
# 26                 (are, be, VERB, ROOT)
# 27                   (of, of, ADP, prep)
# 28    (portraying, portray, VERB, pcomp)
# 29           (getting, get, VERB, ccomp)
# ..                                   ...
# 884  (struggling, struggle, VERB, ccomp)
# 885       (clicking, click, VERB, ccomp)
# 886        (between, between, ADP, prep)
# 887                (for, for, ADP, prep)
# 888         (carving, carve, NOUN, attr)
# 889            (about, about, ADP, prep)
# 890                  (of, of, ADP, prep)
# 891                (are, be, VERB, ROOT)
# 892              (into, into, ADP, prep)
# 893        (animals, animal, NOUN, pobj)
# 894             (had, have, VERB, relcl)
# 895  (separating, separate, VERB, advcl)
# 896                (are, be, VERB, ROOT)
# 897                 (be, be, VERB, conj)
# 898           (flesh, flesh, ADJ, xcomp)
# 899                (be, be, VERB, ccomp)
# 900        (fleshed, flesh, VERB, ccomp)
# 901            (about, about, ADP, prep)
# 902             (film, film, NOUN, attr)
# 903                  (of, of, ADP, prep)
# 904         (fleshed, flesh, VERB, ROOT)
# 905                  (of, of, ADP, prep)
# 906              (with, with, ADP, prep)
# 907                  (of, of, ADP, prep)
# 908               (get, get, VERB, conj)
# 909                (are, be, VERB, conj)
# 910               (are, be, VERB, pcomp)
# 911                  (of, of, ADP, prep)
# 912               (are, be, VERB, pcomp)
# 913    (developed, develope, VERB, conj)
#
#                                    cinematography  \
# 0                    (cramped, cramp, VERB, conj)
# 1                            (is, be, VERB, conj)
# 2                            (is, be, VERB, ROOT)
# 3                         ('s, have, VERB, advcl)
# 4                   (despite, despite, ADP, prep)
# 5                           (was, be, VERB, ROOT)
# 6                          (did, do, VERB, relcl)
# 7                 (costumes, costume, NOUN, conj)
# 8                        (make, make, VERB, ROOT)
# 9                           (was, be, VERB, ROOT)
# 10   (cinematography, cinematography, NOUN, ROOT)
# 11                          (do, do, VERB, xcomp)
# 12                           (is, be, VERB, ROOT)
# 13                           (is, be, VERB, conj)
# 14                  (handle, handle, VERB, xcomp)
# 15        (scenography, scenography, NOUN, nsubj)
# 16                        (has, have, VERB, ROOT)
# 17             (direction, direction, NOUN, conj)
# 18                           (is, be, VERB, ROOT)
# 19                       (cast, cast, NOUN, intj)
# 20            (undermined, undermine, VERB, ROOT)
# 21        (photography, photography, NOUN, nsubj)
# 22                      (acting, act, NOUN, conj)
# 23                           (is, be, VERB, ROOT)
# 24                            (of, of, ADP, prep)
# 25                            (to, to, ADP, prep)
# 26                     (watch, watch, VERB, conj)
# 27                        (were, be, VERB, ccomp)
# 28                    (clad, clothe, VERB, ccomp)
# 29                        (sets, set, NOUN, ROOT)
# ..                                            ...
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909
# 910
# 911
# 912
# 913
#
#                                   dialogue
# 0              (sounds, sound, VERB, conj)
# 1                 (kept, keep, VERB, ROOT)
# 2                     (is, be, VERB, ROOT)
# 3                  (with, with, ADP, prep)
# 4                   (were, be, VERB, ROOT)
# 5      (developing, develope, VERB, pcomp)
# 6                  (past, past, ADP, prep)
# 7               (given, give, VERB, pcomp)
# 8                      (of, of, ADP, prep)
# 9                    (was, be, VERB, ROOT)
# 10              (cover, cover, VERB, ROOT)
# 11              (given, give, VERB, pcomp)
# 12               (heavy, heavy, ADJ, amod)
# 13               (heavy, heavy, ADJ, amod)
# 14                    (is, be, VERB, conj)
# 15             (forced, force, VERB, ROOT)
# 16            (scenes, scene, NOUN, nsubj)
# 17   (understand, understand, VERB, ccomp)
# 18                   (is, be, VERB, ccomp)
# 19                     (of, of, ADP, prep)
# 20                  (off, off, PART, prep)
# 21                    (is, be, VERB, ROOT)
# 22             (wavers, waver, NOUN, conj)
# 23                    (is, be, VERB, ROOT)
# 24           (script, script, NOUN, nsubj)
# 25                     (of, of, ADP, prep)
# 26                     (by, by, ADP, prep)
# 27                (have, have, VERB, conj)
# 28         (Baldwin, baldwin, PROPN, pobj)
# 29                      (as, a, ADP, prep)
# ..                                     ...
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909
# 910
# 911
# 912
# 913
#
# [914 rows x 4 columns]
# Dependents
#                                        plot  \
# 0                      (the, the, DET, det)
# 1                      (the, the, DET, det)
# 2                      (the, the, DET, det)
# 3                      (the, the, DET, det)
# 4                 (usual, usual, ADJ, amod)
# 5     (predictable, predictable, ADJ, amod)
# 6        (romance, romance, NOUN, compound)
# 7                      (the, the, DET, det)
# 8                      (the, the, DET, det)
# 9                      (the, the, DET, det)
# 10                     (The, the, DET, det)
# 11                     (the, the, DET, det)
# 12                     (The, the, DET, det)
# 13                     (the, the, DET, det)
# 14                    (and, and, CCONJ, cc)
# 15      (characters, character, NOUN, conj)
# 16                     (the, the, DET, det)
# 17            (central, central, ADJ, amod)
# 18                     (the, the, DET, det)
# 19                     (the, the, DET, det)
# 20                  (like, like, ADP, prep)
# 21                     (The, the, DET, det)
# 22                      (to, to, ADP, prep)
# 23                      (or, or, CCONJ, cc)
# 24               (called, call, VERB, conj)
# 25                     (the, the, DET, det)
# 26                     (the, the, DET, det)
# 27                  (keep, keep, VERB, acl)
# 28               (movie, movie, NOUN, poss)
# 29                     (the, the, DET, det)
# ...                                     ...
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# 1502
# 1503
# 1504
# 1505
# 1506
# 1507
# 1508
# 1509
# 1510
# 1511
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1518
# 1519
# 1520
# 1521
# 1522
# 1523
# 1524
#
#                                characters                      cinematography  \
# 0                    (The, the, DET, det)                (the, the, DET, det)
# 1                    (the, the, DET, det)                (the, the, DET, det)
# 2               (other, other, ADJ, amod)                (the, the, DET, det)
# 3                    (the, the, DET, det)                (the, the, DET, det)
# 4               (other, other, ADJ, amod)           (worst, wrong, ADJ, amod)
# 5                 (two, two, NUM, nummod)           (ever, ever, ADV, advmod)
# 6               (Black, black, ADJ, amod)                (the, the, DET, det)
# 7                    (,, ,, PUNCT, punct)   (beautiful, beautiful, ADJ, amod)
# 8               (loyal, loyal, ADJ, amod)                (the, the, DET, det)
# 9           (several, several, ADJ, amod)                (the, the, DET, det)
# 10                  (key, key, ADJ, amod)               (for, for, ADP, prep)
# 11                   (the, the, DET, det)                (,, ,, PUNCT, punct)
# 12                   (the, the, DET, det)                 (X, x, PROPN, conj)
# 13                    (or, or, CCONJ, cc)                (the, the, DET, det)
# 14               (plot, plot, NOUN, conj)           (awful, awful, ADJ, amod)
# 15                   (the, the, DET, det)                (,, ,, PUNCT, punct)
# 16                (main, main, ADJ, amod)         (editing, edit, NOUN, conj)
# 17                   (the, the, DET, det)             (good, good, ADJ, amod)
# 18                (two, two, NUM, nummod)               (and, and, CCONJ, cc)
# 19                   (the, the, DET, det)          (music, music, NOUN, conj)
# 20                (two, two, NUM, nummod)            (Well, well, INTJ, intj)
# 21      (practicing, practice, VERB, acl)                (,, ,, PUNCT, punct)
# 22                   (the, the, DET, det)             (nice, nice, ADJ, amod)
# 23                (two, two, NUM, nummod)                  (as, a, ADP, prep)
# 24                (lead, lead, ADJ, amod)                (:, :, PUNCT, punct)
# 25                   (the, the, DET, det)  (interiors, interior, NOUN, appos)
# 26           (writing, write, NOUN, amod)                (., ., PUNCT, punct)
# 27                   (the, the, DET, det)                 (80, 80, NUM, poss)
# 28                   (the, the, DET, det)      (style, style, NOUN, compound)
# 29                      (\n, \n, SPACE, )           (Even, even, ADV, advmod)
# ...                                   ...                                 ...
# 1495                 (the, the, DET, det)
# 1496                  (in, in, ADP, prep)
# 1497                 (the, the, DET, det)
# 1498             (thses, ths, NOUN, amod)
# 1499               (are, be, VERB, relcl)
# 1500                 (the, the, DET, det)
# 1501                 (the, the, DET, det)
# 1502    (wonderful, wonderful, ADJ, amod)
# 1503             (film, film, NOUN, poss)
# 1504         (rounded, round, VERB, amod)
# 1505            (human, human, ADJ, amod)
# 1506                 (the, the, DET, det)
# 1507                 (The, the, DET, det)
# 1508                  (of, of, ADP, prep)
# 1509            (five, five, NUM, nummod)
# 1510                  (in, in, ADP, prep)
# 1511              (these, this, DET, det)
# 1512                 (The, the, DET, det)
# 1513                 (the, the, DET, det)
# 1514  (villainous, villainous, ADJ, amod)
# 1515            (some, some, DET, nummod)
# 1516                 (the, the, DET, det)
# 1517            (other, other, ADJ, amod)
# 1518              (main, main, ADJ, amod)
# 1519                 (the, the, DET, det)
# 1520              (these, this, DET, det)
# 1521                 (the, the, DET, det)
# 1522              (these, this, DET, det)
# 1523                 (the, the, DET, det)
# 1524                 (the, the, DET, det)
#
#                              dialogue
# 0                (the, the, DET, det)
# 1            (Her, -PRON-, ADJ, poss)
# 2                (The, the, DET, det)
# 3                (the, the, DET, det)
# 4               (and, and, CCONJ, cc)
# 5             (some, some, DET, conj)
# 6                (the, the, DET, det)
# 7               (bad, bad, ADJ, amod)
# 8               (and, and, CCONJ, cc)
# 9             (some, some, DET, conj)
# 10          (better, well, ADJ, amod)
# 11    (suitable, suitable, ADJ, amod)
# 12            (all, all, ADJ, predet)
# 13               (the, the, DET, det)
# 14    (terrible, terrible, ADJ, amod)
# 15          (acting, act, NOUN, amod)
# 16              (is, be, VERB, relcl)
# 17      (cliched, cliched, ADJ, amod)
# 18               (the, the, DET, det)
# 19                (of, of, ADP, prep)
# 20              (and, and, CCONJ, cc)
# 21           (plot, plot, NOUN, conj)
# 22               (the, the, DET, det)
# 23                (in, in, ADP, prep)
# 24      (cliched, cliched, ADJ, amod)
# 25               (the, the, DET, det)
# 26               (The, the, DET, det)
# 27         (their, -PRON-, ADJ, poss)
# 28               (the, the, DET, det)
# 29     (tortured, torture, ADJ, amod)
# ...                               ...
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# 1502
# 1503
# 1504
# 1505
# 1506
# 1507
# 1508
# 1509
# 1510
# 1511
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1518
# 1519
# 1520
# 1521
# 1522
# 1523
# 1524
#
# [1525 rows x 4 columns]

# %%
# %load solutions/all_heads_deps_features
aspect_words = ["plot","characters","cinematography","dialogue"]
linked_words = defaultdict(lambda: defaultdict(list)) 
for parsed_review in parsed_reviews:
    for token in parsed_review:
        if token.pos_ == 'NOUN' and token.orth_ in aspect_words:
            linked_words[token.orth_]["heads"].append((token.head.orth_,token.head.lemma_,token.head.pos_,token.dep_))
            for child in token.children:
                linked_words[token.orth_]["deps"].append((child.orth_,child.lemma_,child.pos_,child.dep_))
all_heads = [linked_words[word]["heads"] for word in aspect_words]
all_dependents = [linked_words[word]["deps"] for word in aspect_words]
df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Tuple format: (word, lemma, POS, dep. relation)")
print("Heads")
display(df_heads)
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Dependents")
display(df_deps)

# %% [markdown]
# ### Exercise
# We are now ready to filter out some of the entries in the table that are uninteresting.
# To do this, create the following sets:
#
# ```
# unwanted_head_deps = set()
# unwanted_head_lemmas = set()
# unwanted_head_pos = set()
# unwanted_dependent_deps = set()
# unwanted_dependent_pos = set()
# unwanted_dependent_lemmas = set()
# ```
#
# The idea is that you will manually add entries to these sets as you spot ways to eliminate uninteresting entries in the table.
#
# Undertake the following steps:
# 1. Defined an initial version of these sets based on your observations of the tables produced in the previous exercise.
# 2. Adapt the code so that these sets are used to filter out unwanted tokens before they are added to your lists of heads and dependents.
#  - one option here is to define two functions: `uninteresting_head(token)` and `uninteresting_dependent(token)`.
# 3. Run the code to see how well it has improved.
# 4. Keep adding to the sets and re-running your code until you are satisfied that you can't improve them any more.

# %%
unwanted_head_deps = set(['prep','advcl','relcl','xcomp','pobj','pcomp'])
unwanted_head_lemmas = set(['be','to','have','do','for','of','a','off','with'])
unwanted_head_pos = set(['ADP','PART'])
unwanted_dependent_deps = set(['det','relcl','cc','punct','prep','poss','nummod','conj'])
unwanted_dependent_pos = set(['DET','ADP','NUM','SPACE','CCONJ','PUNCT','PROPN',])
unwanted_dependent_lemmas = set(['the','other','and','some','of','or','to','be','a','this','-PRON-'])

def uninteresting_head(token):
    return token.lemma_ in unwanted_head_lemmas or token.pos_ in unwanted_head_pos or token.dep_ in unwanted_head_deps

def uninteresting_dependent(token):
    return token.lemma_ in unwanted_dependent_lemmas or token.pos_ in unwanted_dependent_pos or token.dep_ in unwanted_head_deps

aspect_words = ["plot","characters","cinematography","dialogue"]
word_dict = defaultdict(lambda: defaultdict(list))
for review in parsed_reviews:
    for token in review:
        if token.pos_ == 'NOUN' and token.text in aspect_words:
            if not uninteresting_head(token.head):
                word_dict[token.text]["heads"].append((token.head.text,token.head.lemma_,token.head.pos_,token.head.dep_))
            for child in token.children:
                if not uninteresting_dependent(child):
                    word_dict[token.text]["deps"].append((child.text,child.lemma_,child.pos_,child.dep_))
all_heads = [word_dict[asp_wd]["heads"] for asp_wd in aspect_words]
all_dependents = [word_dict[asp_wd]["deps"] for asp_wd in aspect_words]
print('Done building lists')
df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Tuple format: (word, lemma, POS, dep. relation)")
print("Heads")
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
display(df_heads)
print("Dependents")
display(df_deps)
# Out:
# Done building lists
# Tuple format: (word, lemma, POS, dep. relation)
# Heads
#                                                   plot  \
# 0                            (holes, hole, NOUN, dobj)
# 1                        (centers, center, NOUN, ROOT)
# 2                 (irrelevant, irrelevant, ADJ, ccomp)
# 3               (uninvolving, uninvolving, ADJ, ccomp)
# 4                            (line, line, NOUN, nsubj)
# 5                    (dialogue, dialogue, NOUN, nsubj)
# 6                             (lost, lose, VERB, ROOT)
# 7                       (summary, summary, NOUN, attr)
# 8                              (got, get, VERB, ccomp)
# 9                           (revel, revel, NOUN, ROOT)
# 10                         (chunks, chunk, NOUN, dobj)
# 11                          (revel, revel, NOUN, ROOT)
# 12                             (wise, wise, ADJ, oprd)
# 13                             (gaps, gap, NOUN, attr)
# 14                           (acting, act, NOUN, dobj)
# 15                           (holes, hole, NOUN, ROOT)
# 16                         (story, story, NOUN, nsubj)
# 17                (understood, understand, VERB, ROOT)
# 18                         (twists, twist, NOUN, attr)
# 19                            (plot, plot, NOUN, ROOT)
# 20                (structuring, structure, VERB, conj)
# 21                          (acting, act, NOUN, nsubj)
# 22                     (resolved, resolve, VERB, ROOT)
# 23                            (plot, plot, NOUN, ROOT)
# 24                          (story, story, NOUN, attr)
# 25                     (involves, involve, VERB, ROOT)
# 26                     (involves, involve, VERB, ROOT)
# 27            (unbelievable, unbelievable, ADJ, ccomp)
# 28                            (make, make, VERB, ROOT)
# 29                           (holes, hole, NOUN, conj)
# ..                                                 ...
# 236                     (lines, line, NOUN, nsubjpass)
# 237                       (twists, twist, NOUN, nsubj)
# 238   (characterisation, characterisation, NOUN, dobj)
# 239                           (held, hold, VERB, ROOT)
# 240                 (revenge, revenge, NOUN, compound)
# 241                          (acting, act, NOUN, dobj)
# 242                     (formula, formula, NOUN, attr)
# 243  (characterizations, characterization, NOUN, ns...
# 244                           (plot, plot, NOUN, ROOT)
# 245                       (twists, twist, NOUN, nsubj)
# 246                     (advance, advance, VERB, ROOT)
# 247                        (twists, twist, NOUN, dobj)
# 248                       (action, action, NOUN, ROOT)
# 249                         (turns, turn, VERB, ccomp)
# 250                  (dialogue, dialogue, NOUN, nsubj)
# 251                          (dizzy, dizzy, ADJ, conj)
# 252                           (idea, idea, NOUN, dobj)
# 253                        (setting, set, NOUN, nsubj)
# 254                        (driven, drive, VERB, amod)
# 255                       (fright, fright, NOUN, intj)
# 256                          (holes, hole, NOUN, attr)
# 257             (development, development, NOUN, conj)
# 258                             (man, man, NOUN, dobj)
# 259                          (seems, seem, VERB, ROOT)
# 260                           (line, line, NOUN, conj)
# 261                       (script, script, NOUN, nmod)
# 262                      (centers, center, NOUN, ROOT)
# 263                        (setting, set, NOUN, nsubj)
# 264                         (racing, race, NOUN, nmod)
# 265                      (unfolds, unfold, VERB, conj)
#
#                                    characters  \
# 0                    (talk, talk, VERB, ROOT)
# 1                   (know, know, VERB, ccomp)
# 2                  (lumped, lump, VERB, ROOT)
# 3                  (saying, say, VERB, ccomp)
# 4                   (plot, plot, NOUN, nsubj)
# 5            (presented, present, VERB, ROOT)
# 6           (locations, location, NOUN, conj)
# 7                 (getting, get, VERB, ccomp)
# 8                     (going, go, VERB, ROOT)
# 9                     (hit, hit, VERB, ccomp)
# 10   (grandparents, grandparent, NOUN, appos)
# 11                   (feel, feel, VERB, conj)
# 12                    (pay, pay, VERB, ccomp)
# 13                (fight, fight, VERB, ccomp)
# 14                    (bring, br, VERB, ROOT)
# 15              (created, create, VERB, conj)
# 16               (remind, remind, VERB, ROOT)
# 17               (speech, speech, NOUN, conj)
# 18        (characters, character, NOUN, ROOT)
# 19                (movies, movie, NOUN, dobj)
# 20                  (lacks, lack, VERB, conj)
# 21                (wasted, waste, VERB, ROOT)
# 22       (understood, understand, VERB, ROOT)
# 23             (develop, develop, VERB, conj)
# 24        (characters, character, NOUN, ROOT)
# 25             (engaging, engage, VERB, ROOT)
# 26                  (move, move, VERB, ccomp)
# 27                  (holes, hole, NOUN, conj)
# 28                  (given, give, VERB, conj)
# 29   (grandparents, grandparent, NOUN, appos)
# ..                                        ...
# 236              (fleshed, flesh, VERB, ROOT)
# 237                    (get, get, VERB, conj)
# 238         (developed, develope, VERB, conj)
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
#
#                                    cinematography  \
# 0                    (cramped, cramp, VERB, conj)
# 1                 (costumes, costume, NOUN, conj)
# 2                        (make, make, VERB, ROOT)
# 3    (cinematography, cinematography, NOUN, ROOT)
# 4         (scenography, scenography, NOUN, nsubj)
# 5              (direction, direction, NOUN, conj)
# 6                        (cast, cast, NOUN, intj)
# 7             (undermined, undermine, VERB, ROOT)
# 8         (photography, photography, NOUN, nsubj)
# 9                       (acting, act, NOUN, conj)
# 10                     (watch, watch, VERB, conj)
# 11                    (clad, clothe, VERB, ccomp)
# 12                        (sets, set, NOUN, ROOT)
# 13                      (acting, act, VERB, conj)
# 14                (directing, direct, NOUN, conj)
# 15                     (acting, act, NOUN, nsubj)
# 16                   (writing, write, NOUN, conj)
# 17                (quality, quality, NOUN, nsubj)
# 18                (composes, compose, VERB, ROOT)
# 19   (cinematography, cinematography, NOUN, ROOT)
# 20                (captures, capture, VERB, ROOT)
# 21                    (setting, set, NOUN, nsubj)
# 22                  (moments, moment, NOUN, conj)
# 23             (storyline, storyline, NOUN, conj)
# 24                       (make, make, VERB, ROOT)
# 25                      (mood, mood, NOUN, nsubj)
# 26   (cinematography, cinematography, NOUN, ROOT)
# 27                       (like, like, VERB, ROOT)
# 28                    (actors, actor, NOUN, dobj)
# 29                (enhances, enhance, VERB, conj)
# ..                                            ...
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
#
#                                      dialogue
# 0                 (sounds, sound, VERB, conj)
# 1                    (kept, keep, VERB, ROOT)
# 2                  (cover, cover, VERB, ROOT)
# 3                   (heavy, heavy, ADJ, amod)
# 4                   (heavy, heavy, ADJ, amod)
# 5                 (forced, force, VERB, ROOT)
# 6                (scenes, scene, NOUN, nsubj)
# 7       (understand, understand, VERB, ccomp)
# 8                 (wavers, waver, NOUN, conj)
# 9               (script, script, NOUN, nsubj)
# 10              (comedy, comedy, NOUN, nsubj)
# 11   (Anachronism, anachronism, PROPN, nsubj)
# 12                   (plot, plot, NOUN, nmod)
# 13               (sounded, sound, VERB, conj)
# 14                 (plots, plot, NOUN, nsubj)
# 15                   (saved, save, VERB, acl)
# 16                  (fair, fair, VERB, ccomp)
# 17                (stupid, stupid, ADJ, conj)
# 18            (consists, consist, VERB, ROOT)
# 19              (script, script, NOUN, nsubj)
# 20                   (tries, try, VERB, ROOT)
# 21               (missing, miss, VERB, ccomp)
# 22                   (love, love, VERB, ROOT)
# 23                  (give, give, VERB, ccomp)
# 24              (handles, handle, VERB, ROOT)
# 25                 (music, music, NOUN, conj)
# 26                (actors, actor, NOUN, conj)
# 27                   (film, film, NOUN, attr)
# 28                   (plot, plot, NOUN, attr)
# 29                  (plot, plot, NOUN, nsubj)
# ..                                        ...
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
#
# [266 rows x 4 columns]
# Dependents
#                                       plot  \
# 0                (usual, usual, ADJ, amod)
# 1    (predictable, predictable, ADJ, amod)
# 2       (romance, romance, NOUN, compound)
# 3      (characters, character, NOUN, conj)
# 4            (central, central, ADJ, amod)
# 5               (called, call, VERB, conj)
# 6                  (keep, keep, VERB, acl)
# 7               (movie, movie, NOUN, poss)
# 8           (message, message, NOUN, conj)
# 9                (barfs, barfs, ADJ, conj)
# 10                 (main, main, ADJ, amod)
# 11          (message, message, NOUN, conj)
# 12                 (main, main, ADJ, amod)
# 13             (flimsy, flimsy, ADJ, amod)
# 14        (tunnel, tunnel, NOUN, compound)
# 15        (escape, escape, NOUN, compound)
# 16        (sabotage, sabotage, NOUN, conj)
# 17             (simple, simple, ADJ, amod)
# 18                 (same, same, ADJ, amod)
# 19                 (good, good, ADJ, amod)
# 20             (stupid, stupid, ADJ, amod)
# 21             (entire, entire, ADJ, amod)
# 22             (humor, humor, NOUN, appos)
# 23        (ticket, ticket, NOUN, compound)
# 24              (sub, sub, NOUN, compound)
# 25              (deals, deal, VERB, appos)
# 26             (stopped, stop, VERB, conj)
# 27               (basic, basic, ADJ, amod)
# 28                 (dumb, dumb, ADJ, amod)
# 29         (attempts, attempt, NOUN, conj)
# ..                                     ...
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
#
#                               characters  \
# 0              (Black, black, ADJ, amod)
# 1              (loyal, loyal, ADJ, amod)
# 2          (several, several, ADJ, amod)
# 3                  (key, key, ADJ, amod)
# 4               (plot, plot, NOUN, conj)
# 5                (main, main, ADJ, amod)
# 6      (practicing, practice, VERB, acl)
# 7                (lead, lead, ADJ, amod)
# 8           (writing, write, NOUN, amod)
# 9                (All, all, ADJ, predet)
# 10                 (few, few, ADJ, amod)
# 11     (supporting, support, VERB, amod)
# 12          (spoiled, spoil, VERB, amod)
# 13           (rotten, rotten, ADJ, amod)
# 14         (details, detail, NOUN, conj)
# 15        (depraved, deprave, ADJ, amod)
# 16             (minor, minor, ADJ, amod)
# 17          (addict, addict, NOUN, amod)
# 18               (all, all, ADJ, predet)
# 19         (tedious, tedious, ADJ, amod)
# 20             (human, human, ADJ, amod)
# 21          (singing, singe, NOUN, conj)
# 22                 (few, few, ADJ, amod)
# 23         (central, central, ADJ, amod)
# 24               (same, same, ADJ, amod)
# 25         (obscure, obscure, ADJ, amod)
# 26     (secondary, secondary, ADJ, amod)
# 27               (main, main, ADJ, amod)
# 28           (unique, unique, ADJ, amod)
# 29               (like, like, ADJ, nmod)
# ..                                   ...
# 450        (chinese, chinese, ADJ, amod)
# 451    (secondary, secondary, ADJ, amod)
# 452            (taking, take, VERB, acl)
# 453    (supporting, support, VERB, amod)
# 454    (secondary, secondary, ADJ, amod)
# 455    (secondary, secondary, ADJ, amod)
# 456        (couple, couple, NOUN, appos)
# 457      (favorite, favorite, ADJ, amod)
# 458              (all, all, ADJ, predet)
# 459        (strange, strange, ADJ, amod)
# 460            (minor, minor, ADJ, amod)
# 461        (complex, complex, ADJ, amod)
# 462              (lead, lead, ADJ, amod)
# 463         (fleshed, flesh, VERB, amod)
# 464              (all, all, ADJ, predet)
# 465            (great, great, ADJ, amod)
# 466           (funnest, funn, ADJ, amod)
# 467   (cartoon, cartoon, NOUN, compound)
# 468              (main, main, ADJ, amod)
# 469          (heroic, heroic, ADJ, amod)
# 470              (All, all, ADJ, predet)
# 471              (few, few, ADJ, nummod)
# 472       (recurring, recur, VERB, amod)
# 473             (thses, ths, NOUN, amod)
# 474    (wonderful, wonderful, ADJ, amod)
# 475             (film, film, NOUN, poss)
# 476         (rounded, round, VERB, amod)
# 477            (human, human, ADJ, amod)
# 478  (villainous, villainous, ADJ, amod)
# 479              (main, main, ADJ, amod)
#
#                             cinematography  \
# 0                (worst, wrong, ADJ, amod)
# 1                (ever, ever, ADV, advmod)
# 2        (beautiful, beautiful, ADJ, amod)
# 3                (awful, awful, ADJ, amod)
# 4              (editing, edit, NOUN, conj)
# 5                  (good, good, ADJ, amod)
# 6               (music, music, NOUN, conj)
# 7                 (Well, well, INTJ, intj)
# 8                  (nice, nice, ADJ, amod)
# 9       (interiors, interior, NOUN, appos)
# 10          (style, style, NOUN, compound)
# 11               (Even, even, ADV, advmod)
# 12                 (like, like, ADJ, conj)
# 13          (imagery, imagery, NOUN, conj)
# 14       (marvelous, marvelous, ADJ, amod)
# 15               (great, great, ADJ, amod)
# 16   (beautifully, beautifully, ADV, amod)
# 17               (stark, stark, ADJ, amod)
# 18               (black, black, ADJ, amod)
# 19       (Wonderful, wonderful, ADJ, amod)
# 20          (subject, subject, NOUN, conj)
# 21      (interesting, interest, ADJ, amod)
# 22               (fluid, fluid, ADJ, amod)
# 23       (beautiful, beautiful, ADJ, amod)
# 24         (directing, direct, NOUN, conj)
# 25              (shot, shoot, NOUN, appos)
# 26         (costumes, costume, NOUN, conj)
# 27       (brilliant, brilliant, ADJ, amod)
# 28           (Russian, russian, ADJ, amod)
# 29              (tinted, tint, VERB, amod)
# ..                                     ...
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
#
#                                 dialogue
# 0                  (bad, bad, ADJ, amod)
# 1              (better, well, ADJ, amod)
# 2        (suitable, suitable, ADJ, amod)
# 3                (all, all, ADJ, predet)
# 4        (terrible, terrible, ADJ, amod)
# 5              (acting, act, NOUN, amod)
# 6          (cliched, cliched, ADJ, amod)
# 7               (plot, plot, NOUN, conj)
# 8          (cliched, cliched, ADJ, amod)
# 9         (tortured, torture, ADJ, amod)
# 10          (stilted, stilt, VERB, amod)
# 11     (pointless, pointless, ADJ, amod)
# 12             (tangy, tangy, ADJ, amod)
# 13             (gal, gal, ADJ, compound)
# 14               (Good, good, ADJ, amod)
# 15                 (bad, bad, ADJ, amod)
# 16              (plot, plot, NOUN, conj)
# 17       (horrible, horrible, ADJ, amod)
# 18             (acting, act, VERB, conj)
# 19             (acting, act, NOUN, conj)
# 20            (fisted, fist, VERB, amod)
# 21              (plot, plot, NOUN, conj)
# 22   (obscenity, obscenity, NOUN, appos)
# 23          (written, write, VERB, amod)
# 24            (depth, depth, NOUN, conj)
# 25         (unwitty, unwitty, ADJ, amod)
# 26             (even, even, ADV, advmod)
# 27           (talking, talk, VERB, nmod)
# 28               (all, all, ADJ, predet)
# 29       (florid, florid, ADJ, compound)
# ..                                   ...
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
#
# [480 rows x 4 columns]

# %%
# %load solutions/filtered_heads_deps

# %% [markdown]
# ## Opinion extractor
# Over the remaining exercises in this notebook, we are now going to create and subsequently refine a function called `opinion_extractor`.
#
# `opinion_extractor` takes two arguments:
# - `aspect_token`: an aspect token, such as "*plot*", "*characters*", "*cinematography*" and "*dialogue*".
# - `parsed_sentence`: a parsed sentence
# The output should be a list of extracted opinions, i.e. a list of tokens that tell us something about what the reviewer is saying (in `parsed_sentence`) about `aspect_token`.
#
# ### Exercise
# To begin, in the cell below, complete an initial verison of the function `opinion_extractor` that returns a list of all dependents of the aspect token.
# - This list will be empty when there are no opinions relating `aspect_token` to extract in `parsed_sentence`.

# %%
def opinion_extractor(aspect_token,parsed_sentence):

    opinions = []
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.text == aspect_token:
            for child in token.children:
                opinions.append(child.text)
    return opinions

def show_results(results,aspect_word):
    print("Results for aspect word '{}'\n".format(aspect_word))
    for word,sent,opinions in results:
        if word == aspect_word:
            print("Sentence:\n\t{}".format(sent))
            print("Opinion of '{0}':\n\t '{1}'".format(aspect_word,"', '".join(opinions)))
            print("\n")

aspect_words = ["plot","characters","cinematography","dialogue"]
results = [] 
for parsed_review in parsed_reviews:
    for sentence in parsed_review.sents:
        for aspect_token in aspect_words:
            opinions = opinion_extractor(aspect_token,sentence)
            if opinions:
                results.append((aspect_token,sentence.orth_,opinions))

show_results(results,"plot")
show_results(results,"characters")
show_results(results,"cinematography")
show_results(results,"dialogue")
# Out:
# Results for aspect word 'plot'
#
# Sentence:
# 	However,theplotwaspredictable.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Furthermore,theplotissopredictablethatitmadethemoviedrag.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	well,that'stheusualpredictableromanceplot.
# Opinion of 'plot':
# 	 'usual', 'predictable'
#
#
# Sentence:
# 	TheplotwasOKbutitwouldhavebeenmuchbetteriftheyhadeitherstucktoamoreauthenticrepresentationofJapanesecultureorkeptthestoryinthestates.
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Theperformancesarethinanduneven,theplotisinconsistent,andthedialoguesoundslikeitwaspulledfromfortunecookiesmadebythecastofFriends.
# Opinion of 'plot':
# 	 'inconsistent'
#
#
# Sentence:
# 	AlthoughthismoviewantedtobeinthesameraceandqualityofthemovieCLUE,itfailstorealizethattheplotandcharactersareincrediblyriculousandnotfunnyhahabutfunnystupid.
# Opinion of 'plot':
# 	 'riculous'
#
#
# Sentence:
# 	Theactingishorrible,theplotishorrible,thefilmingishorrible...
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Its"thriller"aspectisartificialandnottiedtothecentralplotline,andentirelypredictablefromthemomentourfriendishandedTHEONLYKEYTHATCANSTOPTHENUKE!
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Theplottothismovieorsocalledsequalishorrible.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'straightforward'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'thin'
#
#
# Sentence:
# 	Withtheirchildestvoices,theyshouldn'tbeusedasamainplotofthestory
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Asfarasthemovieisconcerned,theplotisunoriginalandnotparticularlyengaging.
# Opinion of 'plot':
# 	 'unoriginal'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Thiswassuchacontrivedmoviethathadasimpleplotthatwentnowhere.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Themoviewasn'tfunny(whichissadtosaywhenoneofmyfavoritecomedicactresses,CarolKane,couldn'tevenelicitasmileoutofme),theplotwasfullofholes,andthewritingseemedveryrushedandcontrived.
# Opinion of 'plot':
# 	 'full'
#
#
# Sentence:
# 	Thespecialeffectsareabitcheesy,youcanseethewirespullingthetorpedosandyoucantellthattheyusedscaledmodelships...butifyouoverlookthoseitems,yougetfineactingandagoodplotwithplentyof
# action
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	stupidplot-toomanyholesandstupidending.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theentireplotisself-serving,shallow,andunrealistic.
# Opinion of 'plot':
# 	 'entire', 'serving'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Thebasicplotofthemovieisthatlifesucks(
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	TheplotislameandIamsorryIspentthemoneyonit.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Butthedumbplotandtheunfunnyattemptsatcomedymakeitacompletewasteoftime.
# Opinion of 'plot':
# 	 'dumb'
#
#
# Sentence:
# 	Eraserhasafewscenesthatwillkeepyourattention,butoverallthemoviedisplayedpooracting,stuntsthatareimpossibleandamediocreplot.
# Opinion of 'plot':
# 	 'mediocre'
#
#
# Sentence:
# 	Verypredictableplotfrombeginningtoend.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Iwasveryboredwiththismovieandfoundtheplottobeveryinsulting.
# Opinion of 'plot':
# 	 'insulting'
#
#
# Sentence:
# 	Buysomthingthathasagoodplot.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Oneoftheworstmoviesi'veeverseen,norealplotandactingisasbadasitcanget.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Canyoureallycarry2hourswiththissingleplot?
# Opinion of 'plot':
# 	 'single'
#
#
# Sentence:
# 	Theplotiscomplicatedandthenoiseinthebackgroundaddstothedisorientationwhichisdoneonpurpose.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'thin'
#
#
# Sentence:
# 	Buttheplotwaslame&slow.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'plot':
# 	 'unbelievable'
#
#
# Sentence:
# 	Thisseriesmightbeconsideredaclassicifwatchedbya12-year-old,butadultswillseethoughtheindistinctplotandcharacters.
# Opinion of 'plot':
# 	 'indistinct'
#
#
# Sentence:
# 	Theplotwasadequate.
# Opinion of 'plot':
# 	 'adequate'
#
#
# Sentence:
# 	Ijustcan'tgetoverhowprofoundlycornyandsimpletheplotandeffectsare,
# Opinion of 'plot':
# 	 'corny'
#
#
# Sentence:
# 	BeforeIhitthistooharshly,thisfilmwasintendedtobeatrifle,thekindofmoviethathasbrightcolorsandlightplotforahotsummerdaythatsizzles.
# Opinion of 'plot':
# 	 'light'
#
#
# Sentence:
# 	Soundslikeaninterestingplot,right?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Feebledirectionsimplymissesseveralgoodopportunitiestomakegooduseofthejockey'ssullenlittledaughterSam(KayPanabaker,herfeaturedebut),whocouldhavebeenalittlesurprise(orgem)inthisunconvincingplot.
# Opinion of 'plot':
# 	 'unconvincing'
#
#
# Sentence:
# 	Theonlybluehereistheshadeyouwillturnbytheboredomwiththeweakplot.
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	TheplotwasbadanditdidnothavethatmanypokemonasIthought.
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	...hasaprettythinplot.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Infact,thetrialdoesn'tevenhaveaconnectiontothecentralplotasidefromshowingthatSamandArchiearefriendsandpartners.
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Howeverifyoulikesex,violence,blood,anddebauchery,couldcarelessthefactthattheyhavenothingtodowiththeabsentplot,youcouldfindthisfilminteresting.
# Opinion of 'plot':
# 	 'absent'
#
#
# Sentence:
# 	Andplotissoludicrouslypredictableit'sprettyclearearlyonjustwhothebadguybehindthecurtainis.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Flatlighting,cheapsetsandcostumes,dulldialog,woodenacting,andagoofyplot;evenpervasivesiliconeenhancementcannotsavethismovie.
# Opinion of 'plot':
# 	 'goofy'
#
#
# Sentence:
# 	Theplotifpoorlycontrived,theproductionvalueislow,theactingforthemostpartisawful,andit'sbasicallyjustawaytostitchtogetheraseriesofmusicvideoswhichathisage,mysonhasnointerestin.
# Opinion of 'plot':
# 	 'low'
#
#
# Sentence:
# 	JuryDutysimplywasjustplainawfulwithit'sweak,boringplotandunfunnyhumor!
# Opinion of 'plot':
# 	 'weak', 'boring'
#
#
# Sentence:
# 	Theplotofthemovieisinterestingandkeepsyouwonderingwhatisgonnahappennext.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'horrific'
#
#
# Sentence:
# 	Theplothowever,isexcellent.
# Opinion of 'plot':
# 	 'excellent'
#
#
# Sentence:
# 	Veryinterestingandunpredictableplot.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Theplotfeelssluggishattimesandthere'swaytoomuchXavierCugatandhisorchestra,butAstaireandHayworthareattheirpeak,KernhaswrittensomememorablemelodiesandfewcouldtopMerceratlyricwriting,noneinHollywood.
# Opinion of 'plot':
# 	 'sluggish'
#
#
# Sentence:
# 	Basicplot:
# Opinion of 'plot':
# 	 'Basic'
#
#
# Sentence:
# 	Sowhileitwasaconvenientplotdevice,youwouldexpectsomethinglikethatbysomeonewithonlyminimalknowledgeofdinosaurs.
# Opinion of 'plot':
# 	 'convenient'
#
#
# Sentence:
# 	itwasquitefunny,buttherewaslessactionandlessplotcomparedtootherepisodes.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	Almosttheentireplotisonboardandunderway.
# Opinion of 'plot':
# 	 'entire', 'onboard'
#
#
# Sentence:
# 	Fromthereitjustgetsprogressivelydarkerandtenser,withthelighting,acting,anddirectionallperfectlyservingtoratchetupthefeelingofdesperationandhorrorasToddkickshisill-conceivedrobberyplotintomotionandthingsspinwayoutofcontrol.
# Opinion of 'plot':
# 	 'conceived'
#
#
# Sentence:
# 	Whileit'shardtopickmyfavoritefirstseasonepisode,thecomplexplotof"APriest,A
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Theplotwaswellworn,butitdidn'tfeelstaidorplodding.
# Opinion of 'plot':
# 	 'worn'
#
#
# Sentence:
# 	Theplotisperfectandthescriptiswellwritten.
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplotissweet.
# Opinion of 'plot':
# 	 'sweet'
#
#
# Sentence:
# 	Thequalityofthegraphicsareterrific,theplotisalittlestrange,butbasicallyitsalienswhoinvadeandride4virtualrollercoastersatafuturisticthemepark.
# Opinion of 'plot':
# 	 'strange'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	anywayirecommendthistoanyonewholoves Asianhorrorandlikesagoodplotandmovie!!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisnotveryintriguing,andyouknowthatnothinglikethiscanhappeninthereallife,soitlacksthissenseofreality.
# Opinion of 'plot':
# 	 'intriguing'
#
#
# Sentence:
# 	I'mnotamoviebuff,butDeepCoverhasalltheelementsyouwouldexpectofaclassic:greatacting,memorablelines,interesting(andlogical)plotandadecentending.
# Opinion of 'plot':
# 	 'logical'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'plot':
# 	 'silly', 'funny'
#
#
# Sentence:
# 	TheplotevolvesasmanyotherCoenmovies(RaisingArizonacomestomind)asweareintroducedtomore-and-morecolorfulcharactersandtheplotgetsmore-and-moreoutrageous,yetsomehowstillseemsreal.
# Opinion of 'plot':
# 	 'outrageous'
#
#
# Sentence:
# 	Everyoneknowsthebasicplotbynow:SpockkidnapshiscrippledformerCaptain,andhijackstheEnterprise,andsetscoursefortheoneforbiddenplanetinallTheFederation.
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	Yes,theplotisodd.
# Opinion of 'plot':
# 	 'odd'
#
#
# Sentence:
# 	Itdoesn'tfollowastorylinethat'spredictable,eventhoughtheplotisnotunknown.
# Opinion of 'plot':
# 	 'unknown'
#
#
# Sentence:
# 	Itusesoneoftheworstsuperheroclichesasthemainplot,thatoftheherocallingitquits.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	There'sashadowyplotinvolving$10,000bills,aguerillamovementandguns,butthemoviefocusesmoreonQuinn'sconflictsbecausehischildhoodfriendissuspectedofagrislymurder,andQuinn'sowndiscomfortfromhaving"madegood"butendingupcaughtbetweentwoworlds,whiteandblack.
# Opinion of 'plot':
# 	 'shadowy'
#
#
# Sentence:
# 	Wasitcancelledbecausetheplotwasflimsyordumb?
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Theplot,thesetting,thedialogues,thespecialeffects,andthemusicareallwonderful!
# Opinion of 'plot':
# 	 'wonderful'
#
#
# Sentence:
# 	Theplotisinteresting,itkeepsyouguessing,andthesuspensekeepsyouontheedgeofyourseat.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	DirectedbyTamraDaviswithakeeneyeoncharacterizationandhumor,thismovieisoneofthoseyousmilemostofthetime,andhaveagoodtimewithitssurrealandzanyplot.
# Opinion of 'plot':
# 	 'surreal'
#
#
# Sentence:
# 	Theplotwasn'thorrible,itwasactuallyprettygoodforafrightflick.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplot,thesetting,theacting,andthedialoguesareallverygood.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotiscomplex.
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Eventhoughthefilmisbasedonafictionalplot,itstillhasanauthenticfeelandisratedanalltimeclassic.
# Opinion of 'plot':
# 	 'fictional'
#
#
# Sentence:
# 	Theplotisgood,andDeoxys''destructive'intentionsarelesscruelthanonewouldthink.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotanddialogueisincrediblebecauseitexploresalltheshadesofgreyinthecharacters.
# Opinion of 'plot':
# 	 'incredible'
#
#
# Sentence:
# 	theplotwasprettyoriginal.
# Opinion of 'plot':
# 	 'original'
#
#
# Sentence:
# 	Thisfilmmaynotbeperfect,andtherearesomeboringscenesastheytrytohardtoexplainthestateNickisin,buttheoverallplotofthisfilmisoneI'veneverseendonebefore.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisprettyunrealisticbutthenitisascrewycomedysoithelpsifyoususpendagooddealofdisbelief.
# Opinion of 'plot':
# 	 'unrealistic'
#
#
# Sentence:
# 	ItcombinesabunchofthebestFrenchactrices,andanenjoyableplot.
# Opinion of 'plot':
# 	 'enjoyable'
#
#
# Sentence:
# 	theplotwasdry,liketheother2oftheseries,buthowexcitingofaplotcanyouhavewiththeamountofactionandskilleddrivingpackedintothemovie.
# Opinion of 'plot':
# 	 'dry'
#
#
# Sentence:
# 	Suretheplotofweakandtherelationshipsareunbelievable,ImeanwhocanhonestlysaythattheyfeelakingpintotheJapanese/Chinese/Oriental(whateveritwas)
# Opinion of 'plot':
# 	 'unbelievable'
#
#
# Sentence:
# 	Thisfilmhassomegoodactorsinitbuttheplotisprettyshakyandhardtofollowattimes.
# Opinion of 'plot':
# 	 'shaky'
#
#
# Sentence:
# 	Itcouldhavebeenmadebetter--lesscomedyandmoreplotandofcourse--actionandsuspense!!!!
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Theplotwasveryst8fowardandbasicwithafewlittletidbitstolivingitup.
# Opinion of 'plot':
# 	 'foward'
#
#
# Sentence:
# 	Theplotisverygood.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	but,unfortunately,theproducersforgettogivethemacredibleplotandinterestingthingstosay.
# Opinion of 'plot':
# 	 'credible'
#
#
# Sentence:
# 	PeoplewhoreviewSpielbergusuallywanttopigeonholehimintoatype:theET-warm-and-fuzzy-alienchildren'sstorytellerversusthespecial-effects-heavy-but-rather-empty-plotdreamer.
# Opinion of 'plot':
# 	 'empty'
#
#
# Sentence:
# 	Theplotisslowtodevelop,characterdevelopmentlackingandanimationprimitiveatbest.
# Opinion of 'plot':
# 	 'slow'
#
#
# Sentence:
# 	Bothfilmshavethesameborringplot.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Maybethenextfewvolumeswillbemorecreativeandgivemoredetailsonthemainplot,butIpersonallydon'tcaretospendanymoreofmymoneyonsucharisk.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Thebad:Notaveryinterestingorprofoundplot.
# Opinion of 'plot':
# 	 'bad', 'interesting'
#
#
# Sentence:
# 	Theplotofthestoryisreallyinteresting.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'horrific'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whiletheplotisnearlyidentical,AlexanderPayne(director)treatshischaractersmuchharsherthanPerrotta.
# Opinion of 'plot':
# 	 'identical'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'horrific'
#
#
# Sentence:
# 	ThestorybeginswithafailedassasinationplotthenfollowsMalciekChelmicki(ZbigniewCybulskiakaPolandsJamesDean)untilit'sconclusion.
# Opinion of 'plot':
# 	 'failed'
#
#
# Sentence:
# 	Episode16:"TheFactofBeingThere"/"AnotherChance"
# Andallattentionbacktothemainplot.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Althoughtheplotisalittlethin,therearesomeveryfunnymoments.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Theplotwas,insomerespects,totallyillogical,andatothertimesnonsensical.
# Opinion of 'plot':
# 	 'illogical'
#
#
# Sentence:
# 	Theplotisentirelyunconvincingandimplausible.
# Opinion of 'plot':
# 	 'unconvincing'
#
#
# Sentence:
# 	Verygoodplotanddetail
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Insummary,themusicportionofthisDVDratesastrongfivestars,butthesillyplotandtheproblemswiththediskdiscussedabove,bringthisDVDdowntoafourstarproduction
# Opinion of 'plot':
# 	 'silly'
#
#
# Sentence:
# 	Theplotisfartoocomplicatedandtwistytogetinto,andfranklyhasbeengoneoverwithafinetoothcombalreadyonthissite.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Unlike,forexample,LOSTHIGHWAY,thisisacompletelyrealisticplot,withnosupernaturalorunexplainableelements.
# Opinion of 'plot':
# 	 'realistic'
#
#
# Sentence:
# 	OnceyoualreadyknowtheoverallplottheDirector'sCutisbetter,andallthestuffthat'saddediniscool,
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Fourth,theplotisslickandoriginal.
# Opinion of 'plot':
# 	 'slick'
#
#
# Sentence:
# 	It'snotasifthefilmwouldbecompletlyalienatingtonewcomers,notatall,itsjustthatifIhadn'treadthebookbeforehand,I'msureIwouldhavefoundthingsabithardertofollow,asthingsmovefairlyquicklyandthere'saneverthickeningplottokeepaneyeon.
# Opinion of 'plot':
# 	 'thickening'
#
#
# Sentence:
# 	Wellthat'sabouttheentireplotofthismovie.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Allheneedstocompletethisisasmallplotofland.
# Opinion of 'plot':
# 	 'small'
#
#
# Sentence:
# 	this1hasastupidplot.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Yojimboisavastlyentertainingactionfilmwithalltheelementsofthatgenre:fastpace,surprisingplotturns,andajustlyfamoussamuraishowdown.
# Opinion of 'plot':
# 	 'surprising'
#
#
# Sentence:
# 	Myfavoritesongis&quot;NeverTalktoStrangers&quot;.Themovieelaboratesontheoriginalstorybyaddingmoreplottospicethestoryup.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Lynchdoesn'tfollowarealplot;instead,heletsthestorylineslowlysinkintoLaura'sdownfall.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Thisfilmisperfectforeveryone,thealluringplot,amazingacting,entertainingscreenplay.
# Opinion of 'plot':
# 	 'alluring'
#
#
# Sentence:
# 	TheplotcanbealittledumbattimesbutChrisTuckeriswhatthismovieisallabout.
# Opinion of 'plot':
# 	 'dumb'
#
#
# Sentence:
# 	Theplotiscomplexenoughtokeepthewatcherguessingwhatexactlywillhappenandnotboretheaudience.
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Badforanyonewhowantshighproductionvalueoranidentifiableplot
# Opinion of 'plot':
# 	 'identifiable'
#
#
# Sentence:
# 	Plentyofaction,plentyofbeautifulsceneryandpeople,ahalfwaydecentplot,plentyoflogicalunpredictability,anditplayswellonthesmallscreen.
# Opinion of 'plot':
# 	 'decent'
#
#
# Sentence:
# 	Irecommendthismovietoanyonewhoislookingforagoodcomedywithaveryfunnyplot.
# Opinion of 'plot':
# 	 'funny'
#
#
# Sentence:
# 	-"LovebeforeBreakfast"isaUniversalproductionandhasthesimplestplotofthecollection;infact,noplotatallreally.
# Opinion of 'plot':
# 	 'simplest'
#
#
# Sentence:
# 	Thefilmcombinestoomanygenresandtheplotbecomesconvoluted.
# Opinion of 'plot':
# 	 'convoluted'
#
#
# Sentence:
# 	Inthistreatmentoftheannoyingplot,heloseshismind.
# Opinion of 'plot':
# 	 'annoying'
#
#
# Sentence:
# 	AnatomyofaMurderisatoncebothadelightfulmysteryandasuspensefulthillerforthosewouldwouldratherthinkaboutallthemanydimensionsandlayersofintriquegoingoninamovieratherthanbespoonfedaformulaicplot.
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Ratherformulaicplot;thedancingisthethinghere
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'thin'
#
#
# Sentence:
# 	Theanimationistotallycool,thekidsarebelievable,theplotisinterestingandhassometwistsandturnstokeepyouguessing,andthedialogisdownrightfunnyattimes.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Theplotisverysimple,thesetsaresimple...butthefilmisgreat.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	CreditneedstobegiventoJamieAnderson'scinematographyandNeilSpisak'sproductiondesignforestablishingsuchaheadyatmosphereperfectforthelabyrinthplot.
# Opinion of 'plot':
# 	 'labyrinth'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Iwon'tre-hashtheplotasAmazonhasalreadyprovidedpotentialbuyerswiththeoutline.
# Opinion of 'plot':
# 	 'hash'
#
#
# Sentence:
# 	Themoviestillhadsappylines,unrealisticplot,andunconvincingelementstoit.
# Opinion of 'plot':
# 	 'unrealistic'
#
#
# Sentence:
# 	Ifyourlookingforanimethathasaction,suspence,romance,humor,andanengagingplotwithlotsoftwistsEscaflowneistheonetoget.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Theplotistooimplausibleandriddledwithinconsistenciestobetakenliterally.
# Opinion of 'plot':
# 	 'implausible'
#
#
# Sentence:
# 	Greatcharacters,awellcraftedplot,andsomeofthebestanimationIhaveeversee.
# Opinion of 'plot':
# 	 'crafted'
#
#
# Sentence:
# 	Theplotisfartooconvolutedtoevenbegintorecount,butthepremiseisthatthesetwounlikelycharactersareabouttobecomein-laws.
# Opinion of 'plot':
# 	 'convoluted'
#
#
# Sentence:
# 	Wonderfullocations,mesmerizingstunts,admirablespecialeffects,averycleverplotandrespectablecastobligatesustoconsiderabsolutelyrecommendable.
# Opinion of 'plot':
# 	 'clever'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Butthereisenoughplottounderstandwhatthestoryisabout.
# Opinion of 'plot':
# 	 'enough'
#
#
# Sentence:
# 	Ienjoyedthismoviebecausetheplotwasverydifferentandnotrunofthemilllikemosthorrormovies.
# Opinion of 'plot':
# 	 'different'
#
#
# Sentence:
# 	TheplotisOKandwithatwistthatshouldn'tberevealedbeforehand
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Themovie"Boo"featuresterribleacting,andadeplorableplot.
# Opinion of 'plot':
# 	 'deplorable'
#
#
# Sentence:
# 	It'snotarevolutionaryplot,andafewscenescouldhavebeenbetterexecuted(theobligatory'break-up'beforethehappyendingisratherweak),butonthewholethemushysideofmeateitup.
# Opinion of 'plot':
# 	 'revolutionary'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Theplotisratherthinandconsistsofthefairyworldtryingtotakeoverthisworld.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	BeeSeason"isjusthorribleandthismoviehasamuchbetterplot,betteractingandabettermessage.
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	IfIhadn'tseentheoriginalI'djustthink,"whatabrilliantplot,toobadtheydecidedtoburyit(nopunintended)witheverythingelseinthemovie".
# Opinion of 'plot':
# 	 'brilliant'
#
#
# Sentence:
# 	belowaverage,thedialoguesarewaybelowaverage,whiletheplotisnotbadatall.
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Theplot isludicrous,thescriptfoolishandinept,theactingsocrudeastobeembarrrassing.
# Opinion of 'plot':
# 	 'foolish', 'ludicrous'
#
#
# Sentence:
# 	Theplotisweakaskingustobelieveincharactersdoingthingsthatnoonewithoneounceoflogicwoulddo(forexample,themotherleaveshomeforafewdaystovisitanauntknowingherhusbandrecentlysluggedhersoninthefacewithoutprovocation).
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Iftheplotwerebetteritwouldbeafilmworthwatching
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	Themovieappealswithitsintricateplot-aningeniouswebawaitedthealmosthelplessWilliamHurt,whowasdazzledbythebeautyofKathleenTurnerandwhosemindwas,nodoubt,slowedbytheintenseheat.
# Opinion of 'plot':
# 	 'intricate'
#
#
# Sentence:
# 	Goodplot.
# Opinion of 'plot':
# 	 'Good'
#
#
# Sentence:
# 	Whetherornotthereactuallyareghostsis,ofcourse,themainplotofthemovie,andtruetothegenreitdancesaroundthequestionforagoodlengthoftimebeforefinallyansweringit.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Itwasnottheactualstory/plot,orit'saccuracythatwasimportanttome.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'straightforward'
#
#
# Sentence:
# 	Criticsarguethattheplotistoocomplicated/clever,butthiswasentertaining,withovertonesofpoliticalconspiracythatmakeyourealizehoweasyitisforthetrulypowerfultomanipulateevents.
# Opinion of 'plot':
# 	 'clever'
#
#
# Sentence:
# 	Foramoreexplosiveride,withamoreentertainingcharacter,andamuchsimplerdrug-inducedandgraphicplot,seetherecentlyreleasedCrank-excellentaction/adventurefromtheTransporterman.
# Opinion of 'plot':
# 	 'simpler', 'induced'
#
#
# Sentence:
# 	JustlikeallDePalmafilms,DressedtoKillfeaturessomeabsolutelybrilliantsequences(elevator,trainstation)dispersedthroughoutaratherclumsyplot.
# Opinion of 'plot':
# 	 'clumsy'
#
#
# Sentence:
# 	SetinWWIILondon,thedarkheartedplotfocusesonNavyLieutenantCommanderCharlesMadison,anespeciallynotoriouspersonalassistanttothementallyunstableAdmiralWilliamJessup.
# Opinion of 'plot':
# 	 'dark', 'hearted'
#
#
# Sentence:
# 	Iamlaughingatthose2starreviewssayinghowAVPisdestroyingtheAlienandPredatorlegacybecauseofitsnonexistentplot.
# Opinion of 'plot':
# 	 'nonexistent'
#
#
# Sentence:
# 	Verysuspenseful,andwonderfullywrittenplotmakethisa5starfilm!
# Opinion of 'plot':
# 	 'suspenseful', 'written'
#
#
# Sentence:
# 	Theplotisfairlysimplewiththetwobrotherstryingtopreventagangofoutlawsfromterrorizingagroupoffarmersandstealingtheirland.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Theplotisnotnew.
# Opinion of 'plot':
# 	 'new'
#
#
# Sentence:
# 	Goodversusevil,ofcourse,buttheplotismoreabouttheclasses.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	TheplotisUNEXPECTED,thatiamnotsureifit'sgoodornot!
# Opinion of 'plot':
# 	 'UNEXPECTED'
#
#
# Sentence:
# 	Theplotisfartocomplicatedtoexplaininareasonableamountoftime,butissumsuptobeaboutabunchofpeople,withcompletelydifferentlifestyles,whosomehowgetthrowntogetherbecauseofabigbombthatlookslikeagarbedgedisposal.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Fromthere,theplotgoesnuts,butthat'sokay,becauseit'swhatmakesBigTroublesuchafunnyandstrangelysmartmovie.
# Opinion of 'plot':
# 	 'nuts'
#
#
# Sentence:
# 	Thisisagoodmoviewithaninterestingplot,goodacting,decentdirectingandapoliticallyreleventcommentontheexcessesoftheUSPress.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Alotofpeopletendtosaythatthisanimeisconfusinganddoesn'thavearealplot.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Ithinkthedirectorneedsprozactodirectthismovie,thewholeplotissomessup,juniorhighstudentcanwritebetterstorythanthis..whatwashethinking.
# Opinion of 'plot':
# 	 'whole', 'mess'
#
#
# Sentence:
# 	Thecharactersaresoveryinteresting(butsubtle),theycouldhavewrittenanyoldplotandIwouldhavewatchedhungrily.
# Opinion of 'plot':
# 	 'old'
#
#
# Sentence:
# 	Whileultimatelythissetofindividualepisodesdoesn'tseemtofurtheranyoverallplot,thecomplexityoftheTachikomasandhowtheyworkisactuallyprettyinteresting.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisalittlethin,butAlyssaMilanoisthereasontowatchthismovie.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Thesewerealllosersbecausetheyhadashallowplot,alackoftalentedactors/actresses,andnomoralfibertothemwhatsoever.
# Opinion of 'plot':
# 	 'shallow'
#
#
# Sentence:
# 	Idon'tknowwhoplaysPatsy,butsheissuperbandthisplotstrandisverypoignant.
# Opinion of 'plot':
# 	 'poignant'
#
#
# Sentence:
# 	Itisthesethemesthatmaketheseriestrulyshine,asthesimplisticoverallplotservesmerelyasavehiclefortheseideas.
# Opinion of 'plot':
# 	 'simplistic', 'overall'
#
#
# Sentence:
# 	Theplotisratherpredictableandyoucouldsensetheendingalmostfromthebeginning.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Theplotisfairlysimple.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	NowobviouslythisissameplotusedintheSantaClause
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	IthasafairlysimpleplotwhichsendsthecharactersrunningaroundNYConenightatChristmastime-eachwithhisorherownmisunderstandingofwhatisgoingon.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Watchtheperfectmurderplotbeingexecuted
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplottothefilmissocomplicatedthatitreallyistoughtokeepupwith,eventhoughtherereallyisn'tthatmuchgoingonthroughoutmostofthefilm.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	ShefindsadischargenoticeinRyu'spants,andthenextthingweknowshehasfiguredouttheentireplot,includingthekidnapping.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Theplotandsupportingcastarebetterthanpassable,thisisn'tatotallybadflick.
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	McGiverhasfallenforKhanandsays,"Iwilldoanything",sellsoutherselftoopower,andagreeswithhisevilplottootakeovertheEnterprise.
# Opinion of 'plot':
# 	 'evil'
#
#
# Sentence:
# 	Thecharacterworkisverygoodandtheplotgetsmoreandmoreinterestingasthemoviegoeson.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	"Stargate"isstilloneofthescience-fictiongreatsthatsuccessfullyblendshistoryandscience-fictioninoneeffectiveplot.
# Opinion of 'plot':
# 	 'effective'
#
#
# Sentence:
# 	ThisDVDofTeentitansthe2ndseasionhasagoodstoryplot,andIforoneloveit!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Nowtothemeatofthereview,theplotinthismovieisn'treallythatgood,butnotveryhorrible.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Notaparticularlyinvolvedplot,butthenI'veseenjustaboutallthereare,butaverynicelittlefilm.
# Opinion of 'plot':
# 	 'involved'
#
#
# Sentence:
# 	Inotherwords,it'sthesimpleBODYSNATCHERSplot.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Moreplot,morestory,moregore(gettheunratedversion)andmoreJASON!
# Opinion of 'plot':
# 	 'More'
#
#
# Sentence:
# 	TheplotisratherShakespearean--themixupoflovers--buteverythingturnsouthappilyintheend.
# Opinion of 'plot':
# 	 'Shakespearean'
#
#
# Sentence:
# 	Nottomentionit'snotexactlythemostcliche-freeplotasthere'ssomescenesthataregoingtobeobviousandwhentheyhappentheydon'treallysurprise(apossibleromancebetweenJohnandFlor,Deborahandhermotherhavinganall-outorjealousyamongFlorandDeborah)butthefilm'sentertaininganyway.
# Opinion of 'plot':
# 	 'free'
#
#
# Sentence:
# 	Theunconvincingcharacterizationsandhackneyedplotarelostinawelterofstrikingincidentaldetails:hundredsofglassbaublesrollingdownastaircaseandintothebloodywaterofasuicidevictim'sbathtub,beingaparticularlyimpressiveexample.
# Opinion of 'plot':
# 	 'hackneyed'
#
#
# Sentence:
# 	Poorplot,script,acting
# Opinion of 'plot':
# 	 'Poor'
#
#
# Sentence:
# 	Greataction,engagingplot,greatcinematography.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Moreblood,nudity,violence,swearing,andsexthanthefirstmovie,lessplotandcharacterization.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	REDPLANETunfortunatelyneededmorethanitsminimalistplottocarryit.
# Opinion of 'plot':
# 	 'minimalist'
#
#
# Sentence:
# 	Thefilmisatreat,especiallythefirsttimearound,despiteacomplicatedplotandanunderachievingstoryline
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Thisplotismucheasiertodigestonscreen.
# Opinion of 'plot':
# 	 'easier'
#
#
# Sentence:
# 	Theplotisgreat,theactingisoverthetop,andthecinematographyisfantastic.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whichonewillgettheirman,aninterestingsub-plot?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Itwasn'tthesameoldboringplotasthereweremanyunexpectedturnsandmisadventuresintheplot.
# Opinion of 'plot':
# 	 'same', 'old', 'boring'
#
#
# Sentence:
# 	Thisisn'tanewplot;You'veseenthis,insomeformoranother,severaltimes.
# Opinion of 'plot':
# 	 'new'
#
#
# Sentence:
# 	Aftertherecentspateofrubberrealityfilmsthatallusedessentiallythesameplot--includingStay(2005),TheJacket(2005),November(2004),TheIInside(2003),andeightornineothersgoingatleastallthewaybacktoJacob'sLadder(1990)andtheshortTheAwakening(1990)--TheDarkHoursveryrefreshinglyusesdifferentkindsoftwistsinitsquestionablyhallucinatorysuccessionofscenes.
# Opinion of 'plot':
# 	 'same'
#
#
# Results for aspect word 'characters'
#
# Sentence:
# 	Thecharacterstalkabouttherelativeintelligenceoftheothercharactersorhowtheothercharacterscan'tpossiblyknowwhatisgoingon.
# Opinion of 'characters':
# 	 'other', 'other'
#
#
# Sentence:
# 	ThereareonlytwoBlackcharacters,bothsentimentallyloyaltotheirSouthernnessandtheirmasters;otherwise,slaveryisbesidethepoint.
# Opinion of 'characters':
# 	 'Black', 'loyal'
#
#
# Sentence:
# 	whenlessthanhalfwaythrough,thestorybecomessomethingutterlyunrecognizablefromtheoriginal,severalkeycharactersarelumpedtogethermostconfusingly,andotherslosealltheircomplexcharm.
# Opinion of 'characters':
# 	 'several', 'key'
#
#
# Sentence:
# 	Ifeltthatwithinallthetimeitran,wedidn'treallygetagoodunderstandingoftheinnerbeingofthemaincharacters;seemedtoremaininshallowwatersallalong.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Otherreviewershavecommentedonthebad,infomerciallevelactingofthetwoleadcharacters.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	"ConExpress"haslotsofactioninit,whichisgreatbecausethishidesthepoorwritinganduninterestingcharacters.
# Opinion of 'characters':
# 	 'writing'
#
#
# Sentence:
# 	ThemoviegetsboringratherfastasBetteandWoodyaretheonlyoneswegettoseeasthereareveryfewsupportingcharacters.
# Opinion of 'characters':
# 	 'few', 'supporting'
#
#
# Sentence:
# 	Thesedisjointedglimpsesdon'tgivetheviewertimeordepthtocarewhathappenstoanyofthespoiledrottencharacters.
# Opinion of 'characters':
# 	 'spoiled', 'rotten'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Thecharactersarethinatbest,andstockatworst.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Can'trememberwhenI'veseenafilmwithmoredepravedandpatheticcharactersthanthis.
# Opinion of 'characters':
# 	 'depraved'
#
#
# Sentence:
# 	ThecharactersareunlikeableexceptforCharity'stwofriends.
# Opinion of 'characters':
# 	 'unlikeable'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Forgoodcounterexampleswatch"Trainspotting",whichhasdrug-addictcharacterswithenoughhumorandlifetobelikableandinterestingand"BubbaHo-Tep",afilmwhichdisplaystheplightofthelonelyelderly50timesbetterthanthisfilmdespitebeingasillyhorror-comedywithamummyinacowboyoutfitinit.
# Opinion of 'characters':
# 	 'addict'
#
#
# Sentence:
# 	NowthatthesetediouscharactershavefinallyhitrockbottomIcangodosomethingelse.
# Opinion of 'characters':
# 	 'tedious'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	AnarrativelikeGettysburgthatgoesbackandforthbetweenafewcentralcharactersinalogicalsequencewithoutallthehamfistedattemptsaproselytizingandallthenoblesseoblige.
# Opinion of 'characters':
# 	 'few', 'central'
#
#
# Sentence:
# 	Iwaswatchingthesametwocharactersfightthroughthesametwochallengesinthisfilm.
# Opinion of 'characters':
# 	 'same'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'characters':
# 	 'obscure', 'secondary', 'main'
#
#
# Sentence:
# 	Ifhewouldhavetightenedthescript,createduniqueand"cult-like"characters,andeliminatedtheracism,hemayhavehadthequintessential"weed"filminHollywood.
# Opinion of 'characters':
# 	 'unique'
#
#
# Sentence:
# 	Hediscoversanewtalent(artistChristinaMilian)andworkshiswaythroughanassortmentofcharactersthataremoretypesandclichesthanrealcharacters.
# Opinion of 'characters':
# 	 'real'
#
#
# Sentence:
# 	Thesoundismurkyandundecipherable,theactingisstrictlyamateurhour,thecharactersarepaper-thinwithnodistinctionorpurpose,thestoryisnon-existent,thedialogueisacompletelyworthlessbore,there'snothingremotelyscary,andthespecialeffects(includingacoupleofcomputereffectsthatlookliketheyweremadeonaCommodore64)arelaughable.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Nothinghappensinthismovie(andImeannothing)exceptabunchofsullencharactersexhanging"comic"glancesandlookingwithdrawnandcynical.
# Opinion of 'characters':
# 	 'sullen'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'characters':
# 	 'same'
#
#
# Sentence:
# 	It'sastudyincontrasts,andit'sdoneimpeccablyinthenovel,withaplethoraofcomplexcharacterstorichenthejourney...
# Opinion of 'characters':
# 	 'complex'
#
#
# Sentence:
# 	Realcharacters?
# Opinion of 'characters':
# 	 'Real'
#
#
# Sentence:
# 	Therestofthisfilmconsistsoftheear-bleedingwhinesandyawn-inducinginfightingofthehumancharacters,ill-conceivedandextremelyunlikablecaricaturesofapseudo-cynicalandextremelyredundant"evilsideofhumannature"messagethatwouldbebetterlefttoJeanRenoir(orevenAdamSandlerconsideringtheresultshere).
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	Iguessit'ssupposedtodepictthehorrorofrepressivereligiousvalues,andwhileIdon'tcondonethose,thefilmlacksclearcharactersoranymotivation.
# Opinion of 'characters':
# 	 'clear'
#
#
# Sentence:
# 	ItiseasytogetsuckedintowatchingGantz,becauseoftheuniqueandinexplicablesituationthatthemaincharacters,whohavealldied,findthemselvesin.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	Thecharactersaresolame
# Opinion of 'characters':
# 	 'lame'
#
#
# Sentence:
# 	Thecharactersare,overall,blandandjustplainuninteresting(e.g.RickAndersonplayedbythe"fool,"TedRaimi,fromtheXenaseries).
# Opinion of 'characters':
# 	 'bland'
#
#
# Sentence:
# 	andIdidn'tcarewhatwouldhappenwiththemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Ireadthebookandsawthemovie,whichotherthantitleandmajorcharacters,havelittleincommon.
# Opinion of 'characters':
# 	 'major'
#
#
# Sentence:
# 	Theminorcharacters,includingthewonderfulTracieThomsas"bestfriend"Lily,aremostlywasted.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	ThebigproblemwithRHisthatneitherFordorBenningaresympatheticcharacters.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Theproducersofthisfilmareoutoftheirmindiftheyexpectanyviewerwho'snotscrewed-upintheheadtofeelsorryforthetwostupidmaincharactersjustbecausetheirsick,incestuous,andadulterouslifestyleisincompatiblewiththeworldtheylivein.
# Opinion of 'characters':
# 	 'stupid', 'main'
#
#
# Sentence:
# 	Tooimplausible,toomanyoverdrawnsecondarycharacters.
# Opinion of 'characters':
# 	 'implausible', 'overdrawn', 'secondary'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	WhoevermasteredthisgreatfilmRUINEDitbyFORGETTINGorREFUSINGtoprovideEnglishsubtitlesfortheJapaneseandItaliancharacters.
# Opinion of 'characters':
# 	 'Japanese'
#
#
# Sentence:
# 	Occasionallywegetashotofsomeoftheothercharacters.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	We'resupposedtofindthecharactersplayedbyRobertRedfordandDebraWingertobeamusing,theiracrimoniousrelationshiptobehilarious,andthewaythattheyendupbeingpartnersdespiteallofthegibestoberomanticallysatisfying.
# Opinion of 'characters':
# 	 'amusing'
#
#
# Sentence:
# 	Long,tediousactionadventurewithrepetitivedialog,badplotholes,andgenerallyboringcharactersishowtodescribethislittleforayintofollowingupthecharactersfromBadBoys.
# Opinion of 'characters':
# 	 'boring'
#
#
# Sentence:
# 	It'samazinghowsomuchmoneyandeffortgointospecialeffectsandexpensivesetsandthescriptitselfishollowwithlousycharacters.
# Opinion of 'characters':
# 	 'lousy'
#
#
# Sentence:
# 	Anditdoesn'tonlycenteraroundthemaincharactersbuthasagreatensemblecastofveryinterestingpeople!
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Haspleasantcharacters;butnotdeep.
# Opinion of 'characters':
# 	 'pleasant'
#
#
# Sentence:
# 	Itsjustbadactingwithstupidandmeancharacters.
# Opinion of 'characters':
# 	 'stupid'
#
#
# Sentence:
# 	Rivkabecomeshercousinandothercharactersareneglectedcompletely.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Afterorbeforekeyscenes,thecameracutstoamonologuefromoneofthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Toitscredit,theactorsdidwhole-heartedlyportraygaycharactersandgaylovescenes.
# Opinion of 'characters':
# 	 'portray', 'gay'
#
#
# Sentence:
# 	Atthetime,gaycharacterswereneverportrayedinapositivelightfromthemedia,anditwasagreatrisktodosohere.
# Opinion of 'characters':
# 	 'gay'
#
#
# Sentence:
# 	CertainlynottheweirdIrishaccentstheleadcharactersadopted.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Theothercharactersarelikewiselackinginrealism,onlyJanetMcTeerfareswell
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Mightbesuitedmoreforanolderchildbutmineis13monthssotherehastobeconstantcolorfulcharactersforhertobeinterested
# Opinion of 'characters':
# 	 'constant', 'colorful'
#
#
# Sentence:
# 	Theplotlinewasnonexistent,andthecharacterswerecompletelyunlikeable.
# Opinion of 'characters':
# 	 'unlikeable'
#
#
# Sentence:
# 	istartedlikingthismovie,ithoughtthepinballmetaphorandwildcharactersandlifesacartoonshizcouldhaveworkedout,ifitwerentforthefactthatbakshiisthinlydisguisinghimselfandhisownfrustrationasbeinganunoriginal"underground"cartoonistwhocaughtontothescenetoolate...ifyoulikethedepressing,gritty,wild,fastpacedstyleofthismovie,checkouttheoriginalmasterROBERTCRUMB,towardwhombakshiisobviouslyseethingwithjealousyandridinganxiouslyonthecoattailsof...
# Opinion of 'characters':
# 	 'wild'
#
#
# Sentence:
# 	Everyminutecharactersinthisseriestrytoremindyouofsomeplotpointasifyou'reashort-attentionspancoachpotatoe.
# Opinion of 'characters':
# 	 'minute'
#
#
# Sentence:
# 	butthenthefilmbasicallyspendstoomuchtimezigzaggingaroundtoallthedifferentcharactersandlocales.
# Opinion of 'characters':
# 	 'different'
#
#
# Sentence:
# 	Itseemstoberidingonit'slaurels,sotospeak,andit'salmostasifwearesupposedtofindthecharactersactingdifferentlyfunny.
# Opinion of 'characters':
# 	 'funny'
#
#
# Sentence:
# 	Butthecharactersarenotsympathetic,funorinteresting.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Thereisnohumor,nolikablecharacters,notevenadecentquoteoroneliner.
# Opinion of 'characters':
# 	 'likable'
#
#
# Sentence:
# 	Therearetwonewsupportingcharactersthistime,Loisand,erm...Jason.
# Opinion of 'characters':
# 	 'new', 'supporting'
#
#
# Sentence:
# 	SheisagreatalternativetoBarneyandalloftheothercommercialcharacters,whoIdon'tcaremuchfor.
# Opinion of 'characters':
# 	 'other', 'commercial'
#
#
# Sentence:
# 	Thestoryissimple,butinthehandsofthewritersWendyHammondandBobGosseandwithGosse'sfinedirection,theentirecastgivesusanensembleofdisparatecharactersinwhomwecanallbelieve.
# Opinion of 'characters':
# 	 'disparate'
#
#
# Sentence:
# 	Theactionisoffthewallwiththetwomaincharacterstreatingustotwostylesoffightingthataretheveryantithesistoeachother.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	In"TheManWhoWasn'tThere,"thephrase"decisiveaction"isanoxymoron;everythingCraneandtheothercharactersdoisgovernedsolelybychance.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Alongthewayheencountersahostofintriguingcharacters,includingacrazy-like-a-foxentrepreneurialbushpilotlookingtomakesomesortofbigscore,anumberofwackybitplayerswhoIcaneasilyimaginewerenotactors,buttherealdeal,andeverybitaseccentricastheyappeared;andanendearinglysageoldInuitoffewwordsbutmanyeloquentsilences.
# Opinion of 'characters':
# 	 'intriguing'
#
#
# Sentence:
# 	Thefilmdepictstheevolutionofthesevariouscharactersastheycometotermswiththeprogressionoftheirlovelivesandprofessions.
# Opinion of 'characters':
# 	 'various'
#
#
# Sentence:
# 	PlotsbasedonbooksbyElmoreLeonardtendtobeaboveaverage,butaremostlydependentuponthecolorfulcharactershewrites.
# Opinion of 'characters':
# 	 'colorful'
#
#
# Sentence:
# 	NotonlydoesthemovieSignsofferawonderfullydifferentkindofalien/ufotale,butitscharactersareverylikableandthestoryisaboutmuchmorethanaliensfromanotherplanet.
# Opinion of 'characters':
# 	 'likable'
#
#
# Sentence:
# 	TheclassicWordsworthpoemfromwhichthefilm'stitleisderivedmakesafittingcodaforthismovie,andIstillfeeltheintractablesenseoflonginginthetwoleadcharacterseverytimeIseethismovie.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Bothmoviesareprettysimilartoeachother...but"BloodIn,BloodOut"kindafocusesonthe3brothers,andthepathseachofthemtakes,whereas"AmericanMe"focusesonthepathsofthemaincharactersinthismovie(likeSantana,Puppet,Lil'Puppet,etc)..butnotonlydoesitshowtheirlifestyles,butitalsofocusesonhowitshavinganeffectontheirfamilies,andhowtheirfamiliesfeelaboutthelifethattheirkidsareleading..."AmericanMe"ithinkinvolvesmoreofthefamilyinthispictureandculture(LaRaza)then"BloodIn,BloodOut"does...
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	becuasethisoneseemstohavealotmoreofastorylinetoit,andmorecharactersitsfocusingon...bothinandoutsidetheprisonwalls..
# Opinion of 'characters':
# 	 'more'
#
#
# Sentence:
# 	Therearemanygoodsupportingcharacterssuchas:BridgetFonda,WoodyHarrelson,BarnardHughesandJulieWarner
# Opinion of 'characters':
# 	 'many', 'good', 'supporting'
#
#
# Sentence:
# 	Themaincharactersalmostentirelyhavehopes,aspirations,andattachmentsbeyondtheratherclosedworldoftheirprofession--Jack'sdesiretobeaseriousfilmmaker;Dirk'sridiculouspseudo-KarateandReed'sequallyridiculouspoetry;Buck'sgoalofopeninghisownstereostore;Amber'sattemptstogetbackintouchwithherson,whichsheblatantlycompensatesforbymotheringherco-stars--helpingusseethemasfleshed-outcharacters,notjustplotdevicesinthestory.
# Opinion of 'characters':
# 	 'main', 'fleshed'
#
#
# Sentence:
# 	Thecharactersarenotsointerestingnoristheacting.
# Opinion of 'characters':
# 	 'interesting'
#
#
# Sentence:
# 	Anothergreataspectoftheshowistheyarenotafraidtokilloffmaincharactersthatyougrowtoloveontheshow,soyouwillnevernowwhatisgoingtohappennextwhichkeepsyouwantingmore.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Itisabeautifulheartwarmingmovie,withgorgeousscenery,unforgettablecharacters,andplentyofmomentstolaughandcry
# Opinion of 'characters':
# 	 'unforgettable'
#
#
# Sentence:
# 	Again(asI'vesaidinotherofmyreviews),minorcharactersareimportant.
# Opinion of 'characters':
# 	 'minor', 'important'
#
#
# Sentence:
# 	AnotherpartofthestoryIfoundannoyingwasthelackofcommunicationbetweenthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Thoserepresentthemaleandfemaleviewpointsofthemaintwocharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Butifyouseethemovieasbeingabouttwointerestingcharacters,passitby.
# Opinion of 'characters':
# 	 'interesting'
#
#
# Sentence:
# 	Itismuchbetterthanhavingdifferentactorsplayingoldcharacters,whichdragsamoviedownalot.
# Opinion of 'characters':
# 	 'old'
#
#
# Sentence:
# 	The"bad"charactersareallprettylikeable,asidefromone,andalliswellintheend.
# Opinion of 'characters':
# 	 'bad', 'likeable'
#
#
# Sentence:
# 	"CinderellaII:DreamsComeTrue"isaseriesofthreestoriesfeaturingmostlycharactersfromtheoriginalCinderellaandafewnewones.
# Opinion of 'characters':
# 	 'mostly'
#
#
# Sentence:
# 	InoneofthemosthilariouscharactersI'veeverseenportrayedonscreen,wemeetDr.Strangelove(PeterSellers,yetagain)astrategistaidingthepeopleintheWarRoom.
# Opinion of 'characters':
# 	 'hilarious'
#
#
# Sentence:
# 	Thecharactersareallverylikeable.
# Opinion of 'characters':
# 	 'likeable'
#
#
# Sentence:
# 	Therearelittleromanticmomentsbetweenthemaincharactersthatmaketheshowmoreinteresting.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Themovietrieshardtofindthehumorinhitmenandquirkycharacters,butitoftenseemstobetryingabittoohard.
# Opinion of 'characters':
# 	 'quirky'
#
#
# Sentence:
# 	Also,whilemostBBCproductionsofliterarymasterpiecesarestudiesinsocialconservatismthisoneobviouslyidentifieswithandinvitesustoidentifywithitsmostirreverentandforward-thinkingcharacters:inthiscasethesultryandsophisticated,andsomewhatlibertine(ina1920'skindofway),LadyChatterly&theearthyandirreverentandsmoldering(smolderingbothwithclassresentmentandwithlustforaladyfromtheoppressiveclass)OliverMellors.
# Opinion of 'characters':
# 	 'irreverent'
#
#
# Sentence:
# 	Uniqueapproachtothesubject,charactersthatareflashyyethumanwithrealemotion,charactersplayedbyJulianneMoore,DonCheadle,HeatherGraham,WilliamH.Macy,andBurtReynoldsrespectfully,aregreattowatch.
# Opinion of 'characters':
# 	 'great'
#
#
# Sentence:
# 	Thecharactersaresowonderfullyindividual,fromself-absorbedKuzko,toevilYzmawithher"secretlab",todimwittedKronkwithhisshoulderangelanddevil
# (Secondly,lookwhatIcando.
# Opinion of 'characters':
# 	 'individual'
#
#
# Sentence:
# 	It'sagoodcombinationofamusicalandastorywithgoodcharactersandcharactersthatdonotmakegoodchoices:-)
# Opinion of 'characters':
# ...
# Opinion of 'dialogue':
# 	 'cliched'
#
#
# Sentence:
# 	Itisaverydialogue-heavyfilmandthedialogueisnotwell-writtenenoughtocarryitoff.
# Opinion of 'dialogue':
# 	 'written'
#
#
# Sentence:
# 	Throwinlotsoftortureddialogueaboutalternativeconsciousnesses/universes/fuelsupplies/sugarsubstitutes.
# Opinion of 'dialogue':
# 	 'tortured'
#
#
# Sentence:
# 	Thedialogueisdifficulttofollowespeciallysincemostofitismeaninglessanyway,andthefilmneverreallyfollowsit'spremiseasmuchasitshould:theriseofFactory.
# Opinion of 'dialogue':
# 	 'difficult'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'unbelievable'
#
#
# Sentence:
# 	Iunderstoodtheplot,andenjoyedsomeofthethoughtsraisedneartheend,butoverallwasboredsillybystilted,pointlessdialogue.
# Opinion of 'dialogue':
# 	 'stilted', 'pointless'
#
#
# Sentence:
# 	WhileBaldwinandtherestofthecastdidwellinfleshingoutBurke'scharactersandhavesometangytough-guy/galdialogue,they'rehamperedbytwothings:
#
# 1.)
# Opinion of 'dialogue':
# 	 'tangy'
#
#
# Sentence:
# 	Gooddialogueislikegoodacting:ifit'sreallygood,youdon'tnoticeituntiltheshow'sover.
# Opinion of 'dialogue':
# 	 'Good'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	soI'msupposedtobelievethatthehorribledialogue,badacting,andridiculousplottingisonpurposejustbecauseMametisarespectedguy?
# Opinion of 'dialogue':
# 	 'horrible'
#
#
# Sentence:
# 	Thedialoguewouldhavebeen1000timesbetter.
# Opinion of 'dialogue':
# 	 'better'
#
#
# Sentence:
# 	It'sthewaythestoryistold-itsham-fisteddialogueandplot,itsforcedobscenityateveryturn-thatrevealsitsteensensibilities.
# Opinion of 'dialogue':
# 	 'fisted'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	Thetwodimensionalniceoldbrotherandsisteraretreatedhorribly,fornogoodreasonwithnomotivationorpayoff,thesongsareunlistnableandthedialogueishardtounderstand,thisisnotalwaysabadthing.
# Opinion of 'dialogue':
# 	 'hard'
#
#
# Sentence:
# 	Youdon'tgotothesemoviestoexpectwell-writtendialogue,characterdepthoranything,youcomeforthekillsandtotellyouthetruth,they'reslightlydisappointing.
# Opinion of 'dialogue':
# 	 'written'
#
#
# Sentence:
# 	Theunwittydialoguetriestobecleverallthroughoutthemovieandisjustsoooboring.
# Opinion of 'dialogue':
# 	 'unwitty'
#
#
# Sentence:
# 	Thedialoguewassharpandyoumighthavetowatchtwicetogetallthesubtlequips.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueiswonderfullyexpressiveandgivesusthesenseofauthenticityandthekindofrealisticeffectseenonlyintheverybestfilms.
# Opinion of 'dialogue':
# 	 'expressive'
#
#
# Sentence:
# 	Thecolorsaredark,thedialoguebetweenthecharactersishonest,realandsimplywonderful.
# Opinion of 'dialogue':
# 	 'honest'
#
#
# Sentence:
# 	thisepisodehasalotoffunnydialogue,butthat'stheonlythingithasworkingforit.
# Opinion of 'dialogue':
# 	 'funny'
#
#
# Sentence:
# 	Inconclusion,thisTVshowhasitall:goodbackgroundmusic,greatdialogue,interestingstories,goodacting,andinterestingcinematography.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	Thedialogueissharpandwitty,althoughthere'salotofswearing,thatdoesn'tmeanthehumourisjustfowlmouthed,it'shillarious,someofthelinesgodowninhistoryassomeofthefunniestonelinersever.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Inanerawherecinematicpalatesseemtitillatedmostlybyfastactionthrillers,thismovieisanotherexampleofhowwellconstructeddialoguemakesforgrippingcinematicdramawhenitgoeshandinhandwithsuperbcastingandperformance
# Opinion of 'dialogue':
# 	 'constructed'
#
#
# Sentence:
# 	You'llbesuckedin,andsurprised,withinthefirsttwominutes,andthere'sverylittledialogue
# Opinion of 'dialogue':
# 	 'little'
#
#
# Sentence:
# 	Itseemsraretodaytofindsuchrichdialogue.
# Opinion of 'dialogue':
# 	 'such', 'rich'
#
#
# Sentence:
# 	OtherPeople'sMoneyisawonderfulmovie,fullofsmartdialogue,goodmusic,andaterrificDannyDeVitoperformance.
# Opinion of 'dialogue':
# 	 'smart'
#
#
# Sentence:
# 	Thedialogueisn'thard-boiledexceptforafewlinesdeliveredbyVicky.
# Opinion of 'dialogue':
# 	 'boiled'
#
#
# Sentence:
# 	iappreciatedtheeffects-nicetouch-butiwouldhavelikedtoseesomerealdialoguethere.
# Opinion of 'dialogue':
# 	 'real'
#
#
# Sentence:
# 	Relyingonsharpdialogueandfacialexpressions,theactorsmanagetoweaveagorgeoussensualdancetogether,bothlightingupthescreenandcreatingtwoofthemostsmolderinglycomplexcharacterseverseeninfilm.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	The'plain'dialogueamongthe'elders'ispainfullynumbing,choppy,andstilted.
# Opinion of 'dialogue':
# 	 'plain', 'numbing'
#
#
# Sentence:
# 	Thesoundtrackisawesome,thecinematographyisgreat,thedialogueisrealistic,andforonce,amoviesetinaforeignlandthatactuallyusesactorsfromthatareaspeakingthelanguageofthatarea!
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thismovieisweak,poorlywrittenandhassomelaugh-out-loudstereotypicalcop-schlockdialogue.
# Opinion of 'dialogue':
# 	 'loud'
#
#
# Sentence:
# 	(Thescript,bytheway,isonegreatlineafteranother,withverynatural,effortlessdialogue.
# Opinion of 'dialogue':
# 	 'natural', 'effortless'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Thestoryisfilledwithbiglaughs--fromcrudehumortosomeofthemostintelligentdialogueI'veprobablyeverheard.
# Opinion of 'dialogue':
# 	 'intelligent'
#
#
# Sentence:
# 	Thesurrealhumourandoff-kilterandunusuallybizarrehumourhasseducedthosethatlikeamixtureofpsychicalcomedy,comicinnerdialogue,aswellascrackingoneliners,mixedwiththeoccasionalrelativelyserioussubjectmatters,andphasesthatcanberecitedamongstfellowfans,tomuchamusement.
# Opinion of 'dialogue':
# 	 'comic', 'inner'
#
#
# Sentence:
# 	Thewritingissmartandwitty,thedialogueischarming,theperformancesaregreat.
# Opinion of 'dialogue':
# 	 'charming'
#
#
# Sentence:
# 	Thedialoguethroughoutwastediousandtrite;thescriptwritershouldbeontheunemploymentline,aswellasthedirectorandtheeditor.
# Opinion of 'dialogue':
# 	 'tedious'
#
#
# Sentence:
# 	Therereallywasn'tmuchanimosityfromeithersideofthe spectrum,rathertherewasalotofwell-intentioneddialoguefrombothsidesthatwouldgiveanybody,regardlessofpoliticalpersuasion,betterinsightintotheissuesinIraqandtheMiddleEast
# Opinion of 'dialogue':
# 	 'intentioned'
#
#
# Sentence:
# 	Ithasgreatfundialogue,isverytechnicallymodernforitstime,extremelyentertaining,fastpaced,andanabsolutejoytowatchthisCLASSICfilm~WHATATREAT!!
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thedialoguetoisequaltothatof"Coctail"-pointless,beentherebefore,densedialogue.
# Opinion of 'dialogue':
# 	 'equal', 'dense'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'unbelievable'
#
#
# Sentence:
# 	MarvellousdialoguebyBolt.
# Opinion of 'dialogue':
# 	 'Marvellous'
#
#
# Sentence:
# 	SetintheSouth,startingintheearly1950s,andasaSouthernermyselfIparticularlyenjoyedtheauthenticdialogue.
# Opinion of 'dialogue':
# 	 'authentic'
#
#
# Sentence:
# 	Thedialogueiswonderful,alloftheperformancesaresuperb,andCapra'sdirectionareexcellent.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	DotDrequiresabraintoenjoyasitisNOTaslambangshoot'emupwithditzydialoguetofillinthegorescenes.
# Opinion of 'dialogue':
# 	 'ditzy'
#
#
# Sentence:
# 	Themiddlesectionisadmittedlyratherdialoguebased,butthisdialogueisneverboringandservestoillustratewhythelivingdeadfeeltheneedtochompdownonwarmflesh.
# Opinion of 'dialogue':
# 	 'boring'
#
#
# Sentence:
# 	(He'smuchbetteronHOUSE,wherehegetssomerealcharacterizationandinfinitelybetterdialogue.)
# Opinion of 'dialogue':
# 	 'better'
#
#
# Sentence:
# 	Ifthedialoguewasn'twitty,festivalaudienceswouldn'thavegonenuts.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Stonecombinessuchwild,lush,andcrazyfilmeditingtodepictthemindsofVickeyandMallory,crazydialogue,uniquestorytelling,andallthewhilepokingfunathowweasthepeopleandthemediagocrazyforit.
# Opinion of 'dialogue':
# 	 'crazy'
#
#
# Sentence:
# 	ThefilmisslightalthoughitbenefitsfromsomesharpHermanMankiewiczdialogue.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Manyclose-upshotsofherbarechest.(d)HighlyXXXdialogue,suchasthelinewhere11yearoldViolettellshercustomerthat"Icanfeelthesteamjustcomingthrumydress"(e)
# Opinion of 'dialogue':
# 	 'bare'
#
#
# Sentence:
# 	Themovieisactionpackedwithexcellentdialogueandtheactionneverstopsuntiltheveryappropriateend.
# Opinion of 'dialogue':
# 	 'excellent'
#
#
# Sentence:
# 	Andthedialogueiscertainlymemorable:
#
# JackBull:
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Itmakesyouquestionwhyyoubuyintosuchsappydialogueandsituations.
# Opinion of 'dialogue':
# 	 'such', 'sappy'
#
#
# Sentence:
# 	Whilewatching,inmyheadIwasfillinginthedialogueforthecharacters,andmydialoguewasalotmoreinterestingthananythingthesepeoplesay.
# Opinion of 'dialogue':
# 	 'interesting'
#
#
# Sentence:
# 	ThoughIcannotdenythatitisunbelievablycheesy,filledwithpracticallyeveryclicheonecanimagineandcontainstonsofembarrassingdialogue(especiallyKurtRussell'sbeggingspeech)andunconvincinglovescenes(Mel,willyoupleasekissherlike
# Opinion of 'dialogue':
# 	 'embarrassing'
#
#
# Sentence:
# 	Thedialogueisveryfunnyandwittyattimes.
# Opinion of 'dialogue':
# 	 'funny'
#
#
# Sentence:
# 	Rarelyhassomuchbeensaidsosuccessfullywithsolittledialogue.
# Opinion of 'dialogue':
# 	 'little'
#
#
# Sentence:
# 	AlthoughI'msureyouwillwanttoseewhathappenedtoallofyourfavoritecharacters,yourhopeswillcertainlybedashedanddisappointedbyapoorstoryandpoordialogue
# Opinion of 'dialogue':
# 	 'poor'
#
#
# Sentence:
# 	Thedialogueisoftenunconvincingandoneoccassionallytiresoftheconstantneedinmoviemakingtouseeachcharachterasanarchetype.
# Opinion of 'dialogue':
# 	 'unconvincing'
#
#
# Sentence:
# 	ThesheeraudacityofthistaskisahallmarkofChayefsky'svitriolicstyle,andthefilmisfullofhisbrittle,observantdialogueandsharplyarticulatesoliloquies.
# Opinion of 'dialogue':
# 	 'observant'
#
#
# Sentence:
# 	Here,inthismovie,you'vegotagoodcast,cooldialogue,andanon-stopactionthrillride.
# Opinion of 'dialogue':
# 	 'cool'
#
#
# Sentence:
# 	AnyonefamiliarwithTheSimpsonswillenjoythehumorinOlive,TheOtherReindeer,aswellastheanimationandwittydialoguethatpassesquicklyinthisforty-fiveminutemovie.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Allinvolverichdialogueandinterestshown.
# Opinion of 'dialogue':
# 	 'rich'
#
#
# Sentence:
# 	First,thedialogueandsituationsaresoinsipidtheyofteninspireunintentionalhilarity.
# Opinion of 'dialogue':
# 	 'insipid'
#
#
# Sentence:
# 	Withoutcontrivedmanipulations,youaredrawnintothedepthsandheightsoftheiremotionsthroughtheuseofstunningvisuals,dramaticportrayals,pithydialogue,momentsofquietcontemplation,andaserenemusicalsoundtrackthatisworthowningonitsownmerits.
# Opinion of 'dialogue':
# 	 'pithy'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Ithashistrademarkrealisticdialogueandwithoutanyflashyeffectshefocusesonthecharacters.
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thedialogueiswarmandwittyandtheactorsarewonderful.
# Opinion of 'dialogue':
# 	 'warm'
#
#
# Sentence:
# 	Allen'sdialogue(whichisalwaysgood)isparticularlygoodintheconversationsbetweenIsaacandMary;ThefinalscenebetweenIsaacandTracyisalsoverymeaningfulandverygood.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	LiketheothermoviesthereissomegreatdialogueinthismovieandIhighlyrecommendthemovietofansofChrisFarley,ChrisRockandSNL.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Yes,themoviehasflaws:thedialoguecanbealittlegoofyattimes,theactingsomewhat-shallwesay-idiosyncratic,thespecialeffectsdon'talwayswork,andtheinternallogicisnotalwaysapparent(theGrailisArthur?
# Opinion of 'dialogue':
# 	 'goofy'
#
#
# Sentence:
# 	Withcringinglyawfulacting,laughablespecialeffects(theridiculousheadinabucketisarealguffawmoment),appallingdubbeddialogue,cheesymusic,inconsistentandconfusingplotandnotensionoratmosphere,TheGrimReaperisatotaldisaster.
# Opinion of 'dialogue':
# 	 'dubbed'
#
#
# Sentence:
# 	Theearlypartofthisfilmisfilledbothwithsnappy,intelligentdialoguebutalsowithasophomoricphysicalcomedywhichcanhonestlybeconsideredtobeatorbelowapie-in-the-facelevelofsophistication.
# Opinion of 'dialogue':
# 	 'snappy', 'intelligent'
#
#
# Sentence:
# 	Betweenincrediblybaddialogueaboutthingslikethe"plutonium-rubycrystalbeamgun,"sillyincidentalmusic,andaVenusianmadeoflatex,twigs,andtissuepaper,thisonecannotbebeat.
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	Baumbach'sscreenplayboastslotsofmemorabledialogue,lotsofclevernessyoumightfindyourself"borrowing."
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	Thegreatsweetbeautyofthisfilm,however,isthemarriageofsuchengagingdialogue,suchearnestdeadpandeliveriesshotinsucheerieclarity--onereminiscentoftheinteriorsinDutchgenrepainting:clean,homely,homiletic.
# Opinion of 'dialogue':
# 	 'such', 'engaging'
#
#
# Sentence:
# 	Itmanagestoturnasuiteofclassicallystaticimages-bronzed,burnished,melancholy-uponafast-drivingdialogueendowedwiththemodestbutenhancingartificialityofapainting,anovelor--betteryet--aninfinitelyrefinedfilm
# Opinion of 'dialogue':
# 	 'bronzed', 'driving'
#
#
# Sentence:
# 	Manywillbemovedbyhownaturalthedialoguesounds(herecordedmostofitonthestreets),alotofitobviouslyinspiredbyhisownlife.
# Opinion of 'dialogue':
# 	 'natural'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'fast'
#
#
# Sentence:
# 	Indeed,thedialogueissobeautifullyeloquent,wefeellikeweareoftengiventhemodernequivalentofShakespeare.
# Opinion of 'dialogue':
# 	 'eloquent'
#
#
# Sentence:
# 	Selectionof
# locations,environmentsandcharactersissimplywonderful--sureto
# keeptheviewerengrossed,eventhoughthedialogueisuncompromisingly
# British.
# Opinion of 'dialogue':
# 	 'British'
#
#
# Sentence:
# 	Recentadaptationsseemafraidtoincludeoriginaldialogueatanylength-
# Opinion of 'dialogue':
# 	 'original'
#
#
# Sentence:
# 	Verywittydialogueandscenes;flawlessactingbyleadandsupportingactors.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	ThisisChaplin'sfirstfulldialoguefilm,eventhough'TheGreatDictator'washisfirstsoundfilm.
# Opinion of 'dialogue':
# 	 'full'
#
#
# Sentence:
# 	Mywifesaysallofhismoviesarethesame,anditbreaksmyhearteverytimeshesaysit...becauseinthatblanketanalysis,theanalystmissestheincrediblestoriesandcraftydialoguethattakesplaceinthemanyWoodyAllenmoviesthatprettymuchtakeplacewithinthesametemplate.
# Opinion of 'dialogue':
# 	 'crafty'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'fast'
#
#
# Sentence:
# 	Thisisamust-haveifyoulikeagoodstoryline,cleverdialogueandhonestlaughs.
# Opinion of 'dialogue':
# 	 'clever'
#
#
# Sentence:
# 	GreatforthepurestinthecrowdbutkillerforthoseofuswholikebadlydubbedEnglishdialogue.
# Opinion of 'dialogue':
# 	 'dubbed', 'English'
#
#
# Sentence:
# 	Theweaknesseswereimmediatelyapparent--awkwarddialogue,lackofvisualstyle--butIhopedthemoviewouldovercomeitsfaults.
# Opinion of 'dialogue':
# 	 'awkward'
#
#
# Sentence:
# 	Thismayhelpsomeofyouslowerpeople(don'tbeashamed)tounderstandthefilm,althoughmuchofitsimportantintricatedialogueandoverallappealwillbelostinthisversion.
# Opinion of 'dialogue':
# 	 'important', 'intricate'
#
#
# Sentence:
# 	Thereareproblemswiththefilm,themostannoyingonebeingthatthedialogueispracticallyinaudibleduetothemikingand,moreso,duetothemusicalscorewhichcoversallthelinestothepointofmakingthemovieseemlikeasilentmoviewithmusicfromthepit!
# Opinion of 'dialogue':
# 	 'inaudible'
#
#
# Sentence:
# 	Themood,thesensuousdialogue;Thisisjustnoiratit'sbest.
# Opinion of 'dialogue':
# 	 'sensuous'
#
#
# Sentence:
# 	Thistart,well-scriptedcomedyisalittlelightonthedancing,butfeaturessomeofthebest,briskestdialoguethatcameAstaire'sway,andafinesupportingcast,includingthefamousHollywood&quot;double-talker,&quot;CliffNazarro,goingthroughhisroutineinnumerousscenes.
# Opinion of 'dialogue':
# 	 'best'

# %%
# %load solutions/opinion_extractor_initial

# %% [markdown]
# ### Exercise
# Look at the output that your opinion extractor is producing.
#
# As you can see, it isn't very good. In the sections below, you will be looking at a variety of ways in which you can refine the `opinion_extractor` function to improve its performance.
#
# The work you will do in the remainder of this notebook forms part of the first assessed coursework for this module. This will involve developing and assessing the effectiveness of several extensions to the opinion extractor.
# - For full details of what is required for the coursework see the coursework specification document which can be downloaded from the module website.
#
# Have a look at the section **Tips for de-bugging and exploration** (see below).
#
# As you are investigating how well your `opinion_extractor` is working, you will want to view your opinion extractor's output for a substantial number of sentences. You might prefer to print your output to a file.
#
# The code in the next cell illustrates how this below.
# - Note that you may wish to replace `"savefile.txt"` with a different path.

# %%
save_file_path = r"savefile.txt" # Set this to the location of the file you wish to create/overwrite with the saved output.

# This is a "with statement", it invokes a context manager, which handles the opening and closing of resources (like files)
with open(save_file_path, "w") as save_file:  # The 'w' says that we want to write to the file            
    for parsed_review in parsed_reviews:
        for sentence in parsed_review.sents:
            for aspect_token in aspect_words:
                opinions = opinion_extractor(aspect_token,sentence)
                if opinions:
                    save_file.write("--- Sentence ---\n{0}\nOpinions on {1}\n{2}\n".
                                    format(sentence,aspect_token,opinions))

# %% [markdown]
# ## Required extensions
# There are 5 required extensions:
# 1. Adjectivel modification
# 2. Adjectives linked by copulae
# 3. Adverbial modifiers
# 4. Negation
# 5. Conjunction
#
# In addition there are a number of optional extensions (see below).
#
# ### Example test set
# In addition to testing out your opinion extractor on the DVD review dataset, we will also be looking at a very small set of examples that illustrate cases of each of the extensions that we will be making.
#
# Run the following cell to load up these sentences.
# - Each example is a three tuple of the form
# `(<example_name>,<sentence>,<set of opinion words>)`

# %%
core = [("A.1","It has an exciting fresh plot.",set(["fresh", "exciting"])),
        ("B.1","The plot was dull.",set(["dull"])),
        ("C.1","It has an excessively dull plot.",set(["excessively-dull"])),
        ("C.2","The plot was excessively dull.",set(["excessively-dull"])),
        ("D.1","The plot wasn't dull.",set(["not-dull"])),
        ("D.2","It wasn't an exciting fresh plot.",set(["not-exciting", "not-fresh"])),
        ("D.3","The plot wasn't excessively dull.",set(["not-excessively-dull"])),
        ("E.1","The plot was cheesy, but fun and inspiring.",set(["cheesy", "fun", "inspiring"])),
        ("E.2","The plot was really cheesy and not particularly special.",set(["really-cheesy", "not-particularly-special"]))
       ]

optional = [("A","The script and plot are utterly excellent.",set(["utterly-excellent"])),
            ("B","The script and plot were unoriginal and boring.",set(["unoriginal", "boring"])),
            ("C","The plot wasn't lacking.",set(["not-lacking"])),
            ("D","The plot is full of holes.",set(["full-of-holes"])),
            ("E","There was no logical plot to this story.",set(["no-logical"])),
            ("F","I loved the plot.",set(["loved"])),
            ("G","I didn't mind the plot.",set(["not-mind"]))
           ]

# %% [markdown]
# ### Problem with displaCy
#
# You have been encouraged to use the dependency tree visualisation tool found [here](https://demos.explosion.ai/displacy).
#
# However, it turns out that what it says on the displaCy site is incorrect, and the displaCy visualiser uses a *different* parsing model from the one that is installed by default with spaCy, and as a result, there are cases where the trees are different.
#
# It is possible to set up spaCy to use the same model as displaCy by doing the following:
#
# ```
# import spacy
# nlp = spacy.load('en')
# python -m spacy download en_core_web_md
# nlp2 = spacy.load('en_core_web_md')
# ```
#
# However, I would recommend that you stick with the spaCy default model, and check for differences. In the cell below, you will find code that can be used to show the structure of the dependency tree produced by spaCy, and it shows an example where the tree differs from that shown by the displaCy visualiser.

# %%
def print_dep_tree(node,indent):
    print(indent,node)
    indent = indent + "  "
    for child in node.children:
        print_dep_tree(child,indent)

sent = "The plot was cheesy, but fun and inspiring."
parsed_sents = nlp(sent)
parsed_sent = next(parsed_sents.sents)
print_dep_tree(parsed_sent.root,"")
# Out:
#  was
#    plot
#      The
#    cheesy
#    ,
#    but
#    fun
#      and
#      inspiring
#    .

# %% [markdown]
# ## Extension A: Adjectival modification
# In this section, we are interested in adjectival modification. This is when we have a noun like "*dog*" or "*plot*", and there are one or more adjectives which are specifying the characteristics of that noun. E.g. "*big brown dog*" or "*exciting fresh plot*" ("*big*" and "*brown*" are both adjectivally modifying "*dog*").
#
# The dependency relation we use to show this relationship is `amod`.
#
# Write a version of the opinion extraction function which, when given sentences such as the example below containing an aspects token (e.g. "*plot*"), uses the `amod` relations to extract a list of the adjectival modifiers of the aspect token (e.g. the two words "*exciting*" and "*fresh*" in this case).
#
# **Core Example A.1**: "*It has an exciting fresh plot.*" should produce "*fresh*", "*exciting*"
#
# The dependency trees for this sentence is shown below.

# %% [markdown]
# ![Extension 1 example](./img/amod_example.png)

# %%
def opinion_extractor(aspect_token,parsed_sentence):

    opinions = []
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.text == aspect_token:
            for child in token.children:
                if child.dep_ == 'amod':
                    opinions.append(child.text)
            
    return opinions

def show_results(results,aspect_word):
    print("Results for aspect word '{}'\n".format(aspect_word))
    for word,sent,opinions in results:
        if word == aspect_word:
            print("Sentence:\n\t{}".format(sent))
            print("Opinion of '{0}':\n\t '{1}'".format(aspect_word,"', '".join(opinions)))
            print("\n")

aspect_words = ["plot","characters","cinematography","dialogue"]
results = [] 
for parsed_review in parsed_reviews:
    for sentence in parsed_review.sents:
        for aspect_token in aspect_words:
            opinions = opinion_extractor(aspect_token,sentence)
            if opinions:
                results.append((aspect_token,sentence.orth_,opinions))

show_results(results,"plot")
show_results(results,"characters")
show_results(results,"cinematography")
show_results(results,"dialogue")

# %% [markdown]
# ### Exercise
# Adapt your opinion extractor so that it just finds adjectival modifiers, and apply it to examples test set in order to check that your function is working as required.
# - Note, your opinion extractor should only get the first example, A.1, correct.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %%
sents = [nlp(entry[1]) for entry in core]
# print(sents)

for index,sen in enumerate(sents):
    opinions = opinion_extractor("plot",sen)
    print(opinions)
    if set(opinions) == core[index][2]:
        print('Test set {} passed\n'.format(index+1))
# Out:
# ['exciting', 'fresh']
# Test set 1 passed
#
# ['dull']
# Test set 2 passed
#
# ['dull']
# ['dull']
# ['dull']
# ['exciting', 'fresh']
# ['dull']
# ['cheesy']
# ['cheesy']

# %% [markdown]
# ## Extension B: Adjectives linked by copulae
# In this section, we are interested in adjectives which are linked to our aspect term via the copula (conjugations of "*to be*": "*is*", "*was*", "*will be*", etc.).
#
# Notice that if we were only looking for `amod` relations, we'd completely miss the word "*dull*" in the dependency tree shown below.
#
# Your opinion extraction function when given a sentences like the example below containing the aspect token "*plot*", should use appropriate dependency relations to output the term opinion word "*dull*".
#
# **Core Example B.1**: "*The plot was dull.*" should produce "*dull*"
#
# The dependency trees for this sentence is shown below.

# %% [markdown]
# ![Extension 2 example](./img/copula_example.png)

# %%
def opinion_extractor(aspect_token,parsed_sentence):

    opinions = []
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.text == aspect_token:
            for child in token.children:
                if child.dep_ == 'amod':
                    opinions.append(child.text)
            if token.dep_ == 'nsubj':
                filterList = set(filter(lambda x: x.dep_ == 'acomp', token.head.children))
#                 print(list(filterList))
                for x in filterList:
                    opinions.append(x.text)
#     print(opinions)
    return opinions

def show_results(results,aspect_word):
    print("Results for aspect word '{}'\n".format(aspect_word))
    for word,sent,opinions in results:
        if word == aspect_word:
            print("Sentence:\n\t{}".format(sent))
            print("Opinion of '{0}':\n\t '{1}'".format(aspect_word,"', '".join(opinions)))
            print("\n")

aspect_words = ["plot","characters","cinematography","dialogue"]
results = [] 
for parsed_review in parsed_reviews:
    for sentence in parsed_review.sents:
        for aspect_token in aspect_words:
            opinions = opinion_extractor(aspect_token,sentence)
            if opinions:
                results.append((aspect_token,sentence.orth_,opinions))

show_results(results,"plot")
show_results(results,"characters")
show_results(results,"cinematography")
show_results(results,"dialogue")
# Out:
# Results for aspect word 'plot'
#
# Sentence:
# 	However,theplotwaspredictable.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Furthermore,theplotissopredictablethatitmadethemoviedrag.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	well,that'stheusualpredictableromanceplot.
# Opinion of 'plot':
# 	 'usual', 'predictable'
#
#
# Sentence:
# 	TheplotwasOKbutitwouldhavebeenmuchbetteriftheyhadeitherstucktoamoreauthenticrepresentationofJapanesecultureorkeptthestoryinthestates.
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Theperformancesarethinanduneven,theplotisinconsistent,andthedialoguesoundslikeitwaspulledfromfortunecookiesmadebythecastofFriends.
# Opinion of 'plot':
# 	 'inconsistent'
#
#
# Sentence:
# 	AlthoughthismoviewantedtobeinthesameraceandqualityofthemovieCLUE,itfailstorealizethattheplotandcharactersareincrediblyriculousandnotfunnyhahabutfunnystupid.
# Opinion of 'plot':
# 	 'riculous'
#
#
# Sentence:
# 	Theactingishorrible,theplotishorrible,thefilmingishorrible...
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Its"thriller"aspectisartificialandnottiedtothecentralplotline,andentirelypredictablefromthemomentourfriendishandedTHEONLYKEYTHATCANSTOPTHENUKE!
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Theplottothismovieorsocalledsequalishorrible.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'straightforward'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'thin'
#
#
# Sentence:
# 	Withtheirchildestvoices,theyshouldn'tbeusedasamainplotofthestory
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Asfarasthemovieisconcerned,theplotisunoriginalandnotparticularlyengaging.
# Opinion of 'plot':
# 	 'unoriginal'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Thiswassuchacontrivedmoviethathadasimpleplotthatwentnowhere.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Themoviewasn'tfunny(whichissadtosaywhenoneofmyfavoritecomedicactresses,CarolKane,couldn'tevenelicitasmileoutofme),theplotwasfullofholes,andthewritingseemedveryrushedandcontrived.
# Opinion of 'plot':
# 	 'full'
#
#
# Sentence:
# 	Thespecialeffectsareabitcheesy,youcanseethewirespullingthetorpedosandyoucantellthattheyusedscaledmodelships...butifyouoverlookthoseitems,yougetfineactingandagoodplotwithplentyof
# action
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	stupidplot-toomanyholesandstupidending.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theentireplotisself-serving,shallow,andunrealistic.
# Opinion of 'plot':
# 	 'entire', 'serving'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Thebasicplotofthemovieisthatlifesucks(
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	TheplotislameandIamsorryIspentthemoneyonit.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Butthedumbplotandtheunfunnyattemptsatcomedymakeitacompletewasteoftime.
# Opinion of 'plot':
# 	 'dumb'
#
#
# Sentence:
# 	Eraserhasafewscenesthatwillkeepyourattention,butoverallthemoviedisplayedpooracting,stuntsthatareimpossibleandamediocreplot.
# Opinion of 'plot':
# 	 'mediocre'
#
#
# Sentence:
# 	Verypredictableplotfrombeginningtoend.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Iwasveryboredwiththismovieandfoundtheplottobeveryinsulting.
# Opinion of 'plot':
# 	 'insulting'
#
#
# Sentence:
# 	Buysomthingthathasagoodplot.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Oneoftheworstmoviesi'veeverseen,norealplotandactingisasbadasitcanget.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Canyoureallycarry2hourswiththissingleplot?
# Opinion of 'plot':
# 	 'single'
#
#
# Sentence:
# 	Theplotiscomplicatedandthenoiseinthebackgroundaddstothedisorientationwhichisdoneonpurpose.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'thin'
#
#
# Sentence:
# 	Buttheplotwaslame&slow.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'plot':
# 	 'unbelievable'
#
#
# Sentence:
# 	Thisseriesmightbeconsideredaclassicifwatchedbya12-year-old,butadultswillseethoughtheindistinctplotandcharacters.
# Opinion of 'plot':
# 	 'indistinct'
#
#
# Sentence:
# 	Theplotwasadequate.
# Opinion of 'plot':
# 	 'adequate'
#
#
# Sentence:
# 	Ijustcan'tgetoverhowprofoundlycornyandsimpletheplotandeffectsare,
# Opinion of 'plot':
# 	 'corny'
#
#
# Sentence:
# 	BeforeIhitthistooharshly,thisfilmwasintendedtobeatrifle,thekindofmoviethathasbrightcolorsandlightplotforahotsummerdaythatsizzles.
# Opinion of 'plot':
# 	 'light'
#
#
# Sentence:
# 	Soundslikeaninterestingplot,right?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Feebledirectionsimplymissesseveralgoodopportunitiestomakegooduseofthejockey'ssullenlittledaughterSam(KayPanabaker,herfeaturedebut),whocouldhavebeenalittlesurprise(orgem)inthisunconvincingplot.
# Opinion of 'plot':
# 	 'unconvincing'
#
#
# Sentence:
# 	Theonlybluehereistheshadeyouwillturnbytheboredomwiththeweakplot.
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	TheplotwasbadanditdidnothavethatmanypokemonasIthought.
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	...hasaprettythinplot.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Infact,thetrialdoesn'tevenhaveaconnectiontothecentralplotasidefromshowingthatSamandArchiearefriendsandpartners.
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Howeverifyoulikesex,violence,blood,anddebauchery,couldcarelessthefactthattheyhavenothingtodowiththeabsentplot,youcouldfindthisfilminteresting.
# Opinion of 'plot':
# 	 'absent'
#
#
# Sentence:
# 	Andplotissoludicrouslypredictableit'sprettyclearearlyonjustwhothebadguybehindthecurtainis.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Flatlighting,cheapsetsandcostumes,dulldialog,woodenacting,andagoofyplot;evenpervasivesiliconeenhancementcannotsavethismovie.
# Opinion of 'plot':
# 	 'goofy'
#
#
# Sentence:
# 	Theplotifpoorlycontrived,theproductionvalueislow,theactingforthemostpartisawful,andit'sbasicallyjustawaytostitchtogetheraseriesofmusicvideoswhichathisage,mysonhasnointerestin.
# Opinion of 'plot':
# 	 'low'
#
#
# Sentence:
# 	JuryDutysimplywasjustplainawfulwithit'sweak,boringplotandunfunnyhumor!
# Opinion of 'plot':
# 	 'weak', 'boring'
#
#
# Sentence:
# 	Theplotofthemovieisinterestingandkeepsyouwonderingwhatisgonnahappennext.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'horrific'
#
#
# Sentence:
# 	Theplothowever,isexcellent.
# Opinion of 'plot':
# 	 'excellent'
#
#
# Sentence:
# 	Veryinterestingandunpredictableplot.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Theplotfeelssluggishattimesandthere'swaytoomuchXavierCugatandhisorchestra,butAstaireandHayworthareattheirpeak,KernhaswrittensomememorablemelodiesandfewcouldtopMerceratlyricwriting,noneinHollywood.
# Opinion of 'plot':
# 	 'sluggish'
#
#
# Sentence:
# 	Basicplot:
# Opinion of 'plot':
# 	 'Basic'
#
#
# Sentence:
# 	Sowhileitwasaconvenientplotdevice,youwouldexpectsomethinglikethatbysomeonewithonlyminimalknowledgeofdinosaurs.
# Opinion of 'plot':
# 	 'convenient'
#
#
# Sentence:
# 	itwasquitefunny,buttherewaslessactionandlessplotcomparedtootherepisodes.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	Almosttheentireplotisonboardandunderway.
# Opinion of 'plot':
# 	 'entire', 'onboard'
#
#
# Sentence:
# 	Fromthereitjustgetsprogressivelydarkerandtenser,withthelighting,acting,anddirectionallperfectlyservingtoratchetupthefeelingofdesperationandhorrorasToddkickshisill-conceivedrobberyplotintomotionandthingsspinwayoutofcontrol.
# Opinion of 'plot':
# 	 'conceived'
#
#
# Sentence:
# 	Whileit'shardtopickmyfavoritefirstseasonepisode,thecomplexplotof"APriest,A
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Theplotwaswellworn,butitdidn'tfeelstaidorplodding.
# Opinion of 'plot':
# 	 'worn'
#
#
# Sentence:
# 	Theplotisperfectandthescriptiswellwritten.
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplotissweet.
# Opinion of 'plot':
# 	 'sweet'
#
#
# Sentence:
# 	Thequalityofthegraphicsareterrific,theplotisalittlestrange,butbasicallyitsalienswhoinvadeandride4virtualrollercoastersatafuturisticthemepark.
# Opinion of 'plot':
# 	 'strange'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	anywayirecommendthistoanyonewholoves Asianhorrorandlikesagoodplotandmovie!!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisnotveryintriguing,andyouknowthatnothinglikethiscanhappeninthereallife,soitlacksthissenseofreality.
# Opinion of 'plot':
# 	 'intriguing'
#
#
# Sentence:
# 	I'mnotamoviebuff,butDeepCoverhasalltheelementsyouwouldexpectofaclassic:greatacting,memorablelines,interesting(andlogical)plotandadecentending.
# Opinion of 'plot':
# 	 'logical'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'plot':
# 	 'silly', 'funny'
#
#
# Sentence:
# 	TheplotevolvesasmanyotherCoenmovies(RaisingArizonacomestomind)asweareintroducedtomore-and-morecolorfulcharactersandtheplotgetsmore-and-moreoutrageous,yetsomehowstillseemsreal.
# Opinion of 'plot':
# 	 'outrageous'
#
#
# Sentence:
# 	Everyoneknowsthebasicplotbynow:SpockkidnapshiscrippledformerCaptain,andhijackstheEnterprise,andsetscoursefortheoneforbiddenplanetinallTheFederation.
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	Yes,theplotisodd.
# Opinion of 'plot':
# 	 'odd'
#
#
# Sentence:
# 	Itdoesn'tfollowastorylinethat'spredictable,eventhoughtheplotisnotunknown.
# Opinion of 'plot':
# 	 'unknown'
#
#
# Sentence:
# 	Itusesoneoftheworstsuperheroclichesasthemainplot,thatoftheherocallingitquits.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	There'sashadowyplotinvolving$10,000bills,aguerillamovementandguns,butthemoviefocusesmoreonQuinn'sconflictsbecausehischildhoodfriendissuspectedofagrislymurder,andQuinn'sowndiscomfortfromhaving"madegood"butendingupcaughtbetweentwoworlds,whiteandblack.
# Opinion of 'plot':
# 	 'shadowy'
#
#
# Sentence:
# 	Wasitcancelledbecausetheplotwasflimsyordumb?
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Theplot,thesetting,thedialogues,thespecialeffects,andthemusicareallwonderful!
# Opinion of 'plot':
# 	 'wonderful'
#
#
# Sentence:
# 	Theplotisinteresting,itkeepsyouguessing,andthesuspensekeepsyouontheedgeofyourseat.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	DirectedbyTamraDaviswithakeeneyeoncharacterizationandhumor,thismovieisoneofthoseyousmilemostofthetime,andhaveagoodtimewithitssurrealandzanyplot.
# Opinion of 'plot':
# 	 'surreal'
#
#
# Sentence:
# 	Theplotwasn'thorrible,itwasactuallyprettygoodforafrightflick.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplot,thesetting,theacting,andthedialoguesareallverygood.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotiscomplex.
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Eventhoughthefilmisbasedonafictionalplot,itstillhasanauthenticfeelandisratedanalltimeclassic.
# Opinion of 'plot':
# 	 'fictional'
#
#
# Sentence:
# 	Theplotisgood,andDeoxys''destructive'intentionsarelesscruelthanonewouldthink.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotanddialogueisincrediblebecauseitexploresalltheshadesofgreyinthecharacters.
# Opinion of 'plot':
# 	 'incredible'
#
#
# Sentence:
# 	theplotwasprettyoriginal.
# Opinion of 'plot':
# 	 'original'
#
#
# Sentence:
# 	Thisfilmmaynotbeperfect,andtherearesomeboringscenesastheytrytohardtoexplainthestateNickisin,buttheoverallplotofthisfilmisoneI'veneverseendonebefore.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisprettyunrealisticbutthenitisascrewycomedysoithelpsifyoususpendagooddealofdisbelief.
# Opinion of 'plot':
# 	 'unrealistic'
#
#
# Sentence:
# 	ItcombinesabunchofthebestFrenchactrices,andanenjoyableplot.
# Opinion of 'plot':
# 	 'enjoyable'
#
#
# Sentence:
# 	theplotwasdry,liketheother2oftheseries,buthowexcitingofaplotcanyouhavewiththeamountofactionandskilleddrivingpackedintothemovie.
# Opinion of 'plot':
# 	 'dry'
#
#
# Sentence:
# 	Suretheplotofweakandtherelationshipsareunbelievable,ImeanwhocanhonestlysaythattheyfeelakingpintotheJapanese/Chinese/Oriental(whateveritwas)
# Opinion of 'plot':
# 	 'unbelievable'
#
#
# Sentence:
# 	Thisfilmhassomegoodactorsinitbuttheplotisprettyshakyandhardtofollowattimes.
# Opinion of 'plot':
# 	 'shaky'
#
#
# Sentence:
# 	Itcouldhavebeenmadebetter--lesscomedyandmoreplotandofcourse--actionandsuspense!!!!
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Theplotwasveryst8fowardandbasicwithafewlittletidbitstolivingitup.
# Opinion of 'plot':
# 	 'foward'
#
#
# Sentence:
# 	Theplotisverygood.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	but,unfortunately,theproducersforgettogivethemacredibleplotandinterestingthingstosay.
# Opinion of 'plot':
# 	 'credible'
#
#
# Sentence:
# 	PeoplewhoreviewSpielbergusuallywanttopigeonholehimintoatype:theET-warm-and-fuzzy-alienchildren'sstorytellerversusthespecial-effects-heavy-but-rather-empty-plotdreamer.
# Opinion of 'plot':
# 	 'empty'
#
#
# Sentence:
# 	Theplotisslowtodevelop,characterdevelopmentlackingandanimationprimitiveatbest.
# Opinion of 'plot':
# 	 'slow'
#
#
# Sentence:
# 	Bothfilmshavethesameborringplot.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Maybethenextfewvolumeswillbemorecreativeandgivemoredetailsonthemainplot,butIpersonallydon'tcaretospendanymoreofmymoneyonsucharisk.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Thebad:Notaveryinterestingorprofoundplot.
# Opinion of 'plot':
# 	 'bad', 'interesting'
#
#
# Sentence:
# 	Theplotofthestoryisreallyinteresting.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'horrific'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whiletheplotisnearlyidentical,AlexanderPayne(director)treatshischaractersmuchharsherthanPerrotta.
# Opinion of 'plot':
# 	 'identical'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'horrific'
#
#
# Sentence:
# 	ThestorybeginswithafailedassasinationplotthenfollowsMalciekChelmicki(ZbigniewCybulskiakaPolandsJamesDean)untilit'sconclusion.
# Opinion of 'plot':
# 	 'failed'
#
#
# Sentence:
# 	Episode16:"TheFactofBeingThere"/"AnotherChance"
# Andallattentionbacktothemainplot.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Althoughtheplotisalittlethin,therearesomeveryfunnymoments.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Theplotwas,insomerespects,totallyillogical,andatothertimesnonsensical.
# Opinion of 'plot':
# 	 'illogical'
#
#
# Sentence:
# 	Theplotisentirelyunconvincingandimplausible.
# Opinion of 'plot':
# 	 'unconvincing'
#
#
# Sentence:
# 	Verygoodplotanddetail
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Insummary,themusicportionofthisDVDratesastrongfivestars,butthesillyplotandtheproblemswiththediskdiscussedabove,bringthisDVDdowntoafourstarproduction
# Opinion of 'plot':
# 	 'silly'
#
#
# Sentence:
# 	Theplotisfartoocomplicatedandtwistytogetinto,andfranklyhasbeengoneoverwithafinetoothcombalreadyonthissite.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Unlike,forexample,LOSTHIGHWAY,thisisacompletelyrealisticplot,withnosupernaturalorunexplainableelements.
# Opinion of 'plot':
# 	 'realistic'
#
#
# Sentence:
# 	OnceyoualreadyknowtheoverallplottheDirector'sCutisbetter,andallthestuffthat'saddediniscool,
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Fourth,theplotisslickandoriginal.
# Opinion of 'plot':
# 	 'slick'
#
#
# Sentence:
# 	It'snotasifthefilmwouldbecompletlyalienatingtonewcomers,notatall,itsjustthatifIhadn'treadthebookbeforehand,I'msureIwouldhavefoundthingsabithardertofollow,asthingsmovefairlyquicklyandthere'saneverthickeningplottokeepaneyeon.
# Opinion of 'plot':
# 	 'thickening'
#
#
# Sentence:
# 	Wellthat'sabouttheentireplotofthismovie.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Allheneedstocompletethisisasmallplotofland.
# Opinion of 'plot':
# 	 'small'
#
#
# Sentence:
# 	this1hasastupidplot.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Yojimboisavastlyentertainingactionfilmwithalltheelementsofthatgenre:fastpace,surprisingplotturns,andajustlyfamoussamuraishowdown.
# Opinion of 'plot':
# 	 'surprising'
#
#
# Sentence:
# 	Myfavoritesongis&quot;NeverTalktoStrangers&quot;.Themovieelaboratesontheoriginalstorybyaddingmoreplottospicethestoryup.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Lynchdoesn'tfollowarealplot;instead,heletsthestorylineslowlysinkintoLaura'sdownfall.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Thisfilmisperfectforeveryone,thealluringplot,amazingacting,entertainingscreenplay.
# Opinion of 'plot':
# 	 'alluring'
#
#
# Sentence:
# 	TheplotcanbealittledumbattimesbutChrisTuckeriswhatthismovieisallabout.
# Opinion of 'plot':
# 	 'dumb'
#
#
# Sentence:
# 	Theplotiscomplexenoughtokeepthewatcherguessingwhatexactlywillhappenandnotboretheaudience.
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Badforanyonewhowantshighproductionvalueoranidentifiableplot
# Opinion of 'plot':
# 	 'identifiable'
#
#
# Sentence:
# 	Plentyofaction,plentyofbeautifulsceneryandpeople,ahalfwaydecentplot,plentyoflogicalunpredictability,anditplayswellonthesmallscreen.
# Opinion of 'plot':
# 	 'decent'
#
#
# Sentence:
# 	Irecommendthismovietoanyonewhoislookingforagoodcomedywithaveryfunnyplot.
# Opinion of 'plot':
# 	 'funny'
#
#
# Sentence:
# 	-"LovebeforeBreakfast"isaUniversalproductionandhasthesimplestplotofthecollection;infact,noplotatallreally.
# Opinion of 'plot':
# 	 'simplest'
#
#
# Sentence:
# 	Thefilmcombinestoomanygenresandtheplotbecomesconvoluted.
# Opinion of 'plot':
# 	 'convoluted'
#
#
# Sentence:
# 	Inthistreatmentoftheannoyingplot,heloseshismind.
# Opinion of 'plot':
# 	 'annoying'
#
#
# Sentence:
# 	AnatomyofaMurderisatoncebothadelightfulmysteryandasuspensefulthillerforthosewouldwouldratherthinkaboutallthemanydimensionsandlayersofintriquegoingoninamovieratherthanbespoonfedaformulaicplot.
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Ratherformulaicplot;thedancingisthethinghere
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'thin'
#
#
# Sentence:
# 	Theanimationistotallycool,thekidsarebelievable,theplotisinterestingandhassometwistsandturnstokeepyouguessing,andthedialogisdownrightfunnyattimes.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Theplotisverysimple,thesetsaresimple...butthefilmisgreat.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	CreditneedstobegiventoJamieAnderson'scinematographyandNeilSpisak'sproductiondesignforestablishingsuchaheadyatmosphereperfectforthelabyrinthplot.
# Opinion of 'plot':
# 	 'labyrinth'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Iwon'tre-hashtheplotasAmazonhasalreadyprovidedpotentialbuyerswiththeoutline.
# Opinion of 'plot':
# 	 'hash'
#
#
# Sentence:
# 	Themoviestillhadsappylines,unrealisticplot,andunconvincingelementstoit.
# Opinion of 'plot':
# 	 'unrealistic'
#
#
# Sentence:
# 	Ifyourlookingforanimethathasaction,suspence,romance,humor,andanengagingplotwithlotsoftwistsEscaflowneistheonetoget.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Theplotistooimplausibleandriddledwithinconsistenciestobetakenliterally.
# Opinion of 'plot':
# 	 'implausible'
#
#
# Sentence:
# 	Greatcharacters,awellcraftedplot,andsomeofthebestanimationIhaveeversee.
# Opinion of 'plot':
# 	 'crafted'
#
#
# Sentence:
# 	Theplotisfartooconvolutedtoevenbegintorecount,butthepremiseisthatthesetwounlikelycharactersareabouttobecomein-laws.
# Opinion of 'plot':
# 	 'convoluted'
#
#
# Sentence:
# 	Wonderfullocations,mesmerizingstunts,admirablespecialeffects,averycleverplotandrespectablecastobligatesustoconsiderabsolutelyrecommendable.
# Opinion of 'plot':
# 	 'clever'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Butthereisenoughplottounderstandwhatthestoryisabout.
# Opinion of 'plot':
# 	 'enough'
#
#
# Sentence:
# 	Ienjoyedthismoviebecausetheplotwasverydifferentandnotrunofthemilllikemosthorrormovies.
# Opinion of 'plot':
# 	 'different'
#
#
# Sentence:
# 	TheplotisOKandwithatwistthatshouldn'tberevealedbeforehand
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Themovie"Boo"featuresterribleacting,andadeplorableplot.
# Opinion of 'plot':
# 	 'deplorable'
#
#
# Sentence:
# 	It'snotarevolutionaryplot,andafewscenescouldhavebeenbetterexecuted(theobligatory'break-up'beforethehappyendingisratherweak),butonthewholethemushysideofmeateitup.
# Opinion of 'plot':
# 	 'revolutionary'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Theplotisratherthinandconsistsofthefairyworldtryingtotakeoverthisworld.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	BeeSeason"isjusthorribleandthismoviehasamuchbetterplot,betteractingandabettermessage.
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	IfIhadn'tseentheoriginalI'djustthink,"whatabrilliantplot,toobadtheydecidedtoburyit(nopunintended)witheverythingelseinthemovie".
# Opinion of 'plot':
# 	 'brilliant'
#
#
# Sentence:
# 	belowaverage,thedialoguesarewaybelowaverage,whiletheplotisnotbadatall.
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Theplot isludicrous,thescriptfoolishandinept,theactingsocrudeastobeembarrrassing.
# Opinion of 'plot':
# 	 'foolish', 'ludicrous'
#
#
# Sentence:
# 	Theplotisweakaskingustobelieveincharactersdoingthingsthatnoonewithoneounceoflogicwoulddo(forexample,themotherleaveshomeforafewdaystovisitanauntknowingherhusbandrecentlysluggedhersoninthefacewithoutprovocation).
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Iftheplotwerebetteritwouldbeafilmworthwatching
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	Themovieappealswithitsintricateplot-aningeniouswebawaitedthealmosthelplessWilliamHurt,whowasdazzledbythebeautyofKathleenTurnerandwhosemindwas,nodoubt,slowedbytheintenseheat.
# Opinion of 'plot':
# 	 'intricate'
#
#
# Sentence:
# 	Goodplot.
# Opinion of 'plot':
# 	 'Good'
#
#
# Sentence:
# 	Whetherornotthereactuallyareghostsis,ofcourse,themainplotofthemovie,andtruetothegenreitdancesaroundthequestionforagoodlengthoftimebeforefinallyansweringit.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Itwasnottheactualstory/plot,orit'saccuracythatwasimportanttome.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'straightforward'
#
#
# Sentence:
# 	Criticsarguethattheplotistoocomplicated/clever,butthiswasentertaining,withovertonesofpoliticalconspiracythatmakeyourealizehoweasyitisforthetrulypowerfultomanipulateevents.
# Opinion of 'plot':
# 	 'clever'
#
#
# Sentence:
# 	Foramoreexplosiveride,withamoreentertainingcharacter,andamuchsimplerdrug-inducedandgraphicplot,seetherecentlyreleasedCrank-excellentaction/adventurefromtheTransporterman.
# Opinion of 'plot':
# 	 'simpler', 'induced'
#
#
# Sentence:
# 	JustlikeallDePalmafilms,DressedtoKillfeaturessomeabsolutelybrilliantsequences(elevator,trainstation)dispersedthroughoutaratherclumsyplot.
# Opinion of 'plot':
# 	 'clumsy'
#
#
# Sentence:
# 	SetinWWIILondon,thedarkheartedplotfocusesonNavyLieutenantCommanderCharlesMadison,anespeciallynotoriouspersonalassistanttothementallyunstableAdmiralWilliamJessup.
# Opinion of 'plot':
# 	 'dark', 'hearted'
#
#
# Sentence:
# 	Iamlaughingatthose2starreviewssayinghowAVPisdestroyingtheAlienandPredatorlegacybecauseofitsnonexistentplot.
# Opinion of 'plot':
# 	 'nonexistent'
#
#
# Sentence:
# 	Verysuspenseful,andwonderfullywrittenplotmakethisa5starfilm!
# Opinion of 'plot':
# 	 'suspenseful', 'written'
#
#
# Sentence:
# 	Theplotisfairlysimplewiththetwobrotherstryingtopreventagangofoutlawsfromterrorizingagroupoffarmersandstealingtheirland.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Theplotisnotnew.
# Opinion of 'plot':
# 	 'new'
#
#
# Sentence:
# 	Goodversusevil,ofcourse,buttheplotismoreabouttheclasses.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	TheplotisUNEXPECTED,thatiamnotsureifit'sgoodornot!
# Opinion of 'plot':
# 	 'UNEXPECTED'
#
#
# Sentence:
# 	Theplotisfartocomplicatedtoexplaininareasonableamountoftime,butissumsuptobeaboutabunchofpeople,withcompletelydifferentlifestyles,whosomehowgetthrowntogetherbecauseofabigbombthatlookslikeagarbedgedisposal.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Fromthere,theplotgoesnuts,butthat'sokay,becauseit'swhatmakesBigTroublesuchafunnyandstrangelysmartmovie.
# Opinion of 'plot':
# 	 'nuts'
#
#
# Sentence:
# 	Thisisagoodmoviewithaninterestingplot,goodacting,decentdirectingandapoliticallyreleventcommentontheexcessesoftheUSPress.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Alotofpeopletendtosaythatthisanimeisconfusinganddoesn'thavearealplot.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Ithinkthedirectorneedsprozactodirectthismovie,thewholeplotissomessup,juniorhighstudentcanwritebetterstorythanthis..whatwashethinking.
# Opinion of 'plot':
# 	 'whole', 'mess'
#
#
# Sentence:
# 	Thecharactersaresoveryinteresting(butsubtle),theycouldhavewrittenanyoldplotandIwouldhavewatchedhungrily.
# Opinion of 'plot':
# 	 'old'
#
#
# Sentence:
# 	Whileultimatelythissetofindividualepisodesdoesn'tseemtofurtheranyoverallplot,thecomplexityoftheTachikomasandhowtheyworkisactuallyprettyinteresting.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisalittlethin,butAlyssaMilanoisthereasontowatchthismovie.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Thesewerealllosersbecausetheyhadashallowplot,alackoftalentedactors/actresses,andnomoralfibertothemwhatsoever.
# Opinion of 'plot':
# 	 'shallow'
#
#
# Sentence:
# 	Idon'tknowwhoplaysPatsy,butsheissuperbandthisplotstrandisverypoignant.
# Opinion of 'plot':
# 	 'poignant'
#
#
# Sentence:
# 	Itisthesethemesthatmaketheseriestrulyshine,asthesimplisticoverallplotservesmerelyasavehiclefortheseideas.
# Opinion of 'plot':
# 	 'simplistic', 'overall'
#
#
# Sentence:
# 	Theplotisratherpredictableandyoucouldsensetheendingalmostfromthebeginning.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Theplotisfairlysimple.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	NowobviouslythisissameplotusedintheSantaClause
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	IthasafairlysimpleplotwhichsendsthecharactersrunningaroundNYConenightatChristmastime-eachwithhisorherownmisunderstandingofwhatisgoingon.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Watchtheperfectmurderplotbeingexecuted
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplottothefilmissocomplicatedthatitreallyistoughtokeepupwith,eventhoughtherereallyisn'tthatmuchgoingonthroughoutmostofthefilm.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	ShefindsadischargenoticeinRyu'spants,andthenextthingweknowshehasfiguredouttheentireplot,includingthekidnapping.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Theplotandsupportingcastarebetterthanpassable,thisisn'tatotallybadflick.
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	McGiverhasfallenforKhanandsays,"Iwilldoanything",sellsoutherselftoopower,andagreeswithhisevilplottootakeovertheEnterprise.
# Opinion of 'plot':
# 	 'evil'
#
#
# Sentence:
# 	Thecharacterworkisverygoodandtheplotgetsmoreandmoreinterestingasthemoviegoeson.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	"Stargate"isstilloneofthescience-fictiongreatsthatsuccessfullyblendshistoryandscience-fictioninoneeffectiveplot.
# Opinion of 'plot':
# 	 'effective'
#
#
# Sentence:
# 	ThisDVDofTeentitansthe2ndseasionhasagoodstoryplot,andIforoneloveit!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Nowtothemeatofthereview,theplotinthismovieisn'treallythatgood,butnotveryhorrible.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Notaparticularlyinvolvedplot,butthenI'veseenjustaboutallthereare,butaverynicelittlefilm.
# Opinion of 'plot':
# 	 'involved'
#
#
# Sentence:
# 	Inotherwords,it'sthesimpleBODYSNATCHERSplot.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Moreplot,morestory,moregore(gettheunratedversion)andmoreJASON!
# Opinion of 'plot':
# 	 'More'
#
#
# Sentence:
# 	TheplotisratherShakespearean--themixupoflovers--buteverythingturnsouthappilyintheend.
# Opinion of 'plot':
# 	 'Shakespearean'
#
#
# Sentence:
# 	Nottomentionit'snotexactlythemostcliche-freeplotasthere'ssomescenesthataregoingtobeobviousandwhentheyhappentheydon'treallysurprise(apossibleromancebetweenJohnandFlor,Deborahandhermotherhavinganall-outorjealousyamongFlorandDeborah)butthefilm'sentertaininganyway.
# Opinion of 'plot':
# 	 'free'
#
#
# Sentence:
# 	Theunconvincingcharacterizationsandhackneyedplotarelostinawelterofstrikingincidentaldetails:hundredsofglassbaublesrollingdownastaircaseandintothebloodywaterofasuicidevictim'sbathtub,beingaparticularlyimpressiveexample.
# Opinion of 'plot':
# 	 'hackneyed'
#
#
# Sentence:
# 	Poorplot,script,acting
# Opinion of 'plot':
# 	 'Poor'
#
#
# Sentence:
# 	Greataction,engagingplot,greatcinematography.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Moreblood,nudity,violence,swearing,andsexthanthefirstmovie,lessplotandcharacterization.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	REDPLANETunfortunatelyneededmorethanitsminimalistplottocarryit.
# Opinion of 'plot':
# 	 'minimalist'
#
#
# Sentence:
# 	Thefilmisatreat,especiallythefirsttimearound,despiteacomplicatedplotandanunderachievingstoryline
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Thisplotismucheasiertodigestonscreen.
# Opinion of 'plot':
# 	 'easier'
#
#
# Sentence:
# 	Theplotisgreat,theactingisoverthetop,andthecinematographyisfantastic.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whichonewillgettheirman,aninterestingsub-plot?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Itwasn'tthesameoldboringplotasthereweremanyunexpectedturnsandmisadventuresintheplot.
# Opinion of 'plot':
# 	 'same', 'old', 'boring'
#
#
# Sentence:
# 	Thisisn'tanewplot;You'veseenthis,insomeformoranother,severaltimes.
# Opinion of 'plot':
# 	 'new'
#
#
# Sentence:
# 	Aftertherecentspateofrubberrealityfilmsthatallusedessentiallythesameplot--includingStay(2005),TheJacket(2005),November(2004),TheIInside(2003),andeightornineothersgoingatleastallthewaybacktoJacob'sLadder(1990)andtheshortTheAwakening(1990)--TheDarkHoursveryrefreshinglyusesdifferentkindsoftwistsinitsquestionablyhallucinatorysuccessionofscenes.
# Opinion of 'plot':
# 	 'same'
#
#
# Results for aspect word 'characters'
#
# Sentence:
# 	Thecharacterstalkabouttherelativeintelligenceoftheothercharactersorhowtheothercharacterscan'tpossiblyknowwhatisgoingon.
# Opinion of 'characters':
# 	 'other', 'other'
#
#
# Sentence:
# 	ThereareonlytwoBlackcharacters,bothsentimentallyloyaltotheirSouthernnessandtheirmasters;otherwise,slaveryisbesidethepoint.
# Opinion of 'characters':
# 	 'Black', 'loyal'
#
#
# Sentence:
# 	whenlessthanhalfwaythrough,thestorybecomessomethingutterlyunrecognizablefromtheoriginal,severalkeycharactersarelumpedtogethermostconfusingly,andotherslosealltheircomplexcharm.
# Opinion of 'characters':
# 	 'several', 'key'
#
#
# Sentence:
# 	Ifeltthatwithinallthetimeitran,wedidn'treallygetagoodunderstandingoftheinnerbeingofthemaincharacters;seemedtoremaininshallowwatersallalong.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Otherreviewershavecommentedonthebad,infomerciallevelactingofthetwoleadcharacters.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	"ConExpress"haslotsofactioninit,whichisgreatbecausethishidesthepoorwritinganduninterestingcharacters.
# Opinion of 'characters':
# 	 'writing'
#
#
# Sentence:
# 	ThemoviegetsboringratherfastasBetteandWoodyaretheonlyoneswegettoseeasthereareveryfewsupportingcharacters.
# Opinion of 'characters':
# 	 'few', 'supporting'
#
#
# Sentence:
# 	Thesedisjointedglimpsesdon'tgivetheviewertimeordepthtocarewhathappenstoanyofthespoiledrottencharacters.
# Opinion of 'characters':
# 	 'spoiled', 'rotten'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Thecharactersarethinatbest,andstockatworst.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Can'trememberwhenI'veseenafilmwithmoredepravedandpatheticcharactersthanthis.
# Opinion of 'characters':
# 	 'depraved'
#
#
# Sentence:
# 	ThecharactersareunlikeableexceptforCharity'stwofriends.
# Opinion of 'characters':
# 	 'unlikeable'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Forgoodcounterexampleswatch"Trainspotting",whichhasdrug-addictcharacterswithenoughhumorandlifetobelikableandinterestingand"BubbaHo-Tep",afilmwhichdisplaystheplightofthelonelyelderly50timesbetterthanthisfilmdespitebeingasillyhorror-comedywithamummyinacowboyoutfitinit.
# Opinion of 'characters':
# 	 'addict'
#
#
# Sentence:
# 	NowthatthesetediouscharactershavefinallyhitrockbottomIcangodosomethingelse.
# Opinion of 'characters':
# 	 'tedious'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	AnarrativelikeGettysburgthatgoesbackandforthbetweenafewcentralcharactersinalogicalsequencewithoutallthehamfistedattemptsaproselytizingandallthenoblesseoblige.
# Opinion of 'characters':
# 	 'few', 'central'
#
#
# Sentence:
# 	Iwaswatchingthesametwocharactersfightthroughthesametwochallengesinthisfilm.
# Opinion of 'characters':
# 	 'same'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'characters':
# 	 'obscure', 'secondary', 'main'
#
#
# Sentence:
# 	Ifhewouldhavetightenedthescript,createduniqueand"cult-like"characters,andeliminatedtheracism,hemayhavehadthequintessential"weed"filminHollywood.
# Opinion of 'characters':
# 	 'unique'
#
#
# Sentence:
# 	Hediscoversanewtalent(artistChristinaMilian)andworkshiswaythroughanassortmentofcharactersthataremoretypesandclichesthanrealcharacters.
# Opinion of 'characters':
# 	 'real'
#
#
# Sentence:
# 	Thesoundismurkyandundecipherable,theactingisstrictlyamateurhour,thecharactersarepaper-thinwithnodistinctionorpurpose,thestoryisnon-existent,thedialogueisacompletelyworthlessbore,there'snothingremotelyscary,andthespecialeffects(includingacoupleofcomputereffectsthatlookliketheyweremadeonaCommodore64)arelaughable.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Nothinghappensinthismovie(andImeannothing)exceptabunchofsullencharactersexhanging"comic"glancesandlookingwithdrawnandcynical.
# Opinion of 'characters':
# 	 'sullen'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'characters':
# 	 'same'
#
#
# Sentence:
# 	It'sastudyincontrasts,andit'sdoneimpeccablyinthenovel,withaplethoraofcomplexcharacterstorichenthejourney...
# Opinion of 'characters':
# 	 'complex'
#
#
# Sentence:
# 	Realcharacters?
# Opinion of 'characters':
# 	 'Real'
#
#
# Sentence:
# 	Therestofthisfilmconsistsoftheear-bleedingwhinesandyawn-inducinginfightingofthehumancharacters,ill-conceivedandextremelyunlikablecaricaturesofapseudo-cynicalandextremelyredundant"evilsideofhumannature"messagethatwouldbebetterlefttoJeanRenoir(orevenAdamSandlerconsideringtheresultshere).
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	Iguessit'ssupposedtodepictthehorrorofrepressivereligiousvalues,andwhileIdon'tcondonethose,thefilmlacksclearcharactersoranymotivation.
# Opinion of 'characters':
# 	 'clear'
#
#
# Sentence:
# 	ItiseasytogetsuckedintowatchingGantz,becauseoftheuniqueandinexplicablesituationthatthemaincharacters,whohavealldied,findthemselvesin.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	Thecharactersaresolame
# Opinion of 'characters':
# 	 'lame'
#
#
# Sentence:
# 	Thecharactersare,overall,blandandjustplainuninteresting(e.g.RickAndersonplayedbythe"fool,"TedRaimi,fromtheXenaseries).
# Opinion of 'characters':
# 	 'bland'
#
#
# Sentence:
# 	andIdidn'tcarewhatwouldhappenwiththemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Ireadthebookandsawthemovie,whichotherthantitleandmajorcharacters,havelittleincommon.
# Opinion of 'characters':
# 	 'major'
#
#
# Sentence:
# 	Theminorcharacters,includingthewonderfulTracieThomsas"bestfriend"Lily,aremostlywasted.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	ThebigproblemwithRHisthatneitherFordorBenningaresympatheticcharacters.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Theproducersofthisfilmareoutoftheirmindiftheyexpectanyviewerwho'snotscrewed-upintheheadtofeelsorryforthetwostupidmaincharactersjustbecausetheirsick,incestuous,andadulterouslifestyleisincompatiblewiththeworldtheylivein.
# Opinion of 'characters':
# 	 'stupid', 'main'
#
#
# Sentence:
# 	Tooimplausible,toomanyoverdrawnsecondarycharacters.
# Opinion of 'characters':
# 	 'implausible', 'overdrawn', 'secondary'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	WhoevermasteredthisgreatfilmRUINEDitbyFORGETTINGorREFUSINGtoprovideEnglishsubtitlesfortheJapaneseandItaliancharacters.
# Opinion of 'characters':
# 	 'Japanese'
#
#
# Sentence:
# 	Occasionallywegetashotofsomeoftheothercharacters.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	We'resupposedtofindthecharactersplayedbyRobertRedfordandDebraWingertobeamusing,theiracrimoniousrelationshiptobehilarious,andthewaythattheyendupbeingpartnersdespiteallofthegibestoberomanticallysatisfying.
# Opinion of 'characters':
# 	 'amusing'
#
#
# Sentence:
# 	Long,tediousactionadventurewithrepetitivedialog,badplotholes,andgenerallyboringcharactersishowtodescribethislittleforayintofollowingupthecharactersfromBadBoys.
# Opinion of 'characters':
# 	 'boring'
#
#
# Sentence:
# 	It'samazinghowsomuchmoneyandeffortgointospecialeffectsandexpensivesetsandthescriptitselfishollowwithlousycharacters.
# Opinion of 'characters':
# 	 'lousy'
#
#
# Sentence:
# 	Anditdoesn'tonlycenteraroundthemaincharactersbuthasagreatensemblecastofveryinterestingpeople!
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Haspleasantcharacters;butnotdeep.
# Opinion of 'characters':
# 	 'pleasant'
#
#
# Sentence:
# 	Itsjustbadactingwithstupidandmeancharacters.
# Opinion of 'characters':
# 	 'stupid'
#
#
# Sentence:
# 	Rivkabecomeshercousinandothercharactersareneglectedcompletely.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Afterorbeforekeyscenes,thecameracutstoamonologuefromoneofthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Toitscredit,theactorsdidwhole-heartedlyportraygaycharactersandgaylovescenes.
# Opinion of 'characters':
# 	 'portray', 'gay'
#
#
# Sentence:
# 	Atthetime,gaycharacterswereneverportrayedinapositivelightfromthemedia,anditwasagreatrisktodosohere.
# Opinion of 'characters':
# 	 'gay'
#
#
# Sentence:
# 	CertainlynottheweirdIrishaccentstheleadcharactersadopted.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Theothercharactersarelikewiselackinginrealism,onlyJanetMcTeerfareswell
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Mightbesuitedmoreforanolderchildbutmineis13monthssotherehastobeconstantcolorfulcharactersforhertobeinterested
# Opinion of 'characters':
# 	 'constant', 'colorful'
#
#
# Sentence:
# 	Theplotlinewasnonexistent,andthecharacterswerecompletelyunlikeable.
# Opinion of 'characters':
# 	 'unlikeable'
#
#
# Sentence:
# 	istartedlikingthismovie,ithoughtthepinballmetaphorandwildcharactersandlifesacartoonshizcouldhaveworkedout,ifitwerentforthefactthatbakshiisthinlydisguisinghimselfandhisownfrustrationasbeinganunoriginal"underground"cartoonistwhocaughtontothescenetoolate...ifyoulikethedepressing,gritty,wild,fastpacedstyleofthismovie,checkouttheoriginalmasterROBERTCRUMB,towardwhombakshiisobviouslyseethingwithjealousyandridinganxiouslyonthecoattailsof...
# Opinion of 'characters':
# 	 'wild'
#
#
# Sentence:
# 	Everyminutecharactersinthisseriestrytoremindyouofsomeplotpointasifyou'reashort-attentionspancoachpotatoe.
# Opinion of 'characters':
# 	 'minute'
#
#
# Sentence:
# 	butthenthefilmbasicallyspendstoomuchtimezigzaggingaroundtoallthedifferentcharactersandlocales.
# Opinion of 'characters':
# 	 'different'
#
#
# Sentence:
# 	Itseemstoberidingonit'slaurels,sotospeak,andit'salmostasifwearesupposedtofindthecharactersactingdifferentlyfunny.
# Opinion of 'characters':
# 	 'funny'
#
#
# Sentence:
# 	Butthecharactersarenotsympathetic,funorinteresting.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Thereisnohumor,nolikablecharacters,notevenadecentquoteoroneliner.
# Opinion of 'characters':
# 	 'likable'
#
#
# Sentence:
# 	Therearetwonewsupportingcharactersthistime,Loisand,erm...Jason.
# Opinion of 'characters':
# 	 'new', 'supporting'
#
#
# Sentence:
# 	SheisagreatalternativetoBarneyandalloftheothercommercialcharacters,whoIdon'tcaremuchfor.
# Opinion of 'characters':
# 	 'other', 'commercial'
#
#
# Sentence:
# 	Thestoryissimple,butinthehandsofthewritersWendyHammondandBobGosseandwithGosse'sfinedirection,theentirecastgivesusanensembleofdisparatecharactersinwhomwecanallbelieve.
# Opinion of 'characters':
# 	 'disparate'
#
#
# Sentence:
# 	Theactionisoffthewallwiththetwomaincharacterstreatingustotwostylesoffightingthataretheveryantithesistoeachother.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	In"TheManWhoWasn'tThere,"thephrase"decisiveaction"isanoxymoron;everythingCraneandtheothercharactersdoisgovernedsolelybychance.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Alongthewayheencountersahostofintriguingcharacters,includingacrazy-like-a-foxentrepreneurialbushpilotlookingtomakesomesortofbigscore,anumberofwackybitplayerswhoIcaneasilyimaginewerenotactors,buttherealdeal,andeverybitaseccentricastheyappeared;andanendearinglysageoldInuitoffewwordsbutmanyeloquentsilences.
# Opinion of 'characters':
# 	 'intriguing'
#
#
# Sentence:
# 	Thefilmdepictstheevolutionofthesevariouscharactersastheycometotermswiththeprogressionoftheirlovelivesandprofessions.
# Opinion of 'characters':
# 	 'various'
#
#
# Sentence:
# 	PlotsbasedonbooksbyElmoreLeonardtendtobeaboveaverage,butaremostlydependentuponthecolorfulcharactershewrites.
# Opinion of 'characters':
# 	 'colorful'
#
#
# Sentence:
# 	NotonlydoesthemovieSignsofferawonderfullydifferentkindofalien/ufotale,butitscharactersareverylikableandthestoryisaboutmuchmorethanaliensfromanotherplanet.
# Opinion of 'characters':
# 	 'likable'
#
#
# Sentence:
# 	TheclassicWordsworthpoemfromwhichthefilm'stitleisderivedmakesafittingcodaforthismovie,andIstillfeeltheintractablesenseoflonginginthetwoleadcharacterseverytimeIseethismovie.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Bothmoviesareprettysimilartoeachother...but"BloodIn,BloodOut"kindafocusesonthe3brothers,andthepathseachofthemtakes,whereas"AmericanMe"focusesonthepathsofthemaincharactersinthismovie(likeSantana,Puppet,Lil'Puppet,etc)..butnotonlydoesitshowtheirlifestyles,butitalsofocusesonhowitshavinganeffectontheirfamilies,andhowtheirfamiliesfeelaboutthelifethattheirkidsareleading..."AmericanMe"ithinkinvolvesmoreofthefamilyinthispictureandculture(LaRaza)then"BloodIn,BloodOut"does...
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	becuasethisoneseemstohavealotmoreofastorylinetoit,andmorecharactersitsfocusingon...bothinandoutsidetheprisonwalls..
# Opinion of 'characters':
# 	 'more'
#
#
# Sentence:
# 	Therearemanygoodsupportingcharacterssuchas:BridgetFonda,WoodyHarrelson,BarnardHughesandJulieWarner
# Opinion of 'characters':
# 	 'many', 'good', 'supporting'
#
#
# Sentence:
# 	Themaincharactersalmostentirelyhavehopes,aspirations,andattachmentsbeyondtheratherclosedworldoftheirprofession--Jack'sdesiretobeaseriousfilmmaker;Dirk'sridiculouspseudo-KarateandReed'sequallyridiculouspoetry;Buck'sgoalofopeninghisownstereostore;Amber'sattemptstogetbackintouchwithherson,whichsheblatantlycompensatesforbymotheringherco-stars--helpingusseethemasfleshed-outcharacters,notjustplotdevicesinthestory.
# Opinion of 'characters':
# 	 'main', 'fleshed'
#
#
# Sentence:
# 	Thecharactersarenotsointerestingnoristheacting.
# Opinion of 'characters':
# 	 'interesting'
#
#
# Sentence:
# 	Anothergreataspectoftheshowistheyarenotafraidtokilloffmaincharactersthatyougrowtoloveontheshow,soyouwillnevernowwhatisgoingtohappennextwhichkeepsyouwantingmore.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Itisabeautifulheartwarmingmovie,withgorgeousscenery,unforgettablecharacters,andplentyofmomentstolaughandcry
# Opinion of 'characters':
# 	 'unforgettable'
#
#
# Sentence:
# 	Again(asI'vesaidinotherofmyreviews),minorcharactersareimportant.
# Opinion of 'characters':
# 	 'minor', 'important'
#
#
# Sentence:
# 	AnotherpartofthestoryIfoundannoyingwasthelackofcommunicationbetweenthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Thoserepresentthemaleandfemaleviewpointsofthemaintwocharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Butifyouseethemovieasbeingabouttwointerestingcharacters,passitby.
# Opinion of 'characters':
# 	 'interesting'
#
#
# Sentence:
# 	Itismuchbetterthanhavingdifferentactorsplayingoldcharacters,whichdragsamoviedownalot.
# Opinion of 'characters':
# 	 'old'
#
#
# Sentence:
# 	The"bad"charactersareallprettylikeable,asidefromone,andalliswellintheend.
# Opinion of 'characters':
# 	 'bad', 'likeable'
#
#
# Sentence:
# 	"CinderellaII:DreamsComeTrue"isaseriesofthreestoriesfeaturingmostlycharactersfromtheoriginalCinderellaandafewnewones.
# Opinion of 'characters':
# 	 'mostly'
#
#
# Sentence:
# 	InoneofthemosthilariouscharactersI'veeverseenportrayedonscreen,wemeetDr.Strangelove(PeterSellers,yetagain)astrategistaidingthepeopleintheWarRoom.
# Opinion of 'characters':
# 	 'hilarious'
#
#
# Sentence:
# 	Thecharactersareallverylikeable.
# Opinion of 'characters':
# 	 'likeable'
#
#
# Sentence:
# 	Therearelittleromanticmomentsbetweenthemaincharactersthatmaketheshowmoreinteresting.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Themovietrieshardtofindthehumorinhitmenandquirkycharacters,butitoftenseemstobetryingabittoohard.
# Opinion of 'characters':
# 	 'quirky'
#
#
# Sentence:
# 	Also,whilemostBBCproductionsofliterarymasterpiecesarestudiesinsocialconservatismthisoneobviouslyidentifieswithandinvitesustoidentifywithitsmostirreverentandforward-thinkingcharacters:inthiscasethesultryandsophisticated,andsomewhatlibertine(ina1920'skindofway),LadyChatterly&theearthyandirreverentandsmoldering(smolderingbothwithclassresentmentandwithlustforaladyfromtheoppressiveclass)OliverMellors.
# Opinion of 'characters':
# 	 'irreverent'
#
#
# Sentence:
# 	Uniqueapproachtothesubject,charactersthatareflashyyethumanwithrealemotion,charactersplayedbyJulianneMoore,DonCheadle,HeatherGraham,WilliamH.Macy,andBurtReynoldsrespectfully,aregreattowatch.
# Opinion of 'characters':
# 	 'great'
#
#
# Sentence:
# 	Thecharactersaresowonderfullyindividual,fromself-absorbedKuzko,toevilYzmawithher"secretlab",todimwittedKronkwithhisshoulderangelanddevil
# (Secondly,lookwhatIcando.
# Opinion of 'characters':
# 	 'individual'
#
#
# Sentence:
# 	It'sagoodcombinationofamusicalandastorywithgoodcharactersandcharactersthatdonotmakegoodchoices:-)
# Opinion of 'characters':
# ...
# Opinion of 'dialogue':
# 	 'cliched'
#
#
# Sentence:
# 	Itisaverydialogue-heavyfilmandthedialogueisnotwell-writtenenoughtocarryitoff.
# Opinion of 'dialogue':
# 	 'written'
#
#
# Sentence:
# 	Throwinlotsoftortureddialogueaboutalternativeconsciousnesses/universes/fuelsupplies/sugarsubstitutes.
# Opinion of 'dialogue':
# 	 'tortured'
#
#
# Sentence:
# 	Thedialogueisdifficulttofollowespeciallysincemostofitismeaninglessanyway,andthefilmneverreallyfollowsit'spremiseasmuchasitshould:theriseofFactory.
# Opinion of 'dialogue':
# 	 'difficult'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'unbelievable'
#
#
# Sentence:
# 	Iunderstoodtheplot,andenjoyedsomeofthethoughtsraisedneartheend,butoverallwasboredsillybystilted,pointlessdialogue.
# Opinion of 'dialogue':
# 	 'stilted', 'pointless'
#
#
# Sentence:
# 	WhileBaldwinandtherestofthecastdidwellinfleshingoutBurke'scharactersandhavesometangytough-guy/galdialogue,they'rehamperedbytwothings:
#
# 1.)
# Opinion of 'dialogue':
# 	 'tangy'
#
#
# Sentence:
# 	Gooddialogueislikegoodacting:ifit'sreallygood,youdon'tnoticeituntiltheshow'sover.
# Opinion of 'dialogue':
# 	 'Good'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	soI'msupposedtobelievethatthehorribledialogue,badacting,andridiculousplottingisonpurposejustbecauseMametisarespectedguy?
# Opinion of 'dialogue':
# 	 'horrible'
#
#
# Sentence:
# 	Thedialoguewouldhavebeen1000timesbetter.
# Opinion of 'dialogue':
# 	 'better'
#
#
# Sentence:
# 	It'sthewaythestoryistold-itsham-fisteddialogueandplot,itsforcedobscenityateveryturn-thatrevealsitsteensensibilities.
# Opinion of 'dialogue':
# 	 'fisted'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	Thetwodimensionalniceoldbrotherandsisteraretreatedhorribly,fornogoodreasonwithnomotivationorpayoff,thesongsareunlistnableandthedialogueishardtounderstand,thisisnotalwaysabadthing.
# Opinion of 'dialogue':
# 	 'hard'
#
#
# Sentence:
# 	Youdon'tgotothesemoviestoexpectwell-writtendialogue,characterdepthoranything,youcomeforthekillsandtotellyouthetruth,they'reslightlydisappointing.
# Opinion of 'dialogue':
# 	 'written'
#
#
# Sentence:
# 	Theunwittydialoguetriestobecleverallthroughoutthemovieandisjustsoooboring.
# Opinion of 'dialogue':
# 	 'unwitty'
#
#
# Sentence:
# 	Thedialoguewassharpandyoumighthavetowatchtwicetogetallthesubtlequips.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueiswonderfullyexpressiveandgivesusthesenseofauthenticityandthekindofrealisticeffectseenonlyintheverybestfilms.
# Opinion of 'dialogue':
# 	 'expressive'
#
#
# Sentence:
# 	Thecolorsaredark,thedialoguebetweenthecharactersishonest,realandsimplywonderful.
# Opinion of 'dialogue':
# 	 'honest'
#
#
# Sentence:
# 	thisepisodehasalotoffunnydialogue,butthat'stheonlythingithasworkingforit.
# Opinion of 'dialogue':
# 	 'funny'
#
#
# Sentence:
# 	Inconclusion,thisTVshowhasitall:goodbackgroundmusic,greatdialogue,interestingstories,goodacting,andinterestingcinematography.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	Thedialogueissharpandwitty,althoughthere'salotofswearing,thatdoesn'tmeanthehumourisjustfowlmouthed,it'shillarious,someofthelinesgodowninhistoryassomeofthefunniestonelinersever.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Inanerawherecinematicpalatesseemtitillatedmostlybyfastactionthrillers,thismovieisanotherexampleofhowwellconstructeddialoguemakesforgrippingcinematicdramawhenitgoeshandinhandwithsuperbcastingandperformance
# Opinion of 'dialogue':
# 	 'constructed'
#
#
# Sentence:
# 	You'llbesuckedin,andsurprised,withinthefirsttwominutes,andthere'sverylittledialogue
# Opinion of 'dialogue':
# 	 'little'
#
#
# Sentence:
# 	Itseemsraretodaytofindsuchrichdialogue.
# Opinion of 'dialogue':
# 	 'such', 'rich'
#
#
# Sentence:
# 	OtherPeople'sMoneyisawonderfulmovie,fullofsmartdialogue,goodmusic,andaterrificDannyDeVitoperformance.
# Opinion of 'dialogue':
# 	 'smart'
#
#
# Sentence:
# 	Thedialogueisn'thard-boiledexceptforafewlinesdeliveredbyVicky.
# Opinion of 'dialogue':
# 	 'boiled'
#
#
# Sentence:
# 	iappreciatedtheeffects-nicetouch-butiwouldhavelikedtoseesomerealdialoguethere.
# Opinion of 'dialogue':
# 	 'real'
#
#
# Sentence:
# 	Relyingonsharpdialogueandfacialexpressions,theactorsmanagetoweaveagorgeoussensualdancetogether,bothlightingupthescreenandcreatingtwoofthemostsmolderinglycomplexcharacterseverseeninfilm.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	The'plain'dialogueamongthe'elders'ispainfullynumbing,choppy,andstilted.
# Opinion of 'dialogue':
# 	 'plain', 'numbing'
#
#
# Sentence:
# 	Thesoundtrackisawesome,thecinematographyisgreat,thedialogueisrealistic,andforonce,amoviesetinaforeignlandthatactuallyusesactorsfromthatareaspeakingthelanguageofthatarea!
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thismovieisweak,poorlywrittenandhassomelaugh-out-loudstereotypicalcop-schlockdialogue.
# Opinion of 'dialogue':
# 	 'loud'
#
#
# Sentence:
# 	(Thescript,bytheway,isonegreatlineafteranother,withverynatural,effortlessdialogue.
# Opinion of 'dialogue':
# 	 'natural', 'effortless'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Thestoryisfilledwithbiglaughs--fromcrudehumortosomeofthemostintelligentdialogueI'veprobablyeverheard.
# Opinion of 'dialogue':
# 	 'intelligent'
#
#
# Sentence:
# 	Thesurrealhumourandoff-kilterandunusuallybizarrehumourhasseducedthosethatlikeamixtureofpsychicalcomedy,comicinnerdialogue,aswellascrackingoneliners,mixedwiththeoccasionalrelativelyserioussubjectmatters,andphasesthatcanberecitedamongstfellowfans,tomuchamusement.
# Opinion of 'dialogue':
# 	 'comic', 'inner'
#
#
# Sentence:
# 	Thewritingissmartandwitty,thedialogueischarming,theperformancesaregreat.
# Opinion of 'dialogue':
# 	 'charming'
#
#
# Sentence:
# 	Thedialoguethroughoutwastediousandtrite;thescriptwritershouldbeontheunemploymentline,aswellasthedirectorandtheeditor.
# Opinion of 'dialogue':
# 	 'tedious'
#
#
# Sentence:
# 	Therereallywasn'tmuchanimosityfromeithersideofthe spectrum,rathertherewasalotofwell-intentioneddialoguefrombothsidesthatwouldgiveanybody,regardlessofpoliticalpersuasion,betterinsightintotheissuesinIraqandtheMiddleEast
# Opinion of 'dialogue':
# 	 'intentioned'
#
#
# Sentence:
# 	Ithasgreatfundialogue,isverytechnicallymodernforitstime,extremelyentertaining,fastpaced,andanabsolutejoytowatchthisCLASSICfilm~WHATATREAT!!
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thedialoguetoisequaltothatof"Coctail"-pointless,beentherebefore,densedialogue.
# Opinion of 'dialogue':
# 	 'equal', 'dense'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'unbelievable'
#
#
# Sentence:
# 	MarvellousdialoguebyBolt.
# Opinion of 'dialogue':
# 	 'Marvellous'
#
#
# Sentence:
# 	SetintheSouth,startingintheearly1950s,andasaSouthernermyselfIparticularlyenjoyedtheauthenticdialogue.
# Opinion of 'dialogue':
# 	 'authentic'
#
#
# Sentence:
# 	Thedialogueiswonderful,alloftheperformancesaresuperb,andCapra'sdirectionareexcellent.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	DotDrequiresabraintoenjoyasitisNOTaslambangshoot'emupwithditzydialoguetofillinthegorescenes.
# Opinion of 'dialogue':
# 	 'ditzy'
#
#
# Sentence:
# 	Themiddlesectionisadmittedlyratherdialoguebased,butthisdialogueisneverboringandservestoillustratewhythelivingdeadfeeltheneedtochompdownonwarmflesh.
# Opinion of 'dialogue':
# 	 'boring'
#
#
# Sentence:
# 	(He'smuchbetteronHOUSE,wherehegetssomerealcharacterizationandinfinitelybetterdialogue.)
# Opinion of 'dialogue':
# 	 'better'
#
#
# Sentence:
# 	Ifthedialoguewasn'twitty,festivalaudienceswouldn'thavegonenuts.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Stonecombinessuchwild,lush,andcrazyfilmeditingtodepictthemindsofVickeyandMallory,crazydialogue,uniquestorytelling,andallthewhilepokingfunathowweasthepeopleandthemediagocrazyforit.
# Opinion of 'dialogue':
# 	 'crazy'
#
#
# Sentence:
# 	ThefilmisslightalthoughitbenefitsfromsomesharpHermanMankiewiczdialogue.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Manyclose-upshotsofherbarechest.(d)HighlyXXXdialogue,suchasthelinewhere11yearoldViolettellshercustomerthat"Icanfeelthesteamjustcomingthrumydress"(e)
# Opinion of 'dialogue':
# 	 'bare'
#
#
# Sentence:
# 	Themovieisactionpackedwithexcellentdialogueandtheactionneverstopsuntiltheveryappropriateend.
# Opinion of 'dialogue':
# 	 'excellent'
#
#
# Sentence:
# 	Andthedialogueiscertainlymemorable:
#
# JackBull:
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Itmakesyouquestionwhyyoubuyintosuchsappydialogueandsituations.
# Opinion of 'dialogue':
# 	 'such', 'sappy'
#
#
# Sentence:
# 	Whilewatching,inmyheadIwasfillinginthedialogueforthecharacters,andmydialoguewasalotmoreinterestingthananythingthesepeoplesay.
# Opinion of 'dialogue':
# 	 'interesting'
#
#
# Sentence:
# 	ThoughIcannotdenythatitisunbelievablycheesy,filledwithpracticallyeveryclicheonecanimagineandcontainstonsofembarrassingdialogue(especiallyKurtRussell'sbeggingspeech)andunconvincinglovescenes(Mel,willyoupleasekissherlike
# Opinion of 'dialogue':
# 	 'embarrassing'
#
#
# Sentence:
# 	Thedialogueisveryfunnyandwittyattimes.
# Opinion of 'dialogue':
# 	 'funny'
#
#
# Sentence:
# 	Rarelyhassomuchbeensaidsosuccessfullywithsolittledialogue.
# Opinion of 'dialogue':
# 	 'little'
#
#
# Sentence:
# 	AlthoughI'msureyouwillwanttoseewhathappenedtoallofyourfavoritecharacters,yourhopeswillcertainlybedashedanddisappointedbyapoorstoryandpoordialogue
# Opinion of 'dialogue':
# 	 'poor'
#
#
# Sentence:
# 	Thedialogueisoftenunconvincingandoneoccassionallytiresoftheconstantneedinmoviemakingtouseeachcharachterasanarchetype.
# Opinion of 'dialogue':
# 	 'unconvincing'
#
#
# Sentence:
# 	ThesheeraudacityofthistaskisahallmarkofChayefsky'svitriolicstyle,andthefilmisfullofhisbrittle,observantdialogueandsharplyarticulatesoliloquies.
# Opinion of 'dialogue':
# 	 'observant'
#
#
# Sentence:
# 	Here,inthismovie,you'vegotagoodcast,cooldialogue,andanon-stopactionthrillride.
# Opinion of 'dialogue':
# 	 'cool'
#
#
# Sentence:
# 	AnyonefamiliarwithTheSimpsonswillenjoythehumorinOlive,TheOtherReindeer,aswellastheanimationandwittydialoguethatpassesquicklyinthisforty-fiveminutemovie.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Allinvolverichdialogueandinterestshown.
# Opinion of 'dialogue':
# 	 'rich'
#
#
# Sentence:
# 	First,thedialogueandsituationsaresoinsipidtheyofteninspireunintentionalhilarity.
# Opinion of 'dialogue':
# 	 'insipid'
#
#
# Sentence:
# 	Withoutcontrivedmanipulations,youaredrawnintothedepthsandheightsoftheiremotionsthroughtheuseofstunningvisuals,dramaticportrayals,pithydialogue,momentsofquietcontemplation,andaserenemusicalsoundtrackthatisworthowningonitsownmerits.
# Opinion of 'dialogue':
# 	 'pithy'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Ithashistrademarkrealisticdialogueandwithoutanyflashyeffectshefocusesonthecharacters.
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thedialogueiswarmandwittyandtheactorsarewonderful.
# Opinion of 'dialogue':
# 	 'warm'
#
#
# Sentence:
# 	Allen'sdialogue(whichisalwaysgood)isparticularlygoodintheconversationsbetweenIsaacandMary;ThefinalscenebetweenIsaacandTracyisalsoverymeaningfulandverygood.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	LiketheothermoviesthereissomegreatdialogueinthismovieandIhighlyrecommendthemovietofansofChrisFarley,ChrisRockandSNL.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Yes,themoviehasflaws:thedialoguecanbealittlegoofyattimes,theactingsomewhat-shallwesay-idiosyncratic,thespecialeffectsdon'talwayswork,andtheinternallogicisnotalwaysapparent(theGrailisArthur?
# Opinion of 'dialogue':
# 	 'goofy'
#
#
# Sentence:
# 	Withcringinglyawfulacting,laughablespecialeffects(theridiculousheadinabucketisarealguffawmoment),appallingdubbeddialogue,cheesymusic,inconsistentandconfusingplotandnotensionoratmosphere,TheGrimReaperisatotaldisaster.
# Opinion of 'dialogue':
# 	 'dubbed'
#
#
# Sentence:
# 	Theearlypartofthisfilmisfilledbothwithsnappy,intelligentdialoguebutalsowithasophomoricphysicalcomedywhichcanhonestlybeconsideredtobeatorbelowapie-in-the-facelevelofsophistication.
# Opinion of 'dialogue':
# 	 'snappy', 'intelligent'
#
#
# Sentence:
# 	Betweenincrediblybaddialogueaboutthingslikethe"plutonium-rubycrystalbeamgun,"sillyincidentalmusic,andaVenusianmadeoflatex,twigs,andtissuepaper,thisonecannotbebeat.
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	Baumbach'sscreenplayboastslotsofmemorabledialogue,lotsofclevernessyoumightfindyourself"borrowing."
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	Thegreatsweetbeautyofthisfilm,however,isthemarriageofsuchengagingdialogue,suchearnestdeadpandeliveriesshotinsucheerieclarity--onereminiscentoftheinteriorsinDutchgenrepainting:clean,homely,homiletic.
# Opinion of 'dialogue':
# 	 'such', 'engaging'
#
#
# Sentence:
# 	Itmanagestoturnasuiteofclassicallystaticimages-bronzed,burnished,melancholy-uponafast-drivingdialogueendowedwiththemodestbutenhancingartificialityofapainting,anovelor--betteryet--aninfinitelyrefinedfilm
# Opinion of 'dialogue':
# 	 'bronzed', 'driving'
#
#
# Sentence:
# 	Manywillbemovedbyhownaturalthedialoguesounds(herecordedmostofitonthestreets),alotofitobviouslyinspiredbyhisownlife.
# Opinion of 'dialogue':
# 	 'natural'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'fast'
#
#
# Sentence:
# 	Indeed,thedialogueissobeautifullyeloquent,wefeellikeweareoftengiventhemodernequivalentofShakespeare.
# Opinion of 'dialogue':
# 	 'eloquent'
#
#
# Sentence:
# 	Selectionof
# locations,environmentsandcharactersissimplywonderful--sureto
# keeptheviewerengrossed,eventhoughthedialogueisuncompromisingly
# British.
# Opinion of 'dialogue':
# 	 'British'
#
#
# Sentence:
# 	Recentadaptationsseemafraidtoincludeoriginaldialogueatanylength-
# Opinion of 'dialogue':
# 	 'original'
#
#
# Sentence:
# 	Verywittydialogueandscenes;flawlessactingbyleadandsupportingactors.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	ThisisChaplin'sfirstfulldialoguefilm,eventhough'TheGreatDictator'washisfirstsoundfilm.
# Opinion of 'dialogue':
# 	 'full'
#
#
# Sentence:
# 	Mywifesaysallofhismoviesarethesame,anditbreaksmyhearteverytimeshesaysit...becauseinthatblanketanalysis,theanalystmissestheincrediblestoriesandcraftydialoguethattakesplaceinthemanyWoodyAllenmoviesthatprettymuchtakeplacewithinthesametemplate.
# Opinion of 'dialogue':
# 	 'crafty'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'fast'
#
#
# Sentence:
# 	Thisisamust-haveifyoulikeagoodstoryline,cleverdialogueandhonestlaughs.
# Opinion of 'dialogue':
# 	 'clever'
#
#
# Sentence:
# 	GreatforthepurestinthecrowdbutkillerforthoseofuswholikebadlydubbedEnglishdialogue.
# Opinion of 'dialogue':
# 	 'dubbed', 'English'
#
#
# Sentence:
# 	Theweaknesseswereimmediatelyapparent--awkwarddialogue,lackofvisualstyle--butIhopedthemoviewouldovercomeitsfaults.
# Opinion of 'dialogue':
# 	 'awkward'
#
#
# Sentence:
# 	Thismayhelpsomeofyouslowerpeople(don'tbeashamed)tounderstandthefilm,althoughmuchofitsimportantintricatedialogueandoverallappealwillbelostinthisversion.
# Opinion of 'dialogue':
# 	 'important', 'intricate'
#
#
# Sentence:
# 	Thereareproblemswiththefilm,themostannoyingonebeingthatthedialogueispracticallyinaudibleduetothemikingand,moreso,duetothemusicalscorewhichcoversallthelinestothepointofmakingthemovieseemlikeasilentmoviewithmusicfromthepit!
# Opinion of 'dialogue':
# 	 'inaudible'
#
#
# Sentence:
# 	Themood,thesensuousdialogue;Thisisjustnoiratit'sbest.
# Opinion of 'dialogue':
# 	 'sensuous'
#
#
# Sentence:
# 	Thistart,well-scriptedcomedyisalittlelightonthedancing,butfeaturessomeofthebest,briskestdialoguethatcameAstaire'sway,andafinesupportingcast,includingthefamousHollywood&quot;double-talker,&quot;CliffNazarro,goingthroughhisroutineinnumerousscenes.
# Opinion of 'dialogue':
# 	 'best'

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on examples, A.1 and B.1
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %% [markdown]
# ## Extension C: Adverbial modifiers
# If you used the extractor you have built so far on the example sentences below, it will only find the opinion "*dull*". It would not recover an indication of the strength of the opinion. Adverbs like "*excessively*" elaborate on the adjectives that they modify in adverbial modification relations.
#
# The relevant dependency relation we use to show this relationship is "*advmod*".
#
# Your opinion extraction function when given a sentence like those below containing the aspect token "*plot*", should use the `advmod` relation to output features like "*excessively-dull*"
# - If you have an adjective token in a variable `adj_token`, and an adverb in a variable `adv_token` then you could create this feature like this: `adv_token.form + "-" + adj_token.form`.
# - If you have a list of strings, you can use python's `join` function to concatenate them into a single string. The following would join the strings together, placing a `"-"` between each:
# `joined_string = "-".join(listofstrings)`
#
#
# **Core Example C.1**: "*It has an excessively dull plot.*" should produce "*excessively-dull*"
# **Core Example C.2**: "*The plot was excessively dull.*" should produce "*excessively-dull*"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension 3 example](./img/advmod_example_1.png)

# %% [markdown]
# ![Extension 3 example 2](./img/advmod_example_2.png)

# %%
def opinion_extractor(aspect_token,parsed_sentence):

    opinions = []
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.text == aspect_token:
            for child in token.children:
                if child.dep_ == 'amod':
                    advmod = build_advmod_string(child)
#                     for subchild in child.children:
#                         if subchild.dep_ == 'advmod':
#                             advmod += subchild.text + '-'
                    opinions.append(advmod+child.text)
            if token.dep_ == 'nsubj':
                filterList = set(filter(lambda x: x.dep_ == 'acomp', token.head.children))
#                 print(list(filterList))
                for x in filterList:
                    advmod = build_advmod_string(x)
                    opinions.append(advmod+x.text)
#     print(opinions)
    return opinions

def build_advmod_string(token):
    advmod = ''
    for child in token.children:
        if child.dep_ == 'advmod':
            advmod += child.text + '-'
    return advmod

def show_results(results,aspect_word):
    print("Results for aspect word '{}'\n".format(aspect_word))
    for word,sent,opinions in results:
        if word == aspect_word:
            print("Sentence:\n\t{}".format(sent))
            print("Opinion of '{0}':\n\t '{1}'".format(aspect_word,"', '".join(opinions)))
            print("\n")

aspect_words = ["plot","characters","cinematography","dialogue"]
results = [] 
for parsed_review in parsed_reviews:
    for sentence in parsed_review.sents:
        for aspect_token in aspect_words:
            opinions = opinion_extractor(aspect_token,sentence)
            if opinions:
                results.append((aspect_token,sentence.orth_,opinions))

show_results(results,"plot")
show_results(results,"characters")
show_results(results,"cinematography")
show_results(results,"dialogue")
# Out:
# Results for aspect word 'plot'
#
# Sentence:
# 	However,theplotwaspredictable.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Furthermore,theplotissopredictablethatitmadethemoviedrag.
# Opinion of 'plot':
# 	 'so-predictable'
#
#
# Sentence:
# 	well,that'stheusualpredictableromanceplot.
# Opinion of 'plot':
# 	 'usual', 'predictable'
#
#
# Sentence:
# 	TheplotwasOKbutitwouldhavebeenmuchbetteriftheyhadeitherstucktoamoreauthenticrepresentationofJapanesecultureorkeptthestoryinthestates.
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Theperformancesarethinanduneven,theplotisinconsistent,andthedialoguesoundslikeitwaspulledfromfortunecookiesmadebythecastofFriends.
# Opinion of 'plot':
# 	 'inconsistent'
#
#
# Sentence:
# 	AlthoughthismoviewantedtobeinthesameraceandqualityofthemovieCLUE,itfailstorealizethattheplotandcharactersareincrediblyriculousandnotfunnyhahabutfunnystupid.
# Opinion of 'plot':
# 	 'incredibly-riculous'
#
#
# Sentence:
# 	Theactingishorrible,theplotishorrible,thefilmingishorrible...
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Its"thriller"aspectisartificialandnottiedtothecentralplotline,andentirelypredictablefromthemomentourfriendishandedTHEONLYKEYTHATCANSTOPTHENUKE!
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Theplottothismovieorsocalledsequalishorrible.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'surprisingly-straightforward'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Withtheirchildestvoices,theyshouldn'tbeusedasamainplotofthestory
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Asfarasthemovieisconcerned,theplotisunoriginalandnotparticularlyengaging.
# Opinion of 'plot':
# 	 'unoriginal'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Thiswassuchacontrivedmoviethathadasimpleplotthatwentnowhere.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Themoviewasn'tfunny(whichissadtosaywhenoneofmyfavoritecomedicactresses,CarolKane,couldn'tevenelicitasmileoutofme),theplotwasfullofholes,andthewritingseemedveryrushedandcontrived.
# Opinion of 'plot':
# 	 'full'
#
#
# Sentence:
# 	Thespecialeffectsareabitcheesy,youcanseethewirespullingthetorpedosandyoucantellthattheyusedscaledmodelships...butifyouoverlookthoseitems,yougetfineactingandagoodplotwithplentyof
# action
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	stupidplot-toomanyholesandstupidending.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theentireplotisself-serving,shallow,andunrealistic.
# Opinion of 'plot':
# 	 'entire', 'serving'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Thebasicplotofthemovieisthatlifesucks(
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	TheplotislameandIamsorryIspentthemoneyonit.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Butthedumbplotandtheunfunnyattemptsatcomedymakeitacompletewasteoftime.
# Opinion of 'plot':
# 	 'dumb'
#
#
# Sentence:
# 	Eraserhasafewscenesthatwillkeepyourattention,butoverallthemoviedisplayedpooracting,stuntsthatareimpossibleandamediocreplot.
# Opinion of 'plot':
# 	 'mediocre'
#
#
# Sentence:
# 	Verypredictableplotfrombeginningtoend.
# Opinion of 'plot':
# 	 'Very-predictable'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Iwasveryboredwiththismovieandfoundtheplottobeveryinsulting.
# Opinion of 'plot':
# 	 'very-insulting'
#
#
# Sentence:
# 	Buysomthingthathasagoodplot.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Oneoftheworstmoviesi'veeverseen,norealplotandactingisasbadasitcanget.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Canyoureallycarry2hourswiththissingleplot?
# Opinion of 'plot':
# 	 'single'
#
#
# Sentence:
# 	Theplotiscomplicatedandthenoiseinthebackgroundaddstothedisorientationwhichisdoneonpurpose.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Buttheplotwaslame&slow.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'plot':
# 	 'rather-unbelievable'
#
#
# Sentence:
# 	Thisseriesmightbeconsideredaclassicifwatchedbya12-year-old,butadultswillseethoughtheindistinctplotandcharacters.
# Opinion of 'plot':
# 	 'indistinct'
#
#
# Sentence:
# 	Theplotwasadequate.
# Opinion of 'plot':
# 	 'adequate'
#
#
# Sentence:
# 	Ijustcan'tgetoverhowprofoundlycornyandsimpletheplotandeffectsare,
# Opinion of 'plot':
# 	 'profoundly-corny'
#
#
# Sentence:
# 	BeforeIhitthistooharshly,thisfilmwasintendedtobeatrifle,thekindofmoviethathasbrightcolorsandlightplotforahotsummerdaythatsizzles.
# Opinion of 'plot':
# 	 'light'
#
#
# Sentence:
# 	Soundslikeaninterestingplot,right?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Feebledirectionsimplymissesseveralgoodopportunitiestomakegooduseofthejockey'ssullenlittledaughterSam(KayPanabaker,herfeaturedebut),whocouldhavebeenalittlesurprise(orgem)inthisunconvincingplot.
# Opinion of 'plot':
# 	 'unconvincing'
#
#
# Sentence:
# 	Theonlybluehereistheshadeyouwillturnbytheboredomwiththeweakplot.
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	TheplotwasbadanditdidnothavethatmanypokemonasIthought.
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	...hasaprettythinplot.
# Opinion of 'plot':
# 	 'pretty-thin'
#
#
# Sentence:
# 	Infact,thetrialdoesn'tevenhaveaconnectiontothecentralplotasidefromshowingthatSamandArchiearefriendsandpartners.
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Howeverifyoulikesex,violence,blood,anddebauchery,couldcarelessthefactthattheyhavenothingtodowiththeabsentplot,youcouldfindthisfilminteresting.
# Opinion of 'plot':
# 	 'absent'
#
#
# Sentence:
# 	Andplotissoludicrouslypredictableit'sprettyclearearlyonjustwhothebadguybehindthecurtainis.
# Opinion of 'plot':
# 	 'so-ludicrously-predictable'
#
#
# Sentence:
# 	Flatlighting,cheapsetsandcostumes,dulldialog,woodenacting,andagoofyplot;evenpervasivesiliconeenhancementcannotsavethismovie.
# Opinion of 'plot':
# 	 'goofy'
#
#
# Sentence:
# 	Theplotifpoorlycontrived,theproductionvalueislow,theactingforthemostpartisawful,andit'sbasicallyjustawaytostitchtogetheraseriesofmusicvideoswhichathisage,mysonhasnointerestin.
# Opinion of 'plot':
# 	 'low'
#
#
# Sentence:
# 	JuryDutysimplywasjustplainawfulwithit'sweak,boringplotandunfunnyhumor!
# Opinion of 'plot':
# 	 'weak', 'boring'
#
#
# Sentence:
# 	Theplotofthemovieisinterestingandkeepsyouwonderingwhatisgonnahappennext.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	Theplothowever,isexcellent.
# Opinion of 'plot':
# 	 'excellent'
#
#
# Sentence:
# 	Veryinterestingandunpredictableplot.
# Opinion of 'plot':
# 	 'Very-interesting'
#
#
# Sentence:
# 	Theplotfeelssluggishattimesandthere'swaytoomuchXavierCugatandhisorchestra,butAstaireandHayworthareattheirpeak,KernhaswrittensomememorablemelodiesandfewcouldtopMerceratlyricwriting,noneinHollywood.
# Opinion of 'plot':
# 	 'sluggish'
#
#
# Sentence:
# 	Basicplot:
# Opinion of 'plot':
# 	 'Basic'
#
#
# Sentence:
# 	Sowhileitwasaconvenientplotdevice,youwouldexpectsomethinglikethatbysomeonewithonlyminimalknowledgeofdinosaurs.
# Opinion of 'plot':
# 	 'convenient'
#
#
# Sentence:
# 	itwasquitefunny,buttherewaslessactionandlessplotcomparedtootherepisodes.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	Almosttheentireplotisonboardandunderway.
# Opinion of 'plot':
# 	 'entire', 'onboard'
#
#
# Sentence:
# 	Fromthereitjustgetsprogressivelydarkerandtenser,withthelighting,acting,anddirectionallperfectlyservingtoratchetupthefeelingofdesperationandhorrorasToddkickshisill-conceivedrobberyplotintomotionandthingsspinwayoutofcontrol.
# Opinion of 'plot':
# 	 'ill-conceived'
#
#
# Sentence:
# 	Whileit'shardtopickmyfavoritefirstseasonepisode,thecomplexplotof"APriest,A
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Theplotwaswellworn,butitdidn'tfeelstaidorplodding.
# Opinion of 'plot':
# 	 'well-worn'
#
#
# Sentence:
# 	Theplotisperfectandthescriptiswellwritten.
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplotissweet.
# Opinion of 'plot':
# 	 'sweet'
#
#
# Sentence:
# 	Thequalityofthegraphicsareterrific,theplotisalittlestrange,butbasicallyitsalienswhoinvadeandride4virtualrollercoastersatafuturisticthemepark.
# Opinion of 'plot':
# 	 'little-strange'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	anywayirecommendthistoanyonewholoves Asianhorrorandlikesagoodplotandmovie!!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisnotveryintriguing,andyouknowthatnothinglikethiscanhappeninthereallife,soitlacksthissenseofreality.
# Opinion of 'plot':
# 	 'very-intriguing'
#
#
# Sentence:
# 	I'mnotamoviebuff,butDeepCoverhasalltheelementsyouwouldexpectofaclassic:greatacting,memorablelines,interesting(andlogical)plotandadecentending.
# Opinion of 'plot':
# 	 'logical'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'plot':
# 	 'silly', 'funny'
#
#
# Sentence:
# 	TheplotevolvesasmanyotherCoenmovies(RaisingArizonacomestomind)asweareintroducedtomore-and-morecolorfulcharactersandtheplotgetsmore-and-moreoutrageous,yetsomehowstillseemsreal.
# Opinion of 'plot':
# 	 'more-outrageous'
#
#
# Sentence:
# 	Everyoneknowsthebasicplotbynow:SpockkidnapshiscrippledformerCaptain,andhijackstheEnterprise,andsetscoursefortheoneforbiddenplanetinallTheFederation.
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	Yes,theplotisodd.
# Opinion of 'plot':
# 	 'odd'
#
#
# Sentence:
# 	Itdoesn'tfollowastorylinethat'spredictable,eventhoughtheplotisnotunknown.
# Opinion of 'plot':
# 	 'unknown'
#
#
# Sentence:
# 	Itusesoneoftheworstsuperheroclichesasthemainplot,thatoftheherocallingitquits.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	There'sashadowyplotinvolving$10,000bills,aguerillamovementandguns,butthemoviefocusesmoreonQuinn'sconflictsbecausehischildhoodfriendissuspectedofagrislymurder,andQuinn'sowndiscomfortfromhaving"madegood"butendingupcaughtbetweentwoworlds,whiteandblack.
# Opinion of 'plot':
# 	 'shadowy'
#
#
# Sentence:
# 	Wasitcancelledbecausetheplotwasflimsyordumb?
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Theplot,thesetting,thedialogues,thespecialeffects,andthemusicareallwonderful!
# Opinion of 'plot':
# 	 'wonderful'
#
#
# Sentence:
# 	Theplotisinteresting,itkeepsyouguessing,andthesuspensekeepsyouontheedgeofyourseat.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	DirectedbyTamraDaviswithakeeneyeoncharacterizationandhumor,thismovieisoneofthoseyousmilemostofthetime,andhaveagoodtimewithitssurrealandzanyplot.
# Opinion of 'plot':
# 	 'surreal'
#
#
# Sentence:
# 	Theplotwasn'thorrible,itwasactuallyprettygoodforafrightflick.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplot,thesetting,theacting,andthedialoguesareallverygood.
# Opinion of 'plot':
# 	 'very-good'
#
#
# Sentence:
# 	Theplotiscomplex.
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Eventhoughthefilmisbasedonafictionalplot,itstillhasanauthenticfeelandisratedanalltimeclassic.
# Opinion of 'plot':
# 	 'fictional'
#
#
# Sentence:
# 	Theplotisgood,andDeoxys''destructive'intentionsarelesscruelthanonewouldthink.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotanddialogueisincrediblebecauseitexploresalltheshadesofgreyinthecharacters.
# Opinion of 'plot':
# 	 'incredible'
#
#
# Sentence:
# 	theplotwasprettyoriginal.
# Opinion of 'plot':
# 	 'pretty-original'
#
#
# Sentence:
# 	Thisfilmmaynotbeperfect,andtherearesomeboringscenesastheytrytohardtoexplainthestateNickisin,buttheoverallplotofthisfilmisoneI'veneverseendonebefore.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisprettyunrealisticbutthenitisascrewycomedysoithelpsifyoususpendagooddealofdisbelief.
# Opinion of 'plot':
# 	 'pretty-unrealistic'
#
#
# Sentence:
# 	ItcombinesabunchofthebestFrenchactrices,andanenjoyableplot.
# Opinion of 'plot':
# 	 'enjoyable'
#
#
# Sentence:
# 	theplotwasdry,liketheother2oftheseries,buthowexcitingofaplotcanyouhavewiththeamountofactionandskilleddrivingpackedintothemovie.
# Opinion of 'plot':
# 	 'dry'
#
#
# Sentence:
# 	Suretheplotofweakandtherelationshipsareunbelievable,ImeanwhocanhonestlysaythattheyfeelakingpintotheJapanese/Chinese/Oriental(whateveritwas)
# Opinion of 'plot':
# 	 'unbelievable'
#
#
# Sentence:
# 	Thisfilmhassomegoodactorsinitbuttheplotisprettyshakyandhardtofollowattimes.
# Opinion of 'plot':
# 	 'pretty-shaky'
#
#
# Sentence:
# 	Itcouldhavebeenmadebetter--lesscomedyandmoreplotandofcourse--actionandsuspense!!!!
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Theplotwasveryst8fowardandbasicwithafewlittletidbitstolivingitup.
# Opinion of 'plot':
# 	 'foward'
#
#
# Sentence:
# 	Theplotisverygood.
# Opinion of 'plot':
# 	 'very-good'
#
#
# Sentence:
# 	but,unfortunately,theproducersforgettogivethemacredibleplotandinterestingthingstosay.
# Opinion of 'plot':
# 	 'credible'
#
#
# Sentence:
# 	PeoplewhoreviewSpielbergusuallywanttopigeonholehimintoatype:theET-warm-and-fuzzy-alienchildren'sstorytellerversusthespecial-effects-heavy-but-rather-empty-plotdreamer.
# Opinion of 'plot':
# 	 'empty'
#
#
# Sentence:
# 	Theplotisslowtodevelop,characterdevelopmentlackingandanimationprimitiveatbest.
# Opinion of 'plot':
# 	 'slow'
#
#
# Sentence:
# 	Bothfilmshavethesameborringplot.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Maybethenextfewvolumeswillbemorecreativeandgivemoredetailsonthemainplot,butIpersonallydon'tcaretospendanymoreofmymoneyonsucharisk.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Thebad:Notaveryinterestingorprofoundplot.
# Opinion of 'plot':
# 	 'bad', 'very-interesting'
#
#
# Sentence:
# 	Theplotofthestoryisreallyinteresting.
# Opinion of 'plot':
# 	 'really-interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whiletheplotisnearlyidentical,AlexanderPayne(director)treatshischaractersmuchharsherthanPerrotta.
# Opinion of 'plot':
# 	 'nearly-identical'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	ThestorybeginswithafailedassasinationplotthenfollowsMalciekChelmicki(ZbigniewCybulskiakaPolandsJamesDean)untilit'sconclusion.
# Opinion of 'plot':
# 	 'failed'
#
#
# Sentence:
# 	Episode16:"TheFactofBeingThere"/"AnotherChance"
# Andallattentionbacktothemainplot.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Althoughtheplotisalittlethin,therearesomeveryfunnymoments.
# Opinion of 'plot':
# 	 'little-thin'
#
#
# Sentence:
# 	Theplotwas,insomerespects,totallyillogical,andatothertimesnonsensical.
# Opinion of 'plot':
# 	 'totally-illogical'
#
#
# Sentence:
# 	Theplotisentirelyunconvincingandimplausible.
# Opinion of 'plot':
# 	 'entirely-unconvincing'
#
#
# Sentence:
# 	Verygoodplotanddetail
# Opinion of 'plot':
# 	 'Very-good'
#
#
# Sentence:
# 	Insummary,themusicportionofthisDVDratesastrongfivestars,butthesillyplotandtheproblemswiththediskdiscussedabove,bringthisDVDdowntoafourstarproduction
# Opinion of 'plot':
# 	 'silly'
#
#
# Sentence:
# 	Theplotisfartoocomplicatedandtwistytogetinto,andfranklyhasbeengoneoverwithafinetoothcombalreadyonthissite.
# Opinion of 'plot':
# 	 'far-too-complicated'
#
#
# Sentence:
# 	Unlike,forexample,LOSTHIGHWAY,thisisacompletelyrealisticplot,withnosupernaturalorunexplainableelements.
# Opinion of 'plot':
# 	 'completely-realistic'
#
#
# Sentence:
# 	OnceyoualreadyknowtheoverallplottheDirector'sCutisbetter,andallthestuffthat'saddediniscool,
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Fourth,theplotisslickandoriginal.
# Opinion of 'plot':
# 	 'slick'
#
#
# Sentence:
# 	It'snotasifthefilmwouldbecompletlyalienatingtonewcomers,notatall,itsjustthatifIhadn'treadthebookbeforehand,I'msureIwouldhavefoundthingsabithardertofollow,asthingsmovefairlyquicklyandthere'saneverthickeningplottokeepaneyeon.
# Opinion of 'plot':
# 	 'ever-thickening'
#
#
# Sentence:
# 	Wellthat'sabouttheentireplotofthismovie.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Allheneedstocompletethisisasmallplotofland.
# Opinion of 'plot':
# 	 'small'
#
#
# Sentence:
# 	this1hasastupidplot.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Yojimboisavastlyentertainingactionfilmwithalltheelementsofthatgenre:fastpace,surprisingplotturns,andajustlyfamoussamuraishowdown.
# Opinion of 'plot':
# 	 'surprising'
#
#
# Sentence:
# 	Myfavoritesongis&quot;NeverTalktoStrangers&quot;.Themovieelaboratesontheoriginalstorybyaddingmoreplottospicethestoryup.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Lynchdoesn'tfollowarealplot;instead,heletsthestorylineslowlysinkintoLaura'sdownfall.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Thisfilmisperfectforeveryone,thealluringplot,amazingacting,entertainingscreenplay.
# Opinion of 'plot':
# 	 'alluring'
#
#
# Sentence:
# 	TheplotcanbealittledumbattimesbutChrisTuckeriswhatthismovieisallabout.
# Opinion of 'plot':
# 	 'little-dumb'
#
#
# Sentence:
# 	Theplotiscomplexenoughtokeepthewatcherguessingwhatexactlywillhappenandnotboretheaudience.
# Opinion of 'plot':
# 	 'enough-complex'
#
#
# Sentence:
# 	Badforanyonewhowantshighproductionvalueoranidentifiableplot
# Opinion of 'plot':
# 	 'identifiable'
#
#
# Sentence:
# 	Plentyofaction,plentyofbeautifulsceneryandpeople,ahalfwaydecentplot,plentyoflogicalunpredictability,anditplayswellonthesmallscreen.
# Opinion of 'plot':
# 	 'halfway-decent'
#
#
# Sentence:
# 	Irecommendthismovietoanyonewhoislookingforagoodcomedywithaveryfunnyplot.
# Opinion of 'plot':
# 	 'very-funny'
#
#
# Sentence:
# 	-"LovebeforeBreakfast"isaUniversalproductionandhasthesimplestplotofthecollection;infact,noplotatallreally.
# Opinion of 'plot':
# 	 'simplest'
#
#
# Sentence:
# 	Thefilmcombinestoomanygenresandtheplotbecomesconvoluted.
# Opinion of 'plot':
# 	 'convoluted'
#
#
# Sentence:
# 	Inthistreatmentoftheannoyingplot,heloseshismind.
# Opinion of 'plot':
# 	 'annoying'
#
#
# Sentence:
# 	AnatomyofaMurderisatoncebothadelightfulmysteryandasuspensefulthillerforthosewouldwouldratherthinkaboutallthemanydimensionsandlayersofintriquegoingoninamovieratherthanbespoonfedaformulaicplot.
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Ratherformulaicplot;thedancingisthethinghere
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Theanimationistotallycool,thekidsarebelievable,theplotisinterestingandhassometwistsandturnstokeepyouguessing,andthedialogisdownrightfunnyattimes.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Theplotisverysimple,thesetsaresimple...butthefilmisgreat.
# Opinion of 'plot':
# 	 'very-simple'
#
#
# Sentence:
# 	CreditneedstobegiventoJamieAnderson'scinematographyandNeilSpisak'sproductiondesignforestablishingsuchaheadyatmosphereperfectforthelabyrinthplot.
# Opinion of 'plot':
# 	 'labyrinth'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Iwon'tre-hashtheplotasAmazonhasalreadyprovidedpotentialbuyerswiththeoutline.
# Opinion of 'plot':
# 	 'hash'
#
#
# Sentence:
# 	Themoviestillhadsappylines,unrealisticplot,andunconvincingelementstoit.
# Opinion of 'plot':
# 	 'unrealistic'
#
#
# Sentence:
# 	Ifyourlookingforanimethathasaction,suspence,romance,humor,andanengagingplotwithlotsoftwistsEscaflowneistheonetoget.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Theplotistooimplausibleandriddledwithinconsistenciestobetakenliterally.
# Opinion of 'plot':
# 	 'too-implausible'
#
#
# Sentence:
# 	Greatcharacters,awellcraftedplot,andsomeofthebestanimationIhaveeversee.
# Opinion of 'plot':
# 	 'well-crafted'
#
#
# Sentence:
# 	Theplotisfartooconvolutedtoevenbegintorecount,butthepremiseisthatthesetwounlikelycharactersareabouttobecomein-laws.
# Opinion of 'plot':
# 	 'far-too-convoluted'
#
#
# Sentence:
# 	Wonderfullocations,mesmerizingstunts,admirablespecialeffects,averycleverplotandrespectablecastobligatesustoconsiderabsolutelyrecommendable.
# Opinion of 'plot':
# 	 'very-clever'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Butthereisenoughplottounderstandwhatthestoryisabout.
# Opinion of 'plot':
# 	 'enough'
#
#
# Sentence:
# 	Ienjoyedthismoviebecausetheplotwasverydifferentandnotrunofthemilllikemosthorrormovies.
# Opinion of 'plot':
# 	 'very-different'
#
#
# Sentence:
# 	TheplotisOKandwithatwistthatshouldn'tberevealedbeforehand
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Themovie"Boo"featuresterribleacting,andadeplorableplot.
# Opinion of 'plot':
# 	 'deplorable'
#
#
# Sentence:
# 	It'snotarevolutionaryplot,andafewscenescouldhavebeenbetterexecuted(theobligatory'break-up'beforethehappyendingisratherweak),butonthewholethemushysideofmeateitup.
# Opinion of 'plot':
# 	 'revolutionary'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Theplotisratherthinandconsistsofthefairyworldtryingtotakeoverthisworld.
# Opinion of 'plot':
# 	 'rather-thin'
#
#
# Sentence:
# 	BeeSeason"isjusthorribleandthismoviehasamuchbetterplot,betteractingandabettermessage.
# Opinion of 'plot':
# 	 'much-better'
#
#
# Sentence:
# 	IfIhadn'tseentheoriginalI'djustthink,"whatabrilliantplot,toobadtheydecidedtoburyit(nopunintended)witheverythingelseinthemovie".
# Opinion of 'plot':
# 	 'brilliant'
#
#
# Sentence:
# 	belowaverage,thedialoguesarewaybelowaverage,whiletheplotisnotbadatall.
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Theplot isludicrous,thescriptfoolishandinept,theactingsocrudeastobeembarrrassing.
# Opinion of 'plot':
# 	 'foolish', 'ludicrous'
#
#
# Sentence:
# 	Theplotisweakaskingustobelieveincharactersdoingthingsthatnoonewithoneounceoflogicwoulddo(forexample,themotherleaveshomeforafewdaystovisitanauntknowingherhusbandrecentlysluggedhersoninthefacewithoutprovocation).
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Iftheplotwerebetteritwouldbeafilmworthwatching
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	Themovieappealswithitsintricateplot-aningeniouswebawaitedthealmosthelplessWilliamHurt,whowasdazzledbythebeautyofKathleenTurnerandwhosemindwas,nodoubt,slowedbytheintenseheat.
# Opinion of 'plot':
# 	 'intricate'
#
#
# Sentence:
# 	Goodplot.
# Opinion of 'plot':
# 	 'Good'
#
#
# Sentence:
# 	Whetherornotthereactuallyareghostsis,ofcourse,themainplotofthemovie,andtruetothegenreitdancesaroundthequestionforagoodlengthoftimebeforefinallyansweringit.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Itwasnottheactualstory/plot,orit'saccuracythatwasimportanttome.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'surprisingly-straightforward'
#
#
# Sentence:
# 	Criticsarguethattheplotistoocomplicated/clever,butthiswasentertaining,withovertonesofpoliticalconspiracythatmakeyourealizehoweasyitisforthetrulypowerfultomanipulateevents.
# Opinion of 'plot':
# 	 'clever'
#
#
# Sentence:
# 	Foramoreexplosiveride,withamoreentertainingcharacter,andamuchsimplerdrug-inducedandgraphicplot,seetherecentlyreleasedCrank-excellentaction/adventurefromtheTransporterman.
# Opinion of 'plot':
# 	 'much-simpler', 'induced'
#
#
# Sentence:
# 	JustlikeallDePalmafilms,DressedtoKillfeaturessomeabsolutelybrilliantsequences(elevator,trainstation)dispersedthroughoutaratherclumsyplot.
# Opinion of 'plot':
# 	 'rather-clumsy'
#
#
# Sentence:
# 	SetinWWIILondon,thedarkheartedplotfocusesonNavyLieutenantCommanderCharlesMadison,anespeciallynotoriouspersonalassistanttothementallyunstableAdmiralWilliamJessup.
# Opinion of 'plot':
# 	 'dark', 'hearted'
#
#
# Sentence:
# 	Iamlaughingatthose2starreviewssayinghowAVPisdestroyingtheAlienandPredatorlegacybecauseofitsnonexistentplot.
# Opinion of 'plot':
# 	 'nonexistent'
#
#
# Sentence:
# 	Verysuspenseful,andwonderfullywrittenplotmakethisa5starfilm!
# Opinion of 'plot':
# 	 'Very-suspenseful', 'wonderfully-written'
#
#
# Sentence:
# 	Theplotisfairlysimplewiththetwobrotherstryingtopreventagangofoutlawsfromterrorizingagroupoffarmersandstealingtheirland.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	Theplotisnotnew.
# Opinion of 'plot':
# 	 'new'
#
#
# Sentence:
# 	Goodversusevil,ofcourse,buttheplotismoreabouttheclasses.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	TheplotisUNEXPECTED,thatiamnotsureifit'sgoodornot!
# Opinion of 'plot':
# 	 'UNEXPECTED'
#
#
# Sentence:
# 	Theplotisfartocomplicatedtoexplaininareasonableamountoftime,butissumsuptobeaboutabunchofpeople,withcompletelydifferentlifestyles,whosomehowgetthrowntogetherbecauseofabigbombthatlookslikeagarbedgedisposal.
# Opinion of 'plot':
# 	 'far-complicated'
#
#
# Sentence:
# 	Fromthere,theplotgoesnuts,butthat'sokay,becauseit'swhatmakesBigTroublesuchafunnyandstrangelysmartmovie.
# Opinion of 'plot':
# 	 'nuts'
#
#
# Sentence:
# 	Thisisagoodmoviewithaninterestingplot,goodacting,decentdirectingandapoliticallyreleventcommentontheexcessesoftheUSPress.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Alotofpeopletendtosaythatthisanimeisconfusinganddoesn'thavearealplot.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Ithinkthedirectorneedsprozactodirectthismovie,thewholeplotissomessup,juniorhighstudentcanwritebetterstorythanthis..whatwashethinking.
# Opinion of 'plot':
# 	 'whole', 'so-mess'
#
#
# Sentence:
# 	Thecharactersaresoveryinteresting(butsubtle),theycouldhavewrittenanyoldplotandIwouldhavewatchedhungrily.
# Opinion of 'plot':
# 	 'old'
#
#
# Sentence:
# 	Whileultimatelythissetofindividualepisodesdoesn'tseemtofurtheranyoverallplot,thecomplexityoftheTachikomasandhowtheyworkisactuallyprettyinteresting.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisalittlethin,butAlyssaMilanoisthereasontowatchthismovie.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Thesewerealllosersbecausetheyhadashallowplot,alackoftalentedactors/actresses,andnomoralfibertothemwhatsoever.
# Opinion of 'plot':
# 	 'shallow'
#
#
# Sentence:
# 	Idon'tknowwhoplaysPatsy,butsheissuperbandthisplotstrandisverypoignant.
# Opinion of 'plot':
# 	 'very-poignant'
#
#
# Sentence:
# 	Itisthesethemesthatmaketheseriestrulyshine,asthesimplisticoverallplotservesmerelyasavehiclefortheseideas.
# Opinion of 'plot':
# 	 'simplistic', 'overall'
#
#
# Sentence:
# 	Theplotisratherpredictableandyoucouldsensetheendingalmostfromthebeginning.
# Opinion of 'plot':
# 	 'rather-predictable'
#
#
# Sentence:
# 	Theplotisfairlysimple.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	NowobviouslythisissameplotusedintheSantaClause
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	IthasafairlysimpleplotwhichsendsthecharactersrunningaroundNYConenightatChristmastime-eachwithhisorherownmisunderstandingofwhatisgoingon.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	Watchtheperfectmurderplotbeingexecuted
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplottothefilmissocomplicatedthatitreallyistoughtokeepupwith,eventhoughtherereallyisn'tthatmuchgoingonthroughoutmostofthefilm.
# Opinion of 'plot':
# 	 'so-complicated'
#
#
# Sentence:
# 	ShefindsadischargenoticeinRyu'spants,andthenextthingweknowshehasfiguredouttheentireplot,includingthekidnapping.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Theplotandsupportingcastarebetterthanpassable,thisisn'tatotallybadflick.
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	McGiverhasfallenforKhanandsays,"Iwilldoanything",sellsoutherselftoopower,andagreeswithhisevilplottootakeovertheEnterprise.
# Opinion of 'plot':
# 	 'evil'
#
#
# Sentence:
# 	Thecharacterworkisverygoodandtheplotgetsmoreandmoreinterestingasthemoviegoeson.
# Opinion of 'plot':
# 	 'more-interesting'
#
#
# Sentence:
# 	"Stargate"isstilloneofthescience-fictiongreatsthatsuccessfullyblendshistoryandscience-fictioninoneeffectiveplot.
# Opinion of 'plot':
# 	 'effective'
#
#
# Sentence:
# 	ThisDVDofTeentitansthe2ndseasionhasagoodstoryplot,andIforoneloveit!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Nowtothemeatofthereview,theplotinthismovieisn'treallythatgood,butnotveryhorrible.
# Opinion of 'plot':
# 	 'that-good'
#
#
# Sentence:
# 	Notaparticularlyinvolvedplot,butthenI'veseenjustaboutallthereare,butaverynicelittlefilm.
# Opinion of 'plot':
# 	 'particularly-involved'
#
#
# Sentence:
# 	Inotherwords,it'sthesimpleBODYSNATCHERSplot.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Moreplot,morestory,moregore(gettheunratedversion)andmoreJASON!
# Opinion of 'plot':
# 	 'More'
#
#
# Sentence:
# 	TheplotisratherShakespearean--themixupoflovers--buteverythingturnsouthappilyintheend.
# Opinion of 'plot':
# 	 'rather-Shakespearean'
#
#
# Sentence:
# 	Nottomentionit'snotexactlythemostcliche-freeplotasthere'ssomescenesthataregoingtobeobviousandwhentheyhappentheydon'treallysurprise(apossibleromancebetweenJohnandFlor,Deborahandhermotherhavinganall-outorjealousyamongFlorandDeborah)butthefilm'sentertaininganyway.
# Opinion of 'plot':
# 	 'most-free'
#
#
# Sentence:
# 	Theunconvincingcharacterizationsandhackneyedplotarelostinawelterofstrikingincidentaldetails:hundredsofglassbaublesrollingdownastaircaseandintothebloodywaterofasuicidevictim'sbathtub,beingaparticularlyimpressiveexample.
# Opinion of 'plot':
# 	 'hackneyed'
#
#
# Sentence:
# 	Poorplot,script,acting
# Opinion of 'plot':
# 	 'Poor'
#
#
# Sentence:
# 	Greataction,engagingplot,greatcinematography.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Moreblood,nudity,violence,swearing,andsexthanthefirstmovie,lessplotandcharacterization.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	REDPLANETunfortunatelyneededmorethanitsminimalistplottocarryit.
# Opinion of 'plot':
# 	 'minimalist'
#
#
# Sentence:
# 	Thefilmisatreat,especiallythefirsttimearound,despiteacomplicatedplotandanunderachievingstoryline
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Thisplotismucheasiertodigestonscreen.
# Opinion of 'plot':
# 	 'much-easier'
#
#
# Sentence:
# 	Theplotisgreat,theactingisoverthetop,andthecinematographyisfantastic.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whichonewillgettheirman,aninterestingsub-plot?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Itwasn'tthesameoldboringplotasthereweremanyunexpectedturnsandmisadventuresintheplot.
# Opinion of 'plot':
# 	 'same', 'old', 'boring'
#
#
# Sentence:
# 	Thisisn'tanewplot;You'veseenthis,insomeformoranother,severaltimes.
# Opinion of 'plot':
# 	 'new'
#
#
# Sentence:
# 	Aftertherecentspateofrubberrealityfilmsthatallusedessentiallythesameplot--includingStay(2005),TheJacket(2005),November(2004),TheIInside(2003),andeightornineothersgoingatleastallthewaybacktoJacob'sLadder(1990)andtheshortTheAwakening(1990)--TheDarkHoursveryrefreshinglyusesdifferentkindsoftwistsinitsquestionablyhallucinatorysuccessionofscenes.
# Opinion of 'plot':
# 	 'same'
#
#
# Results for aspect word 'characters'
#
# Sentence:
# 	Thecharacterstalkabouttherelativeintelligenceoftheothercharactersorhowtheothercharacterscan'tpossiblyknowwhatisgoingon.
# Opinion of 'characters':
# 	 'other', 'other'
#
#
# Sentence:
# 	ThereareonlytwoBlackcharacters,bothsentimentallyloyaltotheirSouthernnessandtheirmasters;otherwise,slaveryisbesidethepoint.
# Opinion of 'characters':
# 	 'Black', 'sentimentally-loyal'
#
#
# Sentence:
# 	whenlessthanhalfwaythrough,thestorybecomessomethingutterlyunrecognizablefromtheoriginal,severalkeycharactersarelumpedtogethermostconfusingly,andotherslosealltheircomplexcharm.
# Opinion of 'characters':
# 	 'several', 'key'
#
#
# Sentence:
# 	Ifeltthatwithinallthetimeitran,wedidn'treallygetagoodunderstandingoftheinnerbeingofthemaincharacters;seemedtoremaininshallowwatersallalong.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Otherreviewershavecommentedonthebad,infomerciallevelactingofthetwoleadcharacters.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	"ConExpress"haslotsofactioninit,whichisgreatbecausethishidesthepoorwritinganduninterestingcharacters.
# Opinion of 'characters':
# 	 'writing'
#
#
# Sentence:
# 	ThemoviegetsboringratherfastasBetteandWoodyaretheonlyoneswegettoseeasthereareveryfewsupportingcharacters.
# Opinion of 'characters':
# 	 'very-few', 'supporting'
#
#
# Sentence:
# 	Thesedisjointedglimpsesdon'tgivetheviewertimeordepthtocarewhathappenstoanyofthespoiledrottencharacters.
# Opinion of 'characters':
# 	 'spoiled', 'rotten'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Thecharactersarethinatbest,andstockatworst.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Can'trememberwhenI'veseenafilmwithmoredepravedandpatheticcharactersthanthis.
# Opinion of 'characters':
# 	 'more-depraved'
#
#
# Sentence:
# 	ThecharactersareunlikeableexceptforCharity'stwofriends.
# Opinion of 'characters':
# 	 'unlikeable'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Forgoodcounterexampleswatch"Trainspotting",whichhasdrug-addictcharacterswithenoughhumorandlifetobelikableandinterestingand"BubbaHo-Tep",afilmwhichdisplaystheplightofthelonelyelderly50timesbetterthanthisfilmdespitebeingasillyhorror-comedywithamummyinacowboyoutfitinit.
# Opinion of 'characters':
# 	 'addict'
#
#
# Sentence:
# 	NowthatthesetediouscharactershavefinallyhitrockbottomIcangodosomethingelse.
# Opinion of 'characters':
# 	 'tedious'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	AnarrativelikeGettysburgthatgoesbackandforthbetweenafewcentralcharactersinalogicalsequencewithoutallthehamfistedattemptsaproselytizingandallthenoblesseoblige.
# Opinion of 'characters':
# 	 'few', 'central'
#
#
# Sentence:
# 	Iwaswatchingthesametwocharactersfightthroughthesametwochallengesinthisfilm.
# Opinion of 'characters':
# 	 'same'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'characters':
# 	 'obscure', 'secondary', 'main'
#
#
# Sentence:
# 	Ifhewouldhavetightenedthescript,createduniqueand"cult-like"characters,andeliminatedtheracism,hemayhavehadthequintessential"weed"filminHollywood.
# Opinion of 'characters':
# 	 'unique'
#
#
# Sentence:
# 	Hediscoversanewtalent(artistChristinaMilian)andworkshiswaythroughanassortmentofcharactersthataremoretypesandclichesthanrealcharacters.
# Opinion of 'characters':
# 	 'real'
#
#
# Sentence:
# 	Thesoundismurkyandundecipherable,theactingisstrictlyamateurhour,thecharactersarepaper-thinwithnodistinctionorpurpose,thestoryisnon-existent,thedialogueisacompletelyworthlessbore,there'snothingremotelyscary,andthespecialeffects(includingacoupleofcomputereffectsthatlookliketheyweremadeonaCommodore64)arelaughable.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Nothinghappensinthismovie(andImeannothing)exceptabunchofsullencharactersexhanging"comic"glancesandlookingwithdrawnandcynical.
# Opinion of 'characters':
# 	 'sullen'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'characters':
# 	 'both-same'
#
#
# Sentence:
# 	It'sastudyincontrasts,andit'sdoneimpeccablyinthenovel,withaplethoraofcomplexcharacterstorichenthejourney...
# Opinion of 'characters':
# 	 'complex'
#
#
# Sentence:
# 	Realcharacters?
# Opinion of 'characters':
# 	 'Real'
#
#
# Sentence:
# 	Therestofthisfilmconsistsoftheear-bleedingwhinesandyawn-inducinginfightingofthehumancharacters,ill-conceivedandextremelyunlikablecaricaturesofapseudo-cynicalandextremelyredundant"evilsideofhumannature"messagethatwouldbebetterlefttoJeanRenoir(orevenAdamSandlerconsideringtheresultshere).
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	Iguessit'ssupposedtodepictthehorrorofrepressivereligiousvalues,andwhileIdon'tcondonethose,thefilmlacksclearcharactersoranymotivation.
# Opinion of 'characters':
# 	 'clear'
#
#
# Sentence:
# 	ItiseasytogetsuckedintowatchingGantz,becauseoftheuniqueandinexplicablesituationthatthemaincharacters,whohavealldied,findthemselvesin.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	Thecharactersaresolame
# Opinion of 'characters':
# 	 'so-lame'
#
#
# Sentence:
# 	Thecharactersare,overall,blandandjustplainuninteresting(e.g.RickAndersonplayedbythe"fool,"TedRaimi,fromtheXenaseries).
# Opinion of 'characters':
# 	 'bland'
#
#
# Sentence:
# 	andIdidn'tcarewhatwouldhappenwiththemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Ireadthebookandsawthemovie,whichotherthantitleandmajorcharacters,havelittleincommon.
# Opinion of 'characters':
# 	 'major'
#
#
# Sentence:
# 	Theminorcharacters,includingthewonderfulTracieThomsas"bestfriend"Lily,aremostlywasted.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	ThebigproblemwithRHisthatneitherFordorBenningaresympatheticcharacters.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Theproducersofthisfilmareoutoftheirmindiftheyexpectanyviewerwho'snotscrewed-upintheheadtofeelsorryforthetwostupidmaincharactersjustbecausetheirsick,incestuous,andadulterouslifestyleisincompatiblewiththeworldtheylivein.
# Opinion of 'characters':
# 	 'stupid', 'main'
#
#
# Sentence:
# 	Tooimplausible,toomanyoverdrawnsecondarycharacters.
# Opinion of 'characters':
# 	 'Too-implausible', 'overdrawn', 'secondary'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	WhoevermasteredthisgreatfilmRUINEDitbyFORGETTINGorREFUSINGtoprovideEnglishsubtitlesfortheJapaneseandItaliancharacters.
# Opinion of 'characters':
# 	 'Japanese'
#
#
# Sentence:
# 	Occasionallywegetashotofsomeoftheothercharacters.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	We'resupposedtofindthecharactersplayedbyRobertRedfordandDebraWingertobeamusing,theiracrimoniousrelationshiptobehilarious,andthewaythattheyendupbeingpartnersdespiteallofthegibestoberomanticallysatisfying.
# Opinion of 'characters':
# 	 'amusing'
#
#
# Sentence:
# 	Long,tediousactionadventurewithrepetitivedialog,badplotholes,andgenerallyboringcharactersishowtodescribethislittleforayintofollowingupthecharactersfromBadBoys.
# Opinion of 'characters':
# 	 'generally-boring'
#
#
# Sentence:
# 	It'samazinghowsomuchmoneyandeffortgointospecialeffectsandexpensivesetsandthescriptitselfishollowwithlousycharacters.
# Opinion of 'characters':
# 	 'lousy'
#
#
# Sentence:
# 	Anditdoesn'tonlycenteraroundthemaincharactersbuthasagreatensemblecastofveryinterestingpeople!
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Haspleasantcharacters;butnotdeep.
# Opinion of 'characters':
# 	 'pleasant'
#
#
# Sentence:
# 	Itsjustbadactingwithstupidandmeancharacters.
# Opinion of 'characters':
# 	 'stupid'
#
#
# Sentence:
# 	Rivkabecomeshercousinandothercharactersareneglectedcompletely.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Afterorbeforekeyscenes,thecameracutstoamonologuefromoneofthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Toitscredit,theactorsdidwhole-heartedlyportraygaycharactersandgaylovescenes.
# Opinion of 'characters':
# 	 'heartedly-portray', 'gay'
#
#
# Sentence:
# 	Atthetime,gaycharacterswereneverportrayedinapositivelightfromthemedia,anditwasagreatrisktodosohere.
# Opinion of 'characters':
# 	 'gay'
#
#
# Sentence:
# 	CertainlynottheweirdIrishaccentstheleadcharactersadopted.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Theothercharactersarelikewiselackinginrealism,onlyJanetMcTeerfareswell
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Mightbesuitedmoreforanolderchildbutmineis13monthssotherehastobeconstantcolorfulcharactersforhertobeinterested
# Opinion of 'characters':
# 	 'constant', 'colorful'
#
#
# Sentence:
# 	Theplotlinewasnonexistent,andthecharacterswerecompletelyunlikeable.
# Opinion of 'characters':
# 	 'completely-unlikeable'
#
#
# Sentence:
# 	istartedlikingthismovie,ithoughtthepinballmetaphorandwildcharactersandlifesacartoonshizcouldhaveworkedout,ifitwerentforthefactthatbakshiisthinlydisguisinghimselfandhisownfrustrationasbeinganunoriginal"underground"cartoonistwhocaughtontothescenetoolate...ifyoulikethedepressing,gritty,wild,fastpacedstyleofthismovie,checkouttheoriginalmasterROBERTCRUMB,towardwhombakshiisobviouslyseethingwithjealousyandridinganxiouslyonthecoattailsof...
# Opinion of 'characters':
# 	 'wild'
#
#
# Sentence:
# 	Everyminutecharactersinthisseriestrytoremindyouofsomeplotpointasifyou'reashort-attentionspancoachpotatoe.
# Opinion of 'characters':
# 	 'minute'
#
#
# Sentence:
# 	butthenthefilmbasicallyspendstoomuchtimezigzaggingaroundtoallthedifferentcharactersandlocales.
# Opinion of 'characters':
# 	 'different'
#
#
# Sentence:
# 	Itseemstoberidingonit'slaurels,sotospeak,andit'salmostasifwearesupposedtofindthecharactersactingdifferentlyfunny.
# Opinion of 'characters':
# 	 'differently-funny'
#
#
# Sentence:
# 	Butthecharactersarenotsympathetic,funorinteresting.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Thereisnohumor,nolikablecharacters,notevenadecentquoteoroneliner.
# Opinion of 'characters':
# 	 'likable'
#
#
# Sentence:
# 	Therearetwonewsupportingcharactersthistime,Loisand,erm...Jason.
# Opinion of 'characters':
# 	 'new', 'supporting'
#
#
# Sentence:
# 	SheisagreatalternativetoBarneyandalloftheothercommercialcharacters,whoIdon'tcaremuchfor.
# Opinion of 'characters':
# 	 'other', 'commercial'
#
#
# Sentence:
# 	Thestoryissimple,butinthehandsofthewritersWendyHammondandBobGosseandwithGosse'sfinedirection,theentirecastgivesusanensembleofdisparatecharactersinwhomwecanallbelieve.
# Opinion of 'characters':
# 	 'disparate'
#
#
# Sentence:
# 	Theactionisoffthewallwiththetwomaincharacterstreatingustotwostylesoffightingthataretheveryantithesistoeachother.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	In"TheManWhoWasn'tThere,"thephrase"decisiveaction"isanoxymoron;everythingCraneandtheothercharactersdoisgovernedsolelybychance.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Alongthewayheencountersahostofintriguingcharacters,includingacrazy-like-a-foxentrepreneurialbushpilotlookingtomakesomesortofbigscore,anumberofwackybitplayerswhoIcaneasilyimaginewerenotactors,buttherealdeal,andeverybitaseccentricastheyappeared;andanendearinglysageoldInuitoffewwordsbutmanyeloquentsilences.
# Opinion of 'characters':
# 	 'intriguing'
#
#
# Sentence:
# 	Thefilmdepictstheevolutionofthesevariouscharactersastheycometotermswiththeprogressionoftheirlovelivesandprofessions.
# Opinion of 'characters':
# 	 'various'
#
#
# Sentence:
# 	PlotsbasedonbooksbyElmoreLeonardtendtobeaboveaverage,butaremostlydependentuponthecolorfulcharactershewrites.
# Opinion of 'characters':
# 	 'colorful'
#
#
# Sentence:
# 	NotonlydoesthemovieSignsofferawonderfullydifferentkindofalien/ufotale,butitscharactersareverylikableandthestoryisaboutmuchmorethanaliensfromanotherplanet.
# Opinion of 'characters':
# 	 'very-likable'
#
#
# Sentence:
# 	TheclassicWordsworthpoemfromwhichthefilm'stitleisderivedmakesafittingcodaforthismovie,andIstillfeeltheintractablesenseoflonginginthetwoleadcharacterseverytimeIseethismovie.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Bothmoviesareprettysimilartoeachother...but"BloodIn,BloodOut"kindafocusesonthe3brothers,andthepathseachofthemtakes,whereas"AmericanMe"focusesonthepathsofthemaincharactersinthismovie(likeSantana,Puppet,Lil'Puppet,etc)..butnotonlydoesitshowtheirlifestyles,butitalsofocusesonhowitshavinganeffectontheirfamilies,andhowtheirfamiliesfeelaboutthelifethattheirkidsareleading..."AmericanMe"ithinkinvolvesmoreofthefamilyinthispictureandculture(LaRaza)then"BloodIn,BloodOut"does...
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	becuasethisoneseemstohavealotmoreofastorylinetoit,andmorecharactersitsfocusingon...bothinandoutsidetheprisonwalls..
# Opinion of 'characters':
# 	 'more'
#
#
# Sentence:
# 	Therearemanygoodsupportingcharacterssuchas:BridgetFonda,WoodyHarrelson,BarnardHughesandJulieWarner
# Opinion of 'characters':
# 	 'many', 'good', 'supporting'
#
#
# Sentence:
# 	Themaincharactersalmostentirelyhavehopes,aspirations,andattachmentsbeyondtheratherclosedworldoftheirprofession--Jack'sdesiretobeaseriousfilmmaker;Dirk'sridiculouspseudo-KarateandReed'sequallyridiculouspoetry;Buck'sgoalofopeninghisownstereostore;Amber'sattemptstogetbackintouchwithherson,whichsheblatantlycompensatesforbymotheringherco-stars--helpingusseethemasfleshed-outcharacters,notjustplotdevicesinthestory.
# Opinion of 'characters':
# 	 'main', 'fleshed'
#
#
# Sentence:
# 	Thecharactersarenotsointerestingnoristheacting.
# Opinion of 'characters':
# 	 'so-interesting'
#
#
# Sentence:
# 	Anothergreataspectoftheshowistheyarenotafraidtokilloffmaincharactersthatyougrowtoloveontheshow,soyouwillnevernowwhatisgoingtohappennextwhichkeepsyouwantingmore.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Itisabeautifulheartwarmingmovie,withgorgeousscenery,unforgettablecharacters,andplentyofmomentstolaughandcry
# Opinion of 'characters':
# 	 'unforgettable'
#
#
# Sentence:
# 	Again(asI'vesaidinotherofmyreviews),minorcharactersareimportant.
# Opinion of 'characters':
# 	 'minor', 'important'
#
#
# Sentence:
# 	AnotherpartofthestoryIfoundannoyingwasthelackofcommunicationbetweenthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Thoserepresentthemaleandfemaleviewpointsofthemaintwocharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Butifyouseethemovieasbeingabouttwointerestingcharacters,passitby.
# Opinion of 'characters':
# 	 'interesting'
#
#
# Sentence:
# 	Itismuchbetterthanhavingdifferentactorsplayingoldcharacters,whichdragsamoviedownalot.
# Opinion of 'characters':
# 	 'old'
#
#
# Sentence:
# 	The"bad"charactersareallprettylikeable,asidefromone,andalliswellintheend.
# Opinion of 'characters':
# 	 'bad', 'pretty-likeable'
#
#
# Sentence:
# 	"CinderellaII:DreamsComeTrue"isaseriesofthreestoriesfeaturingmostlycharactersfromtheoriginalCinderellaandafewnewones.
# Opinion of 'characters':
# 	 'mostly'
#
#
# Sentence:
# 	InoneofthemosthilariouscharactersI'veeverseenportrayedonscreen,wemeetDr.Strangelove(PeterSellers,yetagain)astrategistaidingthepeopleintheWarRoom.
# Opinion of 'characters':
# 	 'most-hilarious'
#
#
# Sentence:
# 	Thecharactersareallverylikeable.
# Opinion of 'characters':
# 	 'very-likeable'
#
#
# Sentence:
# 	Therearelittleromanticmomentsbetweenthemaincharactersthatmaketheshowmoreinteresting.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Themovietrieshardtofindthehumorinhitmenandquirkycharacters,butitoftenseemstobetryingabittoohard.
# Opinion of 'characters':
# 	 'quirky'
#
#
# Sentence:
# 	Also,whilemostBBCproductionsofliterarymasterpiecesarestudiesinsocialconservatismthisoneobviouslyidentifieswithandinvitesustoidentifywithitsmostirreverentandforward-thinkingcharacters:inthiscasethesultryandsophisticated,andsomewhatlibertine(ina1920'skindofway),LadyChatterly&theearthyandirreverentandsmoldering(smolderingbothwithclassresentmentandwithlustforaladyfromtheoppressiveclass)OliverMellors.
# Opinion of 'characters':
# 	 'most-irreverent'
#
#
# Sentence:
# ...
# 	 'well-enough-written'
#
#
# Sentence:
# 	Throwinlotsoftortureddialogueaboutalternativeconsciousnesses/universes/fuelsupplies/sugarsubstitutes.
# Opinion of 'dialogue':
# 	 'tortured'
#
#
# Sentence:
# 	Thedialogueisdifficulttofollowespeciallysincemostofitismeaninglessanyway,andthefilmneverreallyfollowsit'spremiseasmuchasitshould:theriseofFactory.
# Opinion of 'dialogue':
# 	 'difficult'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'completely-unbelievable'
#
#
# Sentence:
# 	Iunderstoodtheplot,andenjoyedsomeofthethoughtsraisedneartheend,butoverallwasboredsillybystilted,pointlessdialogue.
# Opinion of 'dialogue':
# 	 'stilted', 'pointless'
#
#
# Sentence:
# 	WhileBaldwinandtherestofthecastdidwellinfleshingoutBurke'scharactersandhavesometangytough-guy/galdialogue,they'rehamperedbytwothings:
#
# 1.)
# Opinion of 'dialogue':
# 	 'tangy'
#
#
# Sentence:
# 	Gooddialogueislikegoodacting:ifit'sreallygood,youdon'tnoticeituntiltheshow'sover.
# Opinion of 'dialogue':
# 	 'Good'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	soI'msupposedtobelievethatthehorribledialogue,badacting,andridiculousplottingisonpurposejustbecauseMametisarespectedguy?
# Opinion of 'dialogue':
# 	 'horrible'
#
#
# Sentence:
# 	Thedialoguewouldhavebeen1000timesbetter.
# Opinion of 'dialogue':
# 	 'better'
#
#
# Sentence:
# 	It'sthewaythestoryistold-itsham-fisteddialogueandplot,itsforcedobscenityateveryturn-thatrevealsitsteensensibilities.
# Opinion of 'dialogue':
# 	 'fisted'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'dialogue':
# 	 'so-bad'
#
#
# Sentence:
# 	Thetwodimensionalniceoldbrotherandsisteraretreatedhorribly,fornogoodreasonwithnomotivationorpayoff,thesongsareunlistnableandthedialogueishardtounderstand,thisisnotalwaysabadthing.
# Opinion of 'dialogue':
# 	 'hard'
#
#
# Sentence:
# 	Youdon'tgotothesemoviestoexpectwell-writtendialogue,characterdepthoranything,youcomeforthekillsandtotellyouthetruth,they'reslightlydisappointing.
# Opinion of 'dialogue':
# 	 'well-written'
#
#
# Sentence:
# 	Theunwittydialoguetriestobecleverallthroughoutthemovieandisjustsoooboring.
# Opinion of 'dialogue':
# 	 'unwitty'
#
#
# Sentence:
# 	Thedialoguewassharpandyoumighthavetowatchtwicetogetallthesubtlequips.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueiswonderfullyexpressiveandgivesusthesenseofauthenticityandthekindofrealisticeffectseenonlyintheverybestfilms.
# Opinion of 'dialogue':
# 	 'wonderfully-expressive'
#
#
# Sentence:
# 	Thecolorsaredark,thedialoguebetweenthecharactersishonest,realandsimplywonderful.
# Opinion of 'dialogue':
# 	 'honest'
#
#
# Sentence:
# 	thisepisodehasalotoffunnydialogue,butthat'stheonlythingithasworkingforit.
# Opinion of 'dialogue':
# 	 'funny'
#
#
# Sentence:
# 	Inconclusion,thisTVshowhasitall:goodbackgroundmusic,greatdialogue,interestingstories,goodacting,andinterestingcinematography.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	Thedialogueissharpandwitty,althoughthere'salotofswearing,thatdoesn'tmeanthehumourisjustfowlmouthed,it'shillarious,someofthelinesgodowninhistoryassomeofthefunniestonelinersever.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Inanerawherecinematicpalatesseemtitillatedmostlybyfastactionthrillers,thismovieisanotherexampleofhowwellconstructeddialoguemakesforgrippingcinematicdramawhenitgoeshandinhandwithsuperbcastingandperformance
# Opinion of 'dialogue':
# 	 'well-constructed'
#
#
# Sentence:
# 	You'llbesuckedin,andsurprised,withinthefirsttwominutes,andthere'sverylittledialogue
# Opinion of 'dialogue':
# 	 'very-little'
#
#
# Sentence:
# 	Itseemsraretodaytofindsuchrichdialogue.
# Opinion of 'dialogue':
# 	 'such', 'rich'
#
#
# Sentence:
# 	OtherPeople'sMoneyisawonderfulmovie,fullofsmartdialogue,goodmusic,andaterrificDannyDeVitoperformance.
# Opinion of 'dialogue':
# 	 'smart'
#
#
# Sentence:
# 	Thedialogueisn'thard-boiledexceptforafewlinesdeliveredbyVicky.
# Opinion of 'dialogue':
# 	 'hard-boiled'
#
#
# Sentence:
# 	iappreciatedtheeffects-nicetouch-butiwouldhavelikedtoseesomerealdialoguethere.
# Opinion of 'dialogue':
# 	 'real'
#
#
# Sentence:
# 	Relyingonsharpdialogueandfacialexpressions,theactorsmanagetoweaveagorgeoussensualdancetogether,bothlightingupthescreenandcreatingtwoofthemostsmolderinglycomplexcharacterseverseeninfilm.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	The'plain'dialogueamongthe'elders'ispainfullynumbing,choppy,andstilted.
# Opinion of 'dialogue':
# 	 'plain', 'painfully-numbing'
#
#
# Sentence:
# 	Thesoundtrackisawesome,thecinematographyisgreat,thedialogueisrealistic,andforonce,amoviesetinaforeignlandthatactuallyusesactorsfromthatareaspeakingthelanguageofthatarea!
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thismovieisweak,poorlywrittenandhassomelaugh-out-loudstereotypicalcop-schlockdialogue.
# Opinion of 'dialogue':
# 	 'out-loud'
#
#
# Sentence:
# 	(Thescript,bytheway,isonegreatlineafteranother,withverynatural,effortlessdialogue.
# Opinion of 'dialogue':
# 	 'very-natural', 'effortless'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Thestoryisfilledwithbiglaughs--fromcrudehumortosomeofthemostintelligentdialogueI'veprobablyeverheard.
# Opinion of 'dialogue':
# 	 'most-intelligent'
#
#
# Sentence:
# 	Thesurrealhumourandoff-kilterandunusuallybizarrehumourhasseducedthosethatlikeamixtureofpsychicalcomedy,comicinnerdialogue,aswellascrackingoneliners,mixedwiththeoccasionalrelativelyserioussubjectmatters,andphasesthatcanberecitedamongstfellowfans,tomuchamusement.
# Opinion of 'dialogue':
# 	 'comic', 'inner'
#
#
# Sentence:
# 	Thewritingissmartandwitty,thedialogueischarming,theperformancesaregreat.
# Opinion of 'dialogue':
# 	 'charming'
#
#
# Sentence:
# 	Thedialoguethroughoutwastediousandtrite;thescriptwritershouldbeontheunemploymentline,aswellasthedirectorandtheeditor.
# Opinion of 'dialogue':
# 	 'tedious'
#
#
# Sentence:
# 	Therereallywasn'tmuchanimosityfromeithersideofthe spectrum,rathertherewasalotofwell-intentioneddialoguefrombothsidesthatwouldgiveanybody,regardlessofpoliticalpersuasion,betterinsightintotheissuesinIraqandtheMiddleEast
# Opinion of 'dialogue':
# 	 'well-intentioned'
#
#
# Sentence:
# 	Ithasgreatfundialogue,isverytechnicallymodernforitstime,extremelyentertaining,fastpaced,andanabsolutejoytowatchthisCLASSICfilm~WHATATREAT!!
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thedialoguetoisequaltothatof"Coctail"-pointless,beentherebefore,densedialogue.
# Opinion of 'dialogue':
# 	 'equal', 'dense'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'completely-unbelievable'
#
#
# Sentence:
# 	MarvellousdialoguebyBolt.
# Opinion of 'dialogue':
# 	 'Marvellous'
#
#
# Sentence:
# 	SetintheSouth,startingintheearly1950s,andasaSouthernermyselfIparticularlyenjoyedtheauthenticdialogue.
# Opinion of 'dialogue':
# 	 'authentic'
#
#
# Sentence:
# 	Thedialogueiswonderful,alloftheperformancesaresuperb,andCapra'sdirectionareexcellent.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	DotDrequiresabraintoenjoyasitisNOTaslambangshoot'emupwithditzydialoguetofillinthegorescenes.
# Opinion of 'dialogue':
# 	 'ditzy'
#
#
# Sentence:
# 	Themiddlesectionisadmittedlyratherdialoguebased,butthisdialogueisneverboringandservestoillustratewhythelivingdeadfeeltheneedtochompdownonwarmflesh.
# Opinion of 'dialogue':
# 	 'boring'
#
#
# Sentence:
# 	(He'smuchbetteronHOUSE,wherehegetssomerealcharacterizationandinfinitelybetterdialogue.)
# Opinion of 'dialogue':
# 	 'infinitely-better'
#
#
# Sentence:
# 	Ifthedialoguewasn'twitty,festivalaudienceswouldn'thavegonenuts.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Stonecombinessuchwild,lush,andcrazyfilmeditingtodepictthemindsofVickeyandMallory,crazydialogue,uniquestorytelling,andallthewhilepokingfunathowweasthepeopleandthemediagocrazyforit.
# Opinion of 'dialogue':
# 	 'crazy'
#
#
# Sentence:
# 	ThefilmisslightalthoughitbenefitsfromsomesharpHermanMankiewiczdialogue.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Manyclose-upshotsofherbarechest.(d)HighlyXXXdialogue,suchasthelinewhere11yearoldViolettellshercustomerthat"Icanfeelthesteamjustcomingthrumydress"(e)
# Opinion of 'dialogue':
# 	 'bare'
#
#
# Sentence:
# 	Themovieisactionpackedwithexcellentdialogueandtheactionneverstopsuntiltheveryappropriateend.
# Opinion of 'dialogue':
# 	 'excellent'
#
#
# Sentence:
# 	Andthedialogueiscertainlymemorable:
#
# JackBull:
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Itmakesyouquestionwhyyoubuyintosuchsappydialogueandsituations.
# Opinion of 'dialogue':
# 	 'such', 'sappy'
#
#
# Sentence:
# 	Whilewatching,inmyheadIwasfillinginthedialogueforthecharacters,andmydialoguewasalotmoreinterestingthananythingthesepeoplesay.
# Opinion of 'dialogue':
# 	 'more-interesting'
#
#
# Sentence:
# 	ThoughIcannotdenythatitisunbelievablycheesy,filledwithpracticallyeveryclicheonecanimagineandcontainstonsofembarrassingdialogue(especiallyKurtRussell'sbeggingspeech)andunconvincinglovescenes(Mel,willyoupleasekissherlike
# Opinion of 'dialogue':
# 	 'embarrassing'
#
#
# Sentence:
# 	Thedialogueisveryfunnyandwittyattimes.
# Opinion of 'dialogue':
# 	 'very-funny'
#
#
# Sentence:
# 	Rarelyhassomuchbeensaidsosuccessfullywithsolittledialogue.
# Opinion of 'dialogue':
# 	 'so-little'
#
#
# Sentence:
# 	AlthoughI'msureyouwillwanttoseewhathappenedtoallofyourfavoritecharacters,yourhopeswillcertainlybedashedanddisappointedbyapoorstoryandpoordialogue
# Opinion of 'dialogue':
# 	 'poor'
#
#
# Sentence:
# 	Thedialogueisoftenunconvincingandoneoccassionallytiresoftheconstantneedinmoviemakingtouseeachcharachterasanarchetype.
# Opinion of 'dialogue':
# 	 'unconvincing'
#
#
# Sentence:
# 	ThesheeraudacityofthistaskisahallmarkofChayefsky'svitriolicstyle,andthefilmisfullofhisbrittle,observantdialogueandsharplyarticulatesoliloquies.
# Opinion of 'dialogue':
# 	 'observant'
#
#
# Sentence:
# 	Here,inthismovie,you'vegotagoodcast,cooldialogue,andanon-stopactionthrillride.
# Opinion of 'dialogue':
# 	 'cool'
#
#
# Sentence:
# 	AnyonefamiliarwithTheSimpsonswillenjoythehumorinOlive,TheOtherReindeer,aswellastheanimationandwittydialoguethatpassesquicklyinthisforty-fiveminutemovie.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Allinvolverichdialogueandinterestshown.
# Opinion of 'dialogue':
# 	 'rich'
#
#
# Sentence:
# 	First,thedialogueandsituationsaresoinsipidtheyofteninspireunintentionalhilarity.
# Opinion of 'dialogue':
# 	 'so-insipid'
#
#
# Sentence:
# 	Withoutcontrivedmanipulations,youaredrawnintothedepthsandheightsoftheiremotionsthroughtheuseofstunningvisuals,dramaticportrayals,pithydialogue,momentsofquietcontemplation,andaserenemusicalsoundtrackthatisworthowningonitsownmerits.
# Opinion of 'dialogue':
# 	 'pithy'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Ithashistrademarkrealisticdialogueandwithoutanyflashyeffectshefocusesonthecharacters.
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thedialogueiswarmandwittyandtheactorsarewonderful.
# Opinion of 'dialogue':
# 	 'warm'
#
#
# Sentence:
# 	Allen'sdialogue(whichisalwaysgood)isparticularlygoodintheconversationsbetweenIsaacandMary;ThefinalscenebetweenIsaacandTracyisalsoverymeaningfulandverygood.
# Opinion of 'dialogue':
# 	 'particularly-good'
#
#
# Sentence:
# 	LiketheothermoviesthereissomegreatdialogueinthismovieandIhighlyrecommendthemovietofansofChrisFarley,ChrisRockandSNL.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Yes,themoviehasflaws:thedialoguecanbealittlegoofyattimes,theactingsomewhat-shallwesay-idiosyncratic,thespecialeffectsdon'talwayswork,andtheinternallogicisnotalwaysapparent(theGrailisArthur?
# Opinion of 'dialogue':
# 	 'goofy'
#
#
# Sentence:
# 	Withcringinglyawfulacting,laughablespecialeffects(theridiculousheadinabucketisarealguffawmoment),appallingdubbeddialogue,cheesymusic,inconsistentandconfusingplotandnotensionoratmosphere,TheGrimReaperisatotaldisaster.
# Opinion of 'dialogue':
# 	 'dubbed'
#
#
# Sentence:
# 	Theearlypartofthisfilmisfilledbothwithsnappy,intelligentdialoguebutalsowithasophomoricphysicalcomedywhichcanhonestlybeconsideredtobeatorbelowapie-in-the-facelevelofsophistication.
# Opinion of 'dialogue':
# 	 'snappy', 'intelligent'
#
#
# Sentence:
# 	Betweenincrediblybaddialogueaboutthingslikethe"plutonium-rubycrystalbeamgun,"sillyincidentalmusic,andaVenusianmadeoflatex,twigs,andtissuepaper,thisonecannotbebeat.
# Opinion of 'dialogue':
# 	 'incredibly-bad'
#
#
# Sentence:
# 	Baumbach'sscreenplayboastslotsofmemorabledialogue,lotsofclevernessyoumightfindyourself"borrowing."
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	Thegreatsweetbeautyofthisfilm,however,isthemarriageofsuchengagingdialogue,suchearnestdeadpandeliveriesshotinsucheerieclarity--onereminiscentoftheinteriorsinDutchgenrepainting:clean,homely,homiletic.
# Opinion of 'dialogue':
# 	 'such', 'engaging'
#
#
# Sentence:
# 	Itmanagestoturnasuiteofclassicallystaticimages-bronzed,burnished,melancholy-uponafast-drivingdialogueendowedwiththemodestbutenhancingartificialityofapainting,anovelor--betteryet--aninfinitelyrefinedfilm
# Opinion of 'dialogue':
# 	 'bronzed', 'fast-driving'
#
#
# Sentence:
# 	Manywillbemovedbyhownaturalthedialoguesounds(herecordedmostofitonthestreets),alotofitobviouslyinspiredbyhisownlife.
# Opinion of 'dialogue':
# 	 'how-natural'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'as-fast'
#
#
# Sentence:
# 	Indeed,thedialogueissobeautifullyeloquent,wefeellikeweareoftengiventhemodernequivalentofShakespeare.
# Opinion of 'dialogue':
# 	 'beautifully-eloquent'
#
#
# Sentence:
# 	Selectionof
# locations,environmentsandcharactersissimplywonderful--sureto
# keeptheviewerengrossed,eventhoughthedialogueisuncompromisingly
# British.
# Opinion of 'dialogue':
# 	 'British'
#
#
# Sentence:
# 	Recentadaptationsseemafraidtoincludeoriginaldialogueatanylength-
# Opinion of 'dialogue':
# 	 'original'
#
#
# Sentence:
# 	Verywittydialogueandscenes;flawlessactingbyleadandsupportingactors.
# Opinion of 'dialogue':
# 	 'Very-witty'
#
#
# Sentence:
# 	ThisisChaplin'sfirstfulldialoguefilm,eventhough'TheGreatDictator'washisfirstsoundfilm.
# Opinion of 'dialogue':
# 	 'full'
#
#
# Sentence:
# 	Mywifesaysallofhismoviesarethesame,anditbreaksmyhearteverytimeshesaysit...becauseinthatblanketanalysis,theanalystmissestheincrediblestoriesandcraftydialoguethattakesplaceinthemanyWoodyAllenmoviesthatprettymuchtakeplacewithinthesametemplate.
# Opinion of 'dialogue':
# 	 'crafty'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'as-fast'
#
#
# Sentence:
# 	Thisisamust-haveifyoulikeagoodstoryline,cleverdialogueandhonestlaughs.
# Opinion of 'dialogue':
# 	 'clever'
#
#
# Sentence:
# 	GreatforthepurestinthecrowdbutkillerforthoseofuswholikebadlydubbedEnglishdialogue.
# Opinion of 'dialogue':
# 	 'badly-dubbed', 'English'
#
#
# Sentence:
# 	Theweaknesseswereimmediatelyapparent--awkwarddialogue,lackofvisualstyle--butIhopedthemoviewouldovercomeitsfaults.
# Opinion of 'dialogue':
# 	 'awkward'
#
#
# Sentence:
# 	Thismayhelpsomeofyouslowerpeople(don'tbeashamed)tounderstandthefilm,althoughmuchofitsimportantintricatedialogueandoverallappealwillbelostinthisversion.
# Opinion of 'dialogue':
# 	 'important', 'intricate'
#
#
# Sentence:
# 	Thereareproblemswiththefilm,themostannoyingonebeingthatthedialogueispracticallyinaudibleduetothemikingand,moreso,duetothemusicalscorewhichcoversallthelinestothepointofmakingthemovieseemlikeasilentmoviewithmusicfromthepit!
# Opinion of 'dialogue':
# 	 'practically-inaudible'
#
#
# Sentence:
# 	Themood,thesensuousdialogue;Thisisjustnoiratit'sbest.
# Opinion of 'dialogue':
# 	 'sensuous'
#
#
# Sentence:
# 	Thistart,well-scriptedcomedyisalittlelightonthedancing,butfeaturessomeofthebest,briskestdialoguethatcameAstaire'sway,andafinesupportingcast,includingthefamousHollywood&quot;double-talker,&quot;CliffNazarro,goingthroughhisroutineinnumerousscenes.
# Opinion of 'dialogue':
# 	 'best'

# %%
sents = [nlp(entry[1]) for entry in core]
# print(sents)

for index,sen in enumerate(sents):
    opinions = opinion_extractor("plot",sen)
    print(opinions)
    if set(opinions) == core[index][2]:
        print('Test set {} passed\n'.format(index+1))
# Out:
# ['exciting', 'fresh']
# Test set 1 passed
#
# ['dull']
# Test set 2 passed
#
# ['excessively-dull']
# Test set 3 passed
#
# ['excessively-dull']
# Test set 4 passed
#
# ['dull']
# ['exciting', 'fresh']
# ['excessively-dull']
# ['cheesy']
# ['really-cheesy']

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on examples A.1, B.1, C.1, and C.2.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %% [markdown]
# ## Extension D: Negation
# Look at the tree below; it is an example of an adjective linked by a copula. Your existing opinion extractor would extract "dull". However, notice that the example is saying that the plot was not dull! This is an example of the use of negation.
#
# The dependency relation we use to show this relationship is `neg`.
#
# Your opinion extraction function when given sentences like those below containing the aspect token "*plot*", should use the `neg` relation to output features like "*not-dull*". If you have an adjective token called `"token"`, then you could create this feature like this: `"not-" + token.form`.
#
# **Core Example D.1**: "*The plot wasn't dull.*" should produce "*not-dull*"
# **Core Example D.2**: "*It wasn't an exciting fresh plot.*" should produce "*not-exciting*", "*not-fresh*"
# **Core Example D.3**: "*The plot wasn't excessively dull.*" should produce "*not-excessively-dull*"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension 4 example 1](./img/negation_example_1.png)

# %% [markdown]
# ![Extension 4 example 2](./img/negation_example_2.png)

# %% [markdown]
# ![Extension 4 example 3](./img/negation_example_3.png)

# %%
def opinion_extractor(aspect_token,parsed_sentence):

    opinions = []
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.text == aspect_token:
            negation = build_negation_string(token)
            
            for child in token.children:
                if child.dep_ == 'amod':
                    advmod = build_advmod_string(child)
#                     for subchild in child.children:
#                         if subchild.dep_ == 'advmod':
#                             advmod += subchild.text + '-'
                    opinions.append(negation+advmod+child.text)
            if token.dep_ == 'nsubj':
                filterList = set(filter(lambda x: x.dep_ == 'acomp', token.head.children))
#                 print(list(filterList))
                for x in filterList:
                    advmod = build_advmod_string(x)
                    opinions.append(negation+advmod+x.text)
#     print(opinions)
    return opinions

def build_advmod_string(token):
    advmod = ''
    for child in token.children:
        if child.dep_ == 'advmod':
            advmod += child.text + '-'
    return advmod

def build_negation_string(token):
    negation = ''
    if token.dep_ == 'nsubj' or token.dep_ == 'attr':
        for child in token.head.children:
#             print(child.dep_ + '****\n')
            if child.dep_ == 'neg':
                negation += 'not-'
                break
    return negation

def show_results(results,aspect_word):
    print("Results for aspect word '{}'\n".format(aspect_word))
    for word,sent,opinions in results:
        if word == aspect_word:
            print("Sentence:\n\t{}".format(sent))
            print("Opinion of '{0}':\n\t '{1}'".format(aspect_word,"', '".join(opinions)))
            print("\n")

aspect_words = ["plot","characters","cinematography","dialogue"]
results = [] 
for parsed_review in parsed_reviews:
    for sentence in parsed_review.sents:
        for aspect_token in aspect_words:
            opinions = opinion_extractor(aspect_token,sentence)
            if opinions:
                results.append((aspect_token,sentence.orth_,opinions))

show_results(results,"plot")
show_results(results,"characters")
show_results(results,"cinematography")
show_results(results,"dialogue")
# Out:
# Results for aspect word 'plot'
#
# Sentence:
# 	However,theplotwaspredictable.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Furthermore,theplotissopredictablethatitmadethemoviedrag.
# Opinion of 'plot':
# 	 'so-predictable'
#
#
# Sentence:
# 	well,that'stheusualpredictableromanceplot.
# Opinion of 'plot':
# 	 'usual', 'predictable'
#
#
# Sentence:
# 	TheplotwasOKbutitwouldhavebeenmuchbetteriftheyhadeitherstucktoamoreauthenticrepresentationofJapanesecultureorkeptthestoryinthestates.
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Theperformancesarethinanduneven,theplotisinconsistent,andthedialoguesoundslikeitwaspulledfromfortunecookiesmadebythecastofFriends.
# Opinion of 'plot':
# 	 'inconsistent'
#
#
# Sentence:
# 	AlthoughthismoviewantedtobeinthesameraceandqualityofthemovieCLUE,itfailstorealizethattheplotandcharactersareincrediblyriculousandnotfunnyhahabutfunnystupid.
# Opinion of 'plot':
# 	 'incredibly-riculous'
#
#
# Sentence:
# 	Theactingishorrible,theplotishorrible,thefilmingishorrible...
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Its"thriller"aspectisartificialandnottiedtothecentralplotline,andentirelypredictablefromthemomentourfriendishandedTHEONLYKEYTHATCANSTOPTHENUKE!
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Theplottothismovieorsocalledsequalishorrible.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'surprisingly-straightforward'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Withtheirchildestvoices,theyshouldn'tbeusedasamainplotofthestory
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Asfarasthemovieisconcerned,theplotisunoriginalandnotparticularlyengaging.
# Opinion of 'plot':
# 	 'unoriginal'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Thiswassuchacontrivedmoviethathadasimpleplotthatwentnowhere.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Themoviewasn'tfunny(whichissadtosaywhenoneofmyfavoritecomedicactresses,CarolKane,couldn'tevenelicitasmileoutofme),theplotwasfullofholes,andthewritingseemedveryrushedandcontrived.
# Opinion of 'plot':
# 	 'full'
#
#
# Sentence:
# 	Thespecialeffectsareabitcheesy,youcanseethewirespullingthetorpedosandyoucantellthattheyusedscaledmodelships...butifyouoverlookthoseitems,yougetfineactingandagoodplotwithplentyof
# action
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	stupidplot-toomanyholesandstupidending.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theentireplotisself-serving,shallow,andunrealistic.
# Opinion of 'plot':
# 	 'entire', 'serving'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Thebasicplotofthemovieisthatlifesucks(
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	TheplotislameandIamsorryIspentthemoneyonit.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Butthedumbplotandtheunfunnyattemptsatcomedymakeitacompletewasteoftime.
# Opinion of 'plot':
# 	 'dumb'
#
#
# Sentence:
# 	Eraserhasafewscenesthatwillkeepyourattention,butoverallthemoviedisplayedpooracting,stuntsthatareimpossibleandamediocreplot.
# Opinion of 'plot':
# 	 'mediocre'
#
#
# Sentence:
# 	Verypredictableplotfrombeginningtoend.
# Opinion of 'plot':
# 	 'Very-predictable'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Iwasveryboredwiththismovieandfoundtheplottobeveryinsulting.
# Opinion of 'plot':
# 	 'very-insulting'
#
#
# Sentence:
# 	Buysomthingthathasagoodplot.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Oneoftheworstmoviesi'veeverseen,norealplotandactingisasbadasitcanget.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Canyoureallycarry2hourswiththissingleplot?
# Opinion of 'plot':
# 	 'single'
#
#
# Sentence:
# 	Theplotiscomplicatedandthenoiseinthebackgroundaddstothedisorientationwhichisdoneonpurpose.
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Buttheplotwaslame&slow.
# Opinion of 'plot':
# 	 'lame'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'plot':
# 	 'rather-unbelievable'
#
#
# Sentence:
# 	Thisseriesmightbeconsideredaclassicifwatchedbya12-year-old,butadultswillseethoughtheindistinctplotandcharacters.
# Opinion of 'plot':
# 	 'indistinct'
#
#
# Sentence:
# 	Theplotwasadequate.
# Opinion of 'plot':
# 	 'adequate'
#
#
# Sentence:
# 	Ijustcan'tgetoverhowprofoundlycornyandsimpletheplotandeffectsare,
# Opinion of 'plot':
# 	 'profoundly-corny'
#
#
# Sentence:
# 	BeforeIhitthistooharshly,thisfilmwasintendedtobeatrifle,thekindofmoviethathasbrightcolorsandlightplotforahotsummerdaythatsizzles.
# Opinion of 'plot':
# 	 'light'
#
#
# Sentence:
# 	Soundslikeaninterestingplot,right?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Feebledirectionsimplymissesseveralgoodopportunitiestomakegooduseofthejockey'ssullenlittledaughterSam(KayPanabaker,herfeaturedebut),whocouldhavebeenalittlesurprise(orgem)inthisunconvincingplot.
# Opinion of 'plot':
# 	 'unconvincing'
#
#
# Sentence:
# 	Theonlybluehereistheshadeyouwillturnbytheboredomwiththeweakplot.
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	TheplotwasbadanditdidnothavethatmanypokemonasIthought.
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	...hasaprettythinplot.
# Opinion of 'plot':
# 	 'pretty-thin'
#
#
# Sentence:
# 	Infact,thetrialdoesn'tevenhaveaconnectiontothecentralplotasidefromshowingthatSamandArchiearefriendsandpartners.
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Howeverifyoulikesex,violence,blood,anddebauchery,couldcarelessthefactthattheyhavenothingtodowiththeabsentplot,youcouldfindthisfilminteresting.
# Opinion of 'plot':
# 	 'absent'
#
#
# Sentence:
# 	Andplotissoludicrouslypredictableit'sprettyclearearlyonjustwhothebadguybehindthecurtainis.
# Opinion of 'plot':
# 	 'so-ludicrously-predictable'
#
#
# Sentence:
# 	Flatlighting,cheapsetsandcostumes,dulldialog,woodenacting,andagoofyplot;evenpervasivesiliconeenhancementcannotsavethismovie.
# Opinion of 'plot':
# 	 'goofy'
#
#
# Sentence:
# 	Theplotifpoorlycontrived,theproductionvalueislow,theactingforthemostpartisawful,andit'sbasicallyjustawaytostitchtogetheraseriesofmusicvideoswhichathisage,mysonhasnointerestin.
# Opinion of 'plot':
# 	 'low'
#
#
# Sentence:
# 	JuryDutysimplywasjustplainawfulwithit'sweak,boringplotandunfunnyhumor!
# Opinion of 'plot':
# 	 'weak', 'boring'
#
#
# Sentence:
# 	Theplotofthemovieisinterestingandkeepsyouwonderingwhatisgonnahappennext.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	Theplothowever,isexcellent.
# Opinion of 'plot':
# 	 'excellent'
#
#
# Sentence:
# 	Veryinterestingandunpredictableplot.
# Opinion of 'plot':
# 	 'Very-interesting'
#
#
# Sentence:
# 	Theplotfeelssluggishattimesandthere'swaytoomuchXavierCugatandhisorchestra,butAstaireandHayworthareattheirpeak,KernhaswrittensomememorablemelodiesandfewcouldtopMerceratlyricwriting,noneinHollywood.
# Opinion of 'plot':
# 	 'sluggish'
#
#
# Sentence:
# 	Basicplot:
# Opinion of 'plot':
# 	 'Basic'
#
#
# Sentence:
# 	Sowhileitwasaconvenientplotdevice,youwouldexpectsomethinglikethatbysomeonewithonlyminimalknowledgeofdinosaurs.
# Opinion of 'plot':
# 	 'convenient'
#
#
# Sentence:
# 	itwasquitefunny,buttherewaslessactionandlessplotcomparedtootherepisodes.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	Almosttheentireplotisonboardandunderway.
# Opinion of 'plot':
# 	 'entire', 'onboard'
#
#
# Sentence:
# 	Fromthereitjustgetsprogressivelydarkerandtenser,withthelighting,acting,anddirectionallperfectlyservingtoratchetupthefeelingofdesperationandhorrorasToddkickshisill-conceivedrobberyplotintomotionandthingsspinwayoutofcontrol.
# Opinion of 'plot':
# 	 'ill-conceived'
#
#
# Sentence:
# 	Whileit'shardtopickmyfavoritefirstseasonepisode,thecomplexplotof"APriest,A
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Theplotwaswellworn,butitdidn'tfeelstaidorplodding.
# Opinion of 'plot':
# 	 'well-worn'
#
#
# Sentence:
# 	Theplotisperfectandthescriptiswellwritten.
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplotissweet.
# Opinion of 'plot':
# 	 'sweet'
#
#
# Sentence:
# 	Thequalityofthegraphicsareterrific,theplotisalittlestrange,butbasicallyitsalienswhoinvadeandride4virtualrollercoastersatafuturisticthemepark.
# Opinion of 'plot':
# 	 'little-strange'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	anywayirecommendthistoanyonewholoves Asianhorrorandlikesagoodplotandmovie!!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisnotveryintriguing,andyouknowthatnothinglikethiscanhappeninthereallife,soitlacksthissenseofreality.
# Opinion of 'plot':
# 	 'not-very-intriguing'
#
#
# Sentence:
# 	I'mnotamoviebuff,butDeepCoverhasalltheelementsyouwouldexpectofaclassic:greatacting,memorablelines,interesting(andlogical)plotandadecentending.
# Opinion of 'plot':
# 	 'logical'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'plot':
# 	 'silly', 'funny'
#
#
# Sentence:
# 	TheplotevolvesasmanyotherCoenmovies(RaisingArizonacomestomind)asweareintroducedtomore-and-morecolorfulcharactersandtheplotgetsmore-and-moreoutrageous,yetsomehowstillseemsreal.
# Opinion of 'plot':
# 	 'more-outrageous'
#
#
# Sentence:
# 	Everyoneknowsthebasicplotbynow:SpockkidnapshiscrippledformerCaptain,andhijackstheEnterprise,andsetscoursefortheoneforbiddenplanetinallTheFederation.
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	Yes,theplotisodd.
# Opinion of 'plot':
# 	 'odd'
#
#
# Sentence:
# 	Itdoesn'tfollowastorylinethat'spredictable,eventhoughtheplotisnotunknown.
# Opinion of 'plot':
# 	 'not-unknown'
#
#
# Sentence:
# 	Itusesoneoftheworstsuperheroclichesasthemainplot,thatoftheherocallingitquits.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	There'sashadowyplotinvolving$10,000bills,aguerillamovementandguns,butthemoviefocusesmoreonQuinn'sconflictsbecausehischildhoodfriendissuspectedofagrislymurder,andQuinn'sowndiscomfortfromhaving"madegood"butendingupcaughtbetweentwoworlds,whiteandblack.
# Opinion of 'plot':
# 	 'shadowy'
#
#
# Sentence:
# 	Wasitcancelledbecausetheplotwasflimsyordumb?
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Theplot,thesetting,thedialogues,thespecialeffects,andthemusicareallwonderful!
# Opinion of 'plot':
# 	 'wonderful'
#
#
# Sentence:
# 	Theplotisinteresting,itkeepsyouguessing,andthesuspensekeepsyouontheedgeofyourseat.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	DirectedbyTamraDaviswithakeeneyeoncharacterizationandhumor,thismovieisoneofthoseyousmilemostofthetime,andhaveagoodtimewithitssurrealandzanyplot.
# Opinion of 'plot':
# 	 'surreal'
#
#
# Sentence:
# 	Theplotwasn'thorrible,itwasactuallyprettygoodforafrightflick.
# Opinion of 'plot':
# 	 'not-horrible'
#
#
# Sentence:
# 	Theplot,thesetting,theacting,andthedialoguesareallverygood.
# Opinion of 'plot':
# 	 'very-good'
#
#
# Sentence:
# 	Theplotiscomplex.
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Eventhoughthefilmisbasedonafictionalplot,itstillhasanauthenticfeelandisratedanalltimeclassic.
# Opinion of 'plot':
# 	 'fictional'
#
#
# Sentence:
# 	Theplotisgood,andDeoxys''destructive'intentionsarelesscruelthanonewouldthink.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotanddialogueisincrediblebecauseitexploresalltheshadesofgreyinthecharacters.
# Opinion of 'plot':
# 	 'incredible'
#
#
# Sentence:
# 	theplotwasprettyoriginal.
# Opinion of 'plot':
# 	 'pretty-original'
#
#
# Sentence:
# 	Thisfilmmaynotbeperfect,andtherearesomeboringscenesastheytrytohardtoexplainthestateNickisin,buttheoverallplotofthisfilmisoneI'veneverseendonebefore.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisprettyunrealisticbutthenitisascrewycomedysoithelpsifyoususpendagooddealofdisbelief.
# Opinion of 'plot':
# 	 'pretty-unrealistic'
#
#
# Sentence:
# 	ItcombinesabunchofthebestFrenchactrices,andanenjoyableplot.
# Opinion of 'plot':
# 	 'enjoyable'
#
#
# Sentence:
# 	theplotwasdry,liketheother2oftheseries,buthowexcitingofaplotcanyouhavewiththeamountofactionandskilleddrivingpackedintothemovie.
# Opinion of 'plot':
# 	 'dry'
#
#
# Sentence:
# 	Suretheplotofweakandtherelationshipsareunbelievable,ImeanwhocanhonestlysaythattheyfeelakingpintotheJapanese/Chinese/Oriental(whateveritwas)
# Opinion of 'plot':
# 	 'unbelievable'
#
#
# Sentence:
# 	Thisfilmhassomegoodactorsinitbuttheplotisprettyshakyandhardtofollowattimes.
# Opinion of 'plot':
# 	 'pretty-shaky'
#
#
# Sentence:
# 	Itcouldhavebeenmadebetter--lesscomedyandmoreplotandofcourse--actionandsuspense!!!!
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Theplotwasveryst8fowardandbasicwithafewlittletidbitstolivingitup.
# Opinion of 'plot':
# 	 'foward'
#
#
# Sentence:
# 	Theplotisverygood.
# Opinion of 'plot':
# 	 'very-good'
#
#
# Sentence:
# 	but,unfortunately,theproducersforgettogivethemacredibleplotandinterestingthingstosay.
# Opinion of 'plot':
# 	 'credible'
#
#
# Sentence:
# 	PeoplewhoreviewSpielbergusuallywanttopigeonholehimintoatype:theET-warm-and-fuzzy-alienchildren'sstorytellerversusthespecial-effects-heavy-but-rather-empty-plotdreamer.
# Opinion of 'plot':
# 	 'empty'
#
#
# Sentence:
# 	Theplotisslowtodevelop,characterdevelopmentlackingandanimationprimitiveatbest.
# Opinion of 'plot':
# 	 'slow'
#
#
# Sentence:
# 	Bothfilmshavethesameborringplot.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Maybethenextfewvolumeswillbemorecreativeandgivemoredetailsonthemainplot,butIpersonallydon'tcaretospendanymoreofmymoneyonsucharisk.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Thebad:Notaveryinterestingorprofoundplot.
# Opinion of 'plot':
# 	 'bad', 'very-interesting'
#
#
# Sentence:
# 	Theplotofthestoryisreallyinteresting.
# Opinion of 'plot':
# 	 'really-interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whiletheplotisnearlyidentical,AlexanderPayne(director)treatshischaractersmuchharsherthanPerrotta.
# Opinion of 'plot':
# 	 'nearly-identical'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	ThestorybeginswithafailedassasinationplotthenfollowsMalciekChelmicki(ZbigniewCybulskiakaPolandsJamesDean)untilit'sconclusion.
# Opinion of 'plot':
# 	 'failed'
#
#
# Sentence:
# 	Episode16:"TheFactofBeingThere"/"AnotherChance"
# Andallattentionbacktothemainplot.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Althoughtheplotisalittlethin,therearesomeveryfunnymoments.
# Opinion of 'plot':
# 	 'little-thin'
#
#
# Sentence:
# 	Theplotwas,insomerespects,totallyillogical,andatothertimesnonsensical.
# Opinion of 'plot':
# 	 'totally-illogical'
#
#
# Sentence:
# 	Theplotisentirelyunconvincingandimplausible.
# Opinion of 'plot':
# 	 'entirely-unconvincing'
#
#
# Sentence:
# 	Verygoodplotanddetail
# Opinion of 'plot':
# 	 'Very-good'
#
#
# Sentence:
# 	Insummary,themusicportionofthisDVDratesastrongfivestars,butthesillyplotandtheproblemswiththediskdiscussedabove,bringthisDVDdowntoafourstarproduction
# Opinion of 'plot':
# 	 'silly'
#
#
# Sentence:
# 	Theplotisfartoocomplicatedandtwistytogetinto,andfranklyhasbeengoneoverwithafinetoothcombalreadyonthissite.
# Opinion of 'plot':
# 	 'far-too-complicated'
#
#
# Sentence:
# 	Unlike,forexample,LOSTHIGHWAY,thisisacompletelyrealisticplot,withnosupernaturalorunexplainableelements.
# Opinion of 'plot':
# 	 'completely-realistic'
#
#
# Sentence:
# 	OnceyoualreadyknowtheoverallplottheDirector'sCutisbetter,andallthestuffthat'saddediniscool,
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Fourth,theplotisslickandoriginal.
# Opinion of 'plot':
# 	 'slick'
#
#
# Sentence:
# 	It'snotasifthefilmwouldbecompletlyalienatingtonewcomers,notatall,itsjustthatifIhadn'treadthebookbeforehand,I'msureIwouldhavefoundthingsabithardertofollow,asthingsmovefairlyquicklyandthere'saneverthickeningplottokeepaneyeon.
# Opinion of 'plot':
# 	 'ever-thickening'
#
#
# Sentence:
# 	Wellthat'sabouttheentireplotofthismovie.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Allheneedstocompletethisisasmallplotofland.
# Opinion of 'plot':
# 	 'small'
#
#
# Sentence:
# 	this1hasastupidplot.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Yojimboisavastlyentertainingactionfilmwithalltheelementsofthatgenre:fastpace,surprisingplotturns,andajustlyfamoussamuraishowdown.
# Opinion of 'plot':
# 	 'surprising'
#
#
# Sentence:
# 	Myfavoritesongis&quot;NeverTalktoStrangers&quot;.Themovieelaboratesontheoriginalstorybyaddingmoreplottospicethestoryup.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Lynchdoesn'tfollowarealplot;instead,heletsthestorylineslowlysinkintoLaura'sdownfall.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Thisfilmisperfectforeveryone,thealluringplot,amazingacting,entertainingscreenplay.
# Opinion of 'plot':
# 	 'alluring'
#
#
# Sentence:
# 	TheplotcanbealittledumbattimesbutChrisTuckeriswhatthismovieisallabout.
# Opinion of 'plot':
# 	 'little-dumb'
#
#
# Sentence:
# 	Theplotiscomplexenoughtokeepthewatcherguessingwhatexactlywillhappenandnotboretheaudience.
# Opinion of 'plot':
# 	 'enough-complex'
#
#
# Sentence:
# 	Badforanyonewhowantshighproductionvalueoranidentifiableplot
# Opinion of 'plot':
# 	 'identifiable'
#
#
# Sentence:
# 	Plentyofaction,plentyofbeautifulsceneryandpeople,ahalfwaydecentplot,plentyoflogicalunpredictability,anditplayswellonthesmallscreen.
# Opinion of 'plot':
# 	 'halfway-decent'
#
#
# Sentence:
# 	Irecommendthismovietoanyonewhoislookingforagoodcomedywithaveryfunnyplot.
# Opinion of 'plot':
# 	 'very-funny'
#
#
# Sentence:
# 	-"LovebeforeBreakfast"isaUniversalproductionandhasthesimplestplotofthecollection;infact,noplotatallreally.
# Opinion of 'plot':
# 	 'simplest'
#
#
# Sentence:
# 	Thefilmcombinestoomanygenresandtheplotbecomesconvoluted.
# Opinion of 'plot':
# 	 'convoluted'
#
#
# Sentence:
# 	Inthistreatmentoftheannoyingplot,heloseshismind.
# Opinion of 'plot':
# 	 'annoying'
#
#
# Sentence:
# 	AnatomyofaMurderisatoncebothadelightfulmysteryandasuspensefulthillerforthosewouldwouldratherthinkaboutallthemanydimensionsandlayersofintriquegoingoninamovieratherthanbespoonfedaformulaicplot.
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Ratherformulaicplot;thedancingisthethinghere
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Theanimationistotallycool,thekidsarebelievable,theplotisinterestingandhassometwistsandturnstokeepyouguessing,andthedialogisdownrightfunnyattimes.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Theplotisverysimple,thesetsaresimple...butthefilmisgreat.
# Opinion of 'plot':
# 	 'very-simple'
#
#
# Sentence:
# 	CreditneedstobegiventoJamieAnderson'scinematographyandNeilSpisak'sproductiondesignforestablishingsuchaheadyatmosphereperfectforthelabyrinthplot.
# Opinion of 'plot':
# 	 'labyrinth'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Iwon'tre-hashtheplotasAmazonhasalreadyprovidedpotentialbuyerswiththeoutline.
# Opinion of 'plot':
# 	 'hash'
#
#
# Sentence:
# 	Themoviestillhadsappylines,unrealisticplot,andunconvincingelementstoit.
# Opinion of 'plot':
# 	 'unrealistic'
#
#
# Sentence:
# 	Ifyourlookingforanimethathasaction,suspence,romance,humor,andanengagingplotwithlotsoftwistsEscaflowneistheonetoget.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Theplotistooimplausibleandriddledwithinconsistenciestobetakenliterally.
# Opinion of 'plot':
# 	 'too-implausible'
#
#
# Sentence:
# 	Greatcharacters,awellcraftedplot,andsomeofthebestanimationIhaveeversee.
# Opinion of 'plot':
# 	 'well-crafted'
#
#
# Sentence:
# 	Theplotisfartooconvolutedtoevenbegintorecount,butthepremiseisthatthesetwounlikelycharactersareabouttobecomein-laws.
# Opinion of 'plot':
# 	 'far-too-convoluted'
#
#
# Sentence:
# 	Wonderfullocations,mesmerizingstunts,admirablespecialeffects,averycleverplotandrespectablecastobligatesustoconsiderabsolutelyrecommendable.
# Opinion of 'plot':
# 	 'very-clever'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Butthereisenoughplottounderstandwhatthestoryisabout.
# Opinion of 'plot':
# 	 'enough'
#
#
# Sentence:
# 	Ienjoyedthismoviebecausetheplotwasverydifferentandnotrunofthemilllikemosthorrormovies.
# Opinion of 'plot':
# 	 'very-different'
#
#
# Sentence:
# 	TheplotisOKandwithatwistthatshouldn'tberevealedbeforehand
# Opinion of 'plot':
# 	 'OK'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Themovie"Boo"featuresterribleacting,andadeplorableplot.
# Opinion of 'plot':
# 	 'deplorable'
#
#
# Sentence:
# 	It'snotarevolutionaryplot,andafewscenescouldhavebeenbetterexecuted(theobligatory'break-up'beforethehappyendingisratherweak),butonthewholethemushysideofmeateitup.
# Opinion of 'plot':
# 	 'not-revolutionary'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Theplotisratherthinandconsistsofthefairyworldtryingtotakeoverthisworld.
# Opinion of 'plot':
# 	 'rather-thin'
#
#
# Sentence:
# 	BeeSeason"isjusthorribleandthismoviehasamuchbetterplot,betteractingandabettermessage.
# Opinion of 'plot':
# 	 'much-better'
#
#
# Sentence:
# 	IfIhadn'tseentheoriginalI'djustthink,"whatabrilliantplot,toobadtheydecidedtoburyit(nopunintended)witheverythingelseinthemovie".
# Opinion of 'plot':
# 	 'brilliant'
#
#
# Sentence:
# 	belowaverage,thedialoguesarewaybelowaverage,whiletheplotisnotbadatall.
# Opinion of 'plot':
# 	 'not-bad'
#
#
# Sentence:
# 	Theplot isludicrous,thescriptfoolishandinept,theactingsocrudeastobeembarrrassing.
# Opinion of 'plot':
# 	 'foolish', 'ludicrous'
#
#
# Sentence:
# 	Theplotisweakaskingustobelieveincharactersdoingthingsthatnoonewithoneounceoflogicwoulddo(forexample,themotherleaveshomeforafewdaystovisitanauntknowingherhusbandrecentlysluggedhersoninthefacewithoutprovocation).
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Iftheplotwerebetteritwouldbeafilmworthwatching
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	Themovieappealswithitsintricateplot-aningeniouswebawaitedthealmosthelplessWilliamHurt,whowasdazzledbythebeautyofKathleenTurnerandwhosemindwas,nodoubt,slowedbytheintenseheat.
# Opinion of 'plot':
# 	 'intricate'
#
#
# Sentence:
# 	Goodplot.
# Opinion of 'plot':
# 	 'Good'
#
#
# Sentence:
# 	Whetherornotthereactuallyareghostsis,ofcourse,themainplotofthemovie,andtruetothegenreitdancesaroundthequestionforagoodlengthoftimebeforefinallyansweringit.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Itwasnottheactualstory/plot,orit'saccuracythatwasimportanttome.
# Opinion of 'plot':
# 	 'not-actual'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'surprisingly-straightforward'
#
#
# Sentence:
# 	Criticsarguethattheplotistoocomplicated/clever,butthiswasentertaining,withovertonesofpoliticalconspiracythatmakeyourealizehoweasyitisforthetrulypowerfultomanipulateevents.
# Opinion of 'plot':
# 	 'clever'
#
#
# Sentence:
# 	Foramoreexplosiveride,withamoreentertainingcharacter,andamuchsimplerdrug-inducedandgraphicplot,seetherecentlyreleasedCrank-excellentaction/adventurefromtheTransporterman.
# Opinion of 'plot':
# 	 'much-simpler', 'induced'
#
#
# Sentence:
# 	JustlikeallDePalmafilms,DressedtoKillfeaturessomeabsolutelybrilliantsequences(elevator,trainstation)dispersedthroughoutaratherclumsyplot.
# Opinion of 'plot':
# 	 'rather-clumsy'
#
#
# Sentence:
# 	SetinWWIILondon,thedarkheartedplotfocusesonNavyLieutenantCommanderCharlesMadison,anespeciallynotoriouspersonalassistanttothementallyunstableAdmiralWilliamJessup.
# Opinion of 'plot':
# 	 'dark', 'hearted'
#
#
# Sentence:
# 	Iamlaughingatthose2starreviewssayinghowAVPisdestroyingtheAlienandPredatorlegacybecauseofitsnonexistentplot.
# Opinion of 'plot':
# 	 'nonexistent'
#
#
# Sentence:
# 	Verysuspenseful,andwonderfullywrittenplotmakethisa5starfilm!
# Opinion of 'plot':
# 	 'Very-suspenseful', 'wonderfully-written'
#
#
# Sentence:
# 	Theplotisfairlysimplewiththetwobrotherstryingtopreventagangofoutlawsfromterrorizingagroupoffarmersandstealingtheirland.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	Theplotisnotnew.
# Opinion of 'plot':
# 	 'not-new'
#
#
# Sentence:
# 	Goodversusevil,ofcourse,buttheplotismoreabouttheclasses.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	TheplotisUNEXPECTED,thatiamnotsureifit'sgoodornot!
# Opinion of 'plot':
# 	 'UNEXPECTED'
#
#
# Sentence:
# 	Theplotisfartocomplicatedtoexplaininareasonableamountoftime,butissumsuptobeaboutabunchofpeople,withcompletelydifferentlifestyles,whosomehowgetthrowntogetherbecauseofabigbombthatlookslikeagarbedgedisposal.
# Opinion of 'plot':
# 	 'far-complicated'
#
#
# Sentence:
# 	Fromthere,theplotgoesnuts,butthat'sokay,becauseit'swhatmakesBigTroublesuchafunnyandstrangelysmartmovie.
# Opinion of 'plot':
# 	 'nuts'
#
#
# Sentence:
# 	Thisisagoodmoviewithaninterestingplot,goodacting,decentdirectingandapoliticallyreleventcommentontheexcessesoftheUSPress.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Alotofpeopletendtosaythatthisanimeisconfusinganddoesn'thavearealplot.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Ithinkthedirectorneedsprozactodirectthismovie,thewholeplotissomessup,juniorhighstudentcanwritebetterstorythanthis..whatwashethinking.
# Opinion of 'plot':
# 	 'whole', 'so-mess'
#
#
# Sentence:
# 	Thecharactersaresoveryinteresting(butsubtle),theycouldhavewrittenanyoldplotandIwouldhavewatchedhungrily.
# Opinion of 'plot':
# 	 'old'
#
#
# Sentence:
# 	Whileultimatelythissetofindividualepisodesdoesn'tseemtofurtheranyoverallplot,thecomplexityoftheTachikomasandhowtheyworkisactuallyprettyinteresting.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisalittlethin,butAlyssaMilanoisthereasontowatchthismovie.
# Opinion of 'plot':
# 	 'thin'
#
#
# Sentence:
# 	Thesewerealllosersbecausetheyhadashallowplot,alackoftalentedactors/actresses,andnomoralfibertothemwhatsoever.
# Opinion of 'plot':
# 	 'shallow'
#
#
# Sentence:
# 	Idon'tknowwhoplaysPatsy,butsheissuperbandthisplotstrandisverypoignant.
# Opinion of 'plot':
# 	 'very-poignant'
#
#
# Sentence:
# 	Itisthesethemesthatmaketheseriestrulyshine,asthesimplisticoverallplotservesmerelyasavehiclefortheseideas.
# Opinion of 'plot':
# 	 'simplistic', 'overall'
#
#
# Sentence:
# 	Theplotisratherpredictableandyoucouldsensetheendingalmostfromthebeginning.
# Opinion of 'plot':
# 	 'rather-predictable'
#
#
# Sentence:
# 	Theplotisfairlysimple.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	NowobviouslythisissameplotusedintheSantaClause
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	IthasafairlysimpleplotwhichsendsthecharactersrunningaroundNYConenightatChristmastime-eachwithhisorherownmisunderstandingofwhatisgoingon.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	Watchtheperfectmurderplotbeingexecuted
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplottothefilmissocomplicatedthatitreallyistoughtokeepupwith,eventhoughtherereallyisn'tthatmuchgoingonthroughoutmostofthefilm.
# Opinion of 'plot':
# 	 'so-complicated'
#
#
# Sentence:
# 	ShefindsadischargenoticeinRyu'spants,andthenextthingweknowshehasfiguredouttheentireplot,includingthekidnapping.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Theplotandsupportingcastarebetterthanpassable,thisisn'tatotallybadflick.
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	McGiverhasfallenforKhanandsays,"Iwilldoanything",sellsoutherselftoopower,andagreeswithhisevilplottootakeovertheEnterprise.
# Opinion of 'plot':
# 	 'evil'
#
#
# Sentence:
# 	Thecharacterworkisverygoodandtheplotgetsmoreandmoreinterestingasthemoviegoeson.
# Opinion of 'plot':
# 	 'more-interesting'
#
#
# Sentence:
# 	"Stargate"isstilloneofthescience-fictiongreatsthatsuccessfullyblendshistoryandscience-fictioninoneeffectiveplot.
# Opinion of 'plot':
# 	 'effective'
#
#
# Sentence:
# 	ThisDVDofTeentitansthe2ndseasionhasagoodstoryplot,andIforoneloveit!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Nowtothemeatofthereview,theplotinthismovieisn'treallythatgood,butnotveryhorrible.
# Opinion of 'plot':
# 	 'not-that-good'
#
#
# Sentence:
# 	Notaparticularlyinvolvedplot,butthenI'veseenjustaboutallthereare,butaverynicelittlefilm.
# Opinion of 'plot':
# 	 'particularly-involved'
#
#
# Sentence:
# 	Inotherwords,it'sthesimpleBODYSNATCHERSplot.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Moreplot,morestory,moregore(gettheunratedversion)andmoreJASON!
# Opinion of 'plot':
# 	 'More'
#
#
# Sentence:
# 	TheplotisratherShakespearean--themixupoflovers--buteverythingturnsouthappilyintheend.
# Opinion of 'plot':
# 	 'rather-Shakespearean'
#
#
# Sentence:
# 	Nottomentionit'snotexactlythemostcliche-freeplotasthere'ssomescenesthataregoingtobeobviousandwhentheyhappentheydon'treallysurprise(apossibleromancebetweenJohnandFlor,Deborahandhermotherhavinganall-outorjealousyamongFlorandDeborah)butthefilm'sentertaininganyway.
# Opinion of 'plot':
# 	 'not-most-free'
#
#
# Sentence:
# 	Theunconvincingcharacterizationsandhackneyedplotarelostinawelterofstrikingincidentaldetails:hundredsofglassbaublesrollingdownastaircaseandintothebloodywaterofasuicidevictim'sbathtub,beingaparticularlyimpressiveexample.
# Opinion of 'plot':
# 	 'hackneyed'
#
#
# Sentence:
# 	Poorplot,script,acting
# Opinion of 'plot':
# 	 'Poor'
#
#
# Sentence:
# 	Greataction,engagingplot,greatcinematography.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Moreblood,nudity,violence,swearing,andsexthanthefirstmovie,lessplotandcharacterization.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	REDPLANETunfortunatelyneededmorethanitsminimalistplottocarryit.
# Opinion of 'plot':
# 	 'minimalist'
#
#
# Sentence:
# 	Thefilmisatreat,especiallythefirsttimearound,despiteacomplicatedplotandanunderachievingstoryline
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Thisplotismucheasiertodigestonscreen.
# Opinion of 'plot':
# 	 'much-easier'
#
#
# Sentence:
# 	Theplotisgreat,theactingisoverthetop,andthecinematographyisfantastic.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whichonewillgettheirman,aninterestingsub-plot?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Itwasn'tthesameoldboringplotasthereweremanyunexpectedturnsandmisadventuresintheplot.
# Opinion of 'plot':
# 	 'not-same', 'not-old', 'not-boring'
#
#
# Sentence:
# 	Thisisn'tanewplot;You'veseenthis,insomeformoranother,severaltimes.
# Opinion of 'plot':
# 	 'not-new'
#
#
# Sentence:
# 	Aftertherecentspateofrubberrealityfilmsthatallusedessentiallythesameplot--includingStay(2005),TheJacket(2005),November(2004),TheIInside(2003),andeightornineothersgoingatleastallthewaybacktoJacob'sLadder(1990)andtheshortTheAwakening(1990)--TheDarkHoursveryrefreshinglyusesdifferentkindsoftwistsinitsquestionablyhallucinatorysuccessionofscenes.
# Opinion of 'plot':
# 	 'same'
#
#
# Results for aspect word 'characters'
#
# Sentence:
# 	Thecharacterstalkabouttherelativeintelligenceoftheothercharactersorhowtheothercharacterscan'tpossiblyknowwhatisgoingon.
# Opinion of 'characters':
# 	 'other', 'not-other'
#
#
# Sentence:
# 	ThereareonlytwoBlackcharacters,bothsentimentallyloyaltotheirSouthernnessandtheirmasters;otherwise,slaveryisbesidethepoint.
# Opinion of 'characters':
# 	 'Black', 'sentimentally-loyal'
#
#
# Sentence:
# 	whenlessthanhalfwaythrough,thestorybecomessomethingutterlyunrecognizablefromtheoriginal,severalkeycharactersarelumpedtogethermostconfusingly,andotherslosealltheircomplexcharm.
# Opinion of 'characters':
# 	 'several', 'key'
#
#
# Sentence:
# 	Ifeltthatwithinallthetimeitran,wedidn'treallygetagoodunderstandingoftheinnerbeingofthemaincharacters;seemedtoremaininshallowwatersallalong.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Otherreviewershavecommentedonthebad,infomerciallevelactingofthetwoleadcharacters.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	"ConExpress"haslotsofactioninit,whichisgreatbecausethishidesthepoorwritinganduninterestingcharacters.
# Opinion of 'characters':
# 	 'writing'
#
#
# Sentence:
# 	ThemoviegetsboringratherfastasBetteandWoodyaretheonlyoneswegettoseeasthereareveryfewsupportingcharacters.
# Opinion of 'characters':
# 	 'very-few', 'supporting'
#
#
# Sentence:
# 	Thesedisjointedglimpsesdon'tgivetheviewertimeordepthtocarewhathappenstoanyofthespoiledrottencharacters.
# Opinion of 'characters':
# 	 'spoiled', 'rotten'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Thecharactersarethinatbest,andstockatworst.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Can'trememberwhenI'veseenafilmwithmoredepravedandpatheticcharactersthanthis.
# Opinion of 'characters':
# 	 'more-depraved'
#
#
# Sentence:
# 	ThecharactersareunlikeableexceptforCharity'stwofriends.
# Opinion of 'characters':
# 	 'unlikeable'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Forgoodcounterexampleswatch"Trainspotting",whichhasdrug-addictcharacterswithenoughhumorandlifetobelikableandinterestingand"BubbaHo-Tep",afilmwhichdisplaystheplightofthelonelyelderly50timesbetterthanthisfilmdespitebeingasillyhorror-comedywithamummyinacowboyoutfitinit.
# Opinion of 'characters':
# 	 'addict'
#
#
# Sentence:
# 	NowthatthesetediouscharactershavefinallyhitrockbottomIcangodosomethingelse.
# Opinion of 'characters':
# 	 'tedious'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	AnarrativelikeGettysburgthatgoesbackandforthbetweenafewcentralcharactersinalogicalsequencewithoutallthehamfistedattemptsaproselytizingandallthenoblesseoblige.
# Opinion of 'characters':
# 	 'few', 'central'
#
#
# Sentence:
# 	Iwaswatchingthesametwocharactersfightthroughthesametwochallengesinthisfilm.
# Opinion of 'characters':
# 	 'same'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'characters':
# 	 'obscure', 'secondary', 'main'
#
#
# Sentence:
# 	Ifhewouldhavetightenedthescript,createduniqueand"cult-like"characters,andeliminatedtheracism,hemayhavehadthequintessential"weed"filminHollywood.
# Opinion of 'characters':
# 	 'unique'
#
#
# Sentence:
# 	Hediscoversanewtalent(artistChristinaMilian)andworkshiswaythroughanassortmentofcharactersthataremoretypesandclichesthanrealcharacters.
# Opinion of 'characters':
# 	 'real'
#
#
# Sentence:
# 	Thesoundismurkyandundecipherable,theactingisstrictlyamateurhour,thecharactersarepaper-thinwithnodistinctionorpurpose,thestoryisnon-existent,thedialogueisacompletelyworthlessbore,there'snothingremotelyscary,andthespecialeffects(includingacoupleofcomputereffectsthatlookliketheyweremadeonaCommodore64)arelaughable.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Nothinghappensinthismovie(andImeannothing)exceptabunchofsullencharactersexhanging"comic"glancesandlookingwithdrawnandcynical.
# Opinion of 'characters':
# 	 'sullen'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'characters':
# 	 'both-same'
#
#
# Sentence:
# 	It'sastudyincontrasts,andit'sdoneimpeccablyinthenovel,withaplethoraofcomplexcharacterstorichenthejourney...
# Opinion of 'characters':
# 	 'complex'
#
#
# Sentence:
# 	Realcharacters?
# Opinion of 'characters':
# 	 'Real'
#
#
# Sentence:
# 	Therestofthisfilmconsistsoftheear-bleedingwhinesandyawn-inducinginfightingofthehumancharacters,ill-conceivedandextremelyunlikablecaricaturesofapseudo-cynicalandextremelyredundant"evilsideofhumannature"messagethatwouldbebetterlefttoJeanRenoir(orevenAdamSandlerconsideringtheresultshere).
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	Iguessit'ssupposedtodepictthehorrorofrepressivereligiousvalues,andwhileIdon'tcondonethose,thefilmlacksclearcharactersoranymotivation.
# Opinion of 'characters':
# 	 'clear'
#
#
# Sentence:
# 	ItiseasytogetsuckedintowatchingGantz,becauseoftheuniqueandinexplicablesituationthatthemaincharacters,whohavealldied,findthemselvesin.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	Thecharactersaresolame
# Opinion of 'characters':
# 	 'so-lame'
#
#
# Sentence:
# 	Thecharactersare,overall,blandandjustplainuninteresting(e.g.RickAndersonplayedbythe"fool,"TedRaimi,fromtheXenaseries).
# Opinion of 'characters':
# 	 'bland'
#
#
# Sentence:
# 	andIdidn'tcarewhatwouldhappenwiththemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Ireadthebookandsawthemovie,whichotherthantitleandmajorcharacters,havelittleincommon.
# Opinion of 'characters':
# 	 'major'
#
#
# Sentence:
# 	Theminorcharacters,includingthewonderfulTracieThomsas"bestfriend"Lily,aremostlywasted.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	ThebigproblemwithRHisthatneitherFordorBenningaresympatheticcharacters.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Theproducersofthisfilmareoutoftheirmindiftheyexpectanyviewerwho'snotscrewed-upintheheadtofeelsorryforthetwostupidmaincharactersjustbecausetheirsick,incestuous,andadulterouslifestyleisincompatiblewiththeworldtheylivein.
# Opinion of 'characters':
# 	 'stupid', 'main'
#
#
# Sentence:
# 	Tooimplausible,toomanyoverdrawnsecondarycharacters.
# Opinion of 'characters':
# 	 'Too-implausible', 'overdrawn', 'secondary'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	WhoevermasteredthisgreatfilmRUINEDitbyFORGETTINGorREFUSINGtoprovideEnglishsubtitlesfortheJapaneseandItaliancharacters.
# Opinion of 'characters':
# 	 'Japanese'
#
#
# Sentence:
# 	Occasionallywegetashotofsomeoftheothercharacters.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	We'resupposedtofindthecharactersplayedbyRobertRedfordandDebraWingertobeamusing,theiracrimoniousrelationshiptobehilarious,andthewaythattheyendupbeingpartnersdespiteallofthegibestoberomanticallysatisfying.
# Opinion of 'characters':
# 	 'amusing'
#
#
# Sentence:
# 	Long,tediousactionadventurewithrepetitivedialog,badplotholes,andgenerallyboringcharactersishowtodescribethislittleforayintofollowingupthecharactersfromBadBoys.
# Opinion of 'characters':
# 	 'generally-boring'
#
#
# Sentence:
# 	It'samazinghowsomuchmoneyandeffortgointospecialeffectsandexpensivesetsandthescriptitselfishollowwithlousycharacters.
# Opinion of 'characters':
# 	 'lousy'
#
#
# Sentence:
# 	Anditdoesn'tonlycenteraroundthemaincharactersbuthasagreatensemblecastofveryinterestingpeople!
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'ok'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Haspleasantcharacters;butnotdeep.
# Opinion of 'characters':
# 	 'pleasant'
#
#
# Sentence:
# 	Itsjustbadactingwithstupidandmeancharacters.
# Opinion of 'characters':
# 	 'stupid'
#
#
# Sentence:
# 	Rivkabecomeshercousinandothercharactersareneglectedcompletely.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Afterorbeforekeyscenes,thecameracutstoamonologuefromoneofthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Toitscredit,theactorsdidwhole-heartedlyportraygaycharactersandgaylovescenes.
# Opinion of 'characters':
# 	 'heartedly-portray', 'gay'
#
#
# Sentence:
# 	Atthetime,gaycharacterswereneverportrayedinapositivelightfromthemedia,anditwasagreatrisktodosohere.
# Opinion of 'characters':
# 	 'gay'
#
#
# Sentence:
# 	CertainlynottheweirdIrishaccentstheleadcharactersadopted.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Theothercharactersarelikewiselackinginrealism,onlyJanetMcTeerfareswell
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Mightbesuitedmoreforanolderchildbutmineis13monthssotherehastobeconstantcolorfulcharactersforhertobeinterested
# Opinion of 'characters':
# 	 'constant', 'colorful'
#
#
# Sentence:
# 	Theplotlinewasnonexistent,andthecharacterswerecompletelyunlikeable.
# Opinion of 'characters':
# 	 'completely-unlikeable'
#
#
# Sentence:
# 	istartedlikingthismovie,ithoughtthepinballmetaphorandwildcharactersandlifesacartoonshizcouldhaveworkedout,ifitwerentforthefactthatbakshiisthinlydisguisinghimselfandhisownfrustrationasbeinganunoriginal"underground"cartoonistwhocaughtontothescenetoolate...ifyoulikethedepressing,gritty,wild,fastpacedstyleofthismovie,checkouttheoriginalmasterROBERTCRUMB,towardwhombakshiisobviouslyseethingwithjealousyandridinganxiouslyonthecoattailsof...
# Opinion of 'characters':
# 	 'wild'
#
#
# Sentence:
# 	Everyminutecharactersinthisseriestrytoremindyouofsomeplotpointasifyou'reashort-attentionspancoachpotatoe.
# Opinion of 'characters':
# 	 'minute'
#
#
# Sentence:
# 	butthenthefilmbasicallyspendstoomuchtimezigzaggingaroundtoallthedifferentcharactersandlocales.
# Opinion of 'characters':
# 	 'different'
#
#
# Sentence:
# 	Itseemstoberidingonit'slaurels,sotospeak,andit'salmostasifwearesupposedtofindthecharactersactingdifferentlyfunny.
# Opinion of 'characters':
# 	 'differently-funny'
#
#
# Sentence:
# 	Butthecharactersarenotsympathetic,funorinteresting.
# Opinion of 'characters':
# 	 'not-sympathetic'
#
#
# Sentence:
# 	Thereisnohumor,nolikablecharacters,notevenadecentquoteoroneliner.
# Opinion of 'characters':
# 	 'likable'
#
#
# Sentence:
# 	Therearetwonewsupportingcharactersthistime,Loisand,erm...Jason.
# Opinion of 'characters':
# 	 'new', 'supporting'
#
#
# Sentence:
# 	SheisagreatalternativetoBarneyandalloftheothercommercialcharacters,whoIdon'tcaremuchfor.
# Opinion of 'characters':
# 	 'other', 'commercial'
#
#
# Sentence:
# 	Thestoryissimple,butinthehandsofthewritersWendyHammondandBobGosseandwithGosse'sfinedirection,theentirecastgivesusanensembleofdisparatecharactersinwhomwecanallbelieve.
# Opinion of 'characters':
# 	 'disparate'
#
#
# Sentence:
# 	Theactionisoffthewallwiththetwomaincharacterstreatingustotwostylesoffightingthataretheveryantithesistoeachother.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	In"TheManWhoWasn'tThere,"thephrase"decisiveaction"isanoxymoron;everythingCraneandtheothercharactersdoisgovernedsolelybychance.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Alongthewayheencountersahostofintriguingcharacters,includingacrazy-like-a-foxentrepreneurialbushpilotlookingtomakesomesortofbigscore,anumberofwackybitplayerswhoIcaneasilyimaginewerenotactors,buttherealdeal,andeverybitaseccentricastheyappeared;andanendearinglysageoldInuitoffewwordsbutmanyeloquentsilences.
# Opinion of 'characters':
# 	 'intriguing'
#
#
# Sentence:
# 	Thefilmdepictstheevolutionofthesevariouscharactersastheycometotermswiththeprogressionoftheirlovelivesandprofessions.
# Opinion of 'characters':
# 	 'various'
#
#
# Sentence:
# 	PlotsbasedonbooksbyElmoreLeonardtendtobeaboveaverage,butaremostlydependentuponthecolorfulcharactershewrites.
# Opinion of 'characters':
# 	 'colorful'
#
#
# Sentence:
# 	NotonlydoesthemovieSignsofferawonderfullydifferentkindofalien/ufotale,butitscharactersareverylikableandthestoryisaboutmuchmorethanaliensfromanotherplanet.
# Opinion of 'characters':
# 	 'very-likable'
#
#
# Sentence:
# 	TheclassicWordsworthpoemfromwhichthefilm'stitleisderivedmakesafittingcodaforthismovie,andIstillfeeltheintractablesenseoflonginginthetwoleadcharacterseverytimeIseethismovie.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	Bothmoviesareprettysimilartoeachother...but"BloodIn,BloodOut"kindafocusesonthe3brothers,andthepathseachofthemtakes,whereas"AmericanMe"focusesonthepathsofthemaincharactersinthismovie(likeSantana,Puppet,Lil'Puppet,etc)..butnotonlydoesitshowtheirlifestyles,butitalsofocusesonhowitshavinganeffectontheirfamilies,andhowtheirfamiliesfeelaboutthelifethattheirkidsareleading..."AmericanMe"ithinkinvolvesmoreofthefamilyinthispictureandculture(LaRaza)then"BloodIn,BloodOut"does...
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	becuasethisoneseemstohavealotmoreofastorylinetoit,andmorecharactersitsfocusingon...bothinandoutsidetheprisonwalls..
# Opinion of 'characters':
# 	 'more'
#
#
# Sentence:
# 	Therearemanygoodsupportingcharacterssuchas:BridgetFonda,WoodyHarrelson,BarnardHughesandJulieWarner
# Opinion of 'characters':
# 	 'many', 'good', 'supporting'
#
#
# Sentence:
# 	Themaincharactersalmostentirelyhavehopes,aspirations,andattachmentsbeyondtheratherclosedworldoftheirprofession--Jack'sdesiretobeaseriousfilmmaker;Dirk'sridiculouspseudo-KarateandReed'sequallyridiculouspoetry;Buck'sgoalofopeninghisownstereostore;Amber'sattemptstogetbackintouchwithherson,whichsheblatantlycompensatesforbymotheringherco-stars--helpingusseethemasfleshed-outcharacters,notjustplotdevicesinthestory.
# Opinion of 'characters':
# 	 'main', 'fleshed'
#
#
# Sentence:
# 	Thecharactersarenotsointerestingnoristheacting.
# Opinion of 'characters':
# 	 'not-so-interesting'
#
#
# Sentence:
# 	Anothergreataspectoftheshowistheyarenotafraidtokilloffmaincharactersthatyougrowtoloveontheshow,soyouwillnevernowwhatisgoingtohappennextwhichkeepsyouwantingmore.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Itisabeautifulheartwarmingmovie,withgorgeousscenery,unforgettablecharacters,andplentyofmomentstolaughandcry
# Opinion of 'characters':
# 	 'unforgettable'
#
#
# Sentence:
# 	Again(asI'vesaidinotherofmyreviews),minorcharactersareimportant.
# Opinion of 'characters':
# 	 'minor', 'important'
#
#
# Sentence:
# 	AnotherpartofthestoryIfoundannoyingwasthelackofcommunicationbetweenthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Thoserepresentthemaleandfemaleviewpointsofthemaintwocharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Butifyouseethemovieasbeingabouttwointerestingcharacters,passitby.
# Opinion of 'characters':
# 	 'interesting'
#
#
# Sentence:
# 	Itismuchbetterthanhavingdifferentactorsplayingoldcharacters,whichdragsamoviedownalot.
# Opinion of 'characters':
# 	 'old'
#
#
# Sentence:
# 	The"bad"charactersareallprettylikeable,asidefromone,andalliswellintheend.
# Opinion of 'characters':
# 	 'bad', 'pretty-likeable'
#
#
# Sentence:
# 	"CinderellaII:DreamsComeTrue"isaseriesofthreestoriesfeaturingmostlycharactersfromtheoriginalCinderellaandafewnewones.
# Opinion of 'characters':
# 	 'mostly'
#
#
# Sentence:
# 	InoneofthemosthilariouscharactersI'veeverseenportrayedonscreen,wemeetDr.Strangelove(PeterSellers,yetagain)astrategistaidingthepeopleintheWarRoom.
# Opinion of 'characters':
# 	 'most-hilarious'
#
#
# Sentence:
# 	Thecharactersareallverylikeable.
# Opinion of 'characters':
# 	 'very-likeable'
#
#
# Sentence:
# 	Therearelittleromanticmomentsbetweenthemaincharactersthatmaketheshowmoreinteresting.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Themovietrieshardtofindthehumorinhitmenandquirkycharacters,butitoftenseemstobetryingabittoohard.
# Opinion of 'characters':
# 	 'quirky'
#
#
# Sentence:
# 	Also,whilemostBBCproductionsofliterarymasterpiecesarestudiesinsocialconservatismthisoneobviouslyidentifieswithandinvitesustoidentifywithitsmostirreverentandforward-thinkingcharacters:inthiscasethesultryandsophisticated,andsomewhatlibertine(ina1920'skindofway),LadyChatterly&theearthyandirreverentandsmoldering(smolderingbothwithclassresentmentandwithlustforaladyfromtheoppressiveclass)OliverMellors.
# ...
#
#
# Sentence:
# 	Throwinlotsoftortureddialogueaboutalternativeconsciousnesses/universes/fuelsupplies/sugarsubstitutes.
# Opinion of 'dialogue':
# 	 'tortured'
#
#
# Sentence:
# 	Thedialogueisdifficulttofollowespeciallysincemostofitismeaninglessanyway,andthefilmneverreallyfollowsit'spremiseasmuchasitshould:theriseofFactory.
# Opinion of 'dialogue':
# 	 'difficult'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'completely-unbelievable'
#
#
# Sentence:
# 	Iunderstoodtheplot,andenjoyedsomeofthethoughtsraisedneartheend,butoverallwasboredsillybystilted,pointlessdialogue.
# Opinion of 'dialogue':
# 	 'stilted', 'pointless'
#
#
# Sentence:
# 	WhileBaldwinandtherestofthecastdidwellinfleshingoutBurke'scharactersandhavesometangytough-guy/galdialogue,they'rehamperedbytwothings:
#
# 1.)
# Opinion of 'dialogue':
# 	 'tangy'
#
#
# Sentence:
# 	Gooddialogueislikegoodacting:ifit'sreallygood,youdon'tnoticeituntiltheshow'sover.
# Opinion of 'dialogue':
# 	 'Good'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	soI'msupposedtobelievethatthehorribledialogue,badacting,andridiculousplottingisonpurposejustbecauseMametisarespectedguy?
# Opinion of 'dialogue':
# 	 'horrible'
#
#
# Sentence:
# 	Thedialoguewouldhavebeen1000timesbetter.
# Opinion of 'dialogue':
# 	 'better'
#
#
# Sentence:
# 	It'sthewaythestoryistold-itsham-fisteddialogueandplot,itsforcedobscenityateveryturn-thatrevealsitsteensensibilities.
# Opinion of 'dialogue':
# 	 'fisted'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'dialogue':
# 	 'so-bad'
#
#
# Sentence:
# 	Thetwodimensionalniceoldbrotherandsisteraretreatedhorribly,fornogoodreasonwithnomotivationorpayoff,thesongsareunlistnableandthedialogueishardtounderstand,thisisnotalwaysabadthing.
# Opinion of 'dialogue':
# 	 'hard'
#
#
# Sentence:
# 	Youdon'tgotothesemoviestoexpectwell-writtendialogue,characterdepthoranything,youcomeforthekillsandtotellyouthetruth,they'reslightlydisappointing.
# Opinion of 'dialogue':
# 	 'well-written'
#
#
# Sentence:
# 	Theunwittydialoguetriestobecleverallthroughoutthemovieandisjustsoooboring.
# Opinion of 'dialogue':
# 	 'unwitty'
#
#
# Sentence:
# 	Thedialoguewassharpandyoumighthavetowatchtwicetogetallthesubtlequips.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueiswonderfullyexpressiveandgivesusthesenseofauthenticityandthekindofrealisticeffectseenonlyintheverybestfilms.
# Opinion of 'dialogue':
# 	 'wonderfully-expressive'
#
#
# Sentence:
# 	Thecolorsaredark,thedialoguebetweenthecharactersishonest,realandsimplywonderful.
# Opinion of 'dialogue':
# 	 'honest'
#
#
# Sentence:
# 	thisepisodehasalotoffunnydialogue,butthat'stheonlythingithasworkingforit.
# Opinion of 'dialogue':
# 	 'funny'
#
#
# Sentence:
# 	Inconclusion,thisTVshowhasitall:goodbackgroundmusic,greatdialogue,interestingstories,goodacting,andinterestingcinematography.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	Thedialogueissharpandwitty,althoughthere'salotofswearing,thatdoesn'tmeanthehumourisjustfowlmouthed,it'shillarious,someofthelinesgodowninhistoryassomeofthefunniestonelinersever.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Inanerawherecinematicpalatesseemtitillatedmostlybyfastactionthrillers,thismovieisanotherexampleofhowwellconstructeddialoguemakesforgrippingcinematicdramawhenitgoeshandinhandwithsuperbcastingandperformance
# Opinion of 'dialogue':
# 	 'well-constructed'
#
#
# Sentence:
# 	You'llbesuckedin,andsurprised,withinthefirsttwominutes,andthere'sverylittledialogue
# Opinion of 'dialogue':
# 	 'very-little'
#
#
# Sentence:
# 	Itseemsraretodaytofindsuchrichdialogue.
# Opinion of 'dialogue':
# 	 'such', 'rich'
#
#
# Sentence:
# 	OtherPeople'sMoneyisawonderfulmovie,fullofsmartdialogue,goodmusic,andaterrificDannyDeVitoperformance.
# Opinion of 'dialogue':
# 	 'smart'
#
#
# Sentence:
# 	Thedialogueisn'thard-boiledexceptforafewlinesdeliveredbyVicky.
# Opinion of 'dialogue':
# 	 'not-hard-boiled'
#
#
# Sentence:
# 	iappreciatedtheeffects-nicetouch-butiwouldhavelikedtoseesomerealdialoguethere.
# Opinion of 'dialogue':
# 	 'real'
#
#
# Sentence:
# 	Relyingonsharpdialogueandfacialexpressions,theactorsmanagetoweaveagorgeoussensualdancetogether,bothlightingupthescreenandcreatingtwoofthemostsmolderinglycomplexcharacterseverseeninfilm.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	The'plain'dialogueamongthe'elders'ispainfullynumbing,choppy,andstilted.
# Opinion of 'dialogue':
# 	 'plain', 'painfully-numbing'
#
#
# Sentence:
# 	Thesoundtrackisawesome,thecinematographyisgreat,thedialogueisrealistic,andforonce,amoviesetinaforeignlandthatactuallyusesactorsfromthatareaspeakingthelanguageofthatarea!
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thismovieisweak,poorlywrittenandhassomelaugh-out-loudstereotypicalcop-schlockdialogue.
# Opinion of 'dialogue':
# 	 'out-loud'
#
#
# Sentence:
# 	(Thescript,bytheway,isonegreatlineafteranother,withverynatural,effortlessdialogue.
# Opinion of 'dialogue':
# 	 'very-natural', 'effortless'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Thestoryisfilledwithbiglaughs--fromcrudehumortosomeofthemostintelligentdialogueI'veprobablyeverheard.
# Opinion of 'dialogue':
# 	 'most-intelligent'
#
#
# Sentence:
# 	Thesurrealhumourandoff-kilterandunusuallybizarrehumourhasseducedthosethatlikeamixtureofpsychicalcomedy,comicinnerdialogue,aswellascrackingoneliners,mixedwiththeoccasionalrelativelyserioussubjectmatters,andphasesthatcanberecitedamongstfellowfans,tomuchamusement.
# Opinion of 'dialogue':
# 	 'comic', 'inner'
#
#
# Sentence:
# 	Thewritingissmartandwitty,thedialogueischarming,theperformancesaregreat.
# Opinion of 'dialogue':
# 	 'charming'
#
#
# Sentence:
# 	Thedialoguethroughoutwastediousandtrite;thescriptwritershouldbeontheunemploymentline,aswellasthedirectorandtheeditor.
# Opinion of 'dialogue':
# 	 'tedious'
#
#
# Sentence:
# 	Therereallywasn'tmuchanimosityfromeithersideofthe spectrum,rathertherewasalotofwell-intentioneddialoguefrombothsidesthatwouldgiveanybody,regardlessofpoliticalpersuasion,betterinsightintotheissuesinIraqandtheMiddleEast
# Opinion of 'dialogue':
# 	 'well-intentioned'
#
#
# Sentence:
# 	Ithasgreatfundialogue,isverytechnicallymodernforitstime,extremelyentertaining,fastpaced,andanabsolutejoytowatchthisCLASSICfilm~WHATATREAT!!
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thedialoguetoisequaltothatof"Coctail"-pointless,beentherebefore,densedialogue.
# Opinion of 'dialogue':
# 	 'equal', 'dense'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'completely-unbelievable'
#
#
# Sentence:
# 	MarvellousdialoguebyBolt.
# Opinion of 'dialogue':
# 	 'Marvellous'
#
#
# Sentence:
# 	SetintheSouth,startingintheearly1950s,andasaSouthernermyselfIparticularlyenjoyedtheauthenticdialogue.
# Opinion of 'dialogue':
# 	 'authentic'
#
#
# Sentence:
# 	Thedialogueiswonderful,alloftheperformancesaresuperb,andCapra'sdirectionareexcellent.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	DotDrequiresabraintoenjoyasitisNOTaslambangshoot'emupwithditzydialoguetofillinthegorescenes.
# Opinion of 'dialogue':
# 	 'ditzy'
#
#
# Sentence:
# 	Themiddlesectionisadmittedlyratherdialoguebased,butthisdialogueisneverboringandservestoillustratewhythelivingdeadfeeltheneedtochompdownonwarmflesh.
# Opinion of 'dialogue':
# 	 'not-boring'
#
#
# Sentence:
# 	(He'smuchbetteronHOUSE,wherehegetssomerealcharacterizationandinfinitelybetterdialogue.)
# Opinion of 'dialogue':
# 	 'infinitely-better'
#
#
# Sentence:
# 	Ifthedialoguewasn'twitty,festivalaudienceswouldn'thavegonenuts.
# Opinion of 'dialogue':
# 	 'not-witty'
#
#
# Sentence:
# 	Stonecombinessuchwild,lush,andcrazyfilmeditingtodepictthemindsofVickeyandMallory,crazydialogue,uniquestorytelling,andallthewhilepokingfunathowweasthepeopleandthemediagocrazyforit.
# Opinion of 'dialogue':
# 	 'crazy'
#
#
# Sentence:
# 	ThefilmisslightalthoughitbenefitsfromsomesharpHermanMankiewiczdialogue.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Manyclose-upshotsofherbarechest.(d)HighlyXXXdialogue,suchasthelinewhere11yearoldViolettellshercustomerthat"Icanfeelthesteamjustcomingthrumydress"(e)
# Opinion of 'dialogue':
# 	 'bare'
#
#
# Sentence:
# 	Themovieisactionpackedwithexcellentdialogueandtheactionneverstopsuntiltheveryappropriateend.
# Opinion of 'dialogue':
# 	 'excellent'
#
#
# Sentence:
# 	Andthedialogueiscertainlymemorable:
#
# JackBull:
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Itmakesyouquestionwhyyoubuyintosuchsappydialogueandsituations.
# Opinion of 'dialogue':
# 	 'such', 'sappy'
#
#
# Sentence:
# 	Whilewatching,inmyheadIwasfillinginthedialogueforthecharacters,andmydialoguewasalotmoreinterestingthananythingthesepeoplesay.
# Opinion of 'dialogue':
# 	 'more-interesting'
#
#
# Sentence:
# 	ThoughIcannotdenythatitisunbelievablycheesy,filledwithpracticallyeveryclicheonecanimagineandcontainstonsofembarrassingdialogue(especiallyKurtRussell'sbeggingspeech)andunconvincinglovescenes(Mel,willyoupleasekissherlike
# Opinion of 'dialogue':
# 	 'embarrassing'
#
#
# Sentence:
# 	Thedialogueisveryfunnyandwittyattimes.
# Opinion of 'dialogue':
# 	 'very-funny'
#
#
# Sentence:
# 	Rarelyhassomuchbeensaidsosuccessfullywithsolittledialogue.
# Opinion of 'dialogue':
# 	 'so-little'
#
#
# Sentence:
# 	AlthoughI'msureyouwillwanttoseewhathappenedtoallofyourfavoritecharacters,yourhopeswillcertainlybedashedanddisappointedbyapoorstoryandpoordialogue
# Opinion of 'dialogue':
# 	 'poor'
#
#
# Sentence:
# 	Thedialogueisoftenunconvincingandoneoccassionallytiresoftheconstantneedinmoviemakingtouseeachcharachterasanarchetype.
# Opinion of 'dialogue':
# 	 'unconvincing'
#
#
# Sentence:
# 	ThesheeraudacityofthistaskisahallmarkofChayefsky'svitriolicstyle,andthefilmisfullofhisbrittle,observantdialogueandsharplyarticulatesoliloquies.
# Opinion of 'dialogue':
# 	 'observant'
#
#
# Sentence:
# 	Here,inthismovie,you'vegotagoodcast,cooldialogue,andanon-stopactionthrillride.
# Opinion of 'dialogue':
# 	 'cool'
#
#
# Sentence:
# 	AnyonefamiliarwithTheSimpsonswillenjoythehumorinOlive,TheOtherReindeer,aswellastheanimationandwittydialoguethatpassesquicklyinthisforty-fiveminutemovie.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Allinvolverichdialogueandinterestshown.
# Opinion of 'dialogue':
# 	 'rich'
#
#
# Sentence:
# 	First,thedialogueandsituationsaresoinsipidtheyofteninspireunintentionalhilarity.
# Opinion of 'dialogue':
# 	 'so-insipid'
#
#
# Sentence:
# 	Withoutcontrivedmanipulations,youaredrawnintothedepthsandheightsoftheiremotionsthroughtheuseofstunningvisuals,dramaticportrayals,pithydialogue,momentsofquietcontemplation,andaserenemusicalsoundtrackthatisworthowningonitsownmerits.
# Opinion of 'dialogue':
# 	 'pithy'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Ithashistrademarkrealisticdialogueandwithoutanyflashyeffectshefocusesonthecharacters.
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thedialogueiswarmandwittyandtheactorsarewonderful.
# Opinion of 'dialogue':
# 	 'warm'
#
#
# Sentence:
# 	Allen'sdialogue(whichisalwaysgood)isparticularlygoodintheconversationsbetweenIsaacandMary;ThefinalscenebetweenIsaacandTracyisalsoverymeaningfulandverygood.
# Opinion of 'dialogue':
# 	 'particularly-good'
#
#
# Sentence:
# 	LiketheothermoviesthereissomegreatdialogueinthismovieandIhighlyrecommendthemovietofansofChrisFarley,ChrisRockandSNL.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Yes,themoviehasflaws:thedialoguecanbealittlegoofyattimes,theactingsomewhat-shallwesay-idiosyncratic,thespecialeffectsdon'talwayswork,andtheinternallogicisnotalwaysapparent(theGrailisArthur?
# Opinion of 'dialogue':
# 	 'goofy'
#
#
# Sentence:
# 	Withcringinglyawfulacting,laughablespecialeffects(theridiculousheadinabucketisarealguffawmoment),appallingdubbeddialogue,cheesymusic,inconsistentandconfusingplotandnotensionoratmosphere,TheGrimReaperisatotaldisaster.
# Opinion of 'dialogue':
# 	 'dubbed'
#
#
# Sentence:
# 	Theearlypartofthisfilmisfilledbothwithsnappy,intelligentdialoguebutalsowithasophomoricphysicalcomedywhichcanhonestlybeconsideredtobeatorbelowapie-in-the-facelevelofsophistication.
# Opinion of 'dialogue':
# 	 'snappy', 'intelligent'
#
#
# Sentence:
# 	Betweenincrediblybaddialogueaboutthingslikethe"plutonium-rubycrystalbeamgun,"sillyincidentalmusic,andaVenusianmadeoflatex,twigs,andtissuepaper,thisonecannotbebeat.
# Opinion of 'dialogue':
# 	 'incredibly-bad'
#
#
# Sentence:
# 	Baumbach'sscreenplayboastslotsofmemorabledialogue,lotsofclevernessyoumightfindyourself"borrowing."
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	Thegreatsweetbeautyofthisfilm,however,isthemarriageofsuchengagingdialogue,suchearnestdeadpandeliveriesshotinsucheerieclarity--onereminiscentoftheinteriorsinDutchgenrepainting:clean,homely,homiletic.
# Opinion of 'dialogue':
# 	 'such', 'engaging'
#
#
# Sentence:
# 	Itmanagestoturnasuiteofclassicallystaticimages-bronzed,burnished,melancholy-uponafast-drivingdialogueendowedwiththemodestbutenhancingartificialityofapainting,anovelor--betteryet--aninfinitelyrefinedfilm
# Opinion of 'dialogue':
# 	 'bronzed', 'fast-driving'
#
#
# Sentence:
# 	Manywillbemovedbyhownaturalthedialoguesounds(herecordedmostofitonthestreets),alotofitobviouslyinspiredbyhisownlife.
# Opinion of 'dialogue':
# 	 'how-natural'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'as-fast'
#
#
# Sentence:
# 	Indeed,thedialogueissobeautifullyeloquent,wefeellikeweareoftengiventhemodernequivalentofShakespeare.
# Opinion of 'dialogue':
# 	 'beautifully-eloquent'
#
#
# Sentence:
# 	Selectionof
# locations,environmentsandcharactersissimplywonderful--sureto
# keeptheviewerengrossed,eventhoughthedialogueisuncompromisingly
# British.
# Opinion of 'dialogue':
# 	 'British'
#
#
# Sentence:
# 	Recentadaptationsseemafraidtoincludeoriginaldialogueatanylength-
# Opinion of 'dialogue':
# 	 'original'
#
#
# Sentence:
# 	Verywittydialogueandscenes;flawlessactingbyleadandsupportingactors.
# Opinion of 'dialogue':
# 	 'Very-witty'
#
#
# Sentence:
# 	ThisisChaplin'sfirstfulldialoguefilm,eventhough'TheGreatDictator'washisfirstsoundfilm.
# Opinion of 'dialogue':
# 	 'full'
#
#
# Sentence:
# 	Mywifesaysallofhismoviesarethesame,anditbreaksmyhearteverytimeshesaysit...becauseinthatblanketanalysis,theanalystmissestheincrediblestoriesandcraftydialoguethattakesplaceinthemanyWoodyAllenmoviesthatprettymuchtakeplacewithinthesametemplate.
# Opinion of 'dialogue':
# 	 'crafty'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'as-fast'
#
#
# Sentence:
# 	Thisisamust-haveifyoulikeagoodstoryline,cleverdialogueandhonestlaughs.
# Opinion of 'dialogue':
# 	 'clever'
#
#
# Sentence:
# 	GreatforthepurestinthecrowdbutkillerforthoseofuswholikebadlydubbedEnglishdialogue.
# Opinion of 'dialogue':
# 	 'badly-dubbed', 'English'
#
#
# Sentence:
# 	Theweaknesseswereimmediatelyapparent--awkwarddialogue,lackofvisualstyle--butIhopedthemoviewouldovercomeitsfaults.
# Opinion of 'dialogue':
# 	 'awkward'
#
#
# Sentence:
# 	Thismayhelpsomeofyouslowerpeople(don'tbeashamed)tounderstandthefilm,althoughmuchofitsimportantintricatedialogueandoverallappealwillbelostinthisversion.
# Opinion of 'dialogue':
# 	 'important', 'intricate'
#
#
# Sentence:
# 	Thereareproblemswiththefilm,themostannoyingonebeingthatthedialogueispracticallyinaudibleduetothemikingand,moreso,duetothemusicalscorewhichcoversallthelinestothepointofmakingthemovieseemlikeasilentmoviewithmusicfromthepit!
# Opinion of 'dialogue':
# 	 'practically-inaudible'
#
#
# Sentence:
# 	Themood,thesensuousdialogue;Thisisjustnoiratit'sbest.
# Opinion of 'dialogue':
# 	 'sensuous'
#
#
# Sentence:
# 	Thistart,well-scriptedcomedyisalittlelightonthedancing,butfeaturessomeofthebest,briskestdialoguethatcameAstaire'sway,andafinesupportingcast,includingthefamousHollywood&quot;double-talker,&quot;CliffNazarro,goingthroughhisroutineinnumerousscenes.
# Opinion of 'dialogue':
# 	 'best'

# %%
sents = [nlp(entry[1]) for entry in core]
# print(sents)

for index,sen in enumerate(sents):
    opinions = opinion_extractor("plot",sen)
    print(opinions)
    if set(opinions) == core[index][2]:
        print('Test set {} passed\n'.format(index+1))
# Out:
# ['exciting', 'fresh']
# Test set 1 passed
#
# ['dull']
# Test set 2 passed
#
# ['excessively-dull']
# Test set 3 passed
#
# ['excessively-dull']
# Test set 4 passed
#
# ['not-dull']
# Test set 5 passed
#
# ['not-exciting', 'not-fresh']
# Test set 6 passed
#
# ['not-excessively-dull']
# Test set 7 passed
#
# ['cheesy']
# ['really-cheesy']

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on examples A.1, B.1, C.1, C.2, D.1, D.2, and D.3.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %% [markdown]
# ## Extension E: Conjunction
# If you used your existing extractor on the tree below, it would only extract "*cheesy*". However, "*fun*" and "*inspiring*" are both conjoined with "*cheesy*"; this means that they all apply to the subject ("*plot*").
#
# This conjunction relation is shown via the `conj` dependency. Note that words other than adjectives can be the conjuncts. You could investigate whether this is a problem.
#
# **Core Example E.1**: "*The plot was cheesy but fun and inspiring.*" should produce "*cheesy*", "*fun*", "*inspiring*"
# **Core Example E.2**: "*The plot was really cheesy and not particularly special.*" should produce "*really-cheesy*", "*not-particularly-special*"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension 5 example](./img/conj_example_1.png)

# %% [markdown]
# ![Extension 5 example 2](./img/conj_example_2.png)

# %%
def opinion_extractor(aspect_token,parsed_sentence):

    opinions = []
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.text == aspect_token:
            negation = build_negation_string(token)
            
            for child in token.children:
                if child.dep_ == 'amod':
                    advmod = build_advmod_string(child)
                    opinions.append(negation+advmod+child.text)
            if token.dep_ == 'nsubj':
                filterList = set(filter(lambda x: x.dep_ == 'acomp' or x.dep_ == 'conj', token.head.children))
#                 print(list(filterList))
                for x in filterList: 
                    advmod = build_advmod_string(x)
                    opinions.append(negation+advmod+x.text)
                    add_conj_opinions(opinions,x,negation)
#     print(opinions)
    return opinions

def build_advmod_string(token):
    advmod = ''
    notString = ''
    for child in token.children:
        if child.dep_ == 'advmod':
            advmod += child.text + '-'
        if child.dep_ == 'neg':
            notString = 'not-'
    return notString + advmod

def build_negation_string(token):
    negation = ''
    if token.dep_ == 'nsubj' or token.dep_ == 'attr':
        for child in token.head.children:
            if child.dep_ == 'neg':
                negation += 'not-'
                break
    return negation

def add_conj_opinions(opinions, token, negation):
    for child in token.children:
        if child.dep_ == 'conj':
            advmod = build_advmod_string(child)
            opinions.append(negation+advmod+child.text)
            add_conj_opinions(opinions, child, negation)

def show_results(results,aspect_word):
    print("Results for aspect word '{}'\n".format(aspect_word))
    for word,sent,opinions in results:
        if word == aspect_word:
            print("Sentence:\n\t{}".format(sent))
            print("Opinion of '{0}':\n\t '{1}'".format(aspect_word,"', '".join(opinions)))
            print("\n")

aspect_words = ["plot","characters","cinematography","dialogue"]
results = [] 
for parsed_review in parsed_reviews:
    for sentence in parsed_review.sents:
        for aspect_token in aspect_words:
            opinions = opinion_extractor(aspect_token,sentence)
            if opinions:
                results.append((aspect_token,sentence.orth_,opinions))

show_results(results,"plot")
show_results(results,"characters")
show_results(results,"cinematography")
show_results(results,"dialogue")
# Out:
# Results for aspect word 'plot'
#
# Sentence:
# 	However,theplotwaspredictable.
# Opinion of 'plot':
# 	 'predictable'
#
#
# Sentence:
# 	Furthermore,theplotissopredictablethatitmadethemoviedrag.
# Opinion of 'plot':
# 	 'so-predictable'
#
#
# Sentence:
# 	well,that'stheusualpredictableromanceplot.
# Opinion of 'plot':
# 	 'usual', 'predictable'
#
#
# Sentence:
# 	TheplotwasOKbutitwouldhavebeenmuchbetteriftheyhadeitherstucktoamoreauthenticrepresentationofJapanesecultureorkeptthestoryinthestates.
# Opinion of 'plot':
# 	 'been', 'OK'
#
#
# Sentence:
# 	Theperformancesarethinanduneven,theplotisinconsistent,andthedialoguesoundslikeitwaspulledfromfortunecookiesmadebythecastofFriends.
# Opinion of 'plot':
# 	 'sounds', 'inconsistent'
#
#
# Sentence:
# 	Theplotisuninvolvingandincoherent,thecinematographyiscrampedandcompletelylackinginstyle,themusicisweakduringatimethatspawnedsomanymemorablesoundtracksandthedirectionlacksanyfocuswhatsoever.
# Opinion of 'plot':
# 	 'incoherent', 'cramped', 'completely-lacking'
#
#
# Sentence:
# 	AlthoughthismoviewantedtobeinthesameraceandqualityofthemovieCLUE,itfailstorealizethattheplotandcharactersareincrediblyriculousandnotfunnyhahabutfunnystupid.
# Opinion of 'plot':
# 	 'funny-stupid', 'incredibly-riculous', 'not-funny'
#
#
# Sentence:
# 	Theactingishorrible,theplotishorrible,thefilmingishorrible...
# Opinion of 'plot':
# 	 'is', 'horrible'
#
#
# Sentence:
# 	Its"thriller"aspectisartificialandnottiedtothecentralplotline,andentirelypredictablefromthemomentourfriendishandedTHEONLYKEYTHATCANSTOPTHENUKE!
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Theplottothismovieorsocalledsequalishorrible.
# Opinion of 'plot':
# 	 'horrible'
#
#
# Sentence:
# 	Theplotisaby-the-book"believeinyourdreams"storywithreallylamedialog,butitsdevelopmentisintercutwithextendeddancingsequencesthataresolongandfrequentthatattimesitfeltlikeIwaswatchinganabstractsilentfilm.
# Opinion of 'plot':
# 	 'intercut'
#
#
# Sentence:
# 	Inonepart,theplotlostsomecontinuityandneededreviewingtogettogripswithwhathadhappened.
# Opinion of 'plot':
# 	 'needed'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 ''s', 'surprisingly-straightforward'
#
#
# Sentence:
# 	However,theplotandmessageofthisfilmrevelinhopelessness,anddebaseeveryaspectoflowerincome,urbanpeople.
# Opinion of 'plot':
# 	 'debase'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	However,theplotandmessageofthisfilmrevelinhopelessness,anddebaseeveryaspectoflowerincome,urbanpeople.
# Opinion of 'plot':
# 	 'debase'
#
#
# Sentence:
# 	Withtheirchildestvoices,theyshouldn'tbeusedasamainplotofthestory
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Asfarasthemovieisconcerned,theplotisunoriginalandnotparticularlyengaging.
# Opinion of 'plot':
# 	 'unoriginal', 'not-particularly-engaging'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'plot':
# 	 'flimsy'
#
#
# Sentence:
# 	Thiswassuchacontrivedmoviethathadasimpleplotthatwentnowhere.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Themoviewasn'tfunny(whichissadtosaywhenoneofmyfavoritecomedicactresses,CarolKane,couldn'tevenelicitasmileoutofme),theplotwasfullofholes,andthewritingseemedveryrushedandcontrived.
# Opinion of 'plot':
# 	 'full', 'seemed'
#
#
# Sentence:
# 	Thespecialeffectsareabitcheesy,youcanseethewirespullingthetorpedosandyoucantellthattheyusedscaledmodelships...butifyouoverlookthoseitems,yougetfineactingandagoodplotwithplentyof
# action
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	stupidplot-toomanyholesandstupidending.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theentireplotisself-serving,shallow,andunrealistic.
# Opinion of 'plot':
# 	 'entire', 'serving', 'shallow', 'unrealistic'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Thebasicplotofthemovieisthatlifesucks(
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	TheplotislameandIamsorryIspentthemoneyonit.
# Opinion of 'plot':
# 	 'lame', 'am'
#
#
# Sentence:
# 	Butthedumbplotandtheunfunnyattemptsatcomedymakeitacompletewasteoftime.
# Opinion of 'plot':
# 	 'dumb'
#
#
# Sentence:
# 	Eraserhasafewscenesthatwillkeepyourattention,butoverallthemoviedisplayedpooracting,stuntsthatareimpossibleandamediocreplot.
# Opinion of 'plot':
# 	 'mediocre'
#
#
# Sentence:
# 	Verypredictableplotfrombeginningtoend.
# Opinion of 'plot':
# 	 'Very-predictable'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'plot':
# 	 'bad'
#
#
# Sentence:
# 	Iwasveryboredwiththismovieandfoundtheplottobeveryinsulting.
# Opinion of 'plot':
# 	 'very-insulting'
#
#
# Sentence:
# 	Buysomthingthathasagoodplot.
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Oneoftheworstmoviesi'veeverseen,norealplotandactingisasbadasitcanget.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Theplotmovesalongnicelyandcreatessomedefinitetensionandsuspense.
# Opinion of 'plot':
# 	 'creates'
#
#
# Sentence:
# 	Canyoureallycarry2hourswiththissingleplot?
# Opinion of 'plot':
# 	 'single'
#
#
# Sentence:
# 	Theplotiscomplicatedandthenoiseinthebackgroundaddstothedisorientationwhichisdoneonpurpose.
# Opinion of 'plot':
# 	 'complicated', 'adds'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Buttheplotwaslame&slow.
# Opinion of 'plot':
# 	 'lame', 'slow'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'plot':
# 	 'rather-unbelievable'
#
#
# Sentence:
# 	Thisseriesmightbeconsideredaclassicifwatchedbya12-year-old,butadultswillseethoughtheindistinctplotandcharacters.
# Opinion of 'plot':
# 	 'indistinct'
#
#
# Sentence:
# 	Theplotwasadequate.
# Opinion of 'plot':
# 	 'adequate'
#
#
# Sentence:
# 	Ijustcan'tgetoverhowprofoundlycornyandsimpletheplotandeffectsare,
# Opinion of 'plot':
# 	 'profoundly-corny', 'simple'
#
#
# Sentence:
# 	BeforeIhitthistooharshly,thisfilmwasintendedtobeatrifle,thekindofmoviethathasbrightcolorsandlightplotforahotsummerdaythatsizzles.
# Opinion of 'plot':
# 	 'light'
#
#
# Sentence:
# 	Soundslikeaninterestingplot,right?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Feebledirectionsimplymissesseveralgoodopportunitiestomakegooduseofthejockey'ssullenlittledaughterSam(KayPanabaker,herfeaturedebut),whocouldhavebeenalittlesurprise(orgem)inthisunconvincingplot.
# Opinion of 'plot':
# 	 'unconvincing'
#
#
# Sentence:
# 	Theonlybluehereistheshadeyouwillturnbytheboredomwiththeweakplot.
# Opinion of 'plot':
# 	 'weak'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'plot':
# 	 'stupid', 'is'
#
#
# Sentence:
# 	TheplotwasbadanditdidnothavethatmanypokemonasIthought.
# Opinion of 'plot':
# 	 'bad', 'not-have'
#
#
# Sentence:
# 	...hasaprettythinplot.
# Opinion of 'plot':
# 	 'pretty-thin'
#
#
# Sentence:
# 	Infact,thetrialdoesn'tevenhaveaconnectiontothecentralplotasidefromshowingthatSamandArchiearefriendsandpartners.
# Opinion of 'plot':
# 	 'central'
#
#
# Sentence:
# 	Howeverifyoulikesex,violence,blood,anddebauchery,couldcarelessthefactthattheyhavenothingtodowiththeabsentplot,youcouldfindthisfilminteresting.
# Opinion of 'plot':
# 	 'absent'
#
#
# Sentence:
# 	Andplotissoludicrouslypredictableit'sprettyclearearlyonjustwhothebadguybehindthecurtainis.
# Opinion of 'plot':
# 	 'so-ludicrously-predictable'
#
#
# Sentence:
# 	Flatlighting,cheapsetsandcostumes,dulldialog,woodenacting,andagoofyplot;evenpervasivesiliconeenhancementcannotsavethismovie.
# Opinion of 'plot':
# 	 'goofy'
#
#
# Sentence:
# 	Theplotifpoorlycontrived,theproductionvalueislow,theactingforthemostpartisawful,andit'sbasicallyjustawaytostitchtogetheraseriesofmusicvideoswhichathisage,mysonhasnointerestin.
# Opinion of 'plot':
# 	 'low'
#
#
# Sentence:
# 	JuryDutysimplywasjustplainawfulwithit'sweak,boringplotandunfunnyhumor!
# Opinion of 'plot':
# 	 'weak', 'boring'
#
#
# Sentence:
# 	Theplotofthemovieisinterestingandkeepsyouwonderingwhatisgonnahappennext.
# Opinion of 'plot':
# 	 'interesting', 'keeps'
#
#
# Sentence:
# 	Theplotdoesnotdraganddoesnotbore
# Opinion of 'plot':
# 	 'not-not-bore'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	Theplothowever,isexcellent.
# Opinion of 'plot':
# 	 'excellent'
#
#
# Sentence:
# 	Veryinterestingandunpredictableplot.
# Opinion of 'plot':
# 	 'Very-interesting'
#
#
# Sentence:
# 	Theplotfeelssluggishattimesandthere'swaytoomuchXavierCugatandhisorchestra,butAstaireandHayworthareattheirpeak,KernhaswrittensomememorablemelodiesandfewcouldtopMerceratlyricwriting,noneinHollywood.
# Opinion of 'plot':
# 	 ''s', 'are', 'sluggish'
#
#
# Sentence:
# 	Basicplot:
# Opinion of 'plot':
# 	 'Basic'
#
#
# Sentence:
# 	Sowhileitwasaconvenientplotdevice,youwouldexpectsomethinglikethatbysomeonewithonlyminimalknowledgeofdinosaurs.
# Opinion of 'plot':
# 	 'convenient'
#
#
# Sentence:
# 	itwasquitefunny,buttherewaslessactionandlessplotcomparedtootherepisodes.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	Almosttheentireplotisonboardandunderway.
# Opinion of 'plot':
# 	 'entire', 'onboard', 'underway'
#
#
# Sentence:
# 	Fromthereitjustgetsprogressivelydarkerandtenser,withthelighting,acting,anddirectionallperfectlyservingtoratchetupthefeelingofdesperationandhorrorasToddkickshisill-conceivedrobberyplotintomotionandthingsspinwayoutofcontrol.
# Opinion of 'plot':
# 	 'ill-conceived'
#
#
# Sentence:
# 	Whileit'shardtopickmyfavoritefirstseasonepisode,thecomplexplotof"APriest,A
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Theplotwaswellworn,butitdidn'tfeelstaidorplodding.
# Opinion of 'plot':
# 	 'well-worn', 'not-feel'
#
#
# Sentence:
# 	Theplotisperfectandthescriptiswellwritten.
# Opinion of 'plot':
# 	 'is', 'perfect'
#
#
# Sentence:
# 	Theplotissweet.
# Opinion of 'plot':
# 	 'sweet'
#
#
# Sentence:
# 	Thequalityofthegraphicsareterrific,theplotisalittlestrange,butbasicallyitsalienswhoinvadeandride4virtualrollercoastersatafuturisticthemepark.
# Opinion of 'plot':
# 	 'little-strange', 'basically-aliens'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	anywayirecommendthistoanyonewholoves Asianhorrorandlikesagoodplotandmovie!!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Theplotisnotveryintriguing,andyouknowthatnothinglikethiscanhappeninthereallife,soitlacksthissenseofreality.
# Opinion of 'plot':
# 	 'not-very-intriguing', 'not-know', 'not-so-lacks'
#
#
# Sentence:
# 	I'mnotamoviebuff,butDeepCoverhasalltheelementsyouwouldexpectofaclassic:greatacting,memorablelines,interesting(andlogical)plotandadecentending.
# Opinion of 'plot':
# 	 'logical'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'plot':
# 	 'silly', 'funny'
#
#
# Sentence:
# 	TheplotevolvesasmanyotherCoenmovies(RaisingArizonacomestomind)asweareintroducedtomore-and-morecolorfulcharactersandtheplotgetsmore-and-moreoutrageous,yetsomehowstillseemsreal.
# Opinion of 'plot':
# 	 'more-outrageous'
#
#
# Sentence:
# 	Everyoneknowsthebasicplotbynow:SpockkidnapshiscrippledformerCaptain,andhijackstheEnterprise,andsetscoursefortheoneforbiddenplanetinallTheFederation.
# Opinion of 'plot':
# 	 'basic'
#
#
# Sentence:
# 	Yes,theplotisodd.
# Opinion of 'plot':
# 	 'odd'
#
#
# Sentence:
# 	Itdoesn'tfollowastorylinethat'spredictable,eventhoughtheplotisnotunknown.
# Opinion of 'plot':
# 	 'not-unknown'
#
#
# Sentence:
# 	Itusesoneoftheworstsuperheroclichesasthemainplot,thatoftheherocallingitquits.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	There'sashadowyplotinvolving$10,000bills,aguerillamovementandguns,butthemoviefocusesmoreonQuinn'sconflictsbecausehischildhoodfriendissuspectedofagrislymurder,andQuinn'sowndiscomfortfromhaving"madegood"butendingupcaughtbetweentwoworlds,whiteandblack.
# Opinion of 'plot':
# 	 'shadowy'
#
#
# Sentence:
# 	Wasitcancelledbecausetheplotwasflimsyordumb?
# Opinion of 'plot':
# 	 'flimsy', 'dumb'
#
#
# Sentence:
# 	Theplot,thesetting,thedialogues,thespecialeffects,andthemusicareallwonderful!
# Opinion of 'plot':
# 	 'wonderful'
#
#
# Sentence:
# 	Theplotisinteresting,itkeepsyouguessing,andthesuspensekeepsyouontheedgeofyourseat.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	TheplottakesmanytwistsandturnsasCoraandFranktrytooutmaneuverthelaw,Nick,andalsoapairofunscrupulouslawyerswhoareintenttoseethesultrycoupledouble-crossandselloutoneachother.
# Opinion of 'plot':
# 	 'turns'
#
#
# Sentence:
# 	DirectedbyTamraDaviswithakeeneyeoncharacterizationandhumor,thismovieisoneofthoseyousmilemostofthetime,andhaveagoodtimewithitssurrealandzanyplot.
# Opinion of 'plot':
# 	 'surreal'
#
#
# Sentence:
# 	Theplotwasn'thorrible,itwasactuallyprettygoodforafrightflick.
# Opinion of 'plot':
# 	 'not-horrible'
#
#
# Sentence:
# 	Theplot,thesetting,theacting,andthedialoguesareallverygood.
# Opinion of 'plot':
# 	 'very-good'
#
#
# Sentence:
# 	Theplotiscomplex.
# Opinion of 'plot':
# 	 'complex'
#
#
# Sentence:
# 	Eventhoughthefilmisbasedonafictionalplot,itstillhasanauthenticfeelandisratedanalltimeclassic.
# Opinion of 'plot':
# 	 'fictional'
#
#
# Sentence:
# 	Theplotisgood,andDeoxys''destructive'intentionsarelesscruelthanonewouldthink.
# Opinion of 'plot':
# 	 'are', 'good'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Theplotanddialogueisincrediblebecauseitexploresalltheshadesofgreyinthecharacters.
# Opinion of 'plot':
# 	 'incredible'
#
#
# Sentence:
# 	theplotwasprettyoriginal.
# Opinion of 'plot':
# 	 'pretty-original'
#
#
# Sentence:
# 	Thisfilmmaynotbeperfect,andtherearesomeboringscenesastheytrytohardtoexplainthestateNickisin,buttheoverallplotofthisfilmisoneI'veneverseendonebefore.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisprettyunrealisticbutthenitisascrewycomedysoithelpsifyoususpendagooddealofdisbelief.
# Opinion of 'plot':
# 	 'pretty-unrealistic', 'then-is'
#
#
# Sentence:
# 	ItcombinesabunchofthebestFrenchactrices,andanenjoyableplot.
# Opinion of 'plot':
# 	 'enjoyable'
#
#
# Sentence:
# 	theplotwasdry,liketheother2oftheseries,buthowexcitingofaplotcanyouhavewiththeamountofactionandskilleddrivingpackedintothemovie.
# Opinion of 'plot':
# 	 'dry', 'have'
#
#
# Sentence:
# 	Suretheplotofweakandtherelationshipsareunbelievable,ImeanwhocanhonestlysaythattheyfeelakingpintotheJapanese/Chinese/Oriental(whateveritwas)
# Opinion of 'plot':
# 	 'unbelievable'
#
#
# Sentence:
# 	Thisfilmhassomegoodactorsinitbuttheplotisprettyshakyandhardtofollowattimes.
# Opinion of 'plot':
# 	 'pretty-shaky', 'hard'
#
#
# Sentence:
# 	Itcouldhavebeenmadebetter--lesscomedyandmoreplotandofcourse--actionandsuspense!!!!
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Theplotwasveryst8fowardandbasicwithafewlittletidbitstolivingitup.
# Opinion of 'plot':
# 	 'foward', 'basic'
#
#
# Sentence:
# 	Theplotisverygood.
# Opinion of 'plot':
# 	 'very-good'
#
#
# Sentence:
# 	but,unfortunately,theproducersforgettogivethemacredibleplotandinterestingthingstosay.
# Opinion of 'plot':
# 	 'credible'
#
#
# Sentence:
# 	PeoplewhoreviewSpielbergusuallywanttopigeonholehimintoatype:theET-warm-and-fuzzy-alienchildren'sstorytellerversusthespecial-effects-heavy-but-rather-empty-plotdreamer.
# Opinion of 'plot':
# 	 'empty'
#
#
# Sentence:
# 	Theplotisslowtodevelop,characterdevelopmentlackingandanimationprimitiveatbest.
# Opinion of 'plot':
# 	 'slow'
#
#
# Sentence:
# 	Bothfilmshavethesameborringplot.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	Maybethenextfewvolumeswillbemorecreativeandgivemoredetailsonthemainplot,butIpersonallydon'tcaretospendanymoreofmymoneyonsucharisk.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Thebad:Notaveryinterestingorprofoundplot.
# Opinion of 'plot':
# 	 'bad', 'very-interesting'
#
#
# Sentence:
# 	Theplotofthestoryisreallyinteresting.
# Opinion of 'plot':
# 	 'really-interesting'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whiletheplotisnearlyidentical,AlexanderPayne(director)treatshischaractersmuchharsherthanPerrotta.
# Opinion of 'plot':
# 	 'nearly-identical'
#
#
# Sentence:
# 	Ithinktheactinginthemoviewasoutstanding,thedirectionwasgenius,andtheplotwasamazinglyhorrific.
# Opinion of 'plot':
# 	 'amazingly-horrific'
#
#
# Sentence:
# 	Theplothassomeproblems,butwithsolidactingbyBothJonesandAshley,thisisadecentwaytopassacouplehours.
# Opinion of 'plot':
# 	 'is'
#
#
# Sentence:
# 	ThestorybeginswithafailedassasinationplotthenfollowsMalciekChelmicki(ZbigniewCybulskiakaPolandsJamesDean)untilit'sconclusion.
# Opinion of 'plot':
# 	 'failed'
#
#
# Sentence:
# 	Episode16:"TheFactofBeingThere"/"AnotherChance"
# Andallattentionbacktothemainplot.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Althoughtheplotisalittlethin,therearesomeveryfunnymoments.
# Opinion of 'plot':
# 	 'little-thin'
#
#
# Sentence:
# 	Theplotwas,insomerespects,totallyillogical,andatothertimesnonsensical.
# Opinion of 'plot':
# 	 'totally-illogical'
#
#
# Sentence:
# 	Theplotisentirelyunconvincingandimplausible.
# Opinion of 'plot':
# 	 'entirely-unconvincing', 'implausible'
#
#
# Sentence:
# 	Verygoodplotanddetail
# Opinion of 'plot':
# 	 'Very-good'
#
#
# Sentence:
# 	Insummary,themusicportionofthisDVDratesastrongfivestars,butthesillyplotandtheproblemswiththediskdiscussedabove,bringthisDVDdowntoafourstarproduction
# Opinion of 'plot':
# 	 'silly'
#
#
# Sentence:
# 	Theplotisfartoocomplicatedandtwistytogetinto,andfranklyhasbeengoneoverwithafinetoothcombalreadyonthissite.
# Opinion of 'plot':
# 	 'frankly-gone', 'far-too-complicated', 'twisty'
#
#
# Sentence:
# 	Unlike,forexample,LOSTHIGHWAY,thisisacompletelyrealisticplot,withnosupernaturalorunexplainableelements.
# Opinion of 'plot':
# 	 'completely-realistic'
#
#
# Sentence:
# 	OnceyoualreadyknowtheoverallplottheDirector'sCutisbetter,andallthestuffthat'saddediniscool,
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Fourth,theplotisslickandoriginal.
# Opinion of 'plot':
# 	 'slick', 'original'
#
#
# Sentence:
# 	It'snotasifthefilmwouldbecompletlyalienatingtonewcomers,notatall,itsjustthatifIhadn'treadthebookbeforehand,I'msureIwouldhavefoundthingsabithardertofollow,asthingsmovefairlyquicklyandthere'saneverthickeningplottokeepaneyeon.
# Opinion of 'plot':
# 	 'ever-thickening'
#
#
# Sentence:
# 	Wellthat'sabouttheentireplotofthismovie.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Allheneedstocompletethisisasmallplotofland.
# Opinion of 'plot':
# 	 'small'
#
#
# Sentence:
# 	this1hasastupidplot.
# Opinion of 'plot':
# 	 'stupid'
#
#
# Sentence:
# 	Yojimboisavastlyentertainingactionfilmwithalltheelementsofthatgenre:fastpace,surprisingplotturns,andajustlyfamoussamuraishowdown.
# Opinion of 'plot':
# 	 'surprising', 'showdown'
#
#
# Sentence:
# 	Myfavoritesongis&quot;NeverTalktoStrangers&quot;.Themovieelaboratesontheoriginalstorybyaddingmoreplottospicethestoryup.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Lynchdoesn'tfollowarealplot;instead,heletsthestorylineslowlysinkintoLaura'sdownfall.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Thisisagreatkid'smoviewithalotofcharactersandagreatstoryplot.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Thisfilmisperfectforeveryone,thealluringplot,amazingacting,entertainingscreenplay.
# Opinion of 'plot':
# 	 'alluring'
#
#
# Sentence:
# 	TheplotcanbealittledumbattimesbutChrisTuckeriswhatthismovieisallabout.
# Opinion of 'plot':
# 	 'little-dumb', 'is'
#
#
# Sentence:
# 	Theplotiscomplexenoughtokeepthewatcherguessingwhatexactlywillhappenandnotboretheaudience.
# Opinion of 'plot':
# 	 'enough-complex'
#
#
# Sentence:
# 	Badforanyonewhowantshighproductionvalueoranidentifiableplot
# Opinion of 'plot':
# 	 'identifiable'
#
#
# Sentence:
# 	Plentyofaction,plentyofbeautifulsceneryandpeople,ahalfwaydecentplot,plentyoflogicalunpredictability,anditplayswellonthesmallscreen.
# Opinion of 'plot':
# 	 'halfway-decent'
#
#
# Sentence:
# 	Irecommendthismovietoanyonewhoislookingforagoodcomedywithaveryfunnyplot.
# Opinion of 'plot':
# 	 'very-funny'
#
#
# Sentence:
# 	-"LovebeforeBreakfast"isaUniversalproductionandhasthesimplestplotofthecollection;infact,noplotatallreally.
# Opinion of 'plot':
# 	 'simplest'
#
#
# Sentence:
# 	Thefilmcombinestoomanygenresandtheplotbecomesconvoluted.
# Opinion of 'plot':
# 	 'convoluted'
#
#
# Sentence:
# 	Inthistreatmentoftheannoyingplot,heloseshismind.
# Opinion of 'plot':
# 	 'annoying'
#
#
# Sentence:
# 	AnatomyofaMurderisatoncebothadelightfulmysteryandasuspensefulthillerforthosewouldwouldratherthinkaboutallthemanydimensionsandlayersofintriquegoingoninamovieratherthanbespoonfedaformulaicplot.
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Ratherformulaicplot;thedancingisthethinghere
# Opinion of 'plot':
# 	 'formulaic'
#
#
# Sentence:
# 	Themainplotisverythin(aCIAagentisorderedtokillanoilprince,getscaughtandthenwarnstheprince(why?))andthereforesomeelementswereaddedtomakethemoviemoreinteresting.
# Opinion of 'plot':
# 	 'main', 'very-thin'
#
#
# Sentence:
# 	Theanimationistotallycool,thekidsarebelievable,theplotisinterestingandhassometwistsandturnstokeepyouguessing,andthedialogisdownrightfunnyattimes.
# Opinion of 'plot':
# 	 'interesting', 'is', 'has', 'turns'
#
#
# Sentence:
# 	Theplotisverysimple,thesetsaresimple...butthefilmisgreat.
# Opinion of 'plot':
# 	 'very-simple'
#
#
# Sentence:
# 	CreditneedstobegiventoJamieAnderson'scinematographyandNeilSpisak'sproductiondesignforestablishingsuchaheadyatmosphereperfectforthelabyrinthplot.
# Opinion of 'plot':
# 	 'labyrinth'
#
#
# Sentence:
# 	Furthermore,itdoesseemtohavesomeallegoricalconcernsrelatingtomodernsocietyandwhatnot,andwhileitdoesn'tsayanythingterriblyprofound,Ithinkitcomesupwithsomereasonablysalientandtruthfulcommentsonhowthemodernworldworks,andillustratesthisstuffwellthroughtheactualplotofthefilmratherthanjusttackingiton.
# Opinion of 'plot':
# 	 'actual'
#
#
# Sentence:
# 	Iwon'tre-hashtheplotasAmazonhasalreadyprovidedpotentialbuyerswiththeoutline.
# Opinion of 'plot':
# 	 'hash'
#
#
# Sentence:
# 	Themoviestillhadsappylines,unrealisticplot,andunconvincingelementstoit.
# Opinion of 'plot':
# 	 'unrealistic'
#
#
# Sentence:
# 	Ifyourlookingforanimethathasaction,suspence,romance,humor,andanengagingplotwithlotsoftwistsEscaflowneistheonetoget.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Theplotistooimplausibleandriddledwithinconsistenciestobetakenliterally.
# Opinion of 'plot':
# 	 'too-implausible', 'riddled'
#
#
# Sentence:
# 	Greatcharacters,awellcraftedplot,andsomeofthebestanimationIhaveeversee.
# Opinion of 'plot':
# 	 'well-crafted'
#
#
# Sentence:
# 	Theplotisfartooconvolutedtoevenbegintorecount,butthepremiseisthatthesetwounlikelycharactersareabouttobecomein-laws.
# Opinion of 'plot':
# 	 'far-too-convoluted', 'is'
#
#
# Sentence:
# 	Wonderfullocations,mesmerizingstunts,admirablespecialeffects,averycleverplotandrespectablecastobligatesustoconsiderabsolutelyrecommendable.
# Opinion of 'plot':
# 	 'very-clever'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Butthereisenoughplottounderstandwhatthestoryisabout.
# Opinion of 'plot':
# 	 'enough'
#
#
# Sentence:
# 	Ienjoyedthismoviebecausetheplotwasverydifferentandnotrunofthemilllikemosthorrormovies.
# Opinion of 'plot':
# 	 'very-different', 'not-run'
#
#
# Sentence:
# 	TheplotisOKandwithatwistthatshouldn'tberevealedbeforehand
# Opinion of 'plot':
# 	 'OK', 'with'
#
#
# Sentence:
# 	Inshort,theplotisaverage,whilethesetting,thespecialeffects,andthemusicareEXCELLENT!
# Opinion of 'plot':
# 	 'average'
#
#
# Sentence:
# 	Theplotisafairytaleindeed,butinlastinstance,whocaresaboutit?.
# Opinion of 'plot':
# 	 'cares'
#
#
# Sentence:
# 	Themovie"Boo"featuresterribleacting,andadeplorableplot.
# Opinion of 'plot':
# 	 'deplorable'
#
#
# Sentence:
# 	It'snotarevolutionaryplot,andafewscenescouldhavebeenbetterexecuted(theobligatory'break-up'beforethehappyendingisratherweak),butonthewholethemushysideofmeateitup.
# Opinion of 'plot':
# 	 'not-revolutionary'
#
#
# Sentence:
# 	Themoviegallopsinspeedasweareabsorbedintothegreatplotandbrilliantactingofallthecastinvolved.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Theplotisratherthinandconsistsofthefairyworldtryingtotakeoverthisworld.
# Opinion of 'plot':
# 	 'consists', 'rather-thin'
#
#
# Sentence:
# 	BeeSeason"isjusthorribleandthismoviehasamuchbetterplot,betteractingandabettermessage.
# Opinion of 'plot':
# 	 'much-better'
#
#
# Sentence:
# 	IfIhadn'tseentheoriginalI'djustthink,"whatabrilliantplot,toobadtheydecidedtoburyit(nopunintended)witheverythingelseinthemovie".
# Opinion of 'plot':
# 	 'brilliant'
#
#
# Sentence:
# 	belowaverage,thedialoguesarewaybelowaverage,whiletheplotisnotbadatall.
# Opinion of 'plot':
# 	 'not-bad'
#
#
# Sentence:
# 	Theplot isludicrous,thescriptfoolishandinept,theactingsocrudeastobeembarrrassing.
# Opinion of 'plot':
# 	 'foolish', 'inept', 'ludicrous', 'so-crude'
#
#
# Sentence:
# 	Theplotisweakaskingustobelieveincharactersdoingthingsthatnoonewithoneounceoflogicwoulddo(forexample,themotherleaveshomeforafewdaystovisitanauntknowingherhusbandrecentlysluggedhersoninthefacewithoutprovocation).
# Opinion of 'plot':
# 	 'recently-slugged', 'weak'
#
#
# Sentence:
# 	Iftheplotwerebetteritwouldbeafilmworthwatching
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	Themovieappealswithitsintricateplot-aningeniouswebawaitedthealmosthelplessWilliamHurt,whowasdazzledbythebeautyofKathleenTurnerandwhosemindwas,nodoubt,slowedbytheintenseheat.
# Opinion of 'plot':
# 	 'intricate'
#
#
# Sentence:
# 	Goodplot.
# Opinion of 'plot':
# 	 'Good'
#
#
# Sentence:
# 	Whetherornotthereactuallyareghostsis,ofcourse,themainplotofthemovie,andtruetothegenreitdancesaroundthequestionforagoodlengthoftimebeforefinallyansweringit.
# Opinion of 'plot':
# 	 'main'
#
#
# Sentence:
# 	Itwasnottheactualstory/plot,orit'saccuracythatwasimportanttome.
# Opinion of 'plot':
# 	 'not-actual'
#
#
# Sentence:
# 	Theplotforthemovieisactuallysurprisinglystraightforwardonceyoucutawayallthefiller,butthat'sthebiggestproblem.
# Opinion of 'plot':
# 	 'surprisingly-straightforward', ''s'
#
#
# Sentence:
# 	Criticsarguethattheplotistoocomplicated/clever,butthiswasentertaining,withovertonesofpoliticalconspiracythatmakeyourealizehoweasyitisforthetrulypowerfultomanipulateevents.
# Opinion of 'plot':
# 	 'clever'
#
#
# Sentence:
# 	Foramoreexplosiveride,withamoreentertainingcharacter,andamuchsimplerdrug-inducedandgraphicplot,seetherecentlyreleasedCrank-excellentaction/adventurefromtheTransporterman.
# Opinion of 'plot':
# 	 'much-simpler', 'induced'
#
#
# Sentence:
# 	JustlikeallDePalmafilms,DressedtoKillfeaturessomeabsolutelybrilliantsequences(elevator,trainstation)dispersedthroughoutaratherclumsyplot.
# Opinion of 'plot':
# 	 'rather-clumsy'
#
#
# Sentence:
# 	SetinWWIILondon,thedarkheartedplotfocusesonNavyLieutenantCommanderCharlesMadison,anespeciallynotoriouspersonalassistanttothementallyunstableAdmiralWilliamJessup.
# Opinion of 'plot':
# 	 'dark', 'hearted'
#
#
# Sentence:
# 	Iamlaughingatthose2starreviewssayinghowAVPisdestroyingtheAlienandPredatorlegacybecauseofitsnonexistentplot.
# Opinion of 'plot':
# 	 'nonexistent'
#
#
# Sentence:
# 	Verysuspenseful,andwonderfullywrittenplotmakethisa5starfilm!
# Opinion of 'plot':
# 	 'Very-suspenseful', 'wonderfully-written'
#
#
# Sentence:
# 	Theplotisfairlysimplewiththetwobrotherstryingtopreventagangofoutlawsfromterrorizingagroupoffarmersandstealingtheirland.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	Theplotisnotnew.
# Opinion of 'plot':
# 	 'not-new'
#
#
# Sentence:
# 	Goodversusevil,ofcourse,buttheplotismoreabouttheclasses.
# Opinion of 'plot':
# 	 'more'
#
#
# Sentence:
# 	TheplotisUNEXPECTED,thatiamnotsureifit'sgoodornot!
# Opinion of 'plot':
# 	 'UNEXPECTED'
#
#
# Sentence:
# 	Theplotisfartocomplicatedtoexplaininareasonableamountoftime,butissumsuptobeaboutabunchofpeople,withcompletelydifferentlifestyles,whosomehowgetthrowntogetherbecauseofabigbombthatlookslikeagarbedgedisposal.
# Opinion of 'plot':
# 	 'far-complicated', 'is'
#
#
# Sentence:
# 	Fromthere,theplotgoesnuts,butthat'sokay,becauseit'swhatmakesBigTroublesuchafunnyandstrangelysmartmovie.
# Opinion of 'plot':
# 	 ''s', 'nuts'
#
#
# Sentence:
# 	Thisisagoodmoviewithaninterestingplot,goodacting,decentdirectingandapoliticallyreleventcommentontheexcessesoftheUSPress.
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Alotofpeopletendtosaythatthisanimeisconfusinganddoesn'thavearealplot.
# Opinion of 'plot':
# 	 'real'
#
#
# Sentence:
# 	Ithinkthedirectorneedsprozactodirectthismovie,thewholeplotissomessup,juniorhighstudentcanwritebetterstorythanthis..whatwashethinking.
# Opinion of 'plot':
# 	 'whole', 'so-mess'
#
#
# Sentence:
# 	Thecharactersaresoveryinteresting(butsubtle),theycouldhavewrittenanyoldplotandIwouldhavewatchedhungrily.
# Opinion of 'plot':
# 	 'old'
#
#
# Sentence:
# 	Whileultimatelythissetofindividualepisodesdoesn'tseemtofurtheranyoverallplot,thecomplexityoftheTachikomasandhowtheyworkisactuallyprettyinteresting.
# Opinion of 'plot':
# 	 'overall'
#
#
# Sentence:
# 	Theplotisalittlethin,butAlyssaMilanoisthereasontowatchthismovie.
# Opinion of 'plot':
# 	 'is', 'thin'
#
#
# Sentence:
# 	Theplotseemstobenothingoutoftheordinaryaction/hiest/shoot-em-upmovieplotthatisfoundalltofrequentlyintoday'smovietheaters,buttheendingiswhatmakesthismovieanotableone.
# Opinion of 'plot':
# 	 'is'
#
#
# Sentence:
# 	Thesewerealllosersbecausetheyhadashallowplot,alackoftalentedactors/actresses,andnomoralfibertothemwhatsoever.
# Opinion of 'plot':
# 	 'shallow'
#
#
# Sentence:
# 	Idon'tknowwhoplaysPatsy,butsheissuperbandthisplotstrandisverypoignant.
# Opinion of 'plot':
# 	 'very-poignant'
#
#
# Sentence:
# 	Itisthesethemesthatmaketheseriestrulyshine,asthesimplisticoverallplotservesmerelyasavehiclefortheseideas.
# Opinion of 'plot':
# 	 'simplistic', 'overall'
#
#
# Sentence:
# 	Theplotisratherpredictableandyoucouldsensetheendingalmostfromthebeginning.
# Opinion of 'plot':
# 	 'rather-predictable', 'sense'
#
#
# Sentence:
# 	Theplotisfairlysimple.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	NowobviouslythisissameplotusedintheSantaClause
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	IthasafairlysimpleplotwhichsendsthecharactersrunningaroundNYConenightatChristmastime-eachwithhisorherownmisunderstandingofwhatisgoingon.
# Opinion of 'plot':
# 	 'fairly-simple'
#
#
# Sentence:
# 	Watchtheperfectmurderplotbeingexecuted
# Opinion of 'plot':
# 	 'perfect'
#
#
# Sentence:
# 	Theplottothefilmissocomplicatedthatitreallyistoughtokeepupwith,eventhoughtherereallyisn'tthatmuchgoingonthroughoutmostofthefilm.
# Opinion of 'plot':
# 	 'so-complicated'
#
#
# Sentence:
# 	ShefindsadischargenoticeinRyu'spants,andthenextthingweknowshehasfiguredouttheentireplot,includingthekidnapping.
# Opinion of 'plot':
# 	 'entire'
#
#
# Sentence:
# 	Theplotandsupportingcastarebetterthanpassable,thisisn'tatotallybadflick.
# Opinion of 'plot':
# 	 'better'
#
#
# Sentence:
# 	McGiverhasfallenforKhanandsays,"Iwilldoanything",sellsoutherselftoopower,andagreeswithhisevilplottootakeovertheEnterprise.
# Opinion of 'plot':
# 	 'evil'
#
#
# Sentence:
# 	Thecharacterworkisverygoodandtheplotgetsmoreandmoreinterestingasthemoviegoeson.
# Opinion of 'plot':
# 	 'more-interesting'
#
#
# Sentence:
# 	"Stargate"isstilloneofthescience-fictiongreatsthatsuccessfullyblendshistoryandscience-fictioninoneeffectiveplot.
# Opinion of 'plot':
# 	 'effective'
#
#
# Sentence:
# 	ThisDVDofTeentitansthe2ndseasionhasagoodstoryplot,andIforoneloveit!
# Opinion of 'plot':
# 	 'good'
#
#
# Sentence:
# 	Nowtothemeatofthereview,theplotinthismovieisn'treallythatgood,butnotveryhorrible.
# Opinion of 'plot':
# 	 'not-that-good', 'not-not-very-horrible'
#
#
# Sentence:
# 	Notaparticularlyinvolvedplot,butthenI'veseenjustaboutallthereare,butaverynicelittlefilm.
# Opinion of 'plot':
# 	 'particularly-involved'
#
#
# Sentence:
# 	Inotherwords,it'sthesimpleBODYSNATCHERSplot.
# Opinion of 'plot':
# 	 'simple'
#
#
# Sentence:
# 	Moreplot,morestory,moregore(gettheunratedversion)andmoreJASON!
# Opinion of 'plot':
# 	 'More'
#
#
# Sentence:
# 	TheplotisratherShakespearean--themixupoflovers--buteverythingturnsouthappilyintheend.
# Opinion of 'plot':
# 	 'happily-turns', 'rather-Shakespearean'
#
#
# Sentence:
# 	Nottomentionit'snotexactlythemostcliche-freeplotasthere'ssomescenesthataregoingtobeobviousandwhentheyhappentheydon'treallysurprise(apossibleromancebetweenJohnandFlor,Deborahandhermotherhavinganall-outorjealousyamongFlorandDeborah)butthefilm'sentertaininganyway.
# Opinion of 'plot':
# 	 'not-most-free'
#
#
# Sentence:
# 	Theunconvincingcharacterizationsandhackneyedplotarelostinawelterofstrikingincidentaldetails:hundredsofglassbaublesrollingdownastaircaseandintothebloodywaterofasuicidevictim'sbathtub,beingaparticularlyimpressiveexample.
# Opinion of 'plot':
# 	 'hackneyed'
#
#
# Sentence:
# 	Poorplot,script,acting
# Opinion of 'plot':
# 	 'Poor'
#
#
# Sentence:
# 	Theplotwouldn'tadvanceforepisodes,andIthinkthisiswhatcausedtheratingstoplummet,theytooktoolongtofleshouttheplot
# Opinion of 'plot':
# 	 'not-think'
#
#
# Sentence:
# 	Greataction,engagingplot,greatcinematography.
# Opinion of 'plot':
# 	 'engaging'
#
#
# Sentence:
# 	Moreblood,nudity,violence,swearing,andsexthanthefirstmovie,lessplotandcharacterization.
# Opinion of 'plot':
# 	 'less'
#
#
# Sentence:
# 	REDPLANETunfortunatelyneededmorethanitsminimalistplottocarryit.
# Opinion of 'plot':
# 	 'minimalist'
#
#
# Sentence:
# 	Thefilmisatreat,especiallythefirsttimearound,despiteacomplicatedplotandanunderachievingstoryline
# Opinion of 'plot':
# 	 'complicated'
#
#
# Sentence:
# 	Thisplotismucheasiertodigestonscreen.
# Opinion of 'plot':
# 	 'much-easier'
#
#
# Sentence:
# 	Theplotisgreat,theactingisoverthetop,andthecinematographyisfantastic.
# Opinion of 'plot':
# 	 'great'
#
#
# Sentence:
# 	Whichonewillgettheirman,aninterestingsub-plot?
# Opinion of 'plot':
# 	 'interesting'
#
#
# Sentence:
# 	Itwasn'tthesameoldboringplotasthereweremanyunexpectedturnsandmisadventuresintheplot.
# Opinion of 'plot':
# 	 'not-same', 'not-old', 'not-boring'
#
#
# Sentence:
# 	Thisisn'tanewplot;You'veseenthis,insomeformoranother,severaltimes.
# Opinion of 'plot':
# 	 'not-new'
#
#
# Sentence:
# 	Aftertherecentspateofrubberrealityfilmsthatallusedessentiallythesameplot--includingStay(2005),TheJacket(2005),November(2004),TheIInside(2003),andeightornineothersgoingatleastallthewaybacktoJacob'sLadder(1990)andtheshortTheAwakening(1990)--TheDarkHoursveryrefreshinglyusesdifferentkindsoftwistsinitsquestionablyhallucinatorysuccessionofscenes.
# Opinion of 'plot':
# 	 'same'
#
#
# Results for aspect word 'characters'
#
# Sentence:
# 	Thecharacterstalkabouttherelativeintelligenceoftheothercharactersorhowtheothercharacterscan'tpossiblyknowwhatisgoingon.
# Opinion of 'characters':
# 	 'other', 'not-other'
#
#
# Sentence:
# 	ThereareonlytwoBlackcharacters,bothsentimentallyloyaltotheirSouthernnessandtheirmasters;otherwise,slaveryisbesidethepoint.
# Opinion of 'characters':
# 	 'Black', 'sentimentally-loyal'
#
#
# Sentence:
# 	whenlessthanhalfwaythrough,thestorybecomessomethingutterlyunrecognizablefromtheoriginal,severalkeycharactersarelumpedtogethermostconfusingly,andotherslosealltheircomplexcharm.
# Opinion of 'characters':
# 	 'several', 'key'
#
#
# Sentence:
# 	Ifeltthatwithinallthetimeitran,wedidn'treallygetagoodunderstandingoftheinnerbeingofthemaincharacters;seemedtoremaininshallowwatersallalong.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Otherreviewershavecommentedonthebad,infomerciallevelactingofthetwoleadcharacters.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	"ConExpress"haslotsofactioninit,whichisgreatbecausethishidesthepoorwritinganduninterestingcharacters.
# Opinion of 'characters':
# 	 'writing'
#
#
# Sentence:
# 	Allthecharacterswereseverelyandtragically2-dimensionalwithnoneofthedepthyougetfromreadingthegraphicnovelandverylittleattentionwaspaidtodevelopingbetterdialoguesuitableforabigscreenexperience.
# Opinion of 'characters':
# 	 'paid'
#
#
# Sentence:
# 	ThemoviegetsboringratherfastasBetteandWoodyaretheonlyoneswegettoseeasthereareveryfewsupportingcharacters.
# Opinion of 'characters':
# 	 'very-few', 'supporting'
#
#
# Sentence:
# 	Thesedisjointedglimpsesdon'tgivetheviewertimeordepthtocarewhathappenstoanyofthespoiledrottencharacters.
# Opinion of 'characters':
# 	 'spoiled', 'rotten'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'were', 'ok'
#
#
# Sentence:
# 	Thecharactersarethinatbest,andstockatworst.
# Opinion of 'characters':
# 	 'thin', 'worst-stock'
#
#
# Sentence:
# 	Can'trememberwhenI'veseenafilmwithmoredepravedandpatheticcharactersthanthis.
# Opinion of 'characters':
# 	 'more-depraved'
#
#
# Sentence:
# 	ThecharactersareunlikeableexceptforCharity'stwofriends.
# Opinion of 'characters':
# 	 'unlikeable'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Forgoodcounterexampleswatch"Trainspotting",whichhasdrug-addictcharacterswithenoughhumorandlifetobelikableandinterestingand"BubbaHo-Tep",afilmwhichdisplaystheplightofthelonelyelderly50timesbetterthanthisfilmdespitebeingasillyhorror-comedywithamummyinacowboyoutfitinit.
# Opinion of 'characters':
# 	 'addict'
#
#
# Sentence:
# 	NowthatthesetediouscharactershavefinallyhitrockbottomIcangodosomethingelse.
# Opinion of 'characters':
# 	 'tedious'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	AnarrativelikeGettysburgthatgoesbackandforthbetweenafewcentralcharactersinalogicalsequencewithoutallthehamfistedattemptsaproselytizingandallthenoblesseoblige.
# Opinion of 'characters':
# 	 'few', 'central'
#
#
# Sentence:
# 	Iwaswatchingthesametwocharactersfightthroughthesametwochallengesinthisfilm.
# Opinion of 'characters':
# 	 'same'
#
#
# Sentence:
# 	WhatDylandidtocounterthesimilaritybetweenRedman/MethodManwasbringinobscuresecondarycharactersthataddednothingtotheflimsyplotorhelpedusfeelemotionforourtwomaincharacters.
# Opinion of 'characters':
# 	 'obscure', 'secondary', 'main'
#
#
# Sentence:
# 	Ifhewouldhavetightenedthescript,createduniqueand"cult-like"characters,andeliminatedtheracism,hemayhavehadthequintessential"weed"filminHollywood.
# Opinion of 'characters':
# 	 'unique'
#
#
# Sentence:
# 	Hediscoversanewtalent(artistChristinaMilian)andworkshiswaythroughanassortmentofcharactersthataremoretypesandclichesthanrealcharacters.
# Opinion of 'characters':
# 	 'real'
#
#
# Sentence:
# 	Thesoundismurkyandundecipherable,theactingisstrictlyamateurhour,thecharactersarepaper-thinwithnodistinctionorpurpose,thestoryisnon-existent,thedialogueisacompletelyworthlessbore,there'snothingremotelyscary,andthespecialeffects(includingacoupleofcomputereffectsthatlookliketheyweremadeonaCommodore64)arelaughable.
# Opinion of 'characters':
# 	 'thin'
#
#
# Sentence:
# 	Nothinghappensinthismovie(andImeannothing)exceptabunchofsullencharactersexhanging"comic"glancesandlookingwithdrawnandcynical.
# Opinion of 'characters':
# 	 'sullen'
#
#
# Sentence:
# 	Thesimilaritiesofthese2moviesaresoprominentthatitwouldactuallybeawasteoftimeandmoneytobuyboth-samecharacters,sameplotonlyinadifferentsetting.
# Opinion of 'characters':
# 	 'both-same'
#
#
# Sentence:
# 	It'sastudyincontrasts,andit'sdoneimpeccablyinthenovel,withaplethoraofcomplexcharacterstorichenthejourney...
# Opinion of 'characters':
# 	 'complex'
#
#
# Sentence:
# 	Realcharacters?
# Opinion of 'characters':
# 	 'Real'
#
#
# Sentence:
# 	Therestofthisfilmconsistsoftheear-bleedingwhinesandyawn-inducinginfightingofthehumancharacters,ill-conceivedandextremelyunlikablecaricaturesofapseudo-cynicalandextremelyredundant"evilsideofhumannature"messagethatwouldbebetterlefttoJeanRenoir(orevenAdamSandlerconsideringtheresultshere).
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	Iguessit'ssupposedtodepictthehorrorofrepressivereligiousvalues,andwhileIdon'tcondonethose,thefilmlacksclearcharactersoranymotivation.
# Opinion of 'characters':
# 	 'clear'
#
#
# Sentence:
# 	ItiseasytogetsuckedintowatchingGantz,becauseoftheuniqueandinexplicablesituationthatthemaincharacters,whohavealldied,findthemselvesin.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull', 'insipid', 'leaves'
#
#
# Sentence:
# 	Thecharactersaresolame
# Opinion of 'characters':
# 	 'so-lame'
#
#
# Sentence:
# 	Thecharactersare,overall,blandandjustplainuninteresting(e.g.RickAndersonplayedbythe"fool,"TedRaimi,fromtheXenaseries).
# Opinion of 'characters':
# 	 'bland', 'just-plain-uninteresting'
#
#
# Sentence:
# 	andIdidn'tcarewhatwouldhappenwiththemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Ireadthebookandsawthemovie,whichotherthantitleandmajorcharacters,havelittleincommon.
# Opinion of 'characters':
# 	 'major'
#
#
# Sentence:
# 	Theminorcharacters,includingthewonderfulTracieThomsas"bestfriend"Lily,aremostlywasted.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	ThebigproblemwithRHisthatneitherFordorBenningaresympatheticcharacters.
# Opinion of 'characters':
# 	 'sympathetic'
#
#
# Sentence:
# 	Theproducersofthisfilmareoutoftheirmindiftheyexpectanyviewerwho'snotscrewed-upintheheadtofeelsorryforthetwostupidmaincharactersjustbecausetheirsick,incestuous,andadulterouslifestyleisincompatiblewiththeworldtheylivein.
# Opinion of 'characters':
# 	 'stupid', 'main'
#
#
# Sentence:
# 	Tooimplausible,toomanyoverdrawnsecondarycharacters.
# Opinion of 'characters':
# 	 'Too-implausible', 'overdrawn', 'secondary'
#
#
# Sentence:
# 	Theplotisstupid,thecharactersaredullandinsipid,andthewholemovieleavesyouasking,asthecreditsrun,"
# Opinion of 'characters':
# 	 'dull', 'insipid', 'leaves'
#
#
# Sentence:
# 	somethingthatcan'tbesaidforanyofthehumancharacters.
# Opinion of 'characters':
# 	 'human'
#
#
# Sentence:
# 	WhoevermasteredthisgreatfilmRUINEDitbyFORGETTINGorREFUSINGtoprovideEnglishsubtitlesfortheJapaneseandItaliancharacters.
# Opinion of 'characters':
# 	 'Japanese'
#
#
# Sentence:
# 	Thecharactersarenotengagingandthestoryisjustagenericmurdermysterywithamonsterthrownin.
# Opinion of 'characters':
# 	 'not-is'
#
#
# Sentence:
# 	Occasionallywegetashotofsomeoftheothercharacters.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	We'resupposedtofindthecharactersplayedbyRobertRedfordandDebraWingertobeamusing,theiracrimoniousrelationshiptobehilarious,andthewaythattheyendupbeingpartnersdespiteallofthegibestoberomanticallysatisfying.
# Opinion of 'characters':
# 	 'amusing'
#
#
# Sentence:
# 	Long,tediousactionadventurewithrepetitivedialog,badplotholes,andgenerallyboringcharactersishowtodescribethislittleforayintofollowingupthecharactersfromBadBoys.
# Opinion of 'characters':
# 	 'generally-boring'
#
#
# Sentence:
# 	It'samazinghowsomuchmoneyandeffortgointospecialeffectsandexpensivesetsandthescriptitselfishollowwithlousycharacters.
# Opinion of 'characters':
# 	 'lousy'
#
#
# Sentence:
# 	Anditdoesn'tonlycenteraroundthemaincharactersbuthasagreatensemblecastofveryinterestingpeople!
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Firstofall,thechildactorswerehorrible,welltheCharlieandMikecharacterswereok,butthetwogirlactorsweretheworstI'veseeninalongtime.
# Opinion of 'characters':
# 	 'were', 'ok'
#
#
# Sentence:
# 	Toobadthemembersofthisbandareminorcharacters.
# Opinion of 'characters':
# 	 'minor'
#
#
# Sentence:
# 	Haspleasantcharacters;butnotdeep.
# Opinion of 'characters':
# 	 'pleasant'
#
#
# Sentence:
# 	Itsjustbadactingwithstupidandmeancharacters.
# Opinion of 'characters':
# 	 'stupid'
#
#
# Sentence:
# 	Rivkabecomeshercousinandothercharactersareneglectedcompletely.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Theplotisratherunbelievable,namingthefactthatallthreemaincharactersareleadersintheirfield....
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Afterorbeforekeyscenes,thecameracutstoamonologuefromoneofthemaincharacters.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	Toitscredit,theactorsdidwhole-heartedlyportraygaycharactersandgaylovescenes.
# Opinion of 'characters':
# 	 'heartedly-portray', 'gay'
#
#
# Sentence:
# 	Atthetime,gaycharacterswereneverportrayedinapositivelightfromthemedia,anditwasagreatrisktodosohere.
# Opinion of 'characters':
# 	 'gay'
#
#
# Sentence:
# 	CertainlynottheweirdIrishaccentstheleadcharactersadopted.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# 	EmilyBronte'scharactersjumpoffthepageandwillcontinuetohauntyoulongafteryou'vefinishedthebook.
# Opinion of 'characters':
# 	 'continue'
#
#
# Sentence:
# 	Thecharactersarerepresentationsinnameonlyandfailtocaptureanyofthetruespiritbehindthisamazingbook.
# Opinion of 'characters':
# 	 'fail'
#
#
# Sentence:
# 	Theothercharactersarelikewiselackinginrealism,onlyJanetMcTeerfareswell
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Mightbesuitedmoreforanolderchildbutmineis13monthssotherehastobeconstantcolorfulcharactersforhertobeinterested
# Opinion of 'characters':
# 	 'constant', 'colorful'
#
#
# Sentence:
# 	Theplotlinewasnonexistent,andthecharacterswerecompletelyunlikeable.
# Opinion of 'characters':
# 	 'completely-unlikeable'
#
#
# Sentence:
# 	istartedlikingthismovie,ithoughtthepinballmetaphorandwildcharactersandlifesacartoonshizcouldhaveworkedout,ifitwerentforthefactthatbakshiisthinlydisguisinghimselfandhisownfrustrationasbeinganunoriginal"underground"cartoonistwhocaughtontothescenetoolate...ifyoulikethedepressing,gritty,wild,fastpacedstyleofthismovie,checkouttheoriginalmasterROBERTCRUMB,towardwhombakshiisobviouslyseethingwithjealousyandridinganxiouslyonthecoattailsof...
# Opinion of 'characters':
# 	 'wild'
#
#
# Sentence:
# 	Everyminutecharactersinthisseriestrytoremindyouofsomeplotpointasifyou'reashort-attentionspancoachpotatoe.
# Opinion of 'characters':
# 	 'minute'
#
#
# Sentence:
# 	butthenthefilmbasicallyspendstoomuchtimezigzaggingaroundtoallthedifferentcharactersandlocales.
# Opinion of 'characters':
# 	 'different'
#
#
# Sentence:
# 	Itseemstoberidingonit'slaurels,sotospeak,andit'salmostasifwearesupposedtofindthecharactersactingdifferentlyfunny.
# Opinion of 'characters':
# 	 'differently-funny'
#
#
# Sentence:
# 	Butthecharactersarenotsympathetic,funorinteresting.
# Opinion of 'characters':
# 	 'not-sympathetic', 'not-fun', 'not-interesting'
#
#
# Sentence:
# 	Thereisnohumor,nolikablecharacters,notevenadecentquoteoroneliner.
# Opinion of 'characters':
# 	 'likable'
#
#
# Sentence:
# 	Therearetwonewsupportingcharactersthistime,Loisand,erm...Jason.
# Opinion of 'characters':
# 	 'new', 'supporting'
#
#
# Sentence:
# 	SheisagreatalternativetoBarneyandalloftheothercommercialcharacters,whoIdon'tcaremuchfor.
# Opinion of 'characters':
# 	 'other', 'commercial'
#
#
# Sentence:
# 	Thestoryissimple,butinthehandsofthewritersWendyHammondandBobGosseandwithGosse'sfinedirection,theentirecastgivesusanensembleofdisparatecharactersinwhomwecanallbelieve.
# Opinion of 'characters':
# 	 'disparate'
#
#
# Sentence:
# 	Theactionisoffthewallwiththetwomaincharacterstreatingustotwostylesoffightingthataretheveryantithesistoeachother.
# Opinion of 'characters':
# 	 'main'
#
#
# Sentence:
# 	In"TheManWhoWasn'tThere,"thephrase"decisiveaction"isanoxymoron;everythingCraneandtheothercharactersdoisgovernedsolelybychance.
# Opinion of 'characters':
# 	 'other'
#
#
# Sentence:
# 	Alongthewayheencountersahostofintriguingcharacters,includingacrazy-like-a-foxentrepreneurialbushpilotlookingtomakesomesortofbigscore,anumberofwackybitplayerswhoIcaneasilyimaginewerenotactors,buttherealdeal,andeverybitaseccentricastheyappeared;andanendearinglysageoldInuitoffewwordsbutmanyeloquentsilences.
# Opinion of 'characters':
# 	 'intriguing'
#
#
# Sentence:
# 	Thepremiseissillierthanthefirstfilm(whichwasprettysillyitself),butthecharactersareappealingandtheactionisstreamlinedandintense.
# Opinion of 'characters':
# 	 'streamlined', 'intense'
#
#
# Sentence:
# 	Thefilmdepictstheevolutionofthesevariouscharactersastheycometotermswiththeprogressionoftheirlovelivesandprofessions.
# Opinion of 'characters':
# 	 'various'
#
#
# Sentence:
# 	ThecharactersinthismoviegenerallyactedasIwouldexpectthemto,andtherewerefeweroutrightactsofstupidity.
# Opinion of 'characters':
# 	 'were'
#
#
# Sentence:
# 	PlotsbasedonbooksbyElmoreLeonardtendtobeaboveaverage,butaremostlydependentuponthecolorfulcharactershewrites.
# Opinion of 'characters':
# 	 'colorful'
#
#
# Sentence:
# 	NotonlydoesthemovieSignsofferawonderfullydifferentkindofalien/ufotale,butitscharactersareverylikableandthestoryisaboutmuchmorethanaliensfromanotherplanet.
# Opinion of 'characters':
# 	 'is', 'very-likable'
#
#
# Sentence:
# 	TheclassicWordsworthpoemfromwhichthefilm'stitleisderivedmakesafittingcodaforthismovie,andIstillfeeltheintractablesenseoflonginginthetwoleadcharacterseverytimeIseethismovie.
# Opinion of 'characters':
# 	 'lead'
#
#
# Sentence:
# ...
# Opinion of 'dialogue':
# 	 'difficult', 'not-really-follows'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'completely-unbelievable'
#
#
# Sentence:
# 	Iunderstoodtheplot,andenjoyedsomeofthethoughtsraisedneartheend,butoverallwasboredsillybystilted,pointlessdialogue.
# Opinion of 'dialogue':
# 	 'stilted', 'pointless'
#
#
# Sentence:
# 	WhileBaldwinandtherestofthecastdidwellinfleshingoutBurke'scharactersandhavesometangytough-guy/galdialogue,they'rehamperedbytwothings:
#
# 1.)
# Opinion of 'dialogue':
# 	 'tangy'
#
#
# Sentence:
# 	Gooddialogueislikegoodacting:ifit'sreallygood,youdon'tnoticeituntiltheshow'sover.
# Opinion of 'dialogue':
# 	 'Good'
#
#
# Sentence:
# 	Anachronism,baddialogue,badplotandplainoldbadactingplaguethis"sequel".
# Opinion of 'dialogue':
# 	 'bad'
#
#
# Sentence:
# 	soI'msupposedtobelievethatthehorribledialogue,badacting,andridiculousplottingisonpurposejustbecauseMametisarespectedguy?
# Opinion of 'dialogue':
# 	 'horrible'
#
#
# Sentence:
# 	Thedialoguewouldhavebeen1000timesbetter.
# Opinion of 'dialogue':
# 	 'better'
#
#
# Sentence:
# 	It'sthewaythestoryistold-itsham-fisteddialogueandplot,itsforcedobscenityateveryturn-thatrevealsitsteensensibilities.
# Opinion of 'dialogue':
# 	 'fisted'
#
#
# Sentence:
# 	Theplotisstupid,andthedialogueissobadit'soverthetop.
# Opinion of 'dialogue':
# 	 'so-bad'
#
#
# Sentence:
# 	Thetwodimensionalniceoldbrotherandsisteraretreatedhorribly,fornogoodreasonwithnomotivationorpayoff,thesongsareunlistnableandthedialogueishardtounderstand,thisisnotalwaysabadthing.
# Opinion of 'dialogue':
# 	 'hard', 'not-always-is'
#
#
# Sentence:
# 	Youdon'tgotothesemoviestoexpectwell-writtendialogue,characterdepthoranything,youcomeforthekillsandtotellyouthetruth,they'reslightlydisappointing.
# Opinion of 'dialogue':
# 	 'well-written'
#
#
# Sentence:
# 	Theunwittydialoguetriestobecleverallthroughoutthemovieandisjustsoooboring.
# Opinion of 'dialogue':
# 	 'unwitty', 'just-sooo'
#
#
# Sentence:
# 	Thedialoguewassharpandyoumighthavetowatchtwicetogetallthesubtlequips.
# Opinion of 'dialogue':
# 	 'have', 'sharp'
#
#
# Sentence:
# 	Thedialogueiswonderfullyexpressiveandgivesusthesenseofauthenticityandthekindofrealisticeffectseenonlyintheverybestfilms.
# Opinion of 'dialogue':
# 	 'gives', 'wonderfully-expressive'
#
#
# Sentence:
# 	Thecolorsaredark,thedialoguebetweenthecharactersishonest,realandsimplywonderful.
# Opinion of 'dialogue':
# 	 'honest', 'real', 'simply-wonderful'
#
#
# Sentence:
# 	thisepisodehasalotoffunnydialogue,butthat'stheonlythingithasworkingforit.
# Opinion of 'dialogue':
# 	 'funny'
#
#
# Sentence:
# 	Inconclusion,thisTVshowhasitall:goodbackgroundmusic,greatdialogue,interestingstories,goodacting,andinterestingcinematography.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thisisawonderfulfilm,withasillybutextremleyfunnyplot,andsomewonderfuldialogue,particularlybetweenHortonandBrady,whosomehowmanagetoendupmarriedtoeachother,muchtotheirsurprise.
# Opinion of 'dialogue':
# 	 'wonderful'
#
#
# Sentence:
# 	Thedialogueissharpandwitty,althoughthere'salotofswearing,thatdoesn'tmeanthehumourisjustfowlmouthed,it'shillarious,someofthelinesgodowninhistoryassomeofthefunniestonelinersever.
# Opinion of 'dialogue':
# 	 'sharp', 'witty'
#
#
# Sentence:
# 	Inanerawherecinematicpalatesseemtitillatedmostlybyfastactionthrillers,thismovieisanotherexampleofhowwellconstructeddialoguemakesforgrippingcinematicdramawhenitgoeshandinhandwithsuperbcastingandperformance
# Opinion of 'dialogue':
# 	 'well-constructed'
#
#
# Sentence:
# 	You'llbesuckedin,andsurprised,withinthefirsttwominutes,andthere'sverylittledialogue
# Opinion of 'dialogue':
# 	 'very-little'
#
#
# Sentence:
# 	Itseemsraretodaytofindsuchrichdialogue.
# Opinion of 'dialogue':
# 	 'such', 'rich'
#
#
# Sentence:
# 	OtherPeople'sMoneyisawonderfulmovie,fullofsmartdialogue,goodmusic,andaterrificDannyDeVitoperformance.
# Opinion of 'dialogue':
# 	 'smart'
#
#
# Sentence:
# 	Thedialogueisn'thard-boiledexceptforafewlinesdeliveredbyVicky.
# Opinion of 'dialogue':
# 	 'not-hard-boiled'
#
#
# Sentence:
# 	iappreciatedtheeffects-nicetouch-butiwouldhavelikedtoseesomerealdialoguethere.
# Opinion of 'dialogue':
# 	 'real'
#
#
# Sentence:
# 	Relyingonsharpdialogueandfacialexpressions,theactorsmanagetoweaveagorgeoussensualdancetogether,bothlightingupthescreenandcreatingtwoofthemostsmolderinglycomplexcharacterseverseeninfilm.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	The'plain'dialogueamongthe'elders'ispainfullynumbing,choppy,andstilted.
# Opinion of 'dialogue':
# 	 'plain', 'painfully-numbing', 'choppy', 'stilted'
#
#
# Sentence:
# 	Thesoundtrackisawesome,thecinematographyisgreat,thedialogueisrealistic,andforonce,amoviesetinaforeignlandthatactuallyusesactorsfromthatareaspeakingthelanguageofthatarea!
# Opinion of 'dialogue':
# 	 'realistic', 'movie'
#
#
# Sentence:
# 	Thismovieisweak,poorlywrittenandhassomelaugh-out-loudstereotypicalcop-schlockdialogue.
# Opinion of 'dialogue':
# 	 'out-loud'
#
#
# Sentence:
# 	(Thescript,bytheway,isonegreatlineafteranother,withverynatural,effortlessdialogue.
# Opinion of 'dialogue':
# 	 'very-natural', 'effortless'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Thestoryisfilledwithbiglaughs--fromcrudehumortosomeofthemostintelligentdialogueI'veprobablyeverheard.
# Opinion of 'dialogue':
# 	 'most-intelligent'
#
#
# Sentence:
# 	Thesurrealhumourandoff-kilterandunusuallybizarrehumourhasseducedthosethatlikeamixtureofpsychicalcomedy,comicinnerdialogue,aswellascrackingoneliners,mixedwiththeoccasionalrelativelyserioussubjectmatters,andphasesthatcanberecitedamongstfellowfans,tomuchamusement.
# Opinion of 'dialogue':
# 	 'comic', 'inner'
#
#
# Sentence:
# 	Thewritingissmartandwitty,thedialogueischarming,theperformancesaregreat.
# Opinion of 'dialogue':
# 	 'charming'
#
#
# Sentence:
# 	Thedialoguethroughoutwastediousandtrite;thescriptwritershouldbeontheunemploymentline,aswellasthedirectorandtheeditor.
# Opinion of 'dialogue':
# 	 'tedious', 'trite'
#
#
# Sentence:
# 	Therereallywasn'tmuchanimosityfromeithersideofthe spectrum,rathertherewasalotofwell-intentioneddialoguefrombothsidesthatwouldgiveanybody,regardlessofpoliticalpersuasion,betterinsightintotheissuesinIraqandtheMiddleEast
# Opinion of 'dialogue':
# 	 'well-intentioned'
#
#
# Sentence:
# 	Ithasgreatfundialogue,isverytechnicallymodernforitstime,extremelyentertaining,fastpaced,andanabsolutejoytowatchthisCLASSICfilm~WHATATREAT!!
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Thedialoguetoisequaltothatof"Coctail"-pointless,beentherebefore,densedialogue.
# Opinion of 'dialogue':
# 	 'equal', 'dense'
#
#
# Sentence:
# 	Thedialogueiscompletelyunbelievableconsideringtheageofthesekids.
# Opinion of 'dialogue':
# 	 'completely-unbelievable'
#
#
# Sentence:
# 	MarvellousdialoguebyBolt.
# Opinion of 'dialogue':
# 	 'Marvellous'
#
#
# Sentence:
# 	SetintheSouth,startingintheearly1950s,andasaSouthernermyselfIparticularlyenjoyedtheauthenticdialogue.
# Opinion of 'dialogue':
# 	 'authentic'
#
#
# Sentence:
# 	Thedialogueiswonderful,alloftheperformancesaresuperb,andCapra'sdirectionareexcellent.
# Opinion of 'dialogue':
# 	 'are', 'are', 'wonderful'
#
#
# Sentence:
# 	DotDrequiresabraintoenjoyasitisNOTaslambangshoot'emupwithditzydialoguetofillinthegorescenes.
# Opinion of 'dialogue':
# 	 'ditzy'
#
#
# Sentence:
# 	Themiddlesectionisadmittedlyratherdialoguebased,butthisdialogueisneverboringandservestoillustratewhythelivingdeadfeeltheneedtochompdownonwarmflesh.
# Opinion of 'dialogue':
# 	 'not-serves', 'not-boring'
#
#
# Sentence:
# 	(He'smuchbetteronHOUSE,wherehegetssomerealcharacterizationandinfinitelybetterdialogue.)
# Opinion of 'dialogue':
# 	 'infinitely-better'
#
#
# Sentence:
# 	Ifthedialoguewasn'twitty,festivalaudienceswouldn'thavegonenuts.
# Opinion of 'dialogue':
# 	 'not-witty'
#
#
# Sentence:
# 	Stonecombinessuchwild,lush,andcrazyfilmeditingtodepictthemindsofVickeyandMallory,crazydialogue,uniquestorytelling,andallthewhilepokingfunathowweasthepeopleandthemediagocrazyforit.
# Opinion of 'dialogue':
# 	 'crazy'
#
#
# Sentence:
# 	ThefilmisslightalthoughitbenefitsfromsomesharpHermanMankiewiczdialogue.
# Opinion of 'dialogue':
# 	 'sharp'
#
#
# Sentence:
# 	Manyclose-upshotsofherbarechest.(d)HighlyXXXdialogue,suchasthelinewhere11yearoldViolettellshercustomerthat"Icanfeelthesteamjustcomingthrumydress"(e)
# Opinion of 'dialogue':
# 	 'bare'
#
#
# Sentence:
# 	Themovieisactionpackedwithexcellentdialogueandtheactionneverstopsuntiltheveryappropriateend.
# Opinion of 'dialogue':
# 	 'excellent'
#
#
# Sentence:
# 	Andthedialogueiscertainlymemorable:
#
# JackBull:
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Itmakesyouquestionwhyyoubuyintosuchsappydialogueandsituations.
# Opinion of 'dialogue':
# 	 'such', 'sappy'
#
#
# Sentence:
# 	Whilewatching,inmyheadIwasfillinginthedialogueforthecharacters,andmydialoguewasalotmoreinterestingthananythingthesepeoplesay.
# Opinion of 'dialogue':
# 	 'more-interesting'
#
#
# Sentence:
# 	ThoughIcannotdenythatitisunbelievablycheesy,filledwithpracticallyeveryclicheonecanimagineandcontainstonsofembarrassingdialogue(especiallyKurtRussell'sbeggingspeech)andunconvincinglovescenes(Mel,willyoupleasekissherlike
# Opinion of 'dialogue':
# 	 'embarrassing'
#
#
# Sentence:
# 	Thedialogueisveryfunnyandwittyattimes.
# Opinion of 'dialogue':
# 	 'very-funny', 'witty'
#
#
# Sentence:
# 	Rarelyhassomuchbeensaidsosuccessfullywithsolittledialogue.
# Opinion of 'dialogue':
# 	 'so-little'
#
#
# Sentence:
# 	AlthoughI'msureyouwillwanttoseewhathappenedtoallofyourfavoritecharacters,yourhopeswillcertainlybedashedanddisappointedbyapoorstoryandpoordialogue
# Opinion of 'dialogue':
# 	 'poor'
#
#
# Sentence:
# 	Thedialogueisoftenunconvincingandoneoccassionallytiresoftheconstantneedinmoviemakingtouseeachcharachterasanarchetype.
# Opinion of 'dialogue':
# 	 'unconvincing', 'occassionally-tires'
#
#
# Sentence:
# 	ThesheeraudacityofthistaskisahallmarkofChayefsky'svitriolicstyle,andthefilmisfullofhisbrittle,observantdialogueandsharplyarticulatesoliloquies.
# Opinion of 'dialogue':
# 	 'observant'
#
#
# Sentence:
# 	Here,inthismovie,you'vegotagoodcast,cooldialogue,andanon-stopactionthrillride.
# Opinion of 'dialogue':
# 	 'cool'
#
#
# Sentence:
# 	AnyonefamiliarwithTheSimpsonswillenjoythehumorinOlive,TheOtherReindeer,aswellastheanimationandwittydialoguethatpassesquicklyinthisforty-fiveminutemovie.
# Opinion of 'dialogue':
# 	 'witty'
#
#
# Sentence:
# 	Allinvolverichdialogueandinterestshown.
# Opinion of 'dialogue':
# 	 'rich'
#
#
# Sentence:
# 	First,thedialogueandsituationsaresoinsipidtheyofteninspireunintentionalhilarity.
# Opinion of 'dialogue':
# 	 'so-insipid'
#
#
# Sentence:
# 	Withoutcontrivedmanipulations,youaredrawnintothedepthsandheightsoftheiremotionsthroughtheuseofstunningvisuals,dramaticportrayals,pithydialogue,momentsofquietcontemplation,andaserenemusicalsoundtrackthatisworthowningonitsownmerits.
# Opinion of 'dialogue':
# 	 'pithy'
#
#
# Sentence:
# 	Itoffersawinningcombinationofdramaandcomedy,acertainrealismthatisonlyacquiredthroughgooddialogueandsilence.
# Opinion of 'dialogue':
# 	 'good'
#
#
# Sentence:
# 	Ithashistrademarkrealisticdialogueandwithoutanyflashyeffectshefocusesonthecharacters.
# Opinion of 'dialogue':
# 	 'realistic'
#
#
# Sentence:
# 	Thedialogueiswarmandwittyandtheactorsarewonderful.
# Opinion of 'dialogue':
# 	 'are', 'warm', 'witty'
#
#
# Sentence:
# 	Allen'sdialogue(whichisalwaysgood)isparticularlygoodintheconversationsbetweenIsaacandMary;ThefinalscenebetweenIsaacandTracyisalsoverymeaningfulandverygood.
# Opinion of 'dialogue':
# 	 'particularly-good'
#
#
# Sentence:
# 	LiketheothermoviesthereissomegreatdialogueinthismovieandIhighlyrecommendthemovietofansofChrisFarley,ChrisRockandSNL.
# Opinion of 'dialogue':
# 	 'great'
#
#
# Sentence:
# 	Yes,themoviehasflaws:thedialoguecanbealittlegoofyattimes,theactingsomewhat-shallwesay-idiosyncratic,thespecialeffectsdon'talwayswork,andtheinternallogicisnotalwaysapparent(theGrailisArthur?
# Opinion of 'dialogue':
# 	 'goofy'
#
#
# Sentence:
# 	Withcringinglyawfulacting,laughablespecialeffects(theridiculousheadinabucketisarealguffawmoment),appallingdubbeddialogue,cheesymusic,inconsistentandconfusingplotandnotensionoratmosphere,TheGrimReaperisatotaldisaster.
# Opinion of 'dialogue':
# 	 'dubbed'
#
#
# Sentence:
# 	Theearlypartofthisfilmisfilledbothwithsnappy,intelligentdialoguebutalsowithasophomoricphysicalcomedywhichcanhonestlybeconsideredtobeatorbelowapie-in-the-facelevelofsophistication.
# Opinion of 'dialogue':
# 	 'snappy', 'intelligent'
#
#
# Sentence:
# 	Betweenincrediblybaddialogueaboutthingslikethe"plutonium-rubycrystalbeamgun,"sillyincidentalmusic,andaVenusianmadeoflatex,twigs,andtissuepaper,thisonecannotbebeat.
# Opinion of 'dialogue':
# 	 'incredibly-bad'
#
#
# Sentence:
# 	Baumbach'sscreenplayboastslotsofmemorabledialogue,lotsofclevernessyoumightfindyourself"borrowing."
# Opinion of 'dialogue':
# 	 'memorable'
#
#
# Sentence:
# 	Thedialogueisquick-witted,somethesceneshavebecomeclassics(Allensneezingonthecocaine).
# Opinion of 'dialogue':
# 	 'witted'
#
#
# Sentence:
# 	Thegreatsweetbeautyofthisfilm,however,isthemarriageofsuchengagingdialogue,suchearnestdeadpandeliveriesshotinsucheerieclarity--onereminiscentoftheinteriorsinDutchgenrepainting:clean,homely,homiletic.
# Opinion of 'dialogue':
# 	 'such', 'engaging'
#
#
# Sentence:
# 	Itmanagestoturnasuiteofclassicallystaticimages-bronzed,burnished,melancholy-uponafast-drivingdialogueendowedwiththemodestbutenhancingartificialityofapainting,anovelor--betteryet--aninfinitelyrefinedfilm
# Opinion of 'dialogue':
# 	 'bronzed', 'fast-driving'
#
#
# Sentence:
# 	Manywillbemovedbyhownaturalthedialoguesounds(herecordedmostofitonthestreets),alotofitobviouslyinspiredbyhisownlife.
# Opinion of 'dialogue':
# 	 'how-natural'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'as-fast'
#
#
# Sentence:
# 	Indeed,thedialogueissobeautifullyeloquent,wefeellikeweareoftengiventhemodernequivalentofShakespeare.
# Opinion of 'dialogue':
# 	 'beautifully-eloquent'
#
#
# Sentence:
# 	Selectionof
# locations,environmentsandcharactersissimplywonderful--sureto
# keeptheviewerengrossed,eventhoughthedialogueisuncompromisingly
# British.
# Opinion of 'dialogue':
# 	 'British'
#
#
# Sentence:
# 	Recentadaptationsseemafraidtoincludeoriginaldialogueatanylength-
# Opinion of 'dialogue':
# 	 'original'
#
#
# Sentence:
# 	Verywittydialogueandscenes;flawlessactingbyleadandsupportingactors.
# Opinion of 'dialogue':
# 	 'Very-witty'
#
#
# Sentence:
# 	ThisisChaplin'sfirstfulldialoguefilm,eventhough'TheGreatDictator'washisfirstsoundfilm.
# Opinion of 'dialogue':
# 	 'full'
#
#
# Sentence:
# 	Mywifesaysallofhismoviesarethesame,anditbreaksmyhearteverytimeshesaysit...becauseinthatblanketanalysis,theanalystmissestheincrediblestoriesandcraftydialoguethattakesplaceinthemanyWoodyAllenmoviesthatprettymuchtakeplacewithinthesametemplate.
# Opinion of 'dialogue':
# 	 'crafty'
#
#
# Sentence:
# 	Theirdialogueisasfastastheirwits:"Iwishyouhadn'tdonethat,Hildy."
# Opinion of 'dialogue':
# 	 'as-fast'
#
#
# Sentence:
# 	Thisisamust-haveifyoulikeagoodstoryline,cleverdialogueandhonestlaughs.
# Opinion of 'dialogue':
# 	 'clever'
#
#
# Sentence:
# 	GreatforthepurestinthecrowdbutkillerforthoseofuswholikebadlydubbedEnglishdialogue.
# Opinion of 'dialogue':
# 	 'badly-dubbed', 'English'
#
#
# Sentence:
# 	Theweaknesseswereimmediatelyapparent--awkwarddialogue,lackofvisualstyle--butIhopedthemoviewouldovercomeitsfaults.
# Opinion of 'dialogue':
# 	 'awkward'
#
#
# Sentence:
# 	Thismayhelpsomeofyouslowerpeople(don'tbeashamed)tounderstandthefilm,althoughmuchofitsimportantintricatedialogueandoverallappealwillbelostinthisversion.
# Opinion of 'dialogue':
# 	 'important', 'intricate'
#
#
# Sentence:
# 	Thereareproblemswiththefilm,themostannoyingonebeingthatthedialogueispracticallyinaudibleduetothemikingand,moreso,duetothemusicalscorewhichcoversallthelinestothepointofmakingthemovieseemlikeasilentmoviewithmusicfromthepit!
# Opinion of 'dialogue':
# 	 'practically-inaudible'
#
#
# Sentence:
# 	Themood,thesensuousdialogue;Thisisjustnoiratit'sbest.
# Opinion of 'dialogue':
# 	 'sensuous'
#
#
# Sentence:
# 	Thistart,well-scriptedcomedyisalittlelightonthedancing,butfeaturessomeofthebest,briskestdialoguethatcameAstaire'sway,andafinesupportingcast,includingthefamousHollywood&quot;double-talker,&quot;CliffNazarro,goingthroughhisroutineinnumerousscenes.
# Opinion of 'dialogue':
# 	 'best'

# %%
sents = [nlp(entry[1]) for entry in core]
# print(sents)

for index,sen in enumerate(sents):
    opinions = opinion_extractor("plot",sen)
    print(opinions)
    if set(opinions) == core[index][2]:
        print('Test set {} passed\n'.format(index+1))
# Out:
# ['exciting', 'fresh']
# Test set 1 passed
#
# ['dull']
# Test set 2 passed
#
# ['excessively-dull']
# Test set 3 passed
#
# ['excessively-dull']
# Test set 4 passed
#
# ['not-dull']
# Test set 5 passed
#
# ['not-exciting', 'not-fresh']
# Test set 6 passed
#
# ['not-excessively-dull']
# Test set 7 passed
#
# ['cheesy', 'fun', 'inspiring']
# Test set 8 passed
#
# ['really-cheesy', 'not-particularly-special']
# Test set 9 passed

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on all of the required examples.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %% [markdown]
# ## Additional extensions

# %% [markdown]
# This section presents some examples on which your current opinion extractor will fail. In all of the examples below, "plot" is the aspect token.
#
# You are not required to extend your opinion extractor to handle these cases.
#
# **Optional Example A**: "The script and plot are utterly excellent." produces "utterly-excellent"
# **Optional Example B**: "The script and plot were unoriginal and boring." produces "unoriginal", "boring"
# **Optional Example C**: "The plot wasn't lacking." produces "not-lacking"
# **Optional Example D**: "The plot is full of holes." produces "full-of-holes"
# **Optional Example E**: "There was no logical plot to this story." produces "no-logical"
# **Optional Example F**: "I loved the plot." produces "loved"
# **Optional Example G**: "I didn't mind the plot." produces "not-mind"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension example 2](./img/additional_example_1.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_2.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_3.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_4.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_5.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_6.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_7.png)

# %% [markdown]
# ## Tips for de-bugging and exploration
# When you will be assessing whether your opinion extractor has been effective when analysing a given sentence. Before you look at what the dependency parser says, read the sentence carefully and determine for yourself the scope of the words. Consider the following sentence.
#
# "This film has excellent characters and an intriguing and engaging plot."
#
# It should be obvious to you that here the plot is described as both "intriguing" and "engaging". However, "excellent" is only used to describe the cinematography.
#
# If the parser suggests a structure which implies that plot is also described by "excellent" (for example), something has gone wrong.### Dependency tree visualisation tool
# You may find it useful to use the dependency tree visualisation tool found [here](https://demos.explosion.ai/displacy).
#
# You can copy and past example sentences from the DVD review data to get a good sense of what the dependency parse looks like.
#
# ### Outputing results only from sentences relevant to the current task
# You will find that your output is dominated by examples of adjectival modification and adjectives linked via the copula. This means that when you add a new function (extensions 3-5) it will be difficult to determine the impact of that new functionality.
#
# One way to solve this problem, is to (temporarily) output only those features produced by the new functionality.
#
# For example, imagine you have just completed extensions 1 and 2. Next, you write code that adds the adverbial features (extension 3). When assessing how well your code is working, let your extractor only extract the "new" adverb features.
#
# There are 2 easy ways to achieve this:
#
# 1. Comment out any extractor code that produces features that you're not currently interested in. Or
# 2. Introduce a boolean variable, which you only set to `True` when you have extracted the feature that you are interested in. Then always ouput an empty list if the variable is `False`, otherwise output the full opinion list.
